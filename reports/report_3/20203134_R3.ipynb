# %% [markdown]
# # REPORTE:

# %% [markdown]
# Parte 1 (reporte):
# El siguiente escrito se basará en el texto propuesto de Mendoza, Mancilla y Velarde: Macroeconomía de la cuarentena: un modelo de dos sectores. Dentro del marco de la pandemia del covid – 19, la argumentación de los autores gira en torno a la siguiente pregunta: ¿Cuáles fueron los efectos macroeconómicos de la cuarentena en una economía con dos sectores? Estos últimos se distinguen por su grado de afectación respecto a la misma. Por un lado, el primero consta de los afectados de manera directa por la cuarentena y abarca al sector hotelero, restaurantes y líneas aéreas. Por otro lado, el segundo está conformado por los afectados de manera indirecta: producción de alimentos y bienes y servicios indispensables. Finalmente, ambos convergen en ser keynesianos. Es decir, la producción está determinada por la demanda; y los niveles de precios dependen del nivel esperado de precios y de la brecha del PBI en cada sector.
#
# Sobre las fortalezas del artículo, se encuentra, en primer lugar, los rasgos discursales de su redacción: sucinto y sencillo. Esto permite que un lector sin mucha formación en el tema comprenda la tesis y la argumentación sin dificultad. En segundo lugar, la simulación de una cuarentena en el modelo propuesto. Este señala que tanto las caídas del PBI potencial, como del consumo autónomo son transitorias. Esto quiere decir que los valores pre – pandemia se reestablecerán al cabo de 4 periodos. En términos generales, el documento no tiene grandes falencias. Sin embargo, si se hubiera detallado acerca de las múltiples ecuaciones planteadas con mayor detenimiento, se hubiera encarecido su valor y su comprensión para un público no experto.
#
# La contribución central del archivo es que nos permite estimar los efectos de la cuarentena, tanto a corto como largo plazo, en el consumo autónomo. Esto aborda el impacto de la misma en dos sectores que están vinculados por el consumo que hacen los trabajadores de ambos.  De ese modo, muestra escenarios que van desde la recesión hasta la recuperación de los niveles pre – pandemia tras una serie de cuatro períodos difíciles. Esto es llamado “recuperación vigorosa” y permitió el restablecimiento de PBI potencial a través de la política crediticia concebida dentro del marco del programa “Reactiva Perú”.

# %% [markdown]
# # CÓDIGO:

# %% [markdown]
# Parte 1

# %% [markdown]
# 1.Explique cuáles son los intrumentos de política monetaria que puede utilizar el Banco Central

# %% [markdown]
# Los instrumentos de la política monetaria son cuatro:
# 1. Operación de Mercado Abierto: En este instrumento, el BCR realiza operaciones de índole compra y venta de activos financieros o bonos a los bancos comerciales y privados. De este modo, es mediante la política monetaria expansiva, en la cual el BCR compra bonos y logra inyectar dinero en la economía. Paralelamente, a través de la política monetaria contractiva se da con la venta de bonos al mercado nacional (bancos comerciales) retira dinero de la economía para la reducción de una inflación.
#
#
# 2. El coeficiente legal de encaje como instrumento de política. En el caso de una política monetaria expansiva el BCR puede aumentar el coeficiente de encaje que poseen los bancos para generar préstamos mediante la reducción de la tasa de interés. A partir de lo cual, se espera que los bancos comerciales tengan menos dinero en reservas dentro del BCR. En el caso de la política monetaria contractiva, el BCR aumenta el coeficiente de encaje, es así como los bancos comerciales tienen una mayor proporción de depósitos en reservas y ello reduce el multiplicador bancario y origina una disminución en la oferta monetaria.
#
#
# 3. La tasa de interés como instrumento de política. Con la consideración de la tasa de interés como política, la oferta monetaria pasó a ser una variable endógena. Es así que se comprende que la tasa política es la misma que la tasa de interés de referencia de la política monetaria. En el caso de la política monetaria expansiva, el BCR reduce la tasa de interés de referencia, con lo cual aumenta el dinero en modalidad de préstamo hacia los bancos comerciales y ello incrementa la base monetaria y consecuentemente forma la oferta monetaria. Mientras que en el caso de la política monetaria contractiva el BCR aumenta la tasa de interés de referencia, con lo cual reduce el dinero prestado a los bancos comerciales y ello reduce la base monetaria y la oferta monetaria.
#
#
# 4. Función de Oferta Real de Dinero. La oferta nominal de dinero (𝑀𝑠) al ser una variable exógena e instrumento de política monetaria. Seguidamente en términos reales o a precios constantes, la oferta nominal se divide entre en nivel general de precios de la economía, (𝑃).

# %% [markdown]
# 5. Grafique el equilibrio en el mercado de dinero

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
import pandas as pd
import numpy as np
import random
import math
import sklearn
import scipy as sp
import networkx
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

# %%
# Parameters
r_size = 100

k = 0.5
j = 0.2                
P  = 10 
Y = 35
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_0 = MD(k, j, P, r, Y)
# Necesitamos crear la oferta de dinero.
MS = MS_0 / P
MS
# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="Money Market Equilibrium", xlabel=r'M^s / P', ylabel=r'b')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = 'green')

# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=7.5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 7.5, "$r_0$", fontsize = 12, color = 'black')

ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# Parte 2

# %% [markdown]
# 1. Explique y grafique qué sucede en el mercado de dinero si ∆Y<0

# %%
# Parameters con cambio en el nivel del producto
r_size = 100

k = 0.5
j = 0.2                
P  = 10 
Y_1 = 50
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_1 = MD(k, j, P, r, Y_1)
# Necesitamos crear la oferta de dinero.
MS = MS_0 / P
MS

# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="∆Y<0", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = 'blue')
#ax1.plot(MD_1, label= '$L_0$', color = '#CD5C5C')


# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=7.5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 7.5, "$r_1$", fontsize = 12, color = 'black')
ax1.text(50, 0, "$(Ms/P)_0$", fontsize = 12, color = 'black')
ax1.text(50, 7.5, "$E_1$", fontsize = 12, color = 'black')

# Nuevas curvas a partir del cambio en el nivel del producto
ax1.plot(MD_1, label= '$L_1$', color = 'green')
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")
ax1.axhline(y=15, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")
ax1.text(0, 15, "$r_0$", fontsize = 12, color = 'black')
ax1.text(50, 15, "$E_0$", fontsize = 12, color = 'black')

plt.text(58, 10, '∆Y', fontsize=12, color='black')
plt.text(61, 10, '↓', fontsize=15, color='black')


ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# Explicación: Como se observa en el gráfico, la curva de demanda de dinero se desplaza hacia bajo. Esto sucede debido a que al disminuir el ingreso, la demanda de dinero se ve afectada, por lo que disminuye también. De esta merna se genera exceso de oferta de dinero en el merrcado, por lo que es necesario disminuir la tasa de interés para restablecer el equilibrio.

# %% [markdown]
# 2. Explique y grafique qué sucede en el mercado de dinero si ∆k<0

# %%
# Parameters
r_size = 100

k = 0.6
j = 0.2                
P  = 10 
Y = 35
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_0 = MD(k, j, P, r, Y)
# Necesitamos crear la oferta de dinero.
MS = MS_0 / P
MS

# Parameters con cambio en k
r_size = 100

k = 0.3
j = 0.2                
P  = 10 
Y = 35
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_1 = MD(k, j, P, r, Y_1)
# Necesitamos crear la oferta de dinero.
MS = MS_0 / P
MS

# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="∆k<0", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = 'blue')


# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 5, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 5, "$r_1$", fontsize = 12, color = 'black')
ax1.text(50, 0, "$(Ms/P)_0$", fontsize = 12, color = 'black')
ax1.text(50, 5, "$E_1$", fontsize = 12, color = 'black')

# Nuevas curvas a partir del cambio en el nivel del producto
ax1.plot(MD_1, label= '$L_1$', color = 'green')
ax1.axvline(x = MS,  ymin= 5, ymax= 5, color = "grey")
ax1.axhline(y=11, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")
ax1.text(0, 11.5, "$r_0$", fontsize = 12, color = 'black')
ax1.text(50, 11, "$E_0$", fontsize = 12, color = 'black')

plt.text(42, 9.3, '∆k', fontsize=12, color='black')
plt.text(45, 9, '↓', fontsize=15, color='grey')

ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())


ax1.legend()

plt.show()

# %% [markdown]
# Explicación: Cuando se produce una disminución en la sensibilidad de la demanda real de dinero a consecuencias de una variación en el ingreso, inevitablemente para mantener un equilibrio en el mercado, la demanda de dinero tendrá que disminuir. Al intentar cumplir esta condición de equilibrio, esta disminución de la elasticidad del ingreso genera un exceso de oferta en el mercado. Es así como que, al demandar menos dinero, también provocará que disminuya el nivel de consumo por la carencia de efectivo circulatorio y la sobreoferta de este. Por tanto, el equilibrio debe restablecerse mediante una disminución en la tasa de interés. Este efecto, se reflejará en un desplazamiento de la curva de demanda de dinero hacia abajo o el interior.

# %% [markdown]
# 3. Explique y grafique qué sucede en el mercado de dinero si ∆Ms<0

# %%
# Parameters con cambio en el nivel del producto
r_size = 100

k = 0.5
j = 0.2                
P_1  = 20 
Y = 35
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_1 = MD(k, j, P_1, r, Y)
# Necesitamos crear la oferta de dinero.
MS_1 = MS_0 / P_1
MS

# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="∆Ms<0", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = 'green')
#ax1.plot(MD_1, label= '$L_0$', color = '#CD5C5C')


# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=11, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 11.5, "$r_0$", fontsize = 12, color = 'black')
ax1.text(50.5, 2, "$(Ms/P)_0$", fontsize = 12, color = 'black')
ax1.text(50, 11, "$E_0$", fontsize = 12, color = 'black')


# Nuevas curvas a partir del cambio en el nivel del producto
#ax1.plot(MD_1, label= '$L_1$', color = '#4287f5')
ax1.axvline(x = MS_1,  ymin= 0, ymax= 1, color = "grey")
ax1.axhline(y=16, xmin= 0, xmax= 0.27, linestyle = ":", color = "black")
ax1.text(0, 17, "$r_1$", fontsize = 12, color = 'black')
ax1.text(25, 2, "$(Ms/P)_1$", fontsize = 12, color = 'black')
ax1.text(25, 16.5, "$E_1$", fontsize = 12, color = 'black')

plt.text(32, 19.5, '∆Ms', fontsize=12, color='black')
plt.text(32.4, 18.8, '←', fontsize=15, color='grey')

ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# Explicación: La disminución de la cantidad de dinero circulante dentro de una economía, provoca una disminución de la oferta real de dinero. Por ende, la oferta real de dinero se encuentra en menor cantidad que la demanda real de dinero. Precisamente por ello, se percibe la existencia de un exceso de demanda, lo cual debe de disminuirse con el fin de volver al equilibrio de mercado. Esta disminución se logrará mediante un aumento de la tasa de interés, con ello se producirá un aumento de la oferta. Por lo tanto, al disminuir la cantidad de dinero habrá un movimiento en la curva del mercado monetario, ya que, se disminuye de 𝑀0𝑠 a 𝑀1𝑠, así provocándose que la recta de la oferta real de dinero se desplaza hacia la izquierda o el interior.
