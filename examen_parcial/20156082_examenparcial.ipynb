# %% [markdown]
# # RESOLUCIÓN DE EXAMEN PARCIAL

# %% [markdown]
# ## TEORÍA

# %% [markdown]
# ### 1. Defina el Multiplicador Keynesiano y dé un ejemplo de cómo influye este en el modelo Ingreso-Gasto Keynesiano.

# %% [markdown]
# Multiplicador Keynesiano :
# Un cambio en la magnitud de cualquiera de los componentes autˊonomos de la demanda agregada (que conforman el intercepto), genera un proceso multiplicador del ingreso hasta converger al nuevo ingreso y producto de equilibrio. Asˊı, el aumento multiplicado del ingreso es resultado de los efectos directos e indirectos ocasionados por el aumento de cualquiera de los componentes autˊonomos de la demanda agregada.

# %% [markdown]
# De la ecuación de la demanda agregada: $DA = α_0 + α_1Y $, y de la condición de equilibrio $Y = DA$, se obtiene $ (1 - α_1)Y = α_0 $. Por lo tanto, el multiplicador es: $$ \frac{1}{1 - α_1} = \frac{1}{1 - (b-m)(1-t)} $$

# %% [markdown]
# En este caso donde la producción depende de la demanda, el multiplicador keynesino es una función directa de la propensión a consumir, y una función inversa a la tasa impositiva. Por ejemplo la reducción de la tasa impositiva hace que se incremente la demanda (DA) y por lo tanto la producción (Y).

# %% [markdown]
# ### 2. Grafique y explique cúando sucede un exceso y déficit de demanda en el modelo Ingreso-Gasto. Señale las áreas donde ocurre cada caso. Explique cómo se converge al equilibrio a partir de estos dos escenarios.

# %% [markdown]
# La ecuación de equilibrio para el Ingreso Agregado se deriva de la condición de equilibrio donde el ingreso es igual a la demanda agregada: $DA = Y$:
#
# $$ DA = C + I + G + X - M $$
#
# Donde:
#
# $$ C = C_0 + bY^d $$
# $$ I = I_0 - hr $$
# $$ G = G_0 $$
# $$ X = X_0 $$
# $$ M = mY^d $$
#
# $$ Y^d = 1 - t $$

# %% [markdown]
# Entonces:
#
# $$ DA = C_0 + I_0 + G_0 + X_0 - hr + Y(b - m)(1 - t) $$
#
# De forma corta:
#
# $$ DA = α_0 + α_1Y $$
#
# Donde $ α_0 = (C_0 + I_0 + G_0 + X_0 -hr)$ es el intercepto y $ α_1 = (b - m)(1 - t) $ es la pendiente de la función

# %% [markdown]
# Ahora, considerando la condición de equilibrio $Y = DA$, la ecuación del ingreso de equilibrio a corto plazo es:
#
# $$ Y = C_0 + bY^d + I_0 -hr + G_0 + X_0 - mY^d $$
#
# $$ Y = \frac{1}{1 - (b - m)(1 - t)} (C_0 + I_0 + G_0 + X_0 - hr) $$

# %% [markdown]
# #### a) Exceso de demanda

# %% [markdown]
# Esto ocurre por el aumento de un componente autónomo, podría ser el consumo $(C_0)$, inversión $(I_0)$, gasto $(G_0)$ u otros.
# En este caso $DA>Y$, lo cual obliga a aumentart la producción para igualarla a la demanda agregada. Además, con el aumento de la producción aumenta el empleo, disminuye el desempleo, aumenta el ingreso de las familias, entre otros. Finalmente, a través de este mecanismo se vuelve a la cnvergencia de equilibrio.

# %% [markdown]
# ![exceso%20de%20demanda.jpeg](attachment:exceso%20de%20demanda.jpeg)

# %% [markdown]
# #### b) Déficit de demanda

# %% [markdown]
# Esto ocurre cuando la $DA<Y$; de este modo, la producción va a disminuir para igualar la demanda agregada. De la misma forma, los empresarios van a decidir disminuir su producción y disminuirá el empleo, aumentará la tasa de desempleo y el ingreso de las familias se reducirá. Finalmente, a través de dicho mecanismo de reducción de laa producción, se convergerá al equilibrio.

# %% [markdown]
# ![deficit%20de%20demanda.jpeg](attachment:deficit%20de%20demanda.jpeg)

# %% [markdown]
# ### 3. ¿Cuáles son las herramientas de política fiscal y política monetaria? De un ejemplo para cada una de ellas dentro del contexto peruano. Coloque su fuente en caso sea necesario. (Solo necesita 1 para pol. Fiscal y 1 para Monetaria).

# %% [markdown]
# Herramientas de política fiscal
# - Gasto publico
# - Tasa impositiva
# - Inversión
# - Consumo
#
# Herramientas de politica monetaria
# - Tasas de interés de referencia
# - Mercado monetario (compra y venta de dólares) para controlar la inflación

# %% [markdown]
# Ejemplos para el caso peruano en el contexto del Covid:
#
# 1) El gasto publico como politica fiscal: el gobierno inyectó liquidez para apoyar a las familias y no romper la cadena de pagos
#
# 2) la tasa interés de referencia: se redujo por la politica expansiva para así también inyectar liquidez y se incentive el consumo y no el ahorro

# %% [markdown]
# ### 4. Explique qué funciones del dinero respaldan el éxito de de Yape y Plin(Aplicativos moviles para intercambio de dinero).

# %% [markdown]
# El éxito de yape y plin se puede explicar por la funcionalidad similar de estos aplicativos con el dinero. Por ejemplo, en un primer lugar, la característica más importante es que sirve como un medio de pago que facilita las transacciones monetarias sin tener el dinero de manera física. En segundo lugar, también cumple con el rol de medio de intercambio, ya que ha ganado mucha aceptabilidad entre la gente y sobre todo la confianza al uso de estos alicativos, pese a no poder ver el dinero de forma física. Finalmente, podemos mencionar que su éxito se debe a la facilidad y seguridad de poder llevar dinero en tu equipo móvil, puesto que la mayoría de personas cuenta con un smartphone, por lo que se puede usar desde cualquier lugar.

# %% [markdown]
# ### 5. Cuáles son las conclusiones principales del paper de Dancurt "Inflation Targeting in Peru: The Reasons for the Success"

# %% [markdown]
# Dancourt (2015), en su artículo destaca el desempeño del banco central peruano (Banco Central de Reserva del Perú), pues tomó dos decisiones muy importantes para la economía peruana. Estas dos decisiones fueron la implementación de un sistema de metas de inflación y la acumulación de grandes reservas de divisas. Estas dos decisiones fueron de gran relevancia para la economía peruana, puesto que se demostró que han contribuido en mantener la estabilidad en términos macroeconómicos en contextos favorables o desfavorables en periodos más cortos.

# %% [markdown]
# ## EJERCICIOS

# %% [markdown]
# ### Ejercicio 1 (6 puntos). El modelo ingreso-gasto en una economía abierta

# %% [markdown]
# #### 1. Encuentre el Ingreso de Equilibrio  e identifique el multiplicador keynesiano.

# %% [markdown]
# ![ejercicio1.jpeg](attachment:ejercicio1.jpeg)

# %% [markdown]
# #### 2. Analice los efectos sobre la variable endógena  de una disminución del gasto fiscal . El análisis debe ser intuitivo, matemático y gráfico.

# %% [markdown]
# Intuición:
# $$ Go↓ → G↓ → DA → DA < Y → Y↓ $$
#
# Matemática:
# $$ Go < 0 $$
#
# Entonces:
#
# $$ ∆Y = \frac{∆ - G}{1-(1 - t)(b_o - m_1)} < 0 $$
#
#
# $$ \frac{dY}{dG} < 0 $$

# %% [markdown]
# ![ejercicio%202.jpeg](attachment:ejercicio%202.jpeg)

# %% [markdown]
# #### 3. Analice los efectos sobre la variable endógena  de un incremento del PBI mundial . El análisis debe ser intuitivo, matemático y gráfico.

# %% [markdown]
# Intuición:
# $$ Y^*↑ → X↑ → DA↑  → DA > Y → Y↑  $$
#
# Matemática:
# $$ ∆Y^* > 0 $$
#
# Entonces:
#
# $$ ∆Y = \frac{(X_1)(∆Y^*)}{1-(1 - t)(b_o - m_1)} > 0 $$
#
#
# $$ \frac{dY}{dY^*} < 0 $$

# %% [markdown]
# ![ejer3.jpeg](attachment:ejer3.jpeg)
