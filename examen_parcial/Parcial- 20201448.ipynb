# %% [markdown]
# Nombre: Joaquin del Castillo Ugarte
#
# Codigo: 20201448

# %%
# %matplotlib inline
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd
from causalgraphicalmodels import CausalGraphicalModel

# %% [markdown]
# (1 puntos) Defina el Multiplicador Keynesiano y dé un ejemplo de cómo influye este en el modelo Ingreso-Gasto Keynesiano.
#
# (2 puntos) Grafique y explique cúando sucede un exceso y déficit de demanda en el modelo Ingreso-Gasto. Señale las áreas donde ocurre cada caso. Explique cómo se converge al equilibrio a partir de estos dos escenarios.
#
# (2 puntos) ¿Cuáles son las herramientas de política fiscal y política monetaria? Dea un ejemplo para cada una de ellas dentro del contexto peruano. Coloque su fuente. (Solo necesita 1 para pol. Fiscal y 1 para Monetaria).
# Explique qué funciones del dinero respaldan el exito de de Yape y Plin (Aplicativos moviles para transferencia de dinero).

# %% [markdown]
# ## Teoría:

# %% [markdown]
# ### 1:

# %% [markdown]
# És el multiplicador que nos dice que cuando existe un incremento en la inversión total, el ingreso aumentará en una cantidad que es k veces el incremento de la inversión”. Este siempre tendrá un valor mayor a cero. También se puede decir que este multiplicador demuestra el desarrollo de la multiplicación del ingreso hasta alcanzar a ser un diferente ingreso-producto de equilibrio en función de un cambio en cualquier variable que sea autonoma (B0) de la DA.

# %% [markdown]
# Un ejemplo es en una política contraciclica. En esta si g aumenta ello significa que el multiplicador keynesiano disminuye, pues el denominador aumenta.  Entonces, al disminuir este multiplicador afecta negativamente a la curva de la demanda agregada, pues finalmente esta cae.

# %% [markdown]
# ### 2:

# %% [markdown]
# 2-  En la curva IS los puntos que se encuentran encima de la recta son de equilibrio (I=S). Entonces, en este caso A vendría a representar el equilibrio entre ingreso y ahorro. Entonces, en el caso de B se ve un deficit de demanda o exceso de oferta, pues se ve que a pesar que la tasa de interés no varió el ingreso sí lo hizo y aumentó, lo cual provocó que el ingreso sea mayor a la inversión, por tanto se ve como es que hay un deficit en la demanda. En cambio en el punto C se ve que también la tasa de interés no se movió y que ahora el ingreso disminuyó, por lo que en este punto la inversión es mayor que el ingreso, por tanto en este caso hay un exceso de demanda. En el primer caso para nivelar y volver a equilibrio el ingreso (Y) tiene que disminuir para que con ello el ingreso sea igual a la inversión. Mientras que en el punto C el ingreso (Y) tiene que subir para que deje de existir el exceso de oferta.

# %%
z_size = 100          
z = np.arange(z_size) 
z 


#Parameters
Y_size = 100 
b = 0.2                 # propensión marginal a consumir
m = 0.2                 # propensión a importar
t = 1                   # tasa impositiva
Co = 20                 # consumo autónomo
Io = 10                 # inversión autónoma
Go = 8                  # gasto gobierno 
Xo = 2                  # exportación 
h =  5                  # constante de decisión a invertir

Y = np.arange(Y_size)


def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS


def Y_IS(b, m, t, Co, Io, Go, Xo, h, r):
    Y_IS = (Co + Io + Go + Xo - h*r)/(1-(b-m)*(1-t))
    return Y_IS


r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
r
# Out:
# array([  8. ,   7.8,   7.6,   7.4,   7.2,   7. ,   6.8,   6.6,   6.4,
#          6.2,   6. ,   5.8,   5.6,   5.4,   5.2,   5. ,   4.8,   4.6,
#          4.4,   4.2,   4. ,   3.8,   3.6,   3.4,   3.2,   3. ,   2.8,
#          2.6,   2.4,   2.2,   2. ,   1.8,   1.6,   1.4,   1.2,   1. ,
#          0.8,   0.6,   0.4,   0.2,   0. ,  -0.2,  -0.4,  -0.6,  -0.8,
#         -1. ,  -1.2,  -1.4,  -1.6,  -1.8,  -2. ,  -2.2,  -2.4,  -2.6,
#         -2.8,  -3. ,  -3.2,  -3.4,  -3.6,  -3.8,  -4. ,  -4.2,  -4.4,
#         -4.6,  -4.8,  -5. ,  -5.2,  -5.4,  -5.6,  -5.8,  -6. ,  -6.2,
#         -6.4,  -6.6,  -6.8,  -7. ,  -7.2,  -7.4,  -7.6,  -7.8,  -8. ,
#         -8.2,  -8.4,  -8.6,  -8.8,  -9. ,  -9.2,  -9.4,  -9.6,  -9.8,
#        -10. , -10.2, -10.4, -10.6, -10.8, -11. , -11.2, -11.4, -11.6,
#        -11.8])

# %%
#Graficando: 

y_max = np.max(r)
x_max = Y_IS(b, m, t, Co, Io, Go, Xo, h, 0)


v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="IS SCHEDULE", xlabel=r'Y', ylabel=r'r')
ax.plot(Y, r, "k-")

plt.axvline(x = 8, ymin= 0, ymax = 0.60, linestyle = ":", color = "grey")
plt.axvline(x = 16,  ymin= 0, ymax = 0.60, linestyle = ":", color = "grey")
plt.axvline(x = 24, ymin= 0, ymax = 0.60, linestyle = ":", color = "grey")
plt.axhline(y = 4.8, xmin= 0, xmax= 0.60, linestyle = ":", color = "grey")


plt.text(-2, 4.7, '$r_A$', fontsize = 12, color = 'black')
plt.text(7.2, -0.3, '$Y_C$', fontsize = 15, color = 'black')
plt.text(15.5, -0.3, '$Y_A$', fontsize = 15, color = 'black')  
plt.text(23.3, -0.3, '$Y_B$', fontsize = 15, color = 'black') 
plt.text(7.2, 4.9, '$C$', fontsize = 15, color = 'black')
plt.text(15.5, 4.9, '$A$', fontsize = 15, color = 'black')  
plt.text(23.7, 4.9, '$B$', fontsize = 15, color = 'black') 
plt.text(25, 5.5, 'Deficit  en la  demanda', fontsize = 15, color = 'black')  
plt.text(7, 2.5, 'Exceso de demanda', fontsize = 15, color = 'black') 

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())
    
plt.axis(v)                                    
plt.show()

# %% [markdown]
# ### 3

# %% [markdown]
# La política monetaria sirve para dar estabilidad monetaria, desde el 2002 se conduce bajo un sistema de metas Según el BCR los instrumentos de la política monetaria son los instrumentos de mercado, instrumentos de ventanilla
# y medidas de encaje. Un ejemplo es el generado por el BCR al inicio de la pandemia, en donde redujo la tasa mínima legal en soles de 5% a 4%, con la intención de mantener las cadenas de pagos y creditos y de esa forma incentivar una mayor intermediación extranjera.
#
# Fuente: https://gestion.pe/economia/bcr-redujo-encajes-en-soles-y-dolares-para-mantener-cadena-de-pagos-y-creditos-noticia/
#
#
# Por otro lado, en la política fiscal se encuentra el gasto público y la tributación. Un ejemplo es el de la Pandemia, en el corto plazo, se anunciaron medidas de alivio en el ambito tributario que tenían el objetivo de dar liquidez, con el objetivo de promover el dinamismo en el mercado y también en el consumo nacional. En particular estas modificaciones se centraron en la postergación de pagos de impuesto en la renta de los hogares, y esta medida fue de la mano con facilidades de pago como la posibilidad de pagar en cuotas sin que ello genere un mayor pago por sanciones o intereses.
#
#
# Fuente: https://ideasparaelfuturo.caf.com/media/3011/peru-ganador-10567_peru-_la-implementacio-n-de-una-poli-tica-fiscal-eficiente.pdf

# %% [markdown]
# ### 4:

# %% [markdown]
# En primer lugar su optimización de la función de transacción, pues gracias a este es más sencillo para las personas poder comprar y vender productos, pues permite que las personas no tengan que llevar dinero físico, lo cual muchas veces hace engorroso el proceso de compra-venta pues a veces no hay cambio exacto u otras cuestiones.

# %% [markdown]
# En segundo lugar, también se sustenta en la función de precaución, pues facilita el pago de deudas de la gente, pues mayormente estas suelen grandes cantidades, por lo que con el pago instantaneo que ofrecen Yape y Plin permite tener más seguridad a la hora de pagar y además mayor velocidad.

# %% [markdown]
# ### 5:

# %% [markdown]
# La primera gran conclusión es que en épocas de crisis, en función a la experiencia vivida en el periodo de tiempo estudiado, se debe reducir la tasa de interés y se debe vender la moneda extranjera (dólares). Mientras que en épocas de apogeo económico se debe aumentar la tasa de interés y comprar moneda extranjera (dólares). En base a ello se podría predecir cómo el BCRP debería actuar en crisis económicas futuras como la ocasionada por el COVID-19. Por otra parte el BCR debe evitar a toda costa el endeudamiento externo de los bancos comerciales. Si ello no sucede , no se podrá lograr desdolarizar el crédito bancario.

# %% [markdown]
# ## Código:

# %% [markdown]
# ## 1

# %% [markdown]
# Mediante la resolución de operaciones nos sale lo siguiente:
#
# $$ DA=C0+b(1−t)Y+I0−hr+G0+x1Y∗+x2ε−m1(1−t)Y+m2ε $$
#
# $$ DA=C0+I0+G0+[b(1−t)−m1(1−t)]Y−hr+x1Y∗+(x2+m2)ε $$
#
# $$ DA=w−hr+x1Y∗+(x2+m2)ε0−(x2+m2)ρr+(x2+m2)ρr∗+[(b−m1)(1−t)]Y $$

# %% [markdown]
#  $$ w=C0+I0+G0 $$
#
#
#  $$ DA=[𝑤+x1Y∗+(x2+m2)ε0+(x2+m2)ρr∗−(h+(x2+m2)ρ)r]+[(b−m1)(1−t)]Y $$

# %% [markdown]
# La pendiente es el multiplicador keynesiano asi que este es el siguiente:
#
#  $$ α1=[(b−m1)(1−t)] $$

# %% [markdown]
# ### 1.1. Estática comparativa:

# %% [markdown]
# Intuitivo:
#
# $$ Go↓ → G↓ → DA↓ → DA < Y → Y↓ $$

# %% [markdown]
# Matematico:

# %% [markdown]
#  $$ YΔ < 0 $$

# %% [markdown]
# ### 1.2. Estática comparativa:

# %% [markdown]
# Intuitivo:
#
# $$ Y↑  → G↓ → DA↓ → DA < Y → Y↓ $$
#
#
# Matematico:
#
# El diferencial de R es positivo. $$ rΔ < 0 $$

# %% [markdown]
# ## 2

# %% [markdown]
# Derivar:
#
#  Ecuación de la IS:
#
# Partiendo de:
#
# $$ Y = C + I + G + X - M $$
#
# donde
#
# $$ C = C_0 + b(1-t)Y $$
#
# $$ I = I_0 - hr $$
#
# $$ G = G_0 $$
#
# $$ X = X_0 $$
#
# $$ M = mY $$
#
# Reemplazando:
#
# $$ Y = C_0 + b(1-t)Y + I_0 - hr + G_0 + X_0 - mY $$
#
# La ecuación de la IS es en función de $Y$ es:
#
# $$ Y = \frac{1}{1 - (b - m)(1 - t)} (C_o + I_o + G_o + X_o - hr) $$
#
# o,
#
# $$ Y = \frac{1}{B_1} (B_0) $$
#
# Donde $ B_0 = C_o + I_o + G_o + X_o - hr $ y $ B_1 = 1 - (b - m)(1 - t) $

# %% [markdown]
# - Ecuación de la LM:
#
# $$ \frac{M_o^s}{P_0} = kY - jr $$
#
# Ahora $M^s$ es la variable endogena, por eso escribimos la LM En función de $(M^s)$:
#
# $$ M^s = P_0(kY - jr) $$

# %% [markdown]
# - Ingreso de equilibrio: es igual a la ecuación de la IS
#
# $$ Y^e = \frac{1}{1 - (b - m)(1 - t)} (C_o + I_o + G_o + X_o - hr) $$
#
# - Masa monetaria: reemplazamos $Y$ en $M_s$:
#
# $$ M^e_s = P_0(kY - jr) $$
#
# $$ M^e_s = (\frac{B_0}{B_1})P_0k - P_0jr $$
#
#
# $$ M^e_s = P_0k(\frac{1}{1 - (b - m)(1 - t)} (C_o + I_o + G_o + X_o - hr)) - P_0jr $$

# %% [markdown]
# ##Ahora en base a ello encontramos que en la curva OA y DA los gráficos las ecuaciones son las siguientes:
#
# 1. $$ Y^{eq\_da\_oa} = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$
#
# 3. $$ P^{eq\_da\_oa} = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) $$

# %% [markdown]
# Equilibrio:

# %% [markdown]
# Intuitivo:
#
# $$ r↑ → I↓ → DA↓ → DA < Y → Y↓ $$
#
# $$ r↑ → M^d<M^s → M^s↓ $$
#
# $$ Y↓ → P↓ $$

# %% [markdown]
# si la tasa de interes sube la inversión baja y con ello cae la demanda agregada, para lo cual la producción se tiene que ajustar y caer. Mientras que ello genera que la oferta de dinero sea mayor a la demanda de dinero para lo cual tendra que caer la oferta de dinero. Mientras que en el caso de la producción si esta cae caen los precios.

# %% [markdown]
# Matemático:

# %% [markdown]
# $$ roΔ > 0 $$
#
# $$ YΔ < 0 $$
#
# $$ PΔ < 0 $$

# %% [markdown]
# Gráfico:

# %% [markdown]
# ![WhatsApp%20Image%202022-10-14%20at%205.20.32%20PM.jpeg](attachment:WhatsApp%20Image%202022-10-14%20at%205.20.32%20PM.jpeg)
