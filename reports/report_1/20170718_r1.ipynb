# %% [markdown]
# PARTE I: REPORTE DE LA LECTURA
#
# El objetivo del artículo “The lean times in the Peruvian economy” es describir el impacto de las recesiones en la historia macroeconómica del Perú. Por ello, se hace una diferenciación entre las épocas de bonanzas. La actividad económica, el empleo y  la inversión aumentan en este contexto; además, los precios de exportación tienden a ser altos. Mientras que en las recesiones, estas se contraen y los precios de exportación tienden a ser bajos. Asimismo, el artículo describe el choque externo adverso sufrido por la economía peruana y su impacto recesivo e inflacionario durante el período 2014-15; y analiza la combinación de políticas monetarias y fiscales durante este mismo período. Esto resulta importante ya que evidencia los retos macroeconómicos a los cuales se enfrenta el nuevo gobierno de Pedro Pablo Kuczynski, al asumir el poder.
#
# En este sentido, el artículo busca responder qué medidas debe implementar el BCRP para evitar el estancamiento de la economía urbana del Perú. Primero, una de las fortalezas que presenta el siguiente artículo es que hace una comparación entre los períodos de auge o recesión trimestrales de cada año durante la última década, aproximadamente entre los períodos 2002-16. Se hace un análisis entre la relación de la desaceleración del crecimiento del PBI no primario desde 2012 y la reducción significativa de la expansión del empleo urbano. Además, evidencia cómo el enfriamiento de la economía urbana se asocia con la caída en el valor de las exportaciones; o como es que la caída del precio internacional de los metales es la principal causa de la caída de la economía urbana;  como es que en los períodos de recesión el precio del dólar aumenta, por lo que los deudores en dólares reducen sus gastos; estimulando la producción de bienes y servicios peruanos que compiten con la producción extranjera; entre otras relaciones.
#
# Por el contrario ,el punto negativo es que a pesar de que las autoridades monetarias y fiscales deberían reducir la tasa de interés local y aumentar el gasto público para contrarrestar el choque negativo de demanda; además, de que el BCRP debe vender dólares para frenar la subida del tipo de cambio. La realidad es que en seis de las siete últimas recesiones, el Perú aumentó la tasa de interés y recortó el gasto público intensificando así el impulso recesivo externo. Por otra parte, en el caso de un sistema bancario dolarizado como el peruano , este puede volverse peligrosamente inestable si el banco central no tiene dólares y se produce un shock externo negativo ; un ejemplo de ello es la crisis bancaria y recesión entre 1998-2000, al final de la dictadura de Fujimori. Además, uno de los objetivos es resolver el problema de la meta de inflación establecida, ya que ésta debería ser más alta si se quiere cumplir con cierta estabilidad no solo en tiempos de auge con la disminución del tipo de cambio; sino también en tiempos de escasez, caracterizado por el aumento del tipo de cambio.
#
# La contribución del artículo es analizar el contexto en el que se encontraba el gobierno de Kuczynski para poder hacerle frente al estancamiento de la economía urbana del Perú. Por ello, concluye que el gobierno debe realizar tres tareas principales para contrarrestar este problema. Primero, el gobierno debe dinamizar la economía urbana del Perú y generar empleos en tiempos de escasez, que persistan durante todo el mandato; lo que requeriría impulsos monetarios y fiscales positivos para impulsar la economía urbana. Asi mismo es imprescindible considerar que la política fiscal tiene un efecto recesivo si el sector privado no gasta todo el dinero ahorrado con la reducción de impuestos. Segundo, la otra tarea será diversificar la economía peruana mediante las industrias de la minería y los componentes distintos de gasto de la inversión en los sectores extractivos; además de un sustento de inversión pública para desarrollar nuevas exportaciones no tradicionales; y favorecer el crecimiento económico. Tercero, el nuevo gobierno debe mitigar el incipiente conflicto entre un tipo de cambio real alto y una inflación baja que podría intensificarse. Esto se podría lograr a través de la regulación de los precios locales excesivos de medicamentos, combustible y electricidad.
#
# Según el Informe macroeconómico de América Latina y el Caribe 2015: “El Laberinto: Cómo América Latina y el Caribe puede navegar la economía global”, escrito por Andrew Powell. Este establece que para asegurar un crecimiento fuerte y sostenible, la región de América Latina debe sortear varios obstáculos como los precios bajos de las materias primas y nuevos tipos de riesgos financieros. En este sentido, el próximo paso para responder a esta pregunta es sí los países latinoamericanos deben proceder hacia la realización de un ajuste fiscal. En este caso, la respuesta depende de la situación y contexto de cada país;  es crucial tener en cuenta el nivel actual de la deuda y la rapidez con que está creciendo el ratio de deuda. Por un lado, en los países con bajos ratios de deuda o PBI y no requieran un ajuste fiscal; para mantener esos ratios constantes disponen de un espacio fiscal para adoptar una política contracíclica. Por otro lado, en los países con niveles de deuda altos y que requieran ajustes considerables para mantener constantes los niveles de deuda; sería contraproducente adoptar las medidas de una política contracíclica.

# %%
#Antes de pasar a la parte de códigos en Python, procederemos a instalar las librerías correspondientes

import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd
from causalgraphicalmodels import CausalGraphicalModel

# %% [markdown]
# PARTE II: CÓDIGO EN PYTHON
#
# Ejercicio1: Derive y explique la función de demanda de Consumo
#
# Para poder calcular la función Consumo (C), debemos tomar en cuenta que la Tributación total (T); es decir todo lo que se recauda en el país, es igual a la tasa impositiva (t) por el Ingreso Agregado (Y) de la economía:
#
#
# $$ T = tY $$
#
#
# En este contexto, suponiendo que todas las transferencias (TR) son iguales a cero, el ingreso neto de la tributación es el Ingreso disponible (𝑌ᵈ):
#
#
# $$ Y^d = Y - T $$
#
# $$ Y^d = (1 - t) Y $$
#
#
# Una parte de este Ingreso disponible (𝑌ᵈ) se utiliza para los gastos de consumo, por lo que resulta la siguiente fórmula:
#
#
# $$ C = C_0 + bY^d $$
#
#
# De esta manera, podemos comprender que la función de consumo depende no solo de una parte de este Ingreso Disponible (𝑌ᵈ), sino también del Consumo autónomo (Co) y la propensión marginal a consumir (b) que representa el cambio en el consumo por unidad de cambio en el ingreso disponible; la cual es mayor que cero y menor que uno, 0 < b < 1.

# %%
Yd_size = 100 

Co = 10
b = 0.5 

Yd = np.arange(Yd_size)

# %%
def C(Co, b, Yd):
    C= Co + b*Yd
    return C
C= C(Co, b, Yd)

# %%
# Gráfico

# Dimensiones del gráfico
y_max = np.max(C)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Yd, C, label = "C", color = "#3D59AB")

# Líneas punteadas punto de equilibrio
plt.axvline(x=40,  ymin= 0, ymax= 0.60, linestyle = ":", color = "grey")
plt.axhline(y=40, xmin= 0, xmax= 0.41, linestyle = ":", color = "grey")

plt.axvline(x=30,  ymin= 0, ymax= 0.60, linestyle = ":", color = "grey")
plt.axhline(y=30, xmin= 0, xmax= 0.41, linestyle = ":", color = "grey")

plt.axvline(x=20,  ymin= 0, ymax= 0.60, linestyle = ":", color = "grey")
plt.axhline(y=20, xmin= 0, xmax= 0.41, linestyle = ":", color = "grey")

plt.axvline(x=10,  ymin= 0, ymax= 0.60, linestyle = ":", color = "grey")
plt.axhline(y=10, xmin= 0, xmax= 0.41, linestyle = ":", color = "grey")

# Título y leyenda
ax.set(title="Función de demanda de Consumo", xlabel= r'Yd', ylabel= r'C')
ax.legend()

# %% [markdown]
# Ejercicio2: Derive y explique la función de Inversión.
#
# Para poder calcular la función gasto de Inversión (I), debemos tomar en cuenta que esta depende inversamente de la tasa de interés real (r); y donde el comonente autónomo (Io), que vendría a ser la inversión fija, depende de las expectativas de los inversionistas:
#
#
# $$ I = I_0 - hr$$
#
#
# En esta ecuación, el "h" vendría a ser la sensibilidad de los inversionistas ante la subida o reducción de la tasa de interés real "r". Además, ambas se encuentran en un rango mayor a cero y menor que 1; 0 < h <1 y 0 < r <1.

# %%
# Parámetros

r_size = 100 


Io = 40
h = 0.5
r = 0.8

r = np.arange(r_size)

# %%
def I(Io, h, r):
    I= Io - h*r
    return I
I= I(Io, h, r)

# %%
# Gráfico

# Dimensiones del gráfico
y_max = np.max(I)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(r, I, label = "I", color = "#3D59AB")

# Título y leyenda
ax.set(title="Función de demanda de Inversión", xlabel= r'r', ylabel= r'I')
ax.legend() 

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Texto agregado
plt.text(80, 7, '$I=I_o-hr$', fontsize = 15, color = 'black')
# Out:
# Text(80, 7, '$I=I_o-hr$')

# %% [markdown]
# Ejercicio3: ¿Cuáles son los supuestos del modelo Ingreso-Gasto Keynesiano?
#
#
# -Los precios son fijos, es decir, no varían.
#
# -Existe desempleo de los factores de producción (exceso de capacidad): si aumenta la demanda agregada aumentará la producción.
#
# -La economía es cerrada; no existe ni exportaciones ni importaciones.
#
# -No hay sector público; no existe gasto público ni los impuestos.
#
# -No hay depreciación y las empresas distribuyen todos sus beneficios.
#
# -La inversión planeada es autónoma, esto es, no depende del nivel de producción.

# %% [markdown]
# Ejercicio4:
#
# A partir de las siguientes ecuaciones:
#
#
# $$ C = C_0 + bY^d $$
#
# $$ I = I_0 - hr $$
#
# $$ G = G_0 $$
#
# $$ T = tY $$
#
# $$ X = X_0 $$
#
# $$ M = mY^d $$
#
# $$ DA = C + I + G + X - M $$
#
#
# Encuentre el nivel de Ingreso de equilibrio $Y^e$
#
# La ecuación de equilibrio para el Ingreso Agregado se deriva de la condición de equilibrio donde el ingreso es igual a la demanda agregada: $DA = Y$:
#
#
# $$ DA = C + I + G + X - M $$
#
#
# Con los datos previos, reemplazos los datos anteriores en la función de la Demanda Agregada (DA):
#
#
# $$ Y = C_0 + bY^d + I_0 -hr + G_0 + X_0 - mY^d $$
#
# $$ DA = C_0 + I_0 + G_0 + X_0 - hr + Y(b - m)(1 - t) $$
#
#
# En donde el Intercepto (α0) y la pendiente (α1) son iguales a:
#
#
# $ α_0 = (C_0 + I_0 + G_0 + X_0 -hr)$
#
# $ α_1 = (b - m)(1 - t) $
#
#
# De forma corta:
#
# $$ DA = α_0 + α_1Y $$
#
#
# Considerando la condición de equilibrio $Y = DA$, la ecuación del ingreso de equilibrio a corto plazo es:
#
#
# $$ Y = C_0 + bY^d + I_0 -hr + G_0 + X_0 - mY^d $$
#
# $$ Y = \frac{1}{1 - (b - m)(1 - t)} (C_0 + I_0 + G_0 + X_0 - hr) $$
#
# En este sentido el multiplicador Keynesiano (K) es igual a:
#
# $$ K = \frac{1}{1 - (b - m)(1 - t)}$$
#
# Otra forma de verlo:
#
#
# $$ Y = K (C_0 + I_0 + G_0 + X_0 - hr) $$

# %%
# Parámetros

Y_size = 100 

Co = 30
Io = 45
Go = 65
Xo = 2
h = 0.6
b = 0.7 
m = 0.3
t = 0.4
r = 0.8

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# Recta de 45°

a = 2.5 

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)

# %%
# Gráfico

# Dimensiones del gráfico
y_max = np.max(DA_IS_K)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, DA_IS_K, label = "DA", color = "#3D59AB") #Demanda agregada
ax.plot(Y, L_45, color = "#404040") #Línea de 45º

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Líneas punteadas punto de equilibrio
plt.axvline(x=62.5,  ymin= 0, ymax= 0.62, linestyle = ":", color = "grey")
plt.axhline(y=157, xmin= 0, xmax= 0.62, linestyle = ":", color = "grey")

# Texto agregado
    # punto de equilibrio
plt.text(0, 180, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(72, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(0, 152, '$α_o$', fontsize = 15, color = 'black')
    # línea 45º
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')

# Título y leyenda
ax.set(title="El ingreso de Equilibrio a Corto Plazo", xlabel= r'Y', ylabel= r'DA')
ax.legend() #mostrar leyenda

plt.show()

# %% [markdown]
# Ejercicio5:
#
# Analice una Política Fiscal Expansiva con aumento del Gasto del Gobierno. El análisis debe ser intuitivo, matemático y gráfico.
#
# #### - Política Fiscal contractiva con aumento del Gasto del Gobierno $(G_0)$:
#
# - Intuición:
#
# $$ ↑Go → ↑DA → DA > Y → ↑Y $$
#
# - Matemáticamente: $∆G_0 > 0  →  ¿∆Y?$
#
# $$ Y = \frac{1}{1 - (b - m)(1 - t)} (C_0 + I_0 + G_0 + X_0 - hr) $$
#
# o, considerando el multiplicador keynesiano, $ k > 0 $:
#
# $$ Y = k (C_0 + I_0 + G_0 + X_0 - hr) $$
#
#
# $$ ∆Y = k (∆C_0 + ∆I_0 + ∆G_0 + ∆X_0 - ∆hr) $$
#
# Pero, si no ha habido cambios en $C_0$, $I_0$, $X_0$, $h$ ni $r$, entonces:
#
# $$∆C_0 = ∆I_0 = ∆X_0 = ∆h = ∆r = 0$$
#
# $$ ∆Y = k (∆G_0) $$
#
# Sabiendo que $∆G_0 > 0 $ y que $k > 0$, la multiplicación de un número negativo con un positivo dará otro negativo:
#
# $$ ∆Y = (+)(+) $$
# $$ ∆Y > 0 $$

# %%
# Curva de ingreso de equilibrio ORIGINAL

    # Parámetros
Y_size = 100 

Co = 30
Io = 45
Go = 65
Xo = 2
h = 0.6
b = 0.7
m = 0.3
t = 0.4
r = 0.8

Y = np.arange(Y_size)

    # Ecuación 
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# NUEVA curva de ingreso de equilibrio

    # Definir SOLO el parámetro cambiado
Go = 95

# Generar la ecuación con el nuevo parámetro
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# Gráfico
y_max = np.max(DA_IS_K)
fig, ax = plt.subplots(figsize=(10, 8))


# Curvas a graficar
ax.plot(Y, DA_IS_K, label = "DA", color = "#3D59AB") #curva ORIGINAL
ax.plot(Y, DA_G, label = "DA_G", color = "#EE7600", linestyle = 'dashed') #NUEVA curva
ax.plot(Y, L_45, color = "#404040") #línea de 45º

# Lineas punteadas
plt.axvline(x = 76, ymin= 0, ymax = 0.74, linestyle = ":", color = "grey")
plt.axhline(y = 190, xmin= 0, xmax = 0.75, linestyle = ":", color = "grey")
plt.axvline(x = 62.5,  ymin= 0, ymax = 0.62, linestyle = ":", color = "grey")
plt.axhline(y = 156.5, xmin= 0, xmax = 0.62, linestyle = ":", color = "grey")

# Texto agregado
plt.text(0, 180, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(0, 125, '$DA_G$', fontsize = 11.5, color = '#EE7600')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(72, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(56, 0, '$Y_G$', fontsize = 12, color = '#EE7600')
plt.text(70, 45, '$←$', fontsize = 18, color = 'grey')
plt.text(20, 155, '$↑$', fontsize = 18, color = 'grey')

# Título y leyenda
ax.set(title = "Aumento del Gasto del Gobierno $(G_0)$", xlabel = r'Y', ylabel = r'DA')
ax.legend()

plt.show()

# %% [markdown]
# Analice una Política fiscal expansiva con una reducción de la Tasa de Tributación. El análisis debe ser intuitivo, matemático y gráfico.
#
# #### - Política fiscal expansiva con una reducción de la Tasa de Tributación $(t)$:
#
# - Intuición: ¿contradicción?
#
# $$ t↓ → Co↑ → DA↑ → DA > Y → Y↑ $$
# $$ t↓ → M↑ → DA↓ → DA < Y → Y↓ $$
#
# - Matemáticamente: $∆t < 0  →  ¿∆Y?$
#
# Considernado el diferencial de $∆t$:
#
# $$ \frac{∆Y}{∆t} = \frac{(m-b)(Co + Go + Io + Xo - hr)}{(1-(1-t)(b-m)+1)^2} $$
#
# - Sabiendo que b > m, entonces $(m-b) < 0$
# - Los componentes autónomos no cambian: $∆C_0 = ∆I_0 = ∆X_0 = ∆h = ∆r = 0$
# - Cualquier número elevado al cuadrado será positivo: $ (1-(1-t)(b-m)+1)^2 > 0 $
#
# Entonces:
#
# $$ \frac{∆Y}{∆t} = \frac{(-)}{(+)} $$
#
# Dado que $∆t < 0$, la división de dos positivos da otro positivo:
#
# $$ \frac{∆Y}{(-)} = \frac{(-)}{(+)} $$
#
# $$ ∆Y = \frac{(-)(-)}{(+)} $$
#
# $$ ∆Y > 0 $$

# %%
# Curva de ingreso de equilibrio ORIGINAL

    # Parámetros
Y_size = 100 

Co = 30
Io = 45
Go = 65
Xo = 2
h = 0.6
b = 0.7
m = 0.3
t = 0.4
r = 0.8

Y = np.arange(Y_size)

    # Ecuación 
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# NUEVA curva de ingreso de equilibrio

    # Definir SOLO el parámetro cambiado
t = 0.05

# Generar la ecuación con el nuevo parámetro
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_t = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# Gráfico
y_max = np.max(DA_IS_K)
fig, ax = plt.subplots(figsize=(10, 8))


# Curvas a graficar
ax.plot(Y, DA_IS_K, label = "DA", color = "#3D59AB") #curva ORIGINAL
ax.plot(Y, DA_t, label = "DA_t", color = "#EE7600", linestyle = 'dashed') #NUEVA curva
ax.plot(Y, L_45, color = "#404040") #línea de 45º

# Lineas punteadas
plt.axvline(x = 66.5, ymin= 0, ymax = 0.66, linestyle = ":", color = "grey")
plt.axhline(y = 167, xmin= 0, xmax = 0.65, linestyle = ":", color = "grey")
plt.axvline(x = 62.5,  ymin= 0, ymax = 0.62, linestyle = ":", color = "grey")
plt.axhline(y = 156.5, xmin= 0, xmax = 0.62, linestyle = ":", color = "grey")

# Texto agregado
plt.text(0, 158, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(0, 168, '$DA_t$', fontsize = 11.5, color = '#EE7600')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(63, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(70, 0, '$Y_t$', fontsize = 12, color = '#EE7600')
plt.text(63, 45, '$→$', fontsize = 18, color = 'grey')
plt.text(20, 158, '$↑$', fontsize = 18, color = 'grey')

# Título y leyenda
ax.set(title = "Reducción de la Tasa de Tributación", xlabel = r'Y', ylabel = r'DA')
ax.legend()

plt.show()
