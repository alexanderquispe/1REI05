# %% [markdown]
# # Parte 1: TEORIA

# %% [markdown]
# # 1.1
# El multiplicador keynesiano es el cambio en la magnitud de cualquiera de los componentes autónomos de la demanda agregada que conforman el intercepto. Asimismo, el aumento multiplicado del ingreso es resultado de los efectos directos e indirectos ocasionados por el aumento de cualquiera de los componentes autónomos de la demanda agregada.
#
# El modelo Ingreso-Gasto Keynesiano o cruz keynesiana influye en este modelo porque supone que el nivel de precios es fijo, que el nivel de producto se adapta a los cambios en la dedmanda agregada y que la tasa de interés está determinada fuera del modelo en el mercado monetario. Este es un modelo a corto plazo.

# %% [markdown]
# # 1.2
#
# Si la Demanda Agregada aumenta, se produce un exceso de la misma, y esto provoca que la producción anterior sea insuficiente provocando la caída de los inventarios o la existencia de las empresas; esto quiere decir, que aumenta el empleo, disminuye la tasa de desempleo y aumenta el ingreso disponible de las familias. Asimismo, para que pueda volver al equilibrio estable, los productores deben aumentar la producción para satisfacer la demanda.
#
# Si existe un déficit de demanda o exceso de producción, se produce un déficit de la misma, y esto provoca que la producción anterior sea demasiado alta, en este caso, aumentan los inventarios y las empresas deciden disminuir su producción y el empleo de trabajadores. Asimismo, para que pueda volver al equilibrio estable, los productores deben disminuir la producción.
#
# En el siguiente gráfico nos ayudará a determinar las áreas en donde ocurre cada caso.  Se muestra el proceso de convergencia hacia el punto de equilibrio “E”, partiendo de un punto “A” (exceso de demanda) o del punto “B” (exceso de producción o déficit de demanda). En el punto “A”, la demanda agregada es mayor que el nivel de producción. Hay exceso de demanda que provoca una disminución de los inventarios y aumentos de la producción hasta llegar al equilibrio. De otro lado, en el punto “B” hay un déficit de demanda o un exceso de producción que da lugar a un aumento de los inventarios y a disminuciones de la producción hasta llegar al equilibrio.

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
import pandas as pd
from causalgraphicalmodels import CausalGraphicalModel
from sympy import *

# %%
# Parámetros

Y_size = 100 

Co = 36
Io = 41
Go = 71
Xo = 3
h = 0.6
b = 0.7 # b > m
m = 0.1
t = 0.2
r = 0.8

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# Recta de 45°

a = 2.5

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)


# Gráfico

# Dimensiones del gráfico
y_max = np.max(DA_IS_K)
fig, ax = plt.subplots(figsize=(15, 13))

# Curvas a graficar
ax.plot(Y, DA_IS_K, label = "DA", color = "#3D59AB") #Demanda agregada
ax.plot(Y, L_45, color = "#404040") #Línea de 45º

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Líneas punteadas punto de equilibrio
plt.axvline(x=74.5,  ymin= 0, ymax= 0.73, linestyle = ":", color = "green")
plt.axhline(y=186, xmin= 0, xmax= 0.8, linestyle = ":", color = "green")


# Texto agregado
    # punto de equilibrio
plt.text(0, 180, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(72, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(0, 152, '$α_o$', fontsize = 15, color = 'black')
plt.text(100, 200, '$DA = C+I+G+X-M $', fontsize = 15, color = 'black')
plt.text(90, 215, '$DA<Y$ , en donde aumenta los inventarios y disminuye la producción', fontsize = 15, color = 'black')
plt.text(92, 205, '$↓$', fontsize = 18, color = 'grey')
plt.text(92, 223, '$↑$', fontsize = 18, color = 'grey')
plt.text(2, 100, '$DA>Y$ , en donde disminuye los inventarios y aumenta la producción', fontsize = 15, color = 'black')
plt.text(4, 70, '$↓$', fontsize = 30, color = 'grey')
plt.text(4, 120, '$↑$', fontsize = 30, color = 'grey')
    
    
    # línea 45º
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'red')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')

# Título y leyenda
ax.set(title="Determinación y estabilidad de equilibrio", xlabel= r'Y', ylabel= r'DA')
plt.show()

# definir la función line_intersection
def line_intersection(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    if div == 0:
       raise Exception('lines do not intersect')

    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    return x, y

    # coordenadas de las curvas (x,y)
A = [DA_IS_K[0], Y[0]] # DA, coordenada inicio
B = [DA_IS_K[-1], Y[-1]] # DA, coordenada fin

C = [L_45[0], Y[0]] # L_45, coordenada inicio
D = [L_45[-1], Y[-1]] # L_45, coordenada fin

    # creación de intersección

intersec = line_intersection((A, B), (C, D))
intersec
# Out:
# (186.28712871287132, 74.51485148514854)

# %% [markdown]
# # 1.3
# La política fiscal se definen como herramientas gubernamentales que modifican los ingresos y gastos, una política fiscal en el gasto público dentro del contexto peruano es la política fiscal expansiva con aumento en el gasto de gobierno, esto se puede reflejar en los gastos en contratación de constructoras chinas que se dio con lo cual se tendrá un aumento en la producción de materias primas y aumento de empleo para la economía.
#
#
# La Oferta Monetaria como instrumento de política: El primer instrumento de política monetaria que utiliza el Banco Central para aumentar o disminuir la oferta monetaria, es la Operación de Mercado Abierto. El Banco Central hace estas operaciones mediante la compra o venta de activos financieros o bonos a los bancos comerciales. Un ejemplo de política monetaria expansiva se dio durante la pandemia ya que el banco central aumentó el cantidad de dinero de los bancos comerciales con cuales puedan realizar prestamos con la dismunicuón de tasas

# %% [markdown]
# # 1.4
#
# Yape es una billetera digital del Banco de Crédito (BCP) y Plin es la billetera digital del Banco Interbank, las cuales permiten enviar y recibir dinero en cualquier momento, teniedo el número móvil del destinatario o también escaneando el código QR.
#
# Las funciones que las respaldan son el motivo de transacción, es decir se demanda dinero en función de medio de intercambio, para realizar transacciones. Tanto Yape como Plin cumple esta función de la economía puesto que ambas aplicaciones tienen como principal objetivo el intercambios de dinero.
#
# También se cuenta el motivo de precaución, es decir tener acceso a la posibilidad de pagar sus deudas, esto se ve reflejado en los aplicativos de Yape y el Plin ya que hoy en día son considerados como métodos de pagos pues los costos de transacción no son tan elevados debido al ecosistema en el cual conviven.
#
# Y por motivos de especulación, estos aplicativos cumplen la función de guardar los ingresos generados es decir mayor poder adquisitivo a futuro. Es por ello que se puede afirmar que Yape y Plin han tenido éxito ya que permite tener mayor liquidez y mayor opciones de transacciones.
#
# Estas dos aplicaciones son el boom tecnológico de pagos, han tenido éxito ya que permite tener mayor liquidez y mayor opciones de transacciones.

# %% [markdown]
# # 1.5
# Conclusiones:
#
# * El desempeño en el aspecto macroeconómico en el Perú fue bueno durante los años 2002 al 2013, ya que los lazos externos estimularon el crecimiento del PBI y la tasa de inflación estaba en déficit, pese a que tuvimos una crisis durante casi un año que terminó en el 2009, el Perú logró recuperarse dando buenos resultados en las exportaciones para el año 2014.
#
# * Los instrumentos de la política monetaria, como el coeficiente de encaje legal en moneda nacional y extranjera, la tasa de interés de corto plazo fijada por el BCR, el proceso de desdolarización del crédito bancario y la intervención esterilizada en el mercado de cambio,  fueron importantes para afrontar la crisis que pasó el Perú durante los años 2002 y 2013.
#
# * El papel de la BCR y las medidas por las que optó como la implementación de un sistema de metas de inflación con una tasa de interés de referencia como principal instrumento de política y la acumulación suficiente de reservas de divisas logró combatir el impacto en la tasa de cambio de shock externos o internacionales logró una estabilidad macroeconómica. Durante el el 2008 al 2009 el BCR redujo la tasa de interés y vender monedas entranjeras como medida de acción ante los factores externos, luego el banco central aumenta la tasa de interés y comprar  las divisas favorables a los factores externos. Luego queda por corroborar si este modelo de política monetaria que fue de gran ayuda para la sociedad peruana puede generar un impacto positivo ante un contexto externo no favorable mas prolongado y asu ves si puede continuar operando sin aplicar una tasa e interés de referencia como principal instrumento
#
#
# * Asimismo, para prevenir las crisis bancarias, el BCR debe limitar el endeudamiento externo de los bancos comerciales, ya que sin ello no será posible desdolarizar el crédito bancario. Para esto se debe imponer requisitos de reserva más altos a la deuda externa de los bancos comerciales.
#
# * La política monetaria que propone Blanchard, la cual va dirigida al equilibrio interno, podría ayudar a estabilizar los niveles de precios y la actividad económica sin liquidar los mercados de largo plazo.

# %% [markdown]
# # Parte 2: PRÁCTICA

# %% [markdown]
# # Ejercicio 1:

# %% [markdown]
# # 1.1
#
# $$DA= C_0+b(1-t)Y +I_0-hr+G_0+X_1Y^*+X_2*ε-m_1(1-t)Y+m_2*ε$$
# $$W=C_0+I_0+G_0$$
# $$DA=W+[b(1-t)-m_1(1-t)]Y-hr+X_1Y^*+(X_2+m_2)ε$$
# $$DA=W-hr+X_1Y^*+(X_2+m_2)ε_0-(X_2+m_2)pr+(X_2+m_2)pr^*+[(b-m_1)(1-t)]Y$$
# $$DA=[W+X_1Y^*+(X_2+m_2)ε_0+(X_2+m_2)pr^*-(h+(X_2+m_2)p)r]+[(b-m_1)(1-t)]Y$$
# $$DA=α_0+α_1Y$$
# $$DA=Y=α_0+α_1Y$$
# $$Y(1-α_1)=α_0$$
# $$Y=\dfrac{1}{1-α_1}*α_0$$
#
#
# * Multiplicador Keynesiano
# $$\dfrac{1}{1-(b-m_1)(1-t)}$$

# %% [markdown]
# # 1.2

# %%
# Valores de Parametros
Y_size = 100 

C_0=10
I_0=5
G_0=20
X_1=0.5
y=30
X_2=0.3
m_2=0.6
ε_0=1.4
ρ=1.5
i=0.2
h=1
r=0.4
b=0.8
m_1=0.5
t=0.3


Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio
#Y^*=y
#r^*=i

def DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t):
    DA= ([C_0+I_0+G_0+X_1*y+(X_2+m_2)*ε_0+(X_2+m_2)*ρ*i-(h+(X_2+m_2)*ρ)*r]+[(b-m_1)*(1-t)]*Y)
    return DA

DA_0= DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t)

# Segunda curva de ingreso de equilibrio

    # Definir cualquier parámetro autónomo
G_0=10
# Generar la ecuación con el nuevo parámetro

def DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t):
    DA= ([C_0+I_0+G_0+X_1*y+(X_2+m_2)*ε_0+(X_2+m_2)*ρ*i-(h+(X_2+m_2)*ρ)*r]+[(b-m_1)*(1-t)]*Y)
    return DA

DA_1= DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t)

# Recta de 45°

def L_45(Y):
    L_45 = Y
    return L_45

L_45 = L_45(Y)

 # Dos gráficos en un solo cuadro (ax1 para el primero y ax2 para el segundo)
fig, ax = plt.subplots(figsize=(10, 8))
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())  

#---------------------------------
    # Gráfico 1: ingreso de Equilibrio
    
ax.plot(Y, DA_1, label = "DA_1", linestyle = ":", color = "blue") 
ax.plot(Y, DA_0, label = "DA_0", color = "blue") 
ax.plot(Y, L_45, color = "black") 

plt.plot(63.62,63.62, marker="o", color="black")
plt.plot(50.96,50.96, marker="o", color="black")


ax.text(4, 2, '$45°$', fontsize = 11.5, color = 'black')
ax.text(1, -3, '$◝$', fontsize = 30, color = 'black')

ax.set(title = "Modelo Ingreso Gasto de una Economia Abierta", xlabel = r'Y', ylabel = r'DA')
plt.show()

# %% [markdown]
# # 1.3

# %%
# Valores de Parametros
Y_size = 100 

C_0=10
I_0=5
G_0=20
X_1=0.5
y=30
X_2=0.3
m_2=0.6
ε_0=1.4
ρ=1.5
i=0.2
h=1
r=0.4
b=0.8
m_1=0.5
t=0.3


Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio
#Y^*=y
#r^*=i

def DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t):
    DA= ([C_0+I_0+G_0+X_1*y+(X_2+m_2)*ε_0+(X_2+m_2)*ρ*i-(h+(X_2+m_2)*ρ)*r]+[(b-m_1)*(1-t)]*Y)
    return DA

DA_0= DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t)

# Segunda curva de ingreso de equilibrio

    # Definir cualquier parámetro autónomo
y=15
# Generar la ecuación con el nuevo parámetro

def DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t):
    DA= ([C_0+I_0+G_0+X_1*y+(X_2+m_2)*ε_0+(X_2+m_2)*ρ*i-(h+(X_2+m_2)*ρ)*r]+[(b-m_1)*(1-t)]*Y)
    return DA

DA_1= DA(C_0, I_0, G_0, X_1, y, X_2, m_2, ε_0, ρ, i, h, r, b, m_1, t)

# Recta de 45°

def L_45(Y):
    L_45 = Y
    return L_45

L_45 = L_45(Y)

  # Dos gráficos en un solo cuadro (ax1 para el primero y ax2 para el segundo)
fig, ax = plt.subplots(figsize=(10, 8))
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())  

#---------------------------------
    # Gráfico 1: ingreso de Equilibrio
    
ax.plot(Y, DA_1, label = "DA_1", linestyle = ":", color = "blue") 
ax.plot(Y, DA_0, label = "DA_0", color = "blue") 
ax.plot(Y, L_45, color = "black") 

plt.plot(63.62,63.62, marker="o", color="black")
plt.plot(54.13,54.13, marker="o", color="black")


ax.text(4, 2, '$45°$', fontsize = 11.5, color = 'black')
ax.text(1, -3, '$◝$', fontsize = 30, color = 'black')

ax.set(title = "Derivación de la curva IS a partir del equilibrio $Y=DA$", xlabel = r'Y', ylabel = r'DA')
plt.show()

# %% [markdown]
# # Ejercicio 2:

# %% [markdown]
# # 2.1
# Demanda Agregada
#
# $ IS: [1-b(1-t)]Y= C_o + I_o + G_o -hr_0$
#
# $ IS: \beta_1Y=\beta_0-hr_0$
#
# $ IS: r_0= \frac{\beta_0}{h}-\frac{\beta_1}{h}Y  $
#
# donde:
#
# $ \beta_0 = C_o + I_o + G_o $ y $ \beta_1 = 1 - (b)(1 - t) $
#
# $ LM: M_0^s-P=kY-jr_0$
#
# Se reemplaza ($r$), y se obtiene la ecuación de la demanda agregada ($DA$) , que ahora es una recta y no una hipérbola
#
# $$ M_0^s-P=kY-j\frac{\beta_0}{h}+j\frac{\beta_1}{h}Y $$
#
# $$ P=M_0^s+j\frac{\beta_0}{h}-j\frac{\beta_1}{h}Y -kY$$
#
# $$P=\frac{hM_0^s+j\beta_0}{h}-\frac{j\beta_1+hk}{h}Y$$
#
#
#
# Oferta Agregada
#
# $P = P^e + θ(Y - \bar{Y})$
#
#
# Recordando que en el modelo $DA-OA$ tenemos tres variables endógenas.
#
# $$ Y^{eq}, r^{eq} ,P^{eq}$$
#
# Considerando la ecuación de la demanda agregada $(DA)$:
#
# $$P=\frac{hM_0^s+j\beta_0}{h}-\frac{j\beta_1+hk}{h}Y ...(1)$$
#
# Y la ecuación de la oferta agregada $(OA)$:
#
# $$P=P^e+\theta(Y-Y ̅ ) ...(2)$$
#
# * Para hallar $ Y^{eq\_da\_oa}$ igualamos ecuaciones 1 y 2
#
# $$\frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}Y = P^e + θ(Y - \bar{Y})$$
#
# $$Y^{eq\_da\_oa} = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$
#
# * Para encontrar $P^{eq\_da\_oa}$ solamente reemplazamos $ Y^{eq\_da\_oa}$ en la ecuación de oferta agregada
#
# $$P^eq_da_oa = P^e + θ( Y^{eq\_da\_oa} - \bar{Y} )$$
#
# $$P^eq_da_oa = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} )$$

# %% [markdown]
# # 2.2

# %%
from IPython.display import Image
Image(filename= 'C:/Users/aless/Downloads/GRÁFICO y MATEMÁTICO.jpeg')
