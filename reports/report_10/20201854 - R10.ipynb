# %% [markdown]
# # Reporte 10

# %% [markdown]
# ### Aisha Martínez - 20201854

# %% [markdown]
# #### PARTE LECTURA:

# %% [markdown]
# ¿cuál es la pregunta de investigación?
#
# Bell, Chetty, Jaravel, Petkovan y Van Reenen buscan responder en su texto ‘Who becomes an inventor in America? The importance of exposure to innovation’ la hipótesis planteada en su paper. Esta consiste en observar cuál de las variables propuestas: naturaleza y crianza tiene un índice de influencia mayor en quiénes se convertirán en los próximos inventores de Estados Unidos. Para ello, retroceden en el tiempo mediante una profunda investigación a los actuales inventores con mayor prestigio en el país para así evaluar cuáles son las características y factores presentes en la niñez de la población “inventora” para que estos puedan o no ser exitosos en el campo a analizar. Algunos de estos factores son los ingresos de los padres, si pertenecen o no a una minoría, el género del infante, la exposición a la investigación, y entre otros. Asimismo, un papel importante es el de la crianza y la naturaleza de esta innovación, por ello observan que enfoques pueden ser aplicados para aumentar las tasas de innovación
#
# ¿fortalezas y debilidades?
#
# En el artículo se observaron múltiples fortalezas a lo largo del desarrollo de este. En primer lugar, me pareció interesante la vinculación que se realizó entre las variables puestas para el estudio junto con la exposición a la innovación. Es claro que las personas que tenían un mayor índice o porcentaje de pobreza (u otras variables) no tendrían el mismo nivel de exposición a la innovación en comparación a lo que un niño con padres que tengan mayores ingresos económicos sí podría tener. Me parece esta una fortaleza debido a que son claros al concretar que la brecha socio-económica es imprescindible en el análisis; asimismo, al tratarse de un estudio que busca analizar las consecuencias de personas inventoras en la economía del país, es relevante darle protagonismo al factor económico. En segundo lugar, se aprecia que la base de datos utilizada es bastante amplia, por lo cual nos puede brindar resultados más precisos y objetivos acerca de la pregunta de investigación, teniendo en cuenta el respectivo análisis estadístico por utilizar. De igual forma, el haber implementado tres metodologías de análisis me parece una fortaleza trascendental (características, exposición a la innovación o ambiente en el que crecieron los niños en relación a si las personas a su alrededor también eran inventores, y por último la zona en la que se encontraba – de pobre a una con un mayor nivel de innovación).  Por otro lado, también se observaron un par de debilidades. En primer lugar, el haber centrado parte del estudio en el desempeño de los niños estudiantes en ciertas materias del colegio me parece un indicador no tan preciso; es decir, si bien son importantes las matemáticas y ciencias, hay factores artísticos u de otras materias que podrían resultar de gran influencia para sostener si el niños se convertirá en un inventor o no, no necesariamente por haber obtenido bajas notas en estos cursos se verá afectada su posibilidad de convertirse en el próximo gran inventor de Estados Unidos. En segundo lugar, algo que me parece negativo de la investigación es que este estudio no podría ser aplicado a otros países, por ejemplo, de América Latina, las realidades son distintas a las de Estados Unidos, incluso podría separarse aquellos países en vía de desarrollo con aquello países desarrollados, y en quienes sí podría ser efectivo este análisis es en el segundo grupo mencionado; por lo tanto, opino que se debería hacer el mismo estudio, pero está vez utilizando factores que podrían convertirse en híbridos si se trata de una comparación entre países desarrollados y no.
#
# ¿aporte del autor a la pregunta de investigación?
#
# Los autores lograron responder a la pregunta de investigación satisfactoriamente, esto fue gracias a muchos factores; sin embargo, los que lograron generar un verdadero aporte a la pregunta de investigación son los que se desarrollarán en las siguientes líneas. Primero, se observa que los autores no solo basaron su análisis en el grupo de personas que se prestaron para el estudio, sino también a aquellas que personas inventoras que han tenido éxito. Esto sirve a manera de background para obtener resultados más precisos mediante la identificación de similitudes y diferencias de las personas que lograron el éxito en el mundo de la innovación, de esta forma podría ayudarse a los que están comenzando en este camino. Segundo, haber agregado el factor “ambiente” me pareció también una forma interesante de llevar a cabo el análisis. Como se desarrolló en el texto, por ejemplo, las niñas que se encontraban en un ambiente con figuras femeninas que también hayan incursionado en la innovación obtendrían mejores resultados en el sentido de que existiría una mayor probabilidad a estudiar una carrera afín. Y, por último, logran concluir que definitivamente los resultados obtenidos podrían afectar la economía del país, punto central por el que se comenzó el análisis tras haber observado una decaída de las personas que elegían la carrera de la innovación como la que ejercerían. Esto se debe a que mientras más personas elijan esta carrera más oportunidades habría para el país de incrementar su crecimiento económico mediante el aprovechamiento de los inventos de la población.
#
# ¿qué pasos pueden seguirse para aportar a la pregunta de investigación?
#
# Por último, se comprende que un siguiente paso para poder avanzar con el análisis de la pregunta de investigación, así como también con el estudio puesto en práctica, podría ser evaluar cómo las políticas sugeridas por los autores tienen mejores resultados que los obtenidos en este caso. De esta forma podría darse una evaluación prolongada a largo plazo y la comparación del primer estudio con el segundo estudio, con el fin de contrastar qué tan eficientes podrían ser las políticas. Y observar de igual forma si es que tiene un mayor efecto positivo en la economía del país.

# %% [markdown]
# #### PARTE CÓDIGO:
# ###### Aisha Martínez y Claudia Cabrel

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns, warnings
import statsmodels.formula.api as smf
warnings.filterwarnings('ignore')

# %%
pip install causalgraphicalmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from causalgraphicalmodels import CausalGraphicalModel

# %%
pip install label
# Out:
# ...
#   Created wheel for label: filename=label-0.1.1-py3-none-any.whl size=2353 sha256=26f30936fd8f25d3b84dcab8d0588ff5f3cbd0e57867b6faaa4391b36e8e8e32
#   Stored in directory: c:\users\aisha\appdata\local\pip\cache\wheels\e2\4b\71\6a3948a81db3727e294db233223d5735ea7a2f0bdce258169e
# Successfully built label
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from cProfile import label

# %%
# %matplotlib inline

# %% [markdown]
# Regresión Discontinua
#
# Explique de manera muy breve y resumida en qué consiste una regresión discontinua.
#
# La regresión discontinua es un diseño cauasi experimental que ayuda a realizar inferencia causal en ausencia de aleatorización. Ayuda a comprarar el resultado justo por encima y por debajo del umbral para identificar el efecto del tratamiento en el umbral. Esto es considerado un diseño de sharp RD o RD nítido, ya que la probabilidad de obtener el tratamiento salta de 0 a 1 en el umbral.
#
# Detalle un ejemplo en la vida real en donde podría emplear una regresión discontinua.
#
# Un ejemplo que puede verse en la vida real es el coeficiente Gini que mide la desigualdad salarial en países a nivel mundial y se necesita un análisis para recolectar dato y ver la situación de cada país.
#
# Explique el diseño Sharp Desing y comente un ejemplo en la vida real en donde podría aplicarlo (sea lo más detallado posible).
#
# El diseño Sharp Design suele emplearse en casos en los que se asigna el tratamiento en casos de que se de un punto de corte discreto donde los elegibles eligen el tratamiento y los que no son elegibles no.

# %% [markdown]
# #### APLICACIONES - EJEMPLO 1

# %%
dat = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
dat.loc[dat.x<0, 'x'] = 0
dat = dat[dat.x<100]
dat['D'] = 0

dat.loc[dat.x>50, 'D'] = 1

dat['y'] = 15 + 22*dat.D + 2.5 * dat.x + np.random.normal(0, 20, dat.shape[0])

dat_0 = dat[dat.D == 0]

dat_1 = dat[dat.D == 1]

# %%
treat_c = "orange" 
n_treat = "pink" 

plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

data_y0 = y_hat_lin(dat_0)
data_y1 = y_hat_lin(dat_1)

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3);

# %%
eff = min(data_y1.yhat) - max(data_y0.yhat)
eff = round(eff,  2)
print("Effect:", f"{eff}")
# Out:
# Effect: 20.09

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff}", xy = (51, eff + 76))
plt.annotate("", xy = (51, max(data_y0.yhat)), xytext = (51, min(data_y1.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));

# %% [markdown]
# ##### APLICACIONES EJEMPLO 2

# %%
dat2 = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
dat2.loc[dat2.x<0, 'x'] = 0
dat2 = dat2[dat2.x<100]
dat2['D'] = 0

dat2.loc[dat2.x>50, 'D'] = 1

dat2['y'] = 12 + 60*dat2.D + 1.3 * dat2.x + np.random.normal(0, 20, dat2.shape[0])

dat2_0 = dat2[dat2.D == 0]

dat2_1 = dat2[dat2.D == 1]

# %%
treat_c = "blue" 
n_treat = "magenta" 

plt.scatter("x", "y", data = dat2_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat2_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

data_y02 = y_hat_lin(dat2_0)
data_y12 = y_hat_lin(dat2_1)

# %%
plt.scatter("x", "y", data = dat2_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat2_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y02, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y12, color = treat_c, lw = 3);

# %%
eff2 = min(data_y12.yhat) - max(data_y02.yhat)
eff2 = round(eff2,  2)
print("Effect:", f"{eff2}")
# Out:
# Effect: 60.14

# %%
plt.scatter("x", "y", data = dat2_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat2_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y02, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y12, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff2}", xy = (51, eff2 + 76))
plt.annotate("", xy = (51, max(data_y02.yhat)), xytext = (51, min(data_y12.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));
