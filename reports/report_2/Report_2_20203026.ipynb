# %%
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

# %% [markdown]
# # REPORT_2

# %% [markdown]
# #### Belén Ximena Herrada Ruiz - 20203026

# %% [markdown]
# #### Lectura: The Case of Peru - Martínelli y Vega

# %% [markdown]
# La investigación realizada por Martinelli y Vega denominada como “The Case of Peru” genera un rastreo sobre las consecuencias y recuperación desde la hipermega inflación de 1987 al 1990 en el primer mandato de Alan García hasta el año 2017 sobre aspectos monetarios y fiscales. Los autores plantean realizar, específicamente, una interpretación de dificultades que contribuyeron a tener un aprendizaje social dentro de “las realidades del equilibrio presupuestario fiscal”.
#
# El acercamiento que se visualiza a lo largo del documento es una clara perspectiva histórica y económica que, a su vez, abarca diferentes aspectos sociales. Abordar la economía desde una perspectiva histórica, es claramente una fortaleza para contribuir a un profundo análisis, lo cual se ve al momento de tener como  punto de partida la independencia del Perú al igual que una exploración sobre periodos presidenciales previos a la crisis inflacionaria. Asimismo, el aspecto social al momento de analizar políticas monetarias y fiscales contribuye a proveer una mejor explicación y respuesta  a la pregunta de investigación. Esto último se visualiza cuando se toma en cuenta factores demográficos y clases sociales claves al efectuar la distribución  de recursos. Por otro lado, la identificación del tipo de ciclos exportadores y su relación con la coyuntura económica internacional ahonda en presentar  una respuesta concisa. Además, otra fortaleza que se ha identificado es el análisis posterior a la recuperación de la economía junto al establecimiento de la constitución en la década de los 90s. En contraste, una de las debilidades encontradas en contraposición en el abarcamiento de varios aspectos es la posibilidad de poca especificación de dichos aspectos.
#
# Por último, los siguientes pasos específicos dentro de este debate es generar una análisis comparativo, tal cómo Farlie y Canales realizaron incluyendo aspectos políticos y no con una centralidad al enfoque monetario y fiscal. Entonces, considero que el documento analizado presenta una perspectiva completa al tener aspectos claves como perspectivas históricas, políticas y sociales.

# %% [markdown]
# ## Ejercicio 1

# %% [markdown]
# ### 1.1 Derivación paso a paso de la curva IS

# %% [markdown]
# Teniendo en cuenta que:
#  $Y = C + I + G + X - M$
#
#  $Y= C_o + b * Y^d + I_o - h * r + G_o + X_o - m * Y^d$
#
#  $Y^d = Y - T = (1-t) Y$
#
#  Entonces Y pasando
#
#  $Y = C_o + b(1-t) * Y + I_o - h*r + G_o + X_o - m(1-t) * Y$
#
#  Se deja sola R, siendo $IS$
#
#  $ \frac{C_o+I_o+G_o+X_o}{h}-{Y(1-(1-t)*(b-m))}{h}=r$

# %% [markdown]
# ### 1.2 Encontrar $Δr/ΔY$

# %% [markdown]
# $Δ𝑟=-ΔY \frac{1-(1-t)(b-m)}{h}$
# Entonces ΔY pasando al otro lado:
# $\frac{Δ𝑟}{ΔY}=-\frac{1-(1-t)(b-m)}{h}$
#
# Esto nos indica, que el signo de la pendiente se quedaría en negativo.

# %% [markdown]
# ### 1.3 Gráfico de Derivación de la Curva IS a partir del equilibrio

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8 
m = 0.2
t = 0.3
r = 16

Y = np.arange(Y_size)


def DA(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA

DA_I = DA(Co, Io, Go, Xo, h, r, b, m, t, Y)

    #Definición de de la recta 45°
a = 2.5 

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)


    # Definición del nuevo parametro 
r= 0.1

def DA(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA= (Co+b*(1-t)*Y+Io-h*r+Go+Xo-m*(1-t)*Y)
    return DA

DA_1= DA(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# Gráfico
y_max = np.max(DA_I)
fig, ax = plt.subplots(figsize=(10, 8))

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

ax.set(title = "Derivación de la curva IS a partir del equilibrio $(Y=DA)$", xlabel = r'Y', ylabel = r'DA')

ax.plot(Y, DA_I, label = "DA", color = "#3D59AB") #Curva sin el aumento del Gasto del Gobierno
ax.plot(Y, DA_1, label = "DA_G", color = "Purple", linestyle = 'dashed') #Curva ante el aumento del G
ax.plot(Y, L_45, color = "#404040") #línea de 45º

plt.text(74, 178.5, '$E_1$', fontsize = 11.5, color = 'purple')
plt.text(62, 151, '$E^0$', fontsize = 11.5, color = 'blue') 

plt.axvline(x = 71, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
plt.axvline(x = 65,  ymin= 0, ymax = 0.64, linestyle = ":", color = "grey")


plt.text(74, 149, '$DA(r_o)$', fontsize = 13, color = 'blue')
plt.text(47, 185, '$DA(r_1):siendo r_1<r_o$', fontsize = 13, color = 'Purple')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')

ax.legend()

plt.show()

# %%
# Parámetros de la curva IS

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8 
m = 0.2
t = 0.3
r=0.2

Y = np.arange(Y_size)

def r(b, m, t, Co, Io, Go, Xo, h, Y):
    r= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return r

R_IS = r(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
#Grafico
y_max = np.max(R_IS)
fig, ax = plt.subplots(figsize=(10, 8))


ax.set(title = "Derivación de la curva IS a partir del equilibrio $(Y=DA)$", xlabel = r'Y', ylabel = r'r')

ax.plot(Y, R_IS, label = "R", color = "#3D59AB") #Curva IS
plt.axvline(x = 71, ymin= 0, ymax = 0.99, linestyle = ":", color = "grey")
plt.axvline(x = 65,  ymin= 0, ymax = 0.99, linestyle = ":", color = "grey")

plt.text(72, 150, '$E_1$', fontsize = 13, color = 'blue')
plt.text(62, 151, '$E_0$', fontsize = 13, color = 'blue')

ax.legend()

plt.show()

# %% [markdown]
# ## Ejercicio 2

# %% [markdown]
# Teniendo en cuenta que: $S=I$
# Siendo conformado por:
# $-(C_o+G_o+X_o)+(1-(b-m)(1-t))Y = I_o - hr$
#
# $ Y*(t+(1-t)*(1-b+m))-G_0-C_0-X_0-I_0=-h*r  $
#
# $ Y*(t+(1-t)-(1-t)*b+(1-t)*m)-G_0-C_0-X_0-I_0=-h*r $
#
# $ Y*(1-(1-t)*(m-b))-G_0-C_0-X_0-I_0=-h*r $
#
# $ G_0+C_0+X_0+I_0-Y*(1-(1-t)*(m-b))=h*r $
#
# Por lo que h pasa a dividir:
# $ \dfrac{(G_0+C_0+X_0+I_0)}{h}- \dfrac{(1-(1-t)*(m-b))}{h}*Y=r $

# %%
#Parametros 

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8 
m = 0.2
t = 0.3
r=0.2

Y = np.arange(Y_size)

def r(b, m, t, Co, Io, Go, Xo, h, Y):
    r= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return r

R_IS = r(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
#Grafico
y_max = np.max(R_IS)
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, IS, label = "R", color = "purple")

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

ax.set(title = "La Curva IS de Equilibrio en el Mercado de Bienes", xlabel = r'Y', ylabel =r'r')
plt.text(68, 13, '$IS$', fontsize = 11.5, color = 'purple')

plt.show()

# %% [markdown]
# ## Ejercicio 3

# %%
#Parametros 

Y_size = 100 

Co = 15
Io = 18
Go = 28
Xo = 5
h = 0.8
b = 0.5
m = 0.3
t = 0.2

Y = np.arange(Y_size)

def r(b, m, t, Co, Io, Go, Xo, h, Y):
    r= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return r

R_IS= r(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
#Gráfico 
y_max = np.max(IS)
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(Y, IS, label = "R", color = "purple")

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

ax.set(title = "Equilibrio y Desequilibrio en el Mercado de Bienes", xlabel = r'Y', ylabel =r'r')

plt.axvline(x = 60, ymin= 0, ymax = 0.58, linestyle = ":", color = "grey")
plt.axvline(x = 40,  ymin= 0, ymax = 0.58, linestyle = ":", color = "grey")
plt.axvline(x = 20, ymin= 0, ymax = 0.58, linestyle = ":", color = "grey")
plt.axhline(y = 40, xmin= 0, xmax = 0.60, linestyle = ":", color = "grey")

plt.text(68, 13, '$IS$', fontsize = 11.5, color = 'purple')

plt.text(20, 42, '$C$', fontsize = 13, color = 'black')
plt.text(40, 42, '$A$', fontsize = 13, color = 'black')
plt.text(60, 42, '$B$', fontsize = 13, color = 'black')

plt.text(80, 60, '$Exceso  de  Oferta$', fontsize = 12, color = 'black')
plt.text(29, 10, '$Exceso  de  Demanda$', fontsize = 12, color = 'black')


plt.show()

# %% [markdown]
# Los puntos se encuentra fuera de los puntos de equilibrio en el mercado de bienes, en el caso de B de muestra un exceso de oferta. En el caso de C, al no  encontrarse en los puntos de equilibrio en la curva IS se encuentra en el lado del exceso de la Demanda por el aumento de la demanda agregada de bienes lo que genera un exceso.

# %% [markdown]
# ## Ejercicio 4

# %% [markdown]
# ### 4.1 Política fiscal Contractiva con caída del Gasto de Gobierno

# %%
# Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)

    # Ecuación 
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# Definición de la reducción del parametro del Gasto de Gobierno
Go = 50

def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# Gráfico
y_max = np.max(DA_G)
fig, ax = plt.subplots(figsize=(10, 8))

ax.set(title = "Disminución del Gasto del Gobierno $(G_0)$", xlabel = r'Y', ylabel = r'DA')

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

ax.plot(Y, DA_IS_K, label = "DA", color = "#3D59AB") #Curva sin la disminución del Gasto del Gobierno
ax.plot(Y, DA_G, label = "DA_G", color = "Purple", linestyle = 'dashed') #Curva ante la disminución del G
ax.plot(Y, L_45, color = "#404040") #línea de 45º

plt.text(0, 150, '$DA^0$', fontsize = 11.5, color = '#3D59AB')
plt.text(0, 135, '$DA_1$', fontsize = 11.5, color = 'purple') 


plt.text(65, 140, '$←$', fontsize = 18, color = 'grey')
plt.text(20, 145, '$↓$', fontsize = 18, color = 'grey')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')

plt.show()

# %% [markdown]
# ### Manera intuitiva

# %% [markdown]
# $$G↓ → DA ↓ → DA > Y → Y↓$$
#
# Ante la reducción del Gasto de Gobinero $Go$ por  la implementación de una política fiscal contractica, se espera que la $DA$ a su vez sufr una disminución, lo que implica que el nivel de producción tenga un desequilibrio. Por eso, para volver al equilibrio se debe disminuir el nivel de producción $Y$.

# %% [markdown]
# ### 4.2 Política fiscal Contractiva con caída del Gasto de Gobierno

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.5 #tasa de tributación
r = 0.9

Y = np.arange(Y_size)

     
def IS_t(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_t= (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return IS_t

t_IS_T = IS_t(Co, Io, Go, Xo, h, r, b, m, t, Y)

    # Definición de la reducción de la tasa de tributación
t = 0.01

def IS_t(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_t = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return IS_t

T_IS = IS_t(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
y_max = np.max(t_IS_T)
fig, ax = plt.subplots(figsize=(10, 8))

ax.set(title = "Reducción de la Tasa de Tributación", xlabel = r'Y', ylabel = r'r')

ax.plot(Y, t_IS_T, label = "IS", color = "#3D59AB") #Curva sin la reducción de la tasa de tributación
ax.plot(Y, T_IS, label = "IS_T", color = "purple", linestyle = 'dashed') #Curva ante la reducción de la tasa de tributación
ax.plot(Y, L_45, color = "#404040") #línea de 45º


plt.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
plt.axhline(y = 176, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
plt.axvline(x = 77,  ymin= 0, ymax = 0.75, linestyle = ":", color = "grey")
plt.axhline(y = 192, xmin= 0, xmax = 0.75, linestyle = ":", color = "grey")


plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(72, 0, '$Y^e$', fontsize = 12, color = 'black')
plt.text(80, 0, '$Y_t$', fontsize = 12, color = 'purple')
plt.text(72, 45, '$→$', fontsize = 18, color = 'grey')
plt.text(20, 180, '$↑$', fontsize = 18, color = 'grey')

ax.legend()

plt.show()

# %% [markdown]
# ### Manera intuitiva

# %% [markdown]
# $t↓ → (1-t)Y↑ → Y^d↑ → C → DA ↑ → DA > Y → Y↑$
#
# Se ve un ingreso disponible ante la reducción de la tasa de impuestos, y por eso  aumenta la demanda de consumo y la demanda agregada, por lo que se aumenta el nivel de producción $(Y)$

# %% [markdown]
# ### 4.3 Caída de Propensión Marginal a Consumir $(b)$

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.5 
r = 0.9

Y = np.arange(Y_size)

def IS_b(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_b= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_b

IS_B= IS_b(Co, Io, Go, Xo, h, r, b, m, t, Y)

    #Modificación de la caída de Propensión Marginal a Consumir
b=0.02


def IS_0b(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_0b= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_0b

IS_B2= IS_0b(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Caída de la propensión Marginal", xlabel=r'Y', ylabel=r'r')

ax.plot(IS_B, label = "IS", color = "blue") #Curva sin modificación
ax.plot(IS_B2, label = "IS_1", linestyle=':', color = "purple")  #Curva con la caída de propensión Marginal 
  
plt.text(40, 160, '$←$', fontsize = 18, color = 'grey')
    
plt.show()

# %% [markdown]
# ### Manera intuitiva
# La reducción  de la propresión marginal a consumir $(b)$, se ve con la disminución de la demanda agregda $(DA)$, lo que se traduce en la disminución de $(Y)$ a su vez:
#
# $ 	b ↓→ C↓ → DA↓ → DA < Y → Y↓ $
