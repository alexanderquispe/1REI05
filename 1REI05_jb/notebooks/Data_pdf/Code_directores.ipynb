# %%
pip install camelot-py
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 745.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 28.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 18.8 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get install ghostscript-x
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript libgs9
#   libgs9-common libidn12 libijs-0.35 libjbig2dec0 poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript
#   ghostscript-x libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0
#   poppler-data
# 0 upgraded, 11 newly installed, 0 to remove and 45 not upgraded.
# Need to get 16.8 MB of archives.
# After this operation, 63.3 MB of additional disk space will be used.
# ...

# %%
# !gs --version
# Out:
# 9.55.0

# %%
# !pip install ghostscript

# %%
import camelot

# Read the PDF file and extract tables
tablas = camelot.read_pdf("semidefinitivos.pdf", pages='1')

# Print the extracted tables
for table in tablas:
    print(table.df)
# Out:
#            0               1                                2  \
# 0     REGIÓN      DRE / UGEL                            GRUPO
# 1
# 2   AMAZONAS    DRE AMAZONAS                      EBR Inicial
# 3   AMAZONAS    DRE AMAZONAS                     EBR Primaria
# 4   AMAZONAS    DRE AMAZONAS                     EBR Primaria
# ..       ...             ...                              ...
# 57    ANCASH   UGEL ASUNCIÓN      EBR Secundaria Comunicación
# 58    ANCASH  UGEL BOLOGNESI                     EBR Primaria
# 59    ANCASH  UGEL BOLOGNESI                     EBR Primaria
# 60    ANCASH  UGEL BOLOGNESI      EBR Secundaria Comunicación
# 61    ANCASH  UGEL BOLOGNESI  EBR Secundaria Educación Física
#
#                            3                 4                 5  \
# 0   DOCUMENTO \nDE IDENTIDAD  APELLIDO PATERNO  APELLIDO MATERNO
# 1
# 2                   33430060             RAMOS              YNGA
# 3                   33407050           TRIGOSO            PUERTA
# ...

# %%
table.df
# Out:
#            0               1                                2  \
# 0     REGIÓN      DRE / UGEL                            GRUPO
# 1
# 2   AMAZONAS    DRE AMAZONAS                      EBR Inicial
# 3   AMAZONAS    DRE AMAZONAS                     EBR Primaria
# 4   AMAZONAS    DRE AMAZONAS                     EBR Primaria
# ..       ...             ...                              ...
# 57    ANCASH   UGEL ASUNCIÓN      EBR Secundaria Comunicación
# 58    ANCASH  UGEL BOLOGNESI                     EBR Primaria
# 59    ANCASH  UGEL BOLOGNESI                     EBR Primaria
# 60    ANCASH  UGEL BOLOGNESI      EBR Secundaria Comunicación
# 61    ANCASH  UGEL BOLOGNESI  EBR Secundaria Educación Física
#
#                            3                 4                 5  \
# 0   DOCUMENTO \nDE IDENTIDAD  APELLIDO PATERNO  APELLIDO MATERNO
# 1
# 2                   33430060             RAMOS              YNGA
# 3                   33407050           TRIGOSO            PUERTA
# ...

# %%
import camelot

# Read the PDF file and extract tables
tablas = camelot.read_pdf("semidefinitivos.pdf", pages='all')

# Print the extracted tables
for table in tablas:
    print(table.df)
# Out:
#            0               1                                2  \
# 0     REGIÓN      DRE / UGEL                            GRUPO
# 1
# 2   AMAZONAS    DRE AMAZONAS                      EBR Inicial
# 3   AMAZONAS    DRE AMAZONAS                     EBR Primaria
# 4   AMAZONAS    DRE AMAZONAS                     EBR Primaria
# ..       ...             ...                              ...
# 57    ANCASH   UGEL ASUNCIÓN      EBR Secundaria Comunicación
# 58    ANCASH  UGEL BOLOGNESI                     EBR Primaria
# 59    ANCASH  UGEL BOLOGNESI                     EBR Primaria
# 60    ANCASH  UGEL BOLOGNESI      EBR Secundaria Comunicación
# 61    ANCASH  UGEL BOLOGNESI  EBR Secundaria Educación Física
#
#                            3                 4                 5  \
# 0   DOCUMENTO \nDE IDENTIDAD  APELLIDO PATERNO  APELLIDO MATERNO
# 1
# 2                   33430060             RAMOS              YNGA
# 3                   33407050           TRIGOSO            PUERTA
# ...

# %%
table.df
# Out:
#           0                      1  \
# 0    REGIÓN             DRE / UGEL
# 1
# 2    TUMBES            UGEL TUMBES
# 3    TUMBES            UGEL TUMBES
# 4    TUMBES            UGEL TUMBES
# 5    TUMBES            UGEL TUMBES
# 6    TUMBES         UGEL ZARUMILLA
# 7   UCAYALI            DRE UCAYALI
# 8   UCAYALI            DRE UCAYALI
# 9   UCAYALI            DRE UCAYALI
# 10  UCAYALI            DRE UCAYALI
# 11  UCAYALI            DRE UCAYALI
# 12  UCAYALI            DRE UCAYALI
# 13  UCAYALI           UGEL ATALAYA
# 14  UCAYALI           UGEL ATALAYA
# 15  UCAYALI  UGEL CORONEL PORTILLO
# 16  UCAYALI  UGEL CORONEL PORTILLO
# 17  UCAYALI  UGEL CORONEL PORTILLO
# 18  UCAYALI  UGEL CORONEL PORTILLO
# 19  UCAYALI  UGEL CORONEL PORTILLO
# 20  UCAYALI  UGEL CORONEL PORTILLO
# 21  UCAYALI  UGEL CORONEL PORTILLO
# 22  UCAYALI  UGEL CORONEL PORTILLO
# 23  UCAYALI        UGEL PADRE ABAD
# 24  UCAYALI        UGEL PADRE ABAD
# 25  UCAYALI        UGEL PADRE ABAD
# ...

# %%
# Importamos las librerias
import camelot
import pandas as pd

# Read the PDF file and extract tables
tablas = camelot.read_pdf("semidefinitivos.pdf", pages='all')

# Concatenate all tables into a single DataFrame
df = pd.concat([tabla.df for tabla in tablas])

# Print the concatenated DataFrame
print(df)
# Out:
#            0                1                                         2  \
# 0     REGIÓN       DRE / UGEL                                     GRUPO
# 1
# 2   AMAZONAS     DRE AMAZONAS                               EBR Inicial
# 3   AMAZONAS     DRE AMAZONAS                              EBR Primaria
# 4   AMAZONAS     DRE AMAZONAS                              EBR Primaria
# ..       ...              ...                                       ...
# 24   UCAYALI  UGEL PADRE ABAD                              EBR Primaria
# 25   UCAYALI  UGEL PADRE ABAD                              EBR Primaria
# 26   UCAYALI  UGEL PADRE ABAD  EBR Secundaria Educación para el Trabajo
# 27   UCAYALI  UGEL PADRE ABAD                 EBR Secundaria Matemática
# 28   UCAYALI       UGEL PURUS           EBR Secundaria Educación Física
#
#                            3                 4                 5  \
# 0   DOCUMENTO \nDE IDENTIDAD  APELLIDO PATERNO  APELLIDO MATERNO
# 1
# ...

# %%
df
# Out:
#            0                1                                         2  \
# 0     REGIÓN       DRE / UGEL                                     GRUPO
# 1
# 2   AMAZONAS     DRE AMAZONAS                               EBR Inicial
# 3   AMAZONAS     DRE AMAZONAS                              EBR Primaria
# 4   AMAZONAS     DRE AMAZONAS                              EBR Primaria
# ..       ...              ...                                       ...
# 24   UCAYALI  UGEL PADRE ABAD                              EBR Primaria
# 25   UCAYALI  UGEL PADRE ABAD                              EBR Primaria
# 26   UCAYALI  UGEL PADRE ABAD  EBR Secundaria Educación para el Trabajo
# 27   UCAYALI  UGEL PADRE ABAD                 EBR Secundaria Matemática
# 28   UCAYALI       UGEL PURUS           EBR Secundaria Educación Física
#
#                            3                 4                 5  \
# 0   DOCUMENTO \nDE IDENTIDAD  APELLIDO PATERNO  APELLIDO MATERNO
# 1
# ...

# %%
# Crearemos las columnas para nuestra data
df1= df.columns= ["REGION","DRE_UGEL","GRUPO","DNI","APELLIDO_PATERNO"
,"APELLIDO_MATERNO","NOMBRES","ID_PLAZA"]

# %%
df
# Out:
#       REGION         DRE_UGEL                                     GRUPO  \
# 0     REGIÓN       DRE / UGEL                                     GRUPO
# 1
# 2   AMAZONAS     DRE AMAZONAS                               EBR Inicial
# 3   AMAZONAS     DRE AMAZONAS                              EBR Primaria
# 4   AMAZONAS     DRE AMAZONAS                              EBR Primaria
# ..       ...              ...                                       ...
# 24   UCAYALI  UGEL PADRE ABAD                              EBR Primaria
# 25   UCAYALI  UGEL PADRE ABAD                              EBR Primaria
# 26   UCAYALI  UGEL PADRE ABAD  EBR Secundaria Educación para el Trabajo
# 27   UCAYALI  UGEL PADRE ABAD                 EBR Secundaria Matemática
# 28   UCAYALI       UGEL PURUS           EBR Secundaria Educación Física
#
#                          DNI  APELLIDO_PATERNO  APELLIDO_MATERNO  \
# 0   DOCUMENTO \nDE IDENTIDAD  APELLIDO PATERNO  APELLIDO MATERNO
# 1
# ...

# %%
# Como ha iterado hoja por hoja, ha jalado las cabeceras en cada hoja, procedemos a localizarlas y eliminarlas
df["REGION"] = df["REGION"].str.strip()
errors = df.loc[df["REGION"]=="REGIÓN"]
errors_list = errors.index.tolist()

# %%
Cargo_Especialistas = df.drop(df.index[errors_list])

# %%
Cargo_Especialistas
# Out:
#       REGION         DRE_UGEL                                          GRUPO  \
# 1
# 2   AMAZONAS     DRE AMAZONAS                                    EBR Inicial
# 3   AMAZONAS     DRE AMAZONAS                                   EBR Primaria
# 4   AMAZONAS     DRE AMAZONAS                                   EBR Primaria
# 5   AMAZONAS     DRE AMAZONAS  EBR Secundaria Ciencia, Tecnología y Ambiente
# ..       ...              ...                                            ...
# 24   UCAYALI  UGEL PADRE ABAD                                   EBR Primaria
# 25   UCAYALI  UGEL PADRE ABAD                                   EBR Primaria
# 26   UCAYALI  UGEL PADRE ABAD       EBR Secundaria Educación para el Trabajo
# 27   UCAYALI  UGEL PADRE ABAD                      EBR Secundaria Matemática
# 28   UCAYALI       UGEL PURUS                EBR Secundaria Educación Física
#
#          DNI APELLIDO_PATERNO APELLIDO_MATERNO            NOMBRES  \
# 1
# ...

# %%
Especialistas = Especialistas_clean.dropna(axis=1, how='all')
Especialistas
# Out:
#       REGION         DRE_UGEL                                          GRUPO  \
# 2   AMAZONAS     DRE AMAZONAS                                    EBR Inicial
# 3   AMAZONAS     DRE AMAZONAS                                   EBR Primaria
# 4   AMAZONAS     DRE AMAZONAS                                   EBR Primaria
# 5   AMAZONAS     DRE AMAZONAS  EBR Secundaria Ciencia, Tecnología y Ambiente
# 6   AMAZONAS     DRE AMAZONAS                EBR Secundaria Educación Física
# ..       ...              ...                                            ...
# 24   UCAYALI  UGEL PADRE ABAD                                   EBR Primaria
# 25   UCAYALI  UGEL PADRE ABAD                                   EBR Primaria
# 26   UCAYALI  UGEL PADRE ABAD       EBR Secundaria Educación para el Trabajo
# 27   UCAYALI  UGEL PADRE ABAD                      EBR Secundaria Matemática
# 28   UCAYALI       UGEL PURUS                EBR Secundaria Educación Física
#
# ...

# %%
Especialistas.dropna()
# Out:
#       REGION         DRE_UGEL                                          GRUPO  \
# 2   AMAZONAS     DRE AMAZONAS                                    EBR Inicial
# 3   AMAZONAS     DRE AMAZONAS                                   EBR Primaria
# 4   AMAZONAS     DRE AMAZONAS                                   EBR Primaria
# 5   AMAZONAS     DRE AMAZONAS  EBR Secundaria Ciencia, Tecnología y Ambiente
# 6   AMAZONAS     DRE AMAZONAS                EBR Secundaria Educación Física
# ..       ...              ...                                            ...
# 24   UCAYALI  UGEL PADRE ABAD                                   EBR Primaria
# 25   UCAYALI  UGEL PADRE ABAD                                   EBR Primaria
# 26   UCAYALI  UGEL PADRE ABAD       EBR Secundaria Educación para el Trabajo
# 27   UCAYALI  UGEL PADRE ABAD                      EBR Secundaria Matemática
# 28   UCAYALI       UGEL PURUS                EBR Secundaria Educación Física
#
# ...

# %%
Especialistas = Especialistas.reset_index()
Especialistas
# Out:
#       index    REGION         DRE_UGEL  \
# 0         2  AMAZONAS     DRE AMAZONAS
# 1         3  AMAZONAS     DRE AMAZONAS
# 2         4  AMAZONAS     DRE AMAZONAS
# 3         5  AMAZONAS     DRE AMAZONAS
# 4         6  AMAZONAS     DRE AMAZONAS
# ...     ...       ...              ...
# 1462     24   UCAYALI  UGEL PADRE ABAD
# 1463     25   UCAYALI  UGEL PADRE ABAD
# 1464     26   UCAYALI  UGEL PADRE ABAD
# 1465     27   UCAYALI  UGEL PADRE ABAD
# 1466     28   UCAYALI       UGEL PURUS
#
#                                               GRUPO       DNI  \
# 0                                       EBR Inicial  33430060
# 1                                      EBR Primaria  33407050
# 2                                      EBR Primaria  40077882
# 3     EBR Secundaria Ciencia, Tecnología y Ambiente  33407751
# 4                   EBR Secundaria Educación Física  33431565
# ...                                             ...       ...
# ...

# %%
# Una vez limpia la data la exportamos en formato csv
from google.colab import files
Especialistas.to_csv("Especialistas.csv", index=False)

# %%
# Descargamos la data Especialistsa
files.download('Especialistas.csv')

# %%
#A continuación trabajaremos con los datos

# %%
import camelot
import pandas as pd

# Read the PDF file and extract tables
tablas = camelot.read_pdf("definitivos.pdf", pages='all')

# Concatenate all tables into a single DataFrame
defini = pd.concat([tabla.df for tabla in tablas])

# Print the concatenated DataFrame
print(defini)
# Out:
#           0                1                  2                         3   \
# 0     REGIÓN       DRE / UGEL  MODALIDAD / NIVEL  DOCUMENTO \nDE IDENTIDAD
# 1
# 2   AMAZONAS       UGEL BAGUA       EBR Primaria                  16673205
# 3   AMAZONAS       UGEL BAGUA       EBR Primaria                  16791689
# 4   AMAZONAS       UGEL BAGUA       EBR Primaria                  17592766
# ..       ...              ...                ...                       ...
# 7    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186118
# 8    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186597
# 9    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00187268
# 10   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  00005295
# 11   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  27420660
#
#                   4                 5                6   \
# 0   APELLIDO PATERNO  APELLIDO MATERNO          NOMBRES
# 1
# ...

# %%
defini
# Out:
#           0                1                  2                         3   \
# 0     REGIÓN       DRE / UGEL  MODALIDAD / NIVEL  DOCUMENTO \nDE IDENTIDAD
# 1
# 2   AMAZONAS       UGEL BAGUA       EBR Primaria                  16673205
# 3   AMAZONAS       UGEL BAGUA       EBR Primaria                  16791689
# 4   AMAZONAS       UGEL BAGUA       EBR Primaria                  17592766
# ..       ...              ...                ...                       ...
# 7    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186118
# 8    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186597
# 9    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00187268
# 10   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  00005295
# 11   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  27420660
#
#                   4                 5                6   \
# 0   APELLIDO PATERNO  APELLIDO MATERNO          NOMBRES
# 1
# ...

# %%
# Crearemos las columnas para nuestra data
Direc= defini.columns=  ["REGION","DRE_UGEL","MODALIDAD_NIVEL","DNI","APELLIDO_PATERNO"
,"APELLIDO_MATERNO","NOMBRES","COD_MODULAR","NOMBRE_I_E","CARGO","ID_PLAZA"]

# %%
defini
# Out:
#       REGION         DRE_UGEL    MODALIDAD_NIVEL                       DNI  \
# 0     REGIÓN       DRE / UGEL  MODALIDAD / NIVEL  DOCUMENTO \nDE IDENTIDAD
# 1
# 2   AMAZONAS       UGEL BAGUA       EBR Primaria                  16673205
# 3   AMAZONAS       UGEL BAGUA       EBR Primaria                  16791689
# 4   AMAZONAS       UGEL BAGUA       EBR Primaria                  17592766
# ..       ...              ...                ...                       ...
# 7    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186118
# 8    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186597
# 9    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00187268
# 10   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  00005295
# 11   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  27420660
#
#     APELLIDO_PATERNO  APELLIDO_MATERNO          NOMBRES  \
# 0   APELLIDO PATERNO  APELLIDO MATERNO          NOMBRES
# 1
# ...

# %%
# Como ha iterado hoja por hoja, ha jalado las cabeceras en cada hoja, procedemos a localizarlas y eliminarlas
defini["REGION"] = defini["REGION"].str.strip()
errors = defini.loc[defini["REGION"]=="REGIÓN"]
errors_list = errors.index.tolist()

# %%
defini
# Out:
#       REGION         DRE_UGEL    MODALIDAD_NIVEL                       DNI  \
# 0     REGIÓN       DRE / UGEL  MODALIDAD / NIVEL  DOCUMENTO \nDE IDENTIDAD
# 1
# 2   AMAZONAS       UGEL BAGUA       EBR Primaria                  16673205
# 3   AMAZONAS       UGEL BAGUA       EBR Primaria                  16791689
# 4   AMAZONAS       UGEL BAGUA       EBR Primaria                  17592766
# ..       ...              ...                ...                       ...
# 7    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186118
# 8    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00186597
# 9    UCAYALI  UGEL PADRE ABAD       EBR Primaria                  00187268
# 10   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  00005295
# 11   UCAYALI  UGEL PADRE ABAD     EBR Secundaria                  27420660
#
#     APELLIDO_PATERNO  APELLIDO_MATERNO          NOMBRES  \
# 0   APELLIDO PATERNO  APELLIDO MATERNO          NOMBRES
# 1
# ...

# %%
Cargo_Directores= defini.drop(defini.index[errors_list])
Cargo_Directores
# Out:
#       REGION         DRE_UGEL MODALIDAD_NIVEL       DNI APELLIDO_PATERNO  \
# 1
# 2   AMAZONAS       UGEL BAGUA    EBR Primaria  16673205             ARCE
# 3   AMAZONAS       UGEL BAGUA    EBR Primaria  16791689          VASQUEZ
# 4   AMAZONAS       UGEL BAGUA    EBR Primaria  17592766         CORONADO
# 5   AMAZONAS       UGEL BAGUA    EBR Primaria  33589181            HOYOS
# ..       ...              ...             ...       ...              ...
# 7    UCAYALI  UGEL PADRE ABAD    EBR Primaria  00186118          CABELLO
# 8    UCAYALI  UGEL PADRE ABAD    EBR Primaria  00186597          VASQUEZ
# 9    UCAYALI  UGEL PADRE ABAD    EBR Primaria  00187268          PERALES
# 10   UCAYALI  UGEL PADRE ABAD  EBR Secundaria  00005295             JARA
# 11   UCAYALI  UGEL PADRE ABAD  EBR Secundaria  27420660            MEJIA
#
#    APELLIDO_MATERNO          NOMBRES      COD_MODULAR  \
# 1                                     CÓDIGO\nMODULAR
# ...

# %%
# Como ha iterado hoja por hoja, ha jalado las cabeceras en cada hoja, procedemos a localizarlas y eliminarlas
Cargo_Directores["CARGO"] = Cargo_Directores["CARGO"].str.strip()
errors_ONE = Cargo_Directores.loc[Cargo_Directores["CARGO"]=="CARGO"]
errors_list_ONE = errors.index.tolist()

# %%
Directores = Cargo_Directores.drop(Cargo_Directores.index[errors_list_ONE])

# %%
Directores
# Out:
#       REGION         DRE_UGEL MODALIDAD_NIVEL       DNI APELLIDO_PATERNO  \
# 2   AMAZONAS       UGEL BAGUA    EBR Primaria  16673205             ARCE
# 3   AMAZONAS       UGEL BAGUA    EBR Primaria  16791689          VASQUEZ
# 4   AMAZONAS       UGEL BAGUA    EBR Primaria  17592766         CORONADO
# 5   AMAZONAS       UGEL BAGUA    EBR Primaria  33589181            HOYOS
# 6   AMAZONAS       UGEL BAGUA    EBR Primaria  33591617             DIAZ
# ..       ...              ...             ...       ...              ...
# 7    UCAYALI  UGEL PADRE ABAD    EBR Primaria  00186118          CABELLO
# 8    UCAYALI  UGEL PADRE ABAD    EBR Primaria  00186597          VASQUEZ
# 9    UCAYALI  UGEL PADRE ABAD    EBR Primaria  00187268          PERALES
# 10   UCAYALI  UGEL PADRE ABAD  EBR Secundaria  00005295             JARA
# 11   UCAYALI  UGEL PADRE ABAD  EBR Secundaria  27420660            MEJIA
#
#    APELLIDO_MATERNO          NOMBRES COD_MODULAR  \
# ...

# %%
Directores = Directores.reset_index()
Directores
# Out:
#       index    REGION         DRE_UGEL MODALIDAD_NIVEL       DNI  \
# 0         2  AMAZONAS       UGEL BAGUA    EBR Primaria  16673205
# 1         3  AMAZONAS       UGEL BAGUA    EBR Primaria  16791689
# 2         4  AMAZONAS       UGEL BAGUA    EBR Primaria  17592766
# 3         5  AMAZONAS       UGEL BAGUA    EBR Primaria  33589181
# 4         6  AMAZONAS       UGEL BAGUA    EBR Primaria  33591617
# ...     ...       ...              ...             ...       ...
# 3125      7   UCAYALI  UGEL PADRE ABAD    EBR Primaria  00186118
# 3126      8   UCAYALI  UGEL PADRE ABAD    EBR Primaria  00186597
# 3127      9   UCAYALI  UGEL PADRE ABAD    EBR Primaria  00187268
# 3128     10   UCAYALI  UGEL PADRE ABAD  EBR Secundaria  00005295
# 3129     11   UCAYALI  UGEL PADRE ABAD  EBR Secundaria  27420660
#
#      APELLIDO_PATERNO APELLIDO_MATERNO          NOMBRES COD_MODULAR  \
# 0                ARCE         GONZALES        CLODOMIRO     0259036
# ...

# %%
# Una vez limpia la data la exportamos en formato csv
from google.colab import files
Directores.to_csv("Directores.csv", index=False)

# %%
# Descargamos la data Directores
files.download('Directores.csv')

# %%
import camelot
import pandas as pd

# Read the PDF file and extract tables
tablas = camelot.read_pdf("excepcional.pdf", pages='all')

# Concatenate all tables into a single DataFrame
Excepcional = pd.concat([tabla.df for tabla in tablas])

# Print the concatenated DataFrame
Excepcional
# Out:
#             0                1                  2                         3   \
# 0       REGIÓN       DRE / UGEL  MODALIDAD / NIVEL  DOCUMENTO \nDE IDENTIDAD
# 1
# 2     AMAZONAS   UGEL UTCUBAMBA       EBR Primaria                  33403175
# 3     AMAZONAS   UGEL UTCUBAMBA     EBR Secundaria                  80535357
# 4       ANCASH      UGEL HUARAZ        EBR Inicial                  32728843
# ..         ...              ...                ...                       ...
# 56  SAN MARTIN       UGEL RIOJA     EBR Secundaria                  27047870
# 57  SAN MARTIN  UGEL SAN MARTIN     EBR Secundaria                  01115158
# 58  SAN MARTIN  UGEL SAN MARTIN     EBR Secundaria                  01124515
# 59       TACNA       UGEL TACNA       EBR Primaria                  00423658
# 60       TACNA       UGEL TACNA     EBR Secundaria                  00484392
#
#                   4                 5               6   \
# 0   APELLIDO PATERNO  APELLIDO MATERNO         NOMBRES
# 1
# ...

# %%
# Crearemos las columnas para nuestra data
Direc_E= Excepcional.columns=  ["REGION","DRE_UGEL","MODALIDAD_NIVEL","DNI","APELLIDO_PATERNO"
,"APELLIDO_MATERNO","NOMBRES","COD_MODULAR","NOMBRE_I_E","CARGO","ID_PLAZA"]

# %%
Excepcional
# Out:
#         REGION         DRE_UGEL    MODALIDAD_NIVEL                       DNI  \
# 0       REGIÓN       DRE / UGEL  MODALIDAD / NIVEL  DOCUMENTO \nDE IDENTIDAD
# 1
# 2     AMAZONAS   UGEL UTCUBAMBA       EBR Primaria                  33403175
# 3     AMAZONAS   UGEL UTCUBAMBA     EBR Secundaria                  80535357
# 4       ANCASH      UGEL HUARAZ        EBR Inicial                  32728843
# ..         ...              ...                ...                       ...
# 56  SAN MARTIN       UGEL RIOJA     EBR Secundaria                  27047870
# 57  SAN MARTIN  UGEL SAN MARTIN     EBR Secundaria                  01115158
# 58  SAN MARTIN  UGEL SAN MARTIN     EBR Secundaria                  01124515
# 59       TACNA       UGEL TACNA       EBR Primaria                  00423658
# 60       TACNA       UGEL TACNA     EBR Secundaria                  00484392
#
#     APELLIDO_PATERNO  APELLIDO_MATERNO         NOMBRES  \
# 0   APELLIDO PATERNO  APELLIDO MATERNO         NOMBRES
# 1
# ...

# %%
# Como ha iterado hoja por hoja, ha jalado las cabeceras en cada hoja, procedemos a localizarlas y eliminarlas
Excepcional["REGION"] = Excepcional["REGION"].str.strip()
errors = Excepcional.loc[Excepcional["REGION"]=="REGIÓN"]
errors_list = errors.index.tolist()

# %%
Directores_E = Excepcional.drop(Excepcional.index[errors_list])

# %%
Directores_E  = Directores_E .dropna(axis=1, how='all')
Directores_E
# Out:
#                                                REGION             DRE_UGEL  \
# 1
# 2                                            AMAZONAS       UGEL UTCUBAMBA
# 3                                            AMAZONAS       UGEL UTCUBAMBA
# 4                                              ANCASH          UGEL HUARAZ
# 5                                              ANCASH          UGEL HUARAZ
# 6                                            APURIMAC         UGEL ABANCAY
# 7                                            APURIMAC         UGEL ABANCAY
# 8                                            APURIMAC      UGEL COTABAMBAS
# 9                                            AREQUIPA  UGEL AREQUIPA NORTE
# 10                                           AREQUIPA  UGEL AREQUIPA NORTE
# 11                                           AREQUIPA  UGEL AREQUIPA NORTE
# 12                                           AREQUIPA        UGEL CAYLLOMA
# ...

# %%
Directores_E  = Directores_E.drop([1],axis=0)
Directores_E
# Out:
#                                                REGION             DRE_UGEL  \
# 2                                            AMAZONAS       UGEL UTCUBAMBA
# 3                                            AMAZONAS       UGEL UTCUBAMBA
# 4                                              ANCASH          UGEL HUARAZ
# 5                                              ANCASH          UGEL HUARAZ
# 6                                            APURIMAC         UGEL ABANCAY
# 7                                            APURIMAC         UGEL ABANCAY
# 8                                            APURIMAC      UGEL COTABAMBAS
# 9                                            AREQUIPA  UGEL AREQUIPA NORTE
# 10                                           AREQUIPA  UGEL AREQUIPA NORTE
# 11                                           AREQUIPA  UGEL AREQUIPA NORTE
# 12                                           AREQUIPA        UGEL CAYLLOMA
# ...

# %%
data_directores = pd.concat([Directores, Directores_E])
data_directores
# Out:
#         REGION         DRE_UGEL MODALIDAD_NIVEL       DNI APELLIDO_PATERNO  \
# 2     AMAZONAS       UGEL BAGUA    EBR Primaria  16673205             ARCE
# 3     AMAZONAS       UGEL BAGUA    EBR Primaria  16791689          VASQUEZ
# 4     AMAZONAS       UGEL BAGUA    EBR Primaria  17592766         CORONADO
# 5     AMAZONAS       UGEL BAGUA    EBR Primaria  33589181            HOYOS
# 6     AMAZONAS       UGEL BAGUA    EBR Primaria  33591617             DIAZ
# ..         ...              ...             ...       ...              ...
# 56  SAN MARTIN       UGEL RIOJA  EBR Secundaria  27047870           CHAVEZ
# 57  SAN MARTIN  UGEL SAN MARTIN  EBR Secundaria  01115158            JULCA
# 58  SAN MARTIN  UGEL SAN MARTIN  EBR Secundaria  01124515          HIDALGO
# 59       TACNA       UGEL TACNA    EBR Primaria  00423658           MEDINA
# 60       TACNA       UGEL TACNA  EBR Secundaria  00484392           VARGAS
#
#    APELLIDO_MATERNO          NOMBRES COD_MODULAR  \
# ...

# %%
# Una vez limpia la data la exportamos en formato csv
from google.colab import files
data_directores.to_csv("Directores_complete.csv", index=False)

# %%
# Descargamos la data Directores
files.download('Directores_complete.csv')
