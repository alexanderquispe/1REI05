# %% [markdown]
# # I. Teoría

# %% [markdown]
# *(2 puntos) Defina el Multiplicador Keynesiano y dé un ejemplo de cómo influye este en el modelo Ingreso-Gasto Keynesiano.*
#
# El concepto de lo que Keynes define como multiplicador keynesiano parte de la suposición de una economía cerrada y sin gobierno alguno. En el cual los sectores de producción se dividen en dos: inversión y consumo, y donde el multiplicado, representado con ‘k’ el cual indica que “cuando existe un incremento en la inversión total, el ingreso aumentará en una cantidad que es k veces el incremento de la inversión”. Es decir, cuando se aumenta el gasto autónomo del estado, la economía se mueve proporcionalmente a esta, reflejando así una regla básica de su teorización.
#
#
# *(2 puntos) Grafique y explique cuando sucede un exceso y déficit de demanda en el modelo Ingreso-Gasto. Señale las áreas donde ocurre cada caso. Explique cómo se converge al equilibrio a partir de estos dos escenarios.*

# %%
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

#Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r1 = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

#Dimensiones:
y_max = np.max(r1)
fig, ax = plt.subplots(figsize=(10, 8))
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())
ax.plot(Y, r1, label = "IS", color = "#D291BC") 
#Lineas punteadas:
ax.axvline(x = 70.5, ymin= 0, ymax = 0.45, linestyle = ":", color = "grey")
ax.axvline(x = 54,  ymin= 0, ymax = 0.45, linestyle = ":", color = "grey")
ax.axvline(x = 37,  ymin= 0, ymax = 0.45, linestyle = ":", color = "grey")
plt.axhline(y = 165, xmin= 0, xmax = 0.67, linestyle = ":", color = "grey")
#Leyenda:
ax.text(72, 122, '$Y_B$', fontsize = 12, color = 'black')
ax.text(55, 122, '$Y_A$', fontsize = 12, color = 'black')
ax.text(38, 122, '$Y_C$', fontsize = 12, color = 'black')
ax.text(-8, 167, '$r_A$', fontsize = 12, color = 'black')
ax.text(70, 167, '$B$', fontsize = 14, color = 'black')
ax.text(53, 167, '$A$', fontsize = 14, color = 'black')
ax.text(36, 167, '$C$', fontsize = 14, color = 'black')

#Coordenadas de exceso:

ax.text(70,180, 'Exceso\n    de\n Oferta', fontsize = 15, color = 'black')
ax.text(38,145, '  Exceso\n      de\nDemanda', fontsize = 15, color = 'black')

ax.set(title = "Equilibrio y desequilibrio en el Mercado de Bienes-Exceso de Demanda y Oferta", xlabel = 'Y', ylabel= 'r')
ax.legend()

custom_xlim = (-10, 110)
custom_ylim = (120,220)
plt.setp(ax, xlim=custom_xlim, ylim=custom_ylim)

plt.show()

# %% [markdown]
# Si la Curva IS representa los puntos donde hay un equilibrio en el mercado de bienes, los puntos fuera de la curva señalan un desequilibrio en el mercado. Al lado derecho se encuentra el exceso de demanda [Inversión (I) < Ahorro (S)], mientras que al lado izquierdo se encuentra el desequilibrio por execeso de oferta.
#
#
# *(2 puntos) ¿Cuáles son las herramientas de política fiscal y política monetaria? Dé un ejemplo para cada una de ellas dentro del contexto peruano. Coloque su fuente. (Solo necesita 1 para política. Fiscal y 1 para Monetaria).*
#
# Es la autoridad monetaria del Perú el Banco Central de Reserva del Perú, el cual cuenta con la potestad de gestionar la oferta monetaria en aras de salvaguardar cierta estabilidad, mediante el uso de políticas monetarias tanto expansivas como contractivas.
#
# Dentro de las herramientas de la política monetaria se encuentran la oferta monetaria, la tasa de interés y el coeficiente legal de encaje. La oferta, en primer lugar, se compone de operaciones de compra o venta de bonos a los bancos comerciales; la compra provoca que se incremente la oferta monetaria en tanto hubo un aumento en sus activos y la venta se trata de una política contractiva.  Otra herramienta es la tasa de interés, en la cual esta se convierte en una variable referencial en el mercado, así contrayendo o expandiendo dicha tasa, repercutiendo en el mercado. Y, por último, se tiene al coeficiente legal de encaje, mediante el cual al disminuir esta tasa multiplica el dinero bancario y este implica un incremento en la política monetaria, expansiva en este caso.
#
# Por otro lado, es que en la política fiscal las herramientas a utilizar son la tasa impositiva, el gasto del gobierno y las transferencias, las cuales se tratan de variables exógenas dentro de un modelo ingreso gasto. Estas se ponen a plena disposición del gobierno, la cual puede moldear o determinar los valores de los instrumentos previamente expuestos.
# Asimismo, es que los impuestos y su respectiva función (T =tY) actúa como un estabilizador en las fluctuaciones del producto producido y el contexto que atraviesa el país, ya que es en tiempos de auge cuando la tributación aumenta (claro, ello también dependiendo si el país en cuestión lleva a cabo una política de tipo cíclica o contracíclica).
#
#
# *(2) Explique qué funciones del dinero respaldan el éxito de éxito Yape y Plin (Aplicativos móviles para intercambio de dinero).*
#
# El dinero, como un bien, se define como “un activo financiero […] líquido” con el cual se pueden adquirir productos o servicios en cualquier momento dado a la universalidad de su aceptación. Fungiendo, dentro de la economía, funciones como la unidad de cuenta y patrón de precios (medida aceptada para expresar el precio), medio de intercambio, medio de pago y reserva de valor. Por lo cual para poder desempeñar esas funciones adecuadamente es que cumple con características como la divisibilidad, uniformidad, aceptabilidad, portabilidad y durabilidad.
#
# Es así que el éxito de Yape y Plin deriva fundamentalmente del cumplir e ir más allá de estas características, pues utiliza la unidad de cuenta universal en sus transacciones. Siendo que facilita en gran medida el intercambio de bienes y servicios en tanto la mayoría (si es que no todas las personas) cargan con su celular todo el tiempo para realizar pagos; así pues, sirviendo como reserva intangible de la riqueza que los usuarios posean. Se vuelve aún incluso, una mejor alternativa en tanto quita de las características necesarias del dinero el reconocimiento y durabilidad, ello pues se trata de una operación digital es que hace las transacciones más fáciles y rápidas aún. Es más, debido a la portabilidad que ofrece, junto con las fáciles condiciones con la que uno puede descargarlo y utilizarlo explican su popularización y éxito.
#
# *(3 puntos) Cuáles son las conclusiones principales del paper de Dancourt "Inflation Targeting in Peru: The Reasons for the Success"*
#
# La pregunta de investigación sobre la cual Dancourt centra la investigación son cuáles fueron las causas y las consecuencias e impacto inflacionario en la economía peruana del proceso de ‘vacas flacas’ (y lo recesivo que resultó) que el Perú pasó entre los años 2013—15’; asimismo discute las medidas tomadas por el Estado y las políticas monetarias llevadas a cabo y brinda asesoramiento sobre cuáles han de ser los próximos movimientos del futuro gobierno peruano con el fin de responder efectivamente a este fenómeno y las desastrosas consecuencias que tiene en el país.
#
# Ahí precisamente es que se hallan la mayoría de conclusiones que el autor brinda, en tanto su sección final se dedica a repartir consejos respecto a cuáles, idealmente, han de ser los siguientes pasos del gobierno peruano. En primer lugar, es que recalca la importancia que tiene la reducción de la tasa de interés, con el fin de atraer mucho más capital, y la venta de cambio al atravesar una debacle económico adverso; lo opuesto al pasar por un choque externo favorable. Ya que el sistema que actualmente llevamos si bien ha resultado provechoso y ha salvado una casi moribunda economía es que no se puede tener certeza sobre su funcionamiento a un plazo mucho más alargado. Y es que logra identificar acciones negligentes o deficientes del Estado, como lo sería la excesiva venta de los dólares estatales, la cual menciona el autor compromete la política monetaria futura; siendo más aún que se trata de un sistema bancario dolarizado, al cual le chocaría con más fuerza un choque externo adverso y derribaría rápidamente su estabilidad.
#
# Asimismo, es que el BCRP debe también poner un límite al endeudamiento de los bancos comerciales, ello no como fin último, sino como medio para poder llegar al objetivo fundamental y más urgente: la desdolarización. Particularmente en este caso del crédito bancario, en tanto la única medida efectiva es la imposición requisitos de reserva mayores a los bancos en caso de shocks. Por último, es que aboga también por la causa de la diversificación de las actividades económicas del país, en tanto es que uno de los principales problemas además de los anteriormente expuestos es que dependemos mucho de un solo mercado, la exportación de minerales, y somos muy vulnerables a las bajadas y subidas de su precio en el sistema internacional. En definitiva un proceso que demoraría tiempo, mas valdría la pena, en tanto se contaría con una mayor estabilidad frente a golpes en sectores del mercado internacional.

# %% [markdown]
# # II. Código

# %% [markdown]
# 1. (2 puntos) Encuentre el Ingreso de Equilibrio ($Y^{eq}$) e identifique el multiplicador keynesiano
#
#
# $$DA = C_0 + b(1 - t)Y + I_0 - hr + G_0 + x_1Y* + x_2ε - m_1(1 - t)Y + m_2ε$$
#
# $$DA = C_0 + I_0 + G_0 + [b(1 - t) - m_1(1 - t)]Y + - hr  x_1Y* + (x_2 + m_2)ε$$
#
# $$DA = w - hr + x_1Y* + (x_2 + m_2)ε_0 - (x_2 + m_2)ρr + (x_2 + m_2)ρr* + [b(1 - t) - (1 - t)]Y$$
#
# Siendo que: $w = C_0 + I_0 + G_0$
#
# $$DA = [w + x_1Y* + (x_2 + m_2)ε_0 + (x_2 + m_2)ρr* - (h + (x_2 + m_2)ρ)r] + [b(1 - t) - (1 - t)]Y$$
#
# El ingreso de equilibrio ($Y^{eq}$) entonces se da cuando $Y=DA$
#
# $$Y = w - [h + (x_2 + m_2)ρ]r + x_1Y* +(x_2 + m_2)ε_0 + (x_2 + m_2)ρr* + [(b - m_1)(1 - t)]Y$$
#
# $$Y = \frac{1}{1-(b - m_1)(1 - t)}[w + (x_2 + m_2)ε_0 + (x_2 + m_2)ρr* + x_1Y*] - [\frac{h + (x_2 + m_2)ρ}{1-(b - m_1)(1 - t)}]r$$
#
#
# Identificando a $Y = \frac{1}{1-(b - m_1)(1 - t)}$ como el multiplicador

# %% [markdown]
# -  Ejercicio 2

# %% [markdown]
# 2. (2 puntos) Encuentre las ecuaciones de equilibrio de $Y^{eq\_da\_oa}, P^{eq\_da\_oa}$
#
#
# Considerando la ecuación de la demanda agregada $(DA)$:
#
# $$  P = \frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}Y \ ...(1)$$
#
# Y la ecuación de la oferta agregada $(OA)$:
#
# $$ P = P^e + θ(Y - \bar{Y}) \ ...(2)$$
#
# Para hallar $Y^{eq\_da\_oa}$ igualamos ecuaciones 1 y 2:
#
# $$ \frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}Y = P^e + θ(Y - \bar{Y}) $$
#
# $$ Y^{eq\_da\_oa} = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$
#
# Para encontrar $P^{eq}$ solamente reemplazamos $Y^{eq}$ en la ecuación de oferta agregada
#
# $$ P^{eq\_da\_oa} = P^e + θ( Y^{eq\_da\_oa} - \bar{Y} ) $$
#
# $$ P^{eq\_da\_oa} = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) $$
#
#
# Para hallar $P^e$, despejamos la ecuación de $OA$ en función de Y:
#
# $$ P = P^e + θ(Y - \bar{Y}) $$
#
# $$ Y = \frac{P - P^e - θ\bar{Y}}{θ} $$
#
# Y reemplazamos $Y$ en la ecuación de $DA$:
#
# $$ P^e = (\frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}) * (\frac{P - P^e - θ\bar{Y}}{θ}) $$

# %% [markdown]
# (3 puntos) Analice los efectos sobre las variables endógenas Y, P ante una subida de la tasa de interés de referencia. El análisis debe ser intuitivo, matemático y gráfico.
#
# 1. $$r_0 ↑ → I↓ → DA↓ → Y>DA → Y↓$$
