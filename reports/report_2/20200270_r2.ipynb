# %% [markdown]
# # Lectura

# %% [markdown]
# El working paper escrito por Martinelli y Vega (2019) respone a la pregunta de investigación ¿Cuáles fueron las causas y consecuencias de la crónica inflación durante las décadas de 1970 y 1980 en el Perú? En ese sentido, los autores explican las políticas económicas desde los gobiernos militares, pasando por las medidas tomadas en 1990 como consecuencia de la hiperinflación hasta llegar al 2017. Uno de los puntos más resaltantes que señalan los autores es que, en el régimen de dominancia fiscal sobre la política monetaria en el cual se encontraba el Perú, la necesidad de impuestos inflacionarios fue principal causa de la inflación que sufrió el Perú en la década de 1970 y 1980.
#
# El texto presenta grandes fortalezas, empezando por la idoneidad de los autores debido a su trayectoria profesional y conocimiento sobre el tema. Otra fortaleza que se evidencia en el texto es que se toman en cuenta los cambios de gobierno como puntos de inflexión por las diferencias en las políticas implementadas. También considera los factores sociales como la influencia de la oponión pública sobre los políticos para llevar a cabo ciertas políticas en la década de 1990. Asimismo, la presencia de los gráficos enfatizando los años de estudio y relevancia, así como las fórmulas económicas a la par del texto ayudaron a que los autores puedan responder su pregunta de investigación con mayor claridad. Por otro lado, las debilidades del texto es la falta de profundización respecto al contexto de la economía mundial y al contexto del precio de las materias primas, las cuales tienen un importante impacto en la economía peruana.
#
# De forma global, podemos considerar que el working paper de Martinelli y Vega contribuye, con una mirada holística entre economía, política y social, a la comprensión del impacto de las políticas fiscales y económicas en el Perú durante los diferentes gobiernos. Además responde a la pregunta de invsetigación propuesta, con lo cual, dan a concer las causas y consecuencias de la inflación durante las décadas de 1970 y 1980.
#
# Finalmente, para complementar la pregunta de investigación de Martinelli y Vega, y entender más la situación podemos consultar el artículo de Cáceres y Paredes (1991), donde se explica que entre 1988 y 1989 el Perú sufrió de un proceso de ajuste sin el proceso de estabilización. En ese sentido, se olvidó la importancia del proceso de estabilización macroeconómica como condición para retomar el camino de un crecimiento sostenido en la economía. Por otro lado, como complemento, se puede leer el artículo de Parra (2022) que explica a detalle la importancia de la independencia del Banco Central de Reserva. Esto en relación a que Martinelli y Vega mencionan como un punto importante cuando el Banco Central de REserva del Perú llega a tener autonomía y las decisiones económicas ya no están tan vinculadas con el legislativo y ejecutivo como antes.

# %% [markdown]
# # Código

# %% [markdown]
# Andrea Lucero Salas Angles 20200270
#
# Claudia Andrea Zevallos Amaya 20191511

# %%
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

# %%
pip install --force-reinstall graphviz==0.18
# Out:
# ...
#   Using cached graphviz-0.18-py3-none-any.whl (38 kB)
# ...
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.18
#     Uninstalling graphviz-0.18:
#       Successfully uninstalled graphviz-0.18
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### A)El Modelo Ingreso-Gasto: la Curva IS

# %% [markdown]
# -Utilizando las ecuaciones derive paso a paso la curva IS matemáticamente (a partir de la condición de equilibrio Y = DA)

# %% [markdown]
# Para encontrar la Curva de IS, entendemos nuestra fómula de equilibrio como
#
#             Y=DA
#
# En donde conocemos que:
#
#              Y= (1/(1-(b-m)(1-t))(Co+Io+Go+Xo+hr)
#
# Ya que estamos analizando desde el análisis parte desde el tasa de interés(r); por lo que se hacen las siguientes operaciones
#
#              r= (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
#
# Entonces se puede simplicar como:
#
#             r= L1/h- (L2/h)y
#
# Donde nuestro intercepto está representado por:
#
#             L1: Co+Go+Io+Xo
#
# Y nuestra pendiente está representado por:
#
#             L2: 1-(b-m)(1-t)

# %% [markdown]
# -Utilizando la función de equilibrio IS donde r está en función de Y, encuentre Δr/ΔY

# %%
#Primero representamos nuestra ecuación:
r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h

#Denominamos
Co, Io, Go, Xo, Y, b, m, t, h = symbols('Co Io Go Xo Y b m t h')

dr_IS_Y = diff(r_IS, Y)
dr_IS_Y
# Out:
# ((1 - t)*(b - m) - 1)/h

# %% [markdown]
# -Lea la sección 4.4 del material de enseñanza y explique cómo se deriva la curva IS a partir del equilibrio  y grafique lo siguiente:

# %% [markdown]
# Para encontrar la Curva de IS podemos analizarlo desde el Ingreso y la Demanda agregada que represetan un equilibrio dentro del Mercado de bienes, entendemos nuestra fómula de equilibrio como
#
#                                                    Y=DA
#
# En donde conocemos que:
#
#                                      Y= (1/(1-(b-m)(1-t))(Co+Io+Go+Xo+hr)
#
# Ya que estamos analizando desde el análisis parte desde el tasa de interés; por lo que se hacen las siguientes operaciones
#
#
#                              r= (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
#
#
# Entonces se puede simplicar como:
#
#                                                 r= L1/h- (L2/h)y
#
# Donde nuestro intercepto está representado por:
#
#                                                 L1: Co+Go+Io+Xo
#
# Y nuestra pendiente está representado por:
#
#                                                 L2: 1-(b-m)(1-t)

# %% [markdown]
# GRAFICAMOS:

# %%
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)



def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

#--------------------------------------------------
# Recta de 45°

a = 2.5 

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)

#--------------------------------------------------
# Segunda curva de ingreso de equilibrio

    # Definir cualquier parámetro autónomo
Go = 35

# Generar la ecuación con el nuevo parámetro
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
#Curva IS
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 

#---------------------------------
    # Gráfico 1: ingreso de Equilibrio
ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.plot(Y, DA_IS_K, label = "DA_0", color = "#C6D625") 
ax1.plot(Y, DA_G, label = "DA_1", color = "#C6D625") 
ax1.plot(Y, L_45, color = "#D69B25") 

ax1.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
ax1.axvline(x = 54,  ymin= 0, ymax = 0.54, linestyle = ":", color = "grey")

ax1.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
ax1.text(2.5, -3, '$◝$', fontsize = 30, color = 'black')
ax1.text(72, 0, '$Y_0$', fontsize = 12, color = 'black')
ax1.text(56, 0, '$Y_1$', fontsize = 12, color = 'black')
ax1.text(67, 185, 'E_0', fontsize = 12, color = 'black')
ax1.text(50, 142, 'E_1', fontsize = 12, color = 'black')

ax1.set(title = "Curva IS a partir del equilibrio $Y=DA$", xlabel = r'Y', ylabel = r'DA')
ax1.legend()

#---------------------------------
    # Gráfico 2: Curva IS

ax2.yaxis.set_major_locator(plt.NullLocator())   
ax2.xaxis.set_major_locator(plt.NullLocator())

ax2.plot(Y, r, label = "IS", color = "#FA8072") 

ax2.axvline(x = 70.5, ymin= 0, ymax = 1, linestyle = ":", color = "grey")
ax2.axvline(x = 54,  ymin= 0, ymax = 1, linestyle = ":", color = "grey")
plt.axhline(y = 151.5, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
plt.axhline(y = 165, xmin= 0, xmax = 0.55, linestyle = ":", color = "grey")

ax2.text(72, 128, '$Y_0$', fontsize = 12, color = 'black')
ax2.text(56, 128, '$Y_1$', fontsize = 12, color = 'black')
ax2.text(1, 153, '$r_0$', fontsize = 12, color = 'black')
ax2.text(1, 167, '$r_1$', fontsize = 12, color = 'black')
ax2.text(72, 152, 'E_0', fontsize = 12, color = 'black')
ax2.text(55, 166, 'E_1', fontsize = 12, color = 'black')

ax2.set(title = "Curva IS", xlabel = r'Y', ylabel = r'r')

ax2.legend()

plt.show()

# %% [markdown]
# ### B)La Curva IS o el equilibrio Ahorro- Inversión

# %% [markdown]
# -Derive la ecuación de IS a partir de la igualdad Ahorro-Inversión y grafique la curva IS de equilibrio en el Mercado de Bienes

# %% [markdown]
# Entendemos nuestra fómula de equilibrio como
#
#             Y=DA
#
# En donde
#
#             DA= C+I+G+M-X
#
# Por lo tanto:
#
#             Y=C+I+G+M-X
#
#
# Además conocemos que
# -    T=ty
# -    y(d)=Y-T
# - C=Co+by(d)
# - I=Io-hr
# - G=Go
# - X-M= Xo-my(d)
#
# Ya que estamos analizando desde el análisis parte desde el tasa de interés; por lo que se hacen las siguientes operaciones
#
#             Y-T=C+I+G+X-M-T
#
#             y(d)=C+I+G+X-M-T
#
# Pasamos todo al otro lado
#
#             y(d)-C-G-X+M+T = I
#
#             (y(d)-C) + (T-G) + (M-X) = I
#
#
# De ahí encontramos tres subdivisiones de ahorro:
#
# - El ahorro privado             (y(d)-C)
#
# - El ahorro de Gobierno         (T-G)
#
# - El ahorro Externo:            (M-X)
#
#
# Entonces la suma de los tres tipos de ahorro (S) es la misma expresion de quilibro con respecto a la inversión:
#
#              S=I
#
# Reemplazando econtramos la ecuación para la Curva IS en cuanto a el quilibrio Ahorro= Inversión
#
#         (y(d)-C) + (T-G) + (M-X) = I
#
#         (y(d)- Co -by(d)) + (ty-Go) + (my(d)-Xo)= Io - hr
#
#         (1-(b-m)(1-t)Y - (Co + Go + Xo) = Io-hr
#
#
# En donde:
#
# - La función ahorro está representado por "(1-(b-m)(1-t)Y - (Co + Go + Xo)"
# - La función inversión está representado por  "I = I0 − hr"
#
# Siguiendo con la operación de la fórmula derivamos que:
#
#                     hr= Io-[1-(b-m)(1-t)Y - (Co+Go+Xo)
#                     hr= [Io+ (Co+Go+Xo)] - [1-(b-m)(1-t)]Y >0
#                     r = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
#
# En donde nuestro intercepto está representado por:
#
#             L1: Io+Co+Go+Xo
#
# Y nuestra pendiente está representado por:
#
#             L2: 1-(b-m)(1-t)

# %%
# Parameters

Y_size = 100 

Co = 45
Io = 50
Go = 80
Xo = 2
h = 0.5
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


def Ejer4(b, m, t, Co, Io, Go, Xo, h, Y):
    Ejer4 = (1/h)*(Co + Io + Go + Xo) - (1/h)*(1-(b-m)*(1-t))*Y
    return Ejer4

Ejercicio4 = Ejer4(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
#Graficamos
y_max = np.max(Ejercicio4)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "IS", color = "#6C3483") 

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

ax.set(title = "Curva de IS", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# ### C)Desequilibrios en el mercado de bienes

# %% [markdown]
# -Grafique las áreas de exceso de oferta o exceso de demanda en el mercado de bienes. Explique por qué estos puntos están fuera de los puntos de equilibrio en el mercado de bienes.

# %% [markdown]
# El desequilibrio de la en la curva de IS  surge por un exceso de oferta o de demanda que llega a mover la curva de derecha o izquierda respectivamente. En el presente gáfico en donde hay dos ejes: "r" y "y", en donde se observa tres puntos. El punto A que se encuentra en nuestra curva sería nuestro punto de equilibrio en donde la inversión es igual al ahorro (I = SA) y nuestro escenario perfecto. En el punto B que se puede observar en el lado izquierdo significa el exceso de demanda, en donde se ve que la tasa de interes y la inversión se matiene; sin embargo, el ahorro ha sufrido una caída con lo que representaría un desequilibrio donde la inversión en mayor que el ahorro (I>SB). Por otro lado, en el lado derecho de nuestro punto de equilibrio se encuentra el punto C que representa el exceso de oferta en, de igual manera que la anterior, se mantiene la tasa de interés y de la inversión, pero el ahorro sobrepasa el ahorro en el equilibrio, por lo que el ahorro es mayor que la inversión (I<SC)

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)



def ejer5(b, m, t, Co, Io, Go, Xo, h, Y):
    ejer5 = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return ejer5

ejercicio5 = ejer5(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "ejercicio5", color = "#8B0A50")


ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

ax.axvline(x = 74, ymin= 0, ymax = 0.45, linestyle = ":", color = "grey")
ax.axvline(x = 54,  ymin= 0, ymax = 0.45, linestyle = ":", color = "grey")
ax.axvline(x = 34,  ymin= 0, ymax = 0.45, linestyle = ":", color = "grey")
plt.axhline(y = 165, xmin= 0, xmax = 1, linestyle = ":", color = "grey")


ax.text(74, 165, 'C', fontsize = 20, color = 'black')
ax.text(54, 165, 'A', fontsize = 20, color = 'black')
ax.text(34, 165, 'B', fontsize = 20, color = 'black')
ax.text(1, 165, 'r', fontsize = 16, color = 'black')
plt.text(74, 120, '$Y_C$', fontsize = 16, color = 'black')
plt.text(54, 120, '$Y_A$', fontsize = 16, color = 'black')
plt.text(34, 120, '$Y_B$', fontsize = 16, color = 'black')


# Título, ejes y leyenda
ax.set(title = "Desequilibrios en el mercado de bienes", xlabel= 'Y', ylabel= 'r')
ax.legend()


plt.show()

# %% [markdown]
# ### D)Movimientos de la curva IS

# %% [markdown]
# -Utilizando el modelo macroeconómico en a) responda los siguiente:

# %% [markdown]
# - Analice una Política Fiscal Contractiva con caída del Gasto del Gobierno . El análisis debe ser intuitivo y gráfico.

# %% [markdown]
# Para el análisis intuitivo de una Política Fiscal Contractiva con Caída del Gasto de Gobierno vemos lo siguiente, la caída de Gasto de Gobierno(G) va a significar que la DA baje el motivo es porque son variables que se relación de manera directamente proporciales
#
#          G = Go ↓=DA↓
#
# Entonces el equilibrio se pierde por la disminución de la demanda y Y tiene que bajar para encontrar nuevamente el equilibrio:
#
#          DA↓ = DA<Y = Y↓

# %%
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


#--------------------------------------------------
    

Go = 60


def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_G = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
# Gráfico


y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "IS", color = "black") #IS orginal
ax.plot(Y, r_G, label = "IS_G", color = "#DA5E1B", linestyle = 'dashed') #Nueva IS


plt.text(47, 162, '∆Go', fontsize=12, color='black')
plt.text(49, 159, '←', fontsize=15, color='grey')


ax.set(title = "Política Fiscal Contractiva con caída del Gasto del Gobiernoo $(G_0)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# - Analice una Política Fiscal Expansiva con una caída de la Tasa de Impuestos . El análisis debe ser intuitivo y gráfico

# %% [markdown]
# Para el analisis intuitivo de un Política Fiscal Expansiva con una caída de la Tasa de Impuestos ,entendemos que existe dos cambios al modelo de equilibrio
# En primer lugar, la caída de la tasa de impuestos tiene un efecto inverso en el consumo y en la demanda, en donde:
#
#     t↓ = C↑ = DA↑
#
# Entonces el equilibrio se pierde por el aumento de la demanda y Y tiene que subir para encontrar nuevamente el equilibrio:
#
#      DA↑ = DA>Y = Y↑
#
# Por otro lado, la caída de la tasa de impuesto tiene un efecto inverso con respecto a las importanciones y este, por consecuencia, afecta inversamente a la demanda, es por ello que vemos que:
#
#      t↓ = M↑ = DA↓
#
# Entonces el equilibrio se pierde por la disminución de la demanda y Y tiene que bajar para encontrar nuevamente el equilibrio
#
#      DA↓ = DA<Y = Y↓
#
# Eso significaría también que el intento de enquilibrio de ambos modelos de cambios son contradictorios

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.7

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


#--------------------------------------------------

t = 0.3


def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_t = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "IS", color = "black") #IS orginal
ax.plot(Y, r_t, label = "IS_t", color = "#9863E4", linestyle = 'dashed') #Nueva IS


plt.text(47, 162, '∆t', fontsize=12, color='black')
plt.text(47, 158, '->', fontsize=15, color='grey')


ax.set(title = "Política Fiscal Expansiva con una caída de la Tasa de Impuestos $(t)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# - Analice una caída de la Propensión Marginal a Consumir . El análisis debe ser intuitivo y gráfico.

# %% [markdown]
# Para el análisis de una política de caída de Propensión Marginal a Consumir(PMC) o (b) en donde afecta  a la Demanda de manera proporcional:
#
#         b↓ = C↓ = DA↓
#
# Entonces el equilibrio se pierde por la disminución de la demanda y Y tiene que bajar para encontrar nuevamente el equilibrio
#
#         DA↓ = DA<Y = Y↓

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.7

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


#--------------------------------------------------

b = 0.3


def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_t = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "IS", color = "black") #IS orginal
ax.plot(Y, r_t, label = "IS_r", color = "#E463B5", linestyle = 'dashed') #Nueva IS

plt.text(47, 162, '∆t', fontsize=12, color='black')
plt.text(47, 158, '←', fontsize=15, color='grey')

ax.set(title = "Política de caída de Propensión Marginal $(t)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()
