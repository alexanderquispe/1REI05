# %% [markdown]
# # REPORTE 5
#
# $CLAUDIA  -  CABREL$
#
# $20183351$

# %% [markdown]
# ## PARTE 1 - ENSAYO:
# ### INFLATION TARGETING IN PERU: THE REASONS FOR THE SUCCESS

# %% [markdown]
#     Se observa que como pregunta de investigación Dancourt propone analizar los instrumentos de la política monetaria aplicada en el Perú durante los años 2002 al 2013 para haber podido salir de una crisis inflacionaria e incluso haber tenido éxito en los siguientes años en términos de políticas macroeconómicas.
#     Entre las fortalezas encontradas, se observa que el autor es específico y detallista al momento de desarrollar cuáles fueron estos instrumentos de la política monetaria que fueron utilizados para lograr un resultado eficaz, pues señala que son dos y de acuerdo a ello no solo introduce, sino que desenvuelve una serie de factores de cada uno, como sus limitaciones y consecuencias en su aplicación. Asimismo, el autor hace uso de gráficos que ayudan al lector a tener un mayor entendimiento de lo que está tratando de comunicar, de esta manera se logra que otro tipo de lector, que no conozca mucho del tema, tenga una lectura más viable. Por otra parte, no logro identificar debilidades más allá de considerar que Dancourt pudo haber explicado a mayor detalle algunos argumentos que plantea presentando ejemplos.
#     Acerca del aporte del autor a la pregunta de investigación, se observa que son múltiples. Algunos de ellos son los siguientes: primero, el autor es bastante teórico y práctico pues explica bastante bien los recursos utilizados para que la problemática presentada sea combatida con soluciones viables, asimismo, es práctico pues nos presenta ejemplos que contribuyen a la comprensión del texto; y segundo, no habla únicamente de la gestión del Estado para la solución de la problemática, sino que explica que el papel del Banco Central de Reserva del Perú y sus política tuvieron un papel elemental.
#     Uno de los siguientes pasos para poder avanzar esta investigación podría ser analizar el contexto económico y político previo a esta crisis para ahondar con mayor claridad en las conclusiones.

# %% [markdown]
# ## PARTE 2 - CODIGO PYTHON
#     - Claudia Cabrel
#     - Aisha Martinez

# %% [markdown]
# ### A partir del siguiente sistema de ecuaciones que representan el modelo DA-OA

# %%
# %matplotlib inline
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

# %% [markdown]
# * Encuentre las ecuaciones de Ingreso $(Y^e)$ , tasa de interés $(r^e)$,  $(P^e)$ de equilibrio (Escriba paso a paso la derivación de estas ecuaciones):

# %% [markdown]
# 1. Demanda Agregada $(DA)$:

# %% [markdown]
# $$ IS:[1-b(1-t)Y=C_0+I_0+G_0-hr$$
# $$LM: \frac{M_0^s}{P_0}=kY-jr $$

# %% [markdown]
# 2. Oferta Agregada $(OA)$

# %% [markdown]
# $$ P=P^e+θ(Y-\bar{Y})
# donde
# \bar{Y}=Y_f $$

# %% [markdown]
# La $DA$ se obtiene de la curva IS y LM, luego se debe despejar la tasa de interés $r$

# %% [markdown]
# $$ IS = r = \frac{B_o}{h} - \frac{B_1}{h}Y $$

# %% [markdown]
# $$  LM = r = -\frac{1}{j}\frac{Mo^s}{P} + \frac{k}{j}Y $$

# %% [markdown]
# * Para hallar la ecuación de Ingreso ($Y^e$):
#
# $$ \frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}Y = P^e + θ(Y - \bar{Y}) $$
#
# $$ Y^e = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$

# %% [markdown]
# * Para hallar la ecuación de Equilibrio ($P^e$) podemos reemplazar $(Y^e)$ en la ecuación de Oferta Agregada $(OA)$:
#
# $$ P^e = P^e + θ( Y^{eq\_da\_oa} - \bar{Y} ) $$
#
# $$ P^e = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) $$

# %% [markdown]
# * Para hallar la tasa de interés ($r^e$), reemplazamos ($P^e$) es dicha ecuación de interés.
#
#     Tasa de interés de equilibrio ($Y^e$) :
#
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P)$$
#
#     Tasa de interés de equilibrio en (DA - OA):
#
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P^e)$$
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) ) $$

# %% [markdown]
# Las ecuaciones finales de equilibrio de las variables endógenas son:
#
# 1. Ingreso ($Y^e$):
# $$ Y^e = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$
#
# 2. Tasa de interés ($r^e$):
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*\\\\
#     [(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) ) $$
#
# 3. Equilibrio ($P^e$):
# $$ P^e = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) $$

# %% [markdown]
# * Grafique el equilibrio simultáneo en el modelo DA-OA.

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.4
m = 0.5
t = 0.8

k = 2
j = 1                
Ms = 200             
P  = 8  

Y = np.arange(Y_size)

B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_AD = P_AD(h, Ms, j, B0, B1, k, Y)

Y_size = 100

Pe = 100 
θ = 3
_Y = 20   

Y = np.arange(Y_size)

def P_AS(Pe, _Y, Y, θ):
    P_AS = Pe + θ*(Y-_Y)
    return P_AS

P_AS = P_AS(Pe, _Y, Y, θ)

# %%
def line_intersection(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    if div == 0:
        raise Exception('lines do not intersect')
    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    return x, y

A = [P_AD[0], Y[0]]
B = [P_AD[-1], Y[-1]]
C = [P_AS[0], Y[0]]
D = [P_AS[-1], Y[-1]]

intersec = line_intersection((A, B), (C, D))
intersec
# Out:
# (192.39043824701196, 50.79681274900399)

# %%
y_max = np.max(P)
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Y, P_AD, label = "DA", color = "PINK")
ax.plot(Y, P_AS, label = "OA", color = "MAGENTA")

plt.axhline(y=intersec[0], xmin= 0, xmax= 0.5, linestyle = ":", color = "grey")
plt.axvline(x=intersec[1],  ymin= 0, ymax= 0.49, linestyle = ":", color = "grey")

plt.text(0, 200, '$P_0$', fontsize = 12, color = 'MAGENTA')
plt.text(53, 25, '$Y_0$', fontsize = 12, color = 'MAGENTA')
plt.text(50, 202, '$E_0$', fontsize = 12, color = 'MAGENTA')

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

ax.set(title="MODELA DA-OA", xlabel= r'Y', ylabel= r'P')
ax.legend()

plt.show()

# %% [markdown]
# ## Estática comparativa

# %% [markdown]
# 1. Analice los efectos sobre las variables endógenas Y, P y r de una disminución del gasto fiscal. $(ΔG_0 < 0) $. El análisis debe ser intuitivo, matemático y gráfico. En una figura, se debe que usar los ejes r e Y (modelo IS-LM), y en la otra, los ejes P y r (modelo DA-OA).

# %% [markdown]
# * Análisis Intuitivo:
#     - Para el análisis intuitivo se utiliza el modelo IS-LM y el Modelo OA-DA.\n",
#
#   $$G↓ → DA↓  → DA < Y → Y↓ $$
#
#   $$Y↓ → M_d↓  → M_d < Ms → r↓ $$
#
#   $$Y↓ → Pe↓ → P↓$$

# %% [markdown]
# * Análisis Matemático:
#
# $IS-LM$
#
# $$ {r_eΔ}=\frac{k}{kh+jB_1}ΔG_0 $$
#
# $$r_eΔ= (+) * (-) = (-) < 0$$
#
# $${Y_eΔ}=\frac{j}{kh+jB_1}ΔG_0<0$$
#
# $$Y_eΔ= (+) * (-) = (-) < 0$$
#
#
# $DA-OA$
# $$ PΔ = P^e + θ(YΔ - \bar{Y}) $$
#
# $$ PΔ = (+) + (+) * (-) = (-) < 0 $$

# %% [markdown]
# * Gráfico:

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.4
m = 0.5
t = 0.8

Y = np.arange(Y_size)

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 8           

Y = np.arange(Y_size)

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

Go = 40

def r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_Go = r_IS_Go(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.4
m = 0.5
t = 0.8

k = 2
j = 1                
Ms = 200             
P  = 8  



B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_AD = P_AD(h, Ms, j, B0, B1, k, Y)


Y_size = 100

Pe = 70
θ = 3
_Y = 20  



def P_AS(Pe, _Y, Y, θ):
    P_AS = Pe + θ*(Y-_Y)
    return P_AS

P_AS = P_AS(Pe, _Y, Y, θ)

Go = 32

B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD_Go(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_Go =P_AD_Go(h, Ms, j, B0, B1, k, Y)

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 

ax1.plot(Y, i, label = "LM", color = "LIGHTBLUE")
ax1.plot(Y, r, label="IS", color = "LIGHTBLUE")
ax1.plot(Y, r_Go, label="IS_Go", color = "C0", linestyle ='dashed')  


ax1.axvline(x=52.5,  ymin= 0, ymax= 0.53, linestyle = ":", color = "grey")
ax1.axvline(x=58,  ymin= 0, ymax= 0.58, linestyle = ":", color = "grey")
ax1.axhline(y=80,  xmin= 0, xmax= 0.52, linestyle = ":", color = "grey")
ax1.axhline(y=90,  xmin= 0, xmax= 0.58, linestyle = ":", color = "grey")

ax1.text(50, 85, '↙', fontsize=15, color='grey')
ax1.text(54, -20, '←', fontsize=15, color='grey')
ax1.text(0, 82, '↓', fontsize=15, color='grey')
ax1.text(58, -25, '$Y_0$', fontsize=12, color='black')
ax1.text(45, -25, '$Y_1$', fontsize=12, color='BLUE')
ax1.text(0, 95, '$r_0$', fontsize=12, color='black')
ax1.text(0, 75, '$r_1$', fontsize=12, color='BLUE')


ax1.set(title="DISMINUCIÓN DEL GASTO FISCAL - MODELO (IS LM)", xlabel= r'Y', ylabel= r'r')
ax1.legend()

ax2.plot(Y, P_AS, label = "AS", color = "VIOLET") 
ax2.plot(Y, P_AD, label = "AD", color = "MAGENTA") 
ax2.plot(Y, P_Go, label = "AD_Go", color = "PINK", linestyle = 'dashed') 

ax2.axvline(x=52,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax2.axvline(x=57,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax2.axhline(y=181,  xmin= 0, xmax= 0.58, linestyle = ":", color = "grey")
ax2.axhline(y=166,  xmin= 0, xmax= 0.52, linestyle = ":", color = "grey")

ax2.text(53, 10, '←', fontsize=15, color='grey')
ax2.text(55, 160, ' ↙', fontsize=15, color='grey')
ax2.text(0, 169, '↓', fontsize=15, color='grey')

ax2.text(58, 0, '$Y_0$', fontsize=12, color='black')
ax2.text(45, 0, '$Y_1$', fontsize=12, color='BLACK')
ax2.text(0, 190, '$P_0$', fontsize=12, color='black')
ax2.text(0, 150, '$P_1$', fontsize=12, color='BLACK')

ax2.set(title="DISMINUCIÓN DEL GASTO FISCAL", xlabel= r'Y', ylabel= r'P')
ax2.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 2. Analice los efectos sobre las variables endógenas Y, P y r de una disminución de la masa monetaria. $(ΔM^s < 0) $.
#
# * Análisis Intuitivo:
#     - Para el análisis intuitivo, utilizaremos el modelo IS-LM y el Modelo OA-DA.
#
# $$ M_s↓  → Ms < Md → r↑ $$
#
# $$ r↑ → I↓ → DA↓ → DA < Y → Y↓ $$
#
# $$Y↓ → Pe↓ → P↓$$

# %% [markdown]
# * Análisis Matemático:
#
# $IS-LM$
#
# $${rΔ}=-\frac{k}{kh+jB_1}M_sΔ → 0$$
#
# $$rΔ= (-)*(+) * (-) = (+) > 0$$
#
# $${Y_eΔ}=\frac{j}{kh+jB_1}M_sΔ<0$$
#
# $$YΔ= (+) * (-) = (-) < 0$$
#
#
# $DA-OA$
#
# $$ PΔ = P^e + θ(YΔ - \bar{Y}) $$
#
# $$ PΔ = (+) + (+) * (-) = (-) < 0 $$

# %% [markdown]
# * Gráfico:

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.5
m = 0.4
t = 0.8

Y = np.arange(Y_size)

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 8           

Y = np.arange(Y_size)

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

Ms = -100

def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.5
m = 0.4
t = 0.8

k = 2
j = 1                
Ms = 200             
P  = 8  

Y = np.arange(Y_size)

B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_AD = P_AD(h, Ms, j, B0, B1, k, Y)

Ms = 125

def P_AD_Ms(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_Ms = P_AD_Ms(h, Ms, j, B0, B1, k, Y)


Y_size = 100

Pe = 70
θ = 3
_Y = 20  

Y = np.arange(Y_size)

def P_AS(Pe, _Y, Y, θ):
    P_AS = Pe + θ*(Y-_Y)
    return P_AS

P_AS = P_AS(Pe, _Y, Y, θ)

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 

ax1.plot(Y, r, label = "IS", color = "GREEN")
ax1.plot(Y, i, label="LM", color = "SKYBLUE")  
ax1.plot(Y, i_Ms, label="LM_Ms", color = "DARKGREEN", linestyle ='dashed')  

ax1.axvline(x=45,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax1.axvline(x=57,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax1.axhline(y=88.9,  xmin= 0, xmax= 0.56, linestyle = ":", color = "grey")
ax1.axhline(y=104,  xmin= 0, xmax= 0.46, linestyle = ":", color = "grey")

ax1.text(50, 110, '∆$M_s$', fontsize=12, color='black')
ax1.text(50, 102, '←', fontsize=15, color='grey')
ax1.text(50, 10, '←', fontsize=15, color='grey')
ax1.text(0, 94, '↑', fontsize=15, color='grey')
ax1.text(60, 15, '$Y_0$', fontsize=12, color='black')
ax1.text(40, 15, '$Y_1$', fontsize=12, color='BLACK')
ax1.text(0, 80, '$r_0$', fontsize=12, color='black')
ax1.text(0, 105, '$r_1$', fontsize=12, color='BLACK')


ax1.set(title="DISMINUCIÓN DE LA MASA MONETARIA", xlabel= r'Y', ylabel= r'r')
ax1.legend()

ax2.plot(Y, P_AD, label = "AD", color = "LIGHTPINK")
ax2.plot(Y, P_Ms, label = "AD_Ms", color = "LIGHTPINK", linestyle = 'dashed') 
ax2.plot(Y, P_AS, label = "AS", color = "ORANGE")

ax2.axvline(x=44,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax2.axvline(x=56,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax2.axhline(y=140.5,  xmin= 0, xmax= 0.45, linestyle = ":", color = "grey")
ax2.axhline(y=178,  xmin= 0, xmax= 0.56, linestyle = ":", color = "grey")

ax2.text(48, 0, '←', fontsize=15, color='grey')
ax2.text(36, 210, '∆$M_s$', fontsize=12, color='black')
ax2.text(36, 200, '←', fontsize=15, color='grey')
ax2.text(0, 155, '↓', fontsize=15, color='grey')

ax2.text(58, 0, '$Y_0$', fontsize=12, color='black')
ax2.text(40, 0, '$Y_1$', fontsize=12, color='GREY')
ax2.text(0, 190, '$P_0$', fontsize=12, color='black')
ax2.text(0, 125, '$P_1$', fontsize=12, color='GREY')

ax2.set(xlabel= r'Y', ylabel= r'P')
ax2.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 3. Analice los efectos sobre las variables endógenas Y, P y r de un incremento en la tasa de impuestos. $(Δt > 0) $.
#
# * Análisis Intuitivo:
#
# $$t↑ → Co↓ → DA↓ → DA < Y → Y↓ $$
# $$Y↓ → M_d↓  → M_d < Ms → r↓ $$
# $$Y↓ → Pe↓ → P↓$$

# %% [markdown]
# * Análisis Matemático:
#
# $ IS-LM $
#
# $${ΔY_e}=\frac{j}{kh+ Δt} + \frac{h}{kh + Δt} Δt>0$$
#
# $$ΔY= (-) + (-)  = (-) < 0$$
#
# $${Δr}=\frac{k}{kh+ Δt} + \frac{Δt}{kh + Δt} Δt> 0$$
#
# $$Δr= (-) + (-)  = (-) < 0$$
#
#
#
# $ DA-OA $
#
# $$ ΔP = P^e + θ(YΔ - \bar{Y})  Δt> 0 $$
#
# $$ ΔP= (+) + (+) * (-) = (-) < 0$$

# %% [markdown]
# * Gráfico:

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.5
m = 0.4
t = 0.5

Y = np.arange(Y_size)

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 8           

Y = np.arange(Y_size)

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

t = 0.9

def r_IS_t(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_t = r_IS_t(b, m, t, Co, Io, Go, Xo, h, Y)

Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.5
m = 0.4
t = 0.1

k = 2
j = 1                
Ms = 200             
P  = 8  

Y = np.arange(Y_size)

B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_AD = P_AD(h, Ms, j, B0, B1, k, Y)

t = 0.99

B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD_t(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_t = P_AD_t(h, Ms, j, B0, B1, k, Y)

Y_size = 100

Pe = 70
θ = 3
_Y = 20  

Y = np.arange(Y_size)

def P_AS(Pe, _Y, Y, θ):
    P_AS = Pe + θ*(Y-_Y)
    return P_AS

P_AS = P_AS(Pe, _Y, Y, θ)

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 

ax1.plot(Y, r, label = "IS", color = "PURPLE") #IS
ax1.plot(Y, i, label="LM", color = "BLUE")  #LM
ax1.plot(Y, r_t, label="IS_t", color = "C0", linestyle ='dashed')  #LM

ax1.axvline(x=56.5,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax1.axvline(x=58,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax1.axhline(y=88.9,  xmin= 0, xmax= 0.56, linestyle = ":", color = "grey")
ax1.axhline(y=91.5,  xmin= 0, xmax= 0.58, linestyle = ":", color = "grey")

ax1.text(55, 15, '←', fontsize=15, color='grey')
ax1.text(0, 85, '↓', fontsize=15, color='grey')
ax1.text(60, 15, '$Y_0$', fontsize=12, color='black')
ax1.text(50, 15, '$Y_1$', fontsize=12, color='C0')
ax1.text(0, 95, '$r_0$', fontsize=12, color='black')
ax1.text(0, 75, '$r_1$', fontsize=12, color='LIGHTBLUE')


ax1.set(title="INCREMENTO DE LA TASA DE IMPUESTOS", xlabel= r'Y', ylabel= r'r')
ax1.legend()

ax2.plot(Y, P_AD, label = "AD", color = "RED")
ax2.plot(Y, P_t, label = "AD_t", color = "ORANGE", linestyle = 'dashed')
ax2.plot(Y, P_AS, label = "AS", color = "GOLD")

ax2.axvline(x=57.5,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax2.axvline(x=56,  ymin= 0, ymax= 1, linestyle = ":", color = "grey")
ax2.axhline(y=182,  xmin= 0, xmax= 0.55, linestyle = ":", color = "grey")
ax2.axhline(y=176.5,  xmin= 0, xmax= 0.56, linestyle = ":", color = "grey")

ax2.text(55, 15, '←', fontsize=15, color='grey')
ax2.text(0, 174, '↓', fontsize=15, color='grey')

ax2.text(58, 0, '$Y_0$', fontsize=12, color='black')
ax2.text(50, 0, '$Y_1$', fontsize=12, color='GREY')
ax2.text(0, 190, '$P_0$', fontsize=12, color='black')
ax2.text(0, 158, '$P_1$', fontsize=12, color='GREY')

ax2.set(xlabel= r'Y', ylabel= r'P')
ax2.legend()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
