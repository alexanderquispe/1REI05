# %% [markdown]
#                                                      REPORTE 4

# %%
# %matplotlib widget
# %matplotlib inline
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

# %% [markdown]
# Nombre: Claudia Andrea Zevallos Amaya
# Código: 20191511

# %% [markdown]
# Control de lectura
# ----

# %% [markdown]
# El presente ensayo de Mendoza denominado "DEMANDA Y OFERTA AGREGADA EN PRESENCIA DE POLÍTICAS MONETARIAS NO CONVENCIONALES" en donde nos muestra un nueva ponarama de la utilizacion de modelos y métodos en la macroeconomía que fue utilizado por la FED dentro de la crisis de burbuja inmobilaria del 2008- 2009, dentro del trabajo se plantea la siguiente pregunta ¿Cuáles fueron las políticas no convencionales aplicadas desde FED tras la crisis del 2008-2009 y cómo estos métodos y modelos económicos antiguos son vigentes para comprender la macroeconomía en la actualidad?.
# Como fortaleza vemos que la teoría a sido manejada de manera correcta y uniforme, redacctado de una manera comprensible para lograr resolver la pregunta planteada, además muestra gráficos que nos ayuda en el entendimiento de este, afirmando que el autor conoce de lo que habla. Como debelidades se encuentra dos; en primer lugar, llega a perder el hilo de la pregunta en cuanto a que paso con la crisis del 2008-2009 o como fue aplicadas dichas políticas fiscales y en otro lugar, el texto puede llegar a hacer denso para alguien que no tenga un conocimiento económico previo, por lo que puede llegar a ser confuso para entender el tema planteado.
# El documento tiene su contribución en dar un nuevo enfoque a la comprensión de la macroeconomía , adentrándose en dar explicaciones de cómo los métodos de Keynes, Hicks o Tobin y las estáticas comparativas han dejado de ser teorías del pasado y se pueden incrustar perfectamente en nuestro tiempo. Además, se resalta su importancia para poder explicar y contrastar posibles crisis económicas mundiales como lo fue en el inicio con la crisis del 2008.2009.
# Los dos pasos siguientes para el desarrollo en nuestra pregunta está relacionado a buscar  aclaraciones de las dudas que dejaron nuestras debilidades del ensayo; en primer lugar, se buscará relacionar de una manera más directa como estas medidas dentro la economía ayudaron a salir de la crisis del 2008, un ejemplo de ello es el artículo de Francisco Rosende titulado “La Macroeconomía y la Crisis: ¿La Crisis de la Macroeconomía?” (2009). El trabajo mencionado relata de una manera directa las conexiones económicas con las acciones de políticas estadounidense para la solución de la crisis del 2008, como vemos en las mismas palabras del mismo autor “La severa crisis financiera que han enfrentado las economías industrializadas en los últimos años —particularmente la de los Estados Unidos— ha promovido un importante cuestionamiento a la agenda de investigación que mayoritariamente se configuró en macroeconomía en los últimos treinta años” (Rosende 2009:18), mostrando que se ha realizado un crítica al entendimiento macroeconómico, que podría conectar perfectamente con el planteamiento de Mendoza, ofreciendo otra respuesta como la aplicación de modelos y métodos clásicos económicos. Por otro lado, otro avance que posible análisis de la importancia de estos modelos para la comprensión y búsqueda de políticas benefactoras ante una crisis económicas global, si bien el autor hace la mención, no se explaya para poder justificar porque sería importante tener a consideración modelos como el de Keyness por ejemplo, para ello podríamos tener como base al libro de Juan Tugores Ques denominado “Macroeconomía para entender la crisis de una economía global” (2010) que precisamente nos muestra como modelos macroeconómicos clásicos y modernos de los últimos años pueden convivir para  comprender situaciones de riesgos económicos.
#
#
#
# Bibliografía
#
# Rosende, F. (2009). La Macroeconomía y la Crisis: ¿La Crisis de la Macroeconomía?. Cuadernos de economía, 46, 161-182.
# https://scielo.conicyt.cl/pdf/cecon/v46n134/art02.pdf
#
# Tugores, J. (2010).  Macroeconomía para entender la crisis de una economía global. Editorial UOC

# %% [markdown]
# Código
# ----

# %% [markdown]
# Claudia Andrea Zevallos Amaya 20191511
#
# Ariana Sato Flores 20192304

# %% [markdown]
# 1. Apartir del siguiente sistema de ecuaciones que representan el modelo IS-LM

# %% [markdown]
#     -Encuentre las ecuaciones de Ingreso y tasa de interesde equilibrio(Escriba paso a paso la derivacion de estas ecuaciones).

# %% [markdown]
# Recordemos las ecuaciones IS y LM:
#
# Donde:
#
#                                     r=(Co+Io+Xo)/h-((1-(b-m)*(1-t))/h)*Y
#
#                                    LM=
#                                    r=-(1/j)*(Ms/P)+(k/j)*Y
#
# Debemos encontrar "Y" para reemplazarlo en las ecuaciones, por lo que iniciaremos a derivar de la siguiente manera:
#
# A manera de simplificación y para despejar la "r" , hacemos la siguiente ecuación igualando:
#
#                                    r=(Co+Io+Xo)/h-((1-(b-m)*(1-t))/h)*Y
#
# Factorizamos Y:
# *Ecuación de equilibrio*
#
#                                    Ye=(j*(Co+Io+Go+Xo)/(h*k+j*(1-(b-m)
#
# Factorizamos "Y"
#
#                                    re=(k*(Co+Io+Go+Xo)/(h*k+j*(1-(b-m)

# %% [markdown]
#     -Grafique el equilibrio simultáneo en los mercados de bienes y de dinero.

# %% [markdown]
# Graficamos nuestro equilibrio

# %%
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.4
m = 0.5
t = 0.8

Y = np.arange(Y_size)


 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo)/h - ( ( 1-(b-m)*(1-t) ) / h)*Y  
    return r_IS

r_is = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)




Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 20               

Y = np.arange(Y_size)



def r_LM(k, j, Ms, P, Y):
    r_LM = - (1/j)*(Ms/P) + (k/j)*Y
    return r_LM

r_lm = r_LM( k, j, Ms, P, Y)


y_max = np.max(r_lm)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r_is, label = "IS", color = "#5598ED") #IS

ax.plot(Y, r_lm, label="LM", color = "#66CDAA")  #LM


ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())


plt.axvline(x=51.5,  ymin= 0, ymax= 0.52, linestyle = ":", color = "green")
plt.axhline(y=93, xmin= 0, xmax= 0.52, linestyle = ":", color = "green")


plt.text(49,100, '$E_0$', fontsize = 14, color = 'red')
plt.text(0,100, '$r_0$', fontsize = 12, color = 'red')
plt.text(53,-10, '$Y_0$', fontsize = 12, color = 'red')


plt.text(100,20, '$LM$', fontsize = 15, color = 'red')
plt.text(100,190, '$IS$', fontsize = 15, color = 'red')
plt.text(80,100, '$II$', fontsize = 20, color = 'red')
plt.text(15,100, '$IV$', fontsize = 20, color = 'red')
plt.text(48,145, '$I$', fontsize = 20, color = 'red')
plt.text(48,45, '$III$', fontsize = 20, color = 'red')

ax.set(title="IS-LM Model", xlabel= r'Y', ylabel= r'r')
ax.legend()

plt.show()

# %% [markdown]
# 2. Estadistica comparativa

# %% [markdown]
#     -Analice los efectos sobre las variables endógenas Y, r de una disminución del gasto fiscal. . El análisis debe ser intuitivo, matemático y gráfico.

# %% [markdown]
# Nuestro análisis intuitivo parte de:
#
# -Mercado de Bienes
#
#                 Go↓ →DA<Y→Y↓
#
# Mercado de Dinero
#
#                 Y↓ →Md↓Md<Ms→r↓
#  Vemos como ambas variables endógenas se reducen

# %% [markdown]
# El análisis matemático parte de

# %%
# nombrar variables como símbolos
Co, Io, Go, Xo, h, r, b, m, t, beta_0, beta_1  = symbols ('Co Io Go Xo h r b m t beta_0, beta_1')

# nombrar variables como símbolos
k, j, Ms, P, Y = symbols('k j Ms P Y')

# Beta_0 y beta_1
beta_0 = (Co + Io - Go + Xo)
beta_1 = ( 1-(b-m)*(1-t) )

# Producto de equilibrio y la tasa de interes de equilibrio en el modelo IS-LM
Y_eq = (k*beta_0)/(k*h + j*beta_1) - ( beta_1 / (k*h + j*beta_1) )*(Ms/P)
r_eq = (j*beta_0)/(k*h + j*beta_1) + ( h / (k*h + j*beta_1) )*(Ms/P)

# %%
df_Y_eq_Go = diff(Y_eq, Go)
print("El Diferencial del Producto con respecto al diferencial del gasto autonomo = ", df_Y_eq_Go)
# Out:
# El Diferencial del Producto con respecto al diferencial del gasto autonomo =  -k/(h*k + j*(-(1 - t)*(b - m) + 1))

# %% [markdown]
# ES POSITVA

# %%
df_r_eq_Go = diff(r_eq, Go)
print("El Diferencial de la tasa de interes con respecto al diferencial del gasto autonomo = ", df_r_eq_Go)  o
# Out:
# El Diferencial de la tasa de interes con respecto al diferencial del gasto autonomo =  -j/(h*k + j*(-(1 - t)*(b - m) + 1))

# %% [markdown]
# ES POSITIVA

# %% [markdown]
# Ahora graficamos

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.4
m = 0.5
t = 0.8

Y = np.arange(Y_size)


 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)



Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 20               

Y = np.arange(Y_size)


def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

# %%
# Deffinimos un nuevo gasto de gobierno
Go = 20

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_G = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(i)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "IS_(G_0)", color = "blue") #IS_orginal
ax.plot(Y, r_G, label = "IS_(G_1)", color = "green", linestyle = 'dashed') #IS_modificada

ax.plot(Y, i, label="LM", color = "C0")  #LM_original

# Texto y figuras agregadas
plt.axvline(x=52,  ymin= 0, ymax= 0.55, linestyle = ":", color = "green")
plt.axhline(y=95, xmin= 0, xmax= 0.53, linestyle = ":", color = "green")

plt.axvline(x=39,  ymin= 0, ymax= 0.42, linestyle = ":", color = "green")
plt.axhline(y=68, xmin= 0, xmax= 0.40, linestyle = ":", color = "green")

plt.text(49,100, '$E_0$', fontsize = 14, color = 'red')
plt.text(-1,100, '$r_0$', fontsize = 12, color = 'red')
plt.text(53,-40, '$Y_0$', fontsize = 12, color = 'red')
plt.text(40,49, '$E_1$', fontsize = 14, color = 'skyblue')

plt.text(40,-40, '$Y_1$', fontsize = 12, color = '#008B8B')



ax.set(title="Politica Fiscal Contractiva", xlabel= r'Y', ylabel= r'r')
ax.legend()

plt.show()

# %% [markdown]
#     -Analice los efectos sobre las variables endógenas Y, r de una disminución de la masa monetaria. . El análisis debe ser intuitivo, matemático y gráfico.

# %% [markdown]
# Como análisis intuititivo parte de
#
# Dentro del Mercado de dinero:
#
#                     Mso↓ →Ms>Md→r↑
#
# Dentro del Mercado de bienes afecta pues nuestro interés aumentó
#
#                    r↑= I↓ = DA↓ → DA<Y = Y↓  → DA=Y
#
# Debemos dismunir Y para poder encontrar un equilibrio

# %% [markdown]
# El análisis matemático sería de la siguiente manera

# %%
Co, Io, Go, Xo, h, r, b, m, t, beta_0, beta_1  = symbols('Co Io Go Xo h r b m t beta_0, beta_1')

k, j, Ms, P, Y = symbols('k j Ms P Y')

beta_0 = (Co + Io + Go + Xo)
beta_1 = ( 1-(b-m)*(1-t) )


Y_eq = (k*beta_0)/(k*h + j*beta_1) - ( beta_1 / (k*h + j*beta_1) )*(Ms/P)
r_eq = (j*beta_0)/(k*h + j*beta_1) + ( h / (k*h + j*beta_1) )*(Ms/P)

# %%
df_Y_eq_Ms = diff(Y_eq, Ms)
print("El Diferencial del Producto con respecto al diferencial de la masa monetaria = ", df_Y_eq_Ms)
# Out:
# El Diferencial del Producto con respecto al diferencial del gasto autonomo =  -(-(1 - t)*(b - m) + 1)/(P*(h*k + j*(-(1 - t)*(b - m) + 1)))

# %% [markdown]
# ES POSITIVO

# %%
df_r_eq_Ms = diff(r_eq, Ms)
print("El Diferencial de la tasa de interes con respecto al diferencial de la masa monetaria = ", df_r_eq_Ms)
# Out:
# El Diferencial de la tasa de interes con respecto al diferencial del gasto autonomo =  h/(P*(h*k + j*(-(1 - t)*(b - m) + 1)))

# %% [markdown]
# ES NEGATIVO

# %%
Graficamos

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.5
m = 0.4
t = 0.8

Y = np.arange(Y_size)



def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)



# Curva LM ORIGINAL


Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 20               

Y = np.arange(Y_size)



def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

# %%
#Nueva curva de disminusión de la Masa Monetaria

Ms = 50

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_ejer = i_LM( k, j, Ms, P, Y)

# %%
y_max = np.max(i)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label="IS", color = "orange")  #LM_original

ax.plot(Y, i, label = "LM_(G_0)", color = "#E9967A") #IS_orginal
ax.plot(Y, i_ejer, label = "LM_(G_1)", color = "#CD5C5C") #IS_modificada

# Texto y figuras agregadas
plt.axvline(x=50,  ymin= 0, ymax= 0.53, linestyle = ":", color = "grey")
plt.axhline(y=98, xmin= 0, xmax= 0.51, linestyle = ":", color = "grey")

plt.axvline(x=52.5,  ymin= 0, ymax= 0.50, linestyle = ":", color = "grey")
plt.axhline(y=95, xmin= 0, xmax= 0.53, linestyle = ":", color = "grey")


plt.text(49,103, '$E_0$', fontsize = 14, color = 'red')
plt.text(-1,100, '$r_0$', fontsize = 12, color = 'red')
plt.text(47,-40, '$Y_0$', fontsize = 12, color = 'red')
plt.text(53,60, '$E_1$', fontsize = 14, color = '#008B8B')
#plt.text(-1,72, '$r_1$', fontsize = 12, color = '#008B8B')
plt.text(53,-40, '$Y_1$', fontsize = 12, color = '#008B8B')


ax.set(title="Politica monetaria contractiva de la masa monetaria", xlabel= r'Y', ylabel= r'r')
ax.legend()

plt.show()

# %% [markdown]
#     -Analice los efectos sobre las variables endógenas Y, r de un incremento de la tasa de impuestos. . El análisis debe ser intuitivo, matemático y gráfico.

# %% [markdown]
# Como el análisis intuitivo para una política fiscal de incremento de tasa de impueso:
#
# -Mercado de bienes
#
#        t↑ = Co↓ = DA↓ → DA<Y = Y↓  → DA=Y
#
# -Mercado de dinero:
#
#             Y↓ →Md↓Md<Ms→r↓
#
# Vemos que nuestras ambas variables endógenas se reducen

# %% [markdown]
# Ahora matemáticamente vemos que

# %%
Co, Io, Go, Xo, h, r, b, m, t, beta_0, beta_1  = symbols('Co Io Go Xo h r b m t beta_0, beta_1')

k, j, Ms, P, Y = symbols('k j Ms P Y')

beta_0 = (Co + Io + Go + Xo)
beta_1 = ( 1-(b-m)*(1-t) )


Y_eq = (k*beta_0)/(k*h + j*beta_1) - ( beta_1 / (k*h + j*beta_1) )*(Ms/P)
r_eq = (j*beta_0)/(k*h + j*beta_1) + ( h / (k*h + j*beta_1) )*(Ms/P)

# %%
df_Y_eq_t = diff(Y_eq, t)
print("El Diferencial del Producto con respecto incremento de la tasa de impuestos = ", df_Y_eq_t)
# Out:
# El Diferencial del Producto con respecto incremento de la tasa de impuestos =  Ms*j*(b - m)*(-(1 - t)*(b - m) + 1)/(P*(h*k + j*(-(1 - t)*(b - m) + 1))**2) - Ms*(b - m)/(P*(h*k + j*(-(1 - t)*(b - m) + 1))) - j*k*(b - m)*(Co + Go + Io + Xo)/(h*k + j*(-(1 - t)*(b - m) + 1))**2

# %%
Es negativo

# %%
df_r_eq_t = diff(r_eq, t)
print("El Diferencial de la tasa de interes con respecto al diferencial de la masa monetaria = ", df_r_eq_t)
# Out:
# El Diferencial de la tasa de interes con respecto al diferencial de la masa monetaria =  -Ms*h*j*(b - m)/(P*(h*k + j*(-(1 - t)*(b - m) + 1))**2) - j**2*(b - m)*(Co + Go + Io + Xo)/(h*k + j*(-(1 - t)*(b - m) + 1))**2

# %% [markdown]
# Es 'positivo

# %% [markdown]
# Graficamos

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.5
m = 0.4
t = 0.8

Y = np.arange(Y_size)



def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


# Curva LM ORIGINAL

Y_size = 100
k = 2
j = 1                
Ms = 200             
P  = 20               

Y = np.arange(Y_size)



def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

# %%
#Aumento a la tasa de impuesto
t = 1.90

# Generar la ecuación con el nuevo parámetro
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_TR = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(i)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "IS_(G_0)", color = "#7D3C98") 
ax.plot(Y, r_TR, label = "IS_(G_1)", color = "#C491E5", linestyle = 'dashed') 

ax.plot(Y, i, label="LM", color = "#EE3B87")  

plt.axvline(x=52.5,  ymin= 0, ymax= 0.53, linestyle = ":", color = "grey")
plt.axhline(y=95, xmin= 0, xmax= 0.53, linestyle = ":", color = "grey")

plt.axvline(x=50,  ymin= 0, ymax= 0.5, linestyle = ":", color = "grey")
plt.axhline(y=90, xmin= 0, xmax= 0.52, linestyle = ":", color = "grey")


plt.text(49,100, '$E_0$', fontsize = 14, color = 'red')
plt.text(-1,100, '$r_0$', fontsize = 12, color = 'red')
plt.text(53,-40, '$Y_0$', fontsize = 12, color = 'red')
plt.text(45,90, '$E_1$', fontsize = 14, color = '#008B8B')
plt.text(47,-40, '$Y_1$', fontsize = 12, color = '#008B8B')


ax.set(title="Politica Fiscal Contractiva de la tasa de impuesto", xlabel= r'Y', ylabel= r'r')
ax.legend()

plt.show()
