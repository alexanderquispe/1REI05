# %% [markdown]
# ### Reporte:
#
# El artículo realizado por Alexander M. Bell, Raj Chetty, Xavier Jaravel, Neviana Petkova y John Van Reenen se enfoca en hallar los factores que determinan quién se convierte en inventor en Estados Unidos, a partir del rol de la capacidad inventiva (naturaleza) frente al entorno (crianza). Lo cual, se comprobó a través de datos no identificados de 1,2 millones de inventores procedentes de registros de patentes vinculados a registros fiscales. De este modo, la pregunta del artículo, finalmente, sería ¿Cuáles son las variables que explican quien se convierte en un inventor en Estados Unidos? Al analizar los factores que determinan quién se convierte en inventor, este trabajo de investigación identifica nuevos enfoques para aumentar las tasas de innovación, especialmente entre los subgrupos que actualmente están subrepresentados en el sector de la innovación
#
# Es notorio que el presente artículo posee abundantes fortalezas, en este párrafo presentaremos solo un par. Una de las principales fortalezas es que dicho estudio contribuye a la literatura relacionada con los determinantes del espíritu empresarial que analiza el papel de la capacidad y los efectos de los compañeros. Este análisis complementa tales estudio, en el sentido que: identifica diferentes factores que afectan a la elección de carrera como el efecto causal de la exposición en la infancia, además, presenta datos exhaustivos y estadísticas disponibles públicamente sobre el origen y la carrera de los inventores en Estados Unidos. Otra de las fortalezas es que este estudio investigativo contribuye a la incipiente literatura sobre los orígenes de los inventores que específicamente sobre la "oferta" de innovación,como ejemplo mencionado en este artículo se encontraría, el estudio de Aghion (2017) sobre los inventores en Finlandia que documenta brechas en la innovación según el origen de los padres que coinciden con los resultados de este estudio y caracteriza el poder predictivo de otros factores, como el coeficiente intelectual y la educación de los padres, que no se observan en los datos del documento de Bell, Raj Chetty, Jaravel, Petkova y Van Reenen. En contraste, las debilidades que se han podido percibir del artículo, a pesar de ser un artículo con pocos indicios de poseer debilidades es la limitación de considerar como única base datos a la cifra de inventores obtenidas de la data de patentes de Estados Unidos, puesto que existen inventores no inscritos en patentes, para entender ello, se meniconara el caso de Douglas Engelbart quien cuando se le ocurrió que se debía poder operar el interior de una computadora desde afuera, inventó el mouse que durante décadas acompañó a todas las computadoras y empezó a estar en manos de todos, por lo cual obtener una patente fue imposible, a pesar de haber sido él quien inventó tal producto.
#
# Asimismo, es importante recalcar que la contribución de los autores en este texto es su aporte de preocupación por escribir y centrarse en el tema de innovación, el cual, es relevante desde nuestro punto de vista como personas interesadas en la economía debido a que los inventos forman parte importante de la economía puesto que aumentar la movilidad intergeneracional también pueden ser beneficiosas para aumentar el crecimiento económico. En otras palabras, atraer a un mayor número de niños de bajos ingresos y de minorías a la ciencia y la innovación podría aumentar los ingresos y estimular el crecimiento aprovechando el talento actualmente infrautilizado, reduciendo de esta manera la persistencia de la desigualdad a través de las generaciones.
#
# Una forma de avanzar en la pregunta de investigación, entonces, sería investigaciones acerca dentro del campo específico nacional, además resulta relevante estudiar el tema centrándose en la mujer peruana, la cual siempre ha tenido dificultades de sobresalir en una sociedad machista y opresora como el Perú. Para ello, es útil como la autora Sofía Miñano Suárez muestra la realidad peruana en temas de la relación entre las patentes y la mujer peruana, cuyo talento e ingenio como impulsora de cambio no siempre fue debidamente reconocido. Este texto titulado “La mujer peruana y las patentes: Inventando el futuro” intenta fomentar que las niñas que deseen elegir el camino de las ciencias lo hagan sin dejarse influenciar por factores aún arraigados en nuestra sociedad, muchas veces machista y que en un futuro puedan acceder y crecer profesionalmente de manera equitativa en cualquier campo tecnológico sin disparidades debido a su género.
#
# Bibliografía: Miñano, S. (2019). La mujer peruana y las patentes: Inventando el futuro. Lima (Perú): Repositorio Indecopi.

# %% [markdown]
# -Explique de manera muy breve y resumida en qué consiste una regresión discontinua.
# El método de regresión discontinua es un método cuasiexperimental utilizado para identificar efectos causales de algún tratamiento. Este método se basa en cortes que surgen por ley o por diseño y que implican una discontinuidad en la implementación del tratamiento, mismo que viene definido a lo largo de alguna variable, G (normalmente llamada la variable definitoria. Este método hará posible determinar la relación causal de cambios en el estatus de tratamiento sobre alguna otra variable (la variable dependiente).
#
# -Detalle un ejemplo en la vida real en donde podría emplear una regresión discontinua.
# Un ejemplo en la vida real en donde podría emplear una regresión discontinua serían las votaciones por mayoría, donde hay dos contrincantes en una elección, si se usa la regla de mayoría se obtendrá que un candidato gana si obtiene mas del 50% de las votaciones. En el caso que nos centremos en analizar si los gobiernos de izquierda hacen una diferencia en la política fiscal o económica. Tendría que, el partido de izquierda recibir más del 50% votos para ganar la elección y si recibe menos, por consiguiente, pierde. Entonces, se debería llevar a cabo una estimación de MCO donde la variable dependiente es la tasa impositiva y la variable de interés es que el gobierno de izquierda haya ganado muy probablemente desembocará en un sesgo por variable omitida ( qué tan liberal, el electorado puede llevar a un sesgo). El método de regresión discontinua compara situaciones en las cuales el gobierno de izquierda apenas gana con situaciones donde apenas pierde. En este caso se puede argumentar que justo en la discontinuidad pasamos de una situación en la que el partido de izquierda pierde a una en la que gana. No obstante, en ambos casos el electorado debe ser similarmente liberal (de igual manera no debe haber un brinco abrupto en cualquier otra variable que provoque sesgo).
#
# -Explique el diseño Sharp Desing y comente un ejemplo en la vida real en donde podría aplicarlo (sea lo más detallado posible). Este tipo de discontinuidad se refiere al caso en el cual la probabilidad de formar parte del grupo de tratamiento pasa de 0 a 1 después del corte que determina la discontinuidad. Ejemplos de este tipo de cortes incluye, márgenes por los cuales se pierde una elección y cortes administrativos que definen diferencias en precio (como ejemplo: adulto mayor de 65 años). En la Regresión Discontinua Sharp, la estimación se simplifica pues la variable de tratamiento toma los siguientes valores y reduciendo la expresión a que el impacto es solo la comparación entre los resultados promedio de los individuos de la derecha y de la izquierda del punto de corte.

# %% [markdown]
# **APLICACIONES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns, warnings
import statsmodels.formula.api as smf
warnings.filterwarnings('ignore')
from causalgraphicalmodels import CausalGraphicalModel
from cProfile import label
# %matplotlib inline

# %% [markdown]
# Código elaborado con Luis Alberto Pacheco Concha

# %% [markdown]
# - Siguiendo todo el apartado Simulated Data, trabaje con la siguiente ecuación, según sea su caso, y replique los resultados correspondientes, incluidos los gráficos respectivos.

# %% [markdown]
#         -Ejemplo 1:
# $$Y = 15 + 22D + 2.5X + \epsilon$$

# %%
## Random data
dat = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
dat.loc[dat.x<0, 'x'] = 0
dat = dat[dat.x<100]
dat['D'] = 0
# Cutoff
dat.loc[dat.x>50, 'D'] = 1
# Simulated Y
dat['y'] = 15 + 22*dat.D + 2.5 * dat.x + np.random.normal(0, 20, dat.shape[0])
# Not Treatment
dat_0 = dat[dat.D == 0]
# Treatment
dat_1 = dat[dat.D == 1]

# %%
# Colors 
treat_c = "#568A9B" # Treatment
n_treat = "#A10728" # Not treatment
# Plot
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %% [markdown]
# Ahora estimamos un modelo para cada lado, en este caso el modelo que mejor se ajustaría sería el modelo lineal, para ello generamos una función para incluir las predicciones en la base de datos.

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

data_y0 = y_hat_lin(dat_0)
data_y1 = y_hat_lin(dat_1)

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3);

# %%
eff = min(data_y1.yhat) - max(data_y0.yhat)
eff = round(eff,  2)
print("Effect:", f"{eff}")
# Out:
# Effect: 21.41

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff}", xy = (51, eff + 76))
plt.annotate("", xy = (51, max(data_y0.yhat)), xytext = (51, min(data_y1.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));

# %% [markdown]
#         -Ejemplo 2:
# $$Y = 12 + 60D + 1.3X + \epsilon$$

# %%
## Random data
dat = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
dat.loc[dat.x<0, 'x'] = 0
dat = dat[dat.x<100]
dat['D'] = 0
# Cutoff
dat.loc[dat.x>50, 'D'] = 1
# Simulated Y
dat['y'] = 12 + 60*dat.D + 1.3 * dat.x + np.random.normal(0, 20, dat.shape[0])
# Not Treatment
dat_0 = dat[dat.D == 0]
# Treatment
dat_1 = dat[dat.D == 1]

# %%
# Colors 
treat_c = "#568A9B" # Treatment
n_treat = "#A10728" # Not treatment
# Plot
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

data_y0 = y_hat_lin(dat_0)
data_y1 = y_hat_lin(dat_1)

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3);

# %%
eff = min(data_y1.yhat) - max(data_y0.yhat)
eff = round(eff,  2)
print("Effect:", f"{eff}")
# Out:
# Effect: 58.05

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff}", xy = (51, eff + 76))
plt.annotate("", xy = (51, max(data_y0.yhat)), xytext = (51, min(data_y1.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));
