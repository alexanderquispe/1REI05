# %% [markdown]
# # EXAMEN FINAL

# %% [markdown]
# ### Nombre: Greysi Milagros Arrelucea Castañeda (20200279)

# %% [markdown]
# ## Teoría (10 puntos)

# %% [markdown]
# ### 1. (3 puntos) Instrumental Variables (IV)
#
# Suponga que estamos interesados en estudiar la relación entre educación(X) y el nivel de ingresos(Y).
# Un investigador propone utilizar como variable instrumental(Z) el numero de horas que una persona utilizó para ver televisión cuando era niño.
#
# #### - Indetifique todos los elementos necesarios para implementar un enfoque de IV en este ejemplo.
#
# La utilización de una variable instrumental me permite estimar el efecto de una variable de interés, en este caso “educación”, sobre una variable dependiente, en este caso “nivel de ingresos” a partir de un instrumento, “número de horas que una persona utilizó para ver televisión cuando era niño”, que juegue el rol de esa variable de interés sin tener el problema de endogeneidad. No obstante, para hallar la validez de este instrumento, primero es necesario identificar si cumple con los supuestos de relevancia y validez:
#
# A. La relevancia: La relevancia nos permite ver los supuestos de identificación y uso de variables instrumentales de manera más certera, para así saber que 'Z' (instrumento) se relaciona realmente con 'X' ( tratamiento). De modo que, se busca que la variable instrumental Z si funcione y se evite la endogeneidad(D):la variable independiente se correlaciona con el de error en una regresión. La relevancia evalúa la relación entre parte de la variable independiente'X' y la variable instrumental 'Z' y ve cuán fuerte es, es decir, si la variable 'Z' logra explicar en parte o totalmente la variable independiente X. Cuanto más fuerte sea esta relación, más confianza habrá en  el supuesto de relevancia y menos saltará la estimación de una muestra a otra. En este caso, para que mi instrumento ‘Z’ “número de horas que una persona utilizó para ver televisión cuando era niño” sea relevante, debe estar relacionado con mi variable independiente ‘X’ “educación”; mientras mayor sea la covariación entre Z con X, más confianza se puede tener en el concepto de relevancia.
#
# B. La validez: El supuesto de validez implica que cualquier ruta entre el instrumento Z y el resultado Y (variable dependiente) debe pasar con anterioridad por la variable independiente o el tratamiento X o en todo caso cerrarse para que la suposición sea válida. La validez es también llamada una “restricción de exclusión” porque supone que el instrumento Z puede ser excluido razonablemente del modelo de Y luego de que la ruta  Z → X sea incluida. Por ejemplo, para que el supuesto de validez se cumpla para la variable instrumental Z, se necesita cerrar tanto la ruta Z ← B →Y como la ruta Z → A → Y. Entonces, si se puede controlar las variables A y B, entonces el supuesto se cumple. En este caso particular, se debe comprobar que el instrumento ‘Z’ “número de horas que una persona utilizó para ver televisión cuando era niño” sea una variable que no tenga backdoors abiertas, de manera que cualquier ruta entre el instrumento y el resultado debe pasar por el tratamiento o sino cerrarse. Es decir, que el instrumento se encargue de cerrar todas las puertas abiertas de modo que se pueda obtener una verdadera relación de causalidad entre X y Y.
#
# En este sentido, si mi instrumento “número de horas que una persona utilizó para ver televisión cuando era niño” satisface estos dos supuestos, entonces es válido. Por ende, podré implementar un enfoque de IV para mi análisis.
#
# Al mismo tiempo, se debe tomar en cuenta que un enfoque de IV es empleado en casos donde se evidencia un problema de sesgo o donde no se puede identificar limpiamente el efecto de una variable causal sobre otra. Así, cuando no se puede aplicar un método de aleatoridad completo que elimine los sesgos y, en cambio, se tenga por ejemplo “experimentos aleatorios controlados” el uso de variables instrumentales permitirá eliminar los sesgos por medio de estadísticas y entornos oportunos, limpiando la relación para comprar que efectivamente hay causalidad.
#
#
# #### - Explique el procedimiento para encontrar el efecto causal en este escenario. Puede utilizar ecuaciones
#
#
#
#
# #### - ¿El efecto de la educación sobre el nivel de ingresos es positivo o negativo? Argumente si los resultados serian causales o solamente de correlación
#
# Muy probablemente, al correr una regresión, el efecto de la educación sobre el nivel de ingresos sea positivo, es decir, a mayor educación mayor nivel de ingresos. En efecto, existen muchos estudios que han comprobado esta hipótesis. En este caso, los resultados de correr una regresión, habiendo tomado en cuenta mi variable instrumental “número de horas que una persona utilizó para ver televisión cuando era niño” y habiendo verificado que efectivamente mi variable es válida porque cumple con los supuestos de relevancia y validez, entonces los resultados de la regresión mostrarán relaciones causales y no solamente de correlación. Esto debido a que la utilización de una variable instrumental se emplea en casos donde hay un problema de sesgo o no es posible identificar limpiamente el efecto de una variable causal sobre otra. Así, su uso posibilita estimar el efecto de una variable independiente sobre una dependiente, evitando que esta relación tenga problemas de endogeneidad (que se haya omitido una variable que esté correlacionada con las otras). Por ende, sus resultados mostrarán relaciones causales, limpias y creíbles.

# %% [markdown]
# ### 2. (3 puntos) Regression Discontinuity Design (RDD)
# Supongamos que estamos estudiando la eficacia de un programa de becas creado por el gobierno Peruano sobre las notas de los alumnos al final del primer semestre en la universidad. PRONABEC ha decidido que entregará becas a aquellos postulantes que tengan un promedio superior durante la secundaria igual a 16 .
#
#
# #### - Indetifique todos los elementos necesarios para implementar un RDD en este ejemplo.
#
# #### - Explique el procedimiento para encontrar el efecto causal en este escenario. Puede utilizar ecuaciones.
#
# #### - ¿El efecto de la politica sobre el rendimiento de los estudiantes sería positivo o negativo (solo necesitan usar su intuición)? Argumente si los resultados serian causales o solamente de correlación .
#
#
# #### - Puede concluir que al correr una regresión los resultados muestran relaciones causales o solamente de correlación?

# %% [markdown]
# ### 3. (3 puntos) Difference in Difference (DiD)
# Supongamos que estamos interesados en estudiar el impacto de la migración en la tasa de empleo en dos regiones del Perú en 2017-2018. Tenemos datos anuales sobre la tasa de empleo en Lima, que experimentó una afluencia significativa de inmigrantes en 2018, y Puno que no experimentó el ingreso de migrantes (2017 ninguna de las regiones experimentó afluencia de migrantes). Podemos usar un análisis DID para comparar el cambio en las tasas de empleo entre las dos regiones a lo largo del tiempo para ver si la migración tuvo algún efecto.
#
# #### - Indetifique todos los elementos necesarios para implementar un DiD en este ejemplo.
# Para poder implementar el método de diferencias en diferencias, primero es necesario qu se cumpla con el supuesto de tendencias paralelas. Este supuesto se basa en la búsqueda de un grupo de control cuya tendencia sea paralela a la tendencia del resultado del grupo del tratamiento, para así corroborar que el tratamiento no sea endógeno. Por el contrario, si fuera endógeno, este supuesto no se cumpliría, porque ante la incidencia de un contrafactual el grupo de tratamiento habría variado de todos modos, independientemente del tratamiento. Por ende, para implementar un DiD se necesita exogeneidad, la cual es comprobada por medio del supuesto de tendencias paralelas. A la vez, se debe resaltar que este método solo puede ser aplicado tomándose en cuenta al componente temporal. Así, por medio del DiD se observa a las personas que conforman una muestra a lo largo del tiempo, sin tener que establecer un grupo de control y de tratamiento predeterminado desde el inicio. En este caso, se cuenta con una base de datos con la tasa de desempleo a lo largo del periodo 2017-1018, de modo que el comprobamiento del supuesto más la disponibilidad de esta data permitirá aplicar el análisis DID en la investigación.
#
#
#
# #### - Explique el procedimiento para encontrar el efecto causal en este escenario. Puede utilizar ecuaciones.
# El método de diferencias en diferencias es considero como una estrategia de identificación cuasi-experimental temprana para estimar los efectos causales que preceden a un experimento aleatorio en un determinado periodo de tiempo. Para ello, lo que hace es que compara los cambios en el tiempo en la variable de interés cuando no es posible aleatorizar. Precisamente, por este motivo, el DiD trabaja con contrafactuales, es decir, casos con los cuales se pueda contrastar. Así, en este escenario en particular, se busca comparar el impacto de la migración sobre la tasa de empleo tanto en Lima, que recibió una gran cantidad de migrantes entre 2017-2018, como en Puno, región que no experimentó el ingreso de migrantes en tal periodo de tiempo. Para esto, se evaluará el efecto del tratamiento en el grupo de control antes y después del arribo de migrantes, e igualmente con el grupo de tratamiento, esto permitirá observar los cambios en el tiempo en la variable de interés entre el grupo de tratamiento y el grupo de control, trabajándose en el proceso con contrafactuales, pues como se sabe Puno no experimentó el arribo de migrantes. Sin embargo, por medio de este hecho contrafactual, el método de diferencias de diferecnias podrá observar si el impacto de la migración en el empleo observado en Lima también se habría generado en Puno, en caso esta región también hubiera recibido migrantes, y así determinar si hay una relación de causalidad entre la llegada de migrantes y la tasa de desempleo.
#
#
# #### - ¿El efecto de la migración sobre la tasa de empleo sería positivo o negativo (solo necesitan usar su intuición)? Argumente si los resultados serian causales o solamente de correlación.
# Aunque el efecto de la migración puede ser tanto positivo como negativo, diversos estudios han enfatizado que una migración masiva reduce las tasas de empleo para los nacionales, de modo que su impacto termina siendo negativo. En efecto, de manera intuitiva es posible analizar que la llegada de más migrantes demandantes de plazas laborales, en un torno que permanece con la misma cantidad de oferta de plazas laborales, convergerá en que estas plazas escaseen y perjudiquen a los ciudadanos en cuestiones de empleo. Cabe destacar que los resultados de este ejemplo sí serían causales y no solamente de correlación, dado que precisamente el método de DiD permite subsanar los sesgos que pueden ocasionarse en caso no se pueda aplicar el método de la aletoriedad. Como la investigación cuenta con datos anuales de la tasa de empleo antes y después de la intervención, el DiD podrá ser aplicado y permitirá estimar efectos causales limpios entre el impacto de los migrantes y la tasa de desempleo.

# %% [markdown]
# ### 4. (3 puntos) Lecturas
#
# #### - Bell, A., Chetty, R., Jaravel, X., Petkova, N., & Van Reenen, J. (2019). Who becomes an inventor in America? The importance of exposure to innovation. The Quarterly Journal of Economics, 134(2), 647-713., ¿Cuáles son las debilidades del enfoque del paper para responder su pregunta de investigación?
# Este paper analiza los factores que determinan que alguien se convierta en un innovador en EE.UU., así como los tipos de innovaciones que estos podrías perseguir. De este modo, responde a la pregunta de investigación: ¿Cúales son los factores que explican quien se convierte o no en un inventor EE.UU. y qué tipos de innvovaciones perseguirá? A partir de la revisión del artículo, una debilidad a destacar es que sus resultados se centran en la ciudad de Nueva York, en EE.UU, por lo que no podrían ser aplicados a otras zonas del mundo, como la región Lationamericana, cuyas características difieren del caso estadounidense y po lo tanto hay una posibilidad de que el estudio tenga otros resultados al ser aplicado en tal región. Asimismo, considero que otra debilidad es que el paper solo toma en cuenta los factores de nacimiento como las variables que explican si los niños se llegarán a convertir en innovadores o no, de tal forma se ignoran otros factores que pudieron afectar durante la adolescencia o la adultez de los niños que pudieron afectar en que sean innovadores, como el acceso a una beca, a programas del gobierno, una mudanza, etc. Así, el abordamiento de estas limitaciones prmitiría la mejora del estudio incluso en una mayor medida.
#
#
#
#
# #### - Dell, M. (2010). The persistent effects of Peru's mining mita. Econometrica, 78(6), 1863-1903, ¿Cuáles serían dos próximos pasos específicos para avanzar en su pregunta de investigación?
# En este artículo se analizan los impactos a largo plazo de la mita minera colonial en el desarrollo económico de ciertas regiones del Perú. Para ello, se plantea la siguiente pregunta de investigación: ¿Cuáles son los impactos a largo plazo de la mita minera sobre el desarrollo económico contemporáneo de los distritos peruanos que estuvieron sometidos a ella? Es así que concluye que la mita ha influido en el desarrollo económico contemporáneo mediante tres canales principales de persistencia: la tenencia de la tierra, los bienes públicos y la participación en el mercado.
#
# En este sentido, un primer paso para avanzar en esta pregunta es generar más modelos generales de evolución institucional basados en investigaciones de carácter empírico que muestren la forma en que pueden cambiar a partir de fuerzas externas. Asimismo, según Vargas y Gonzáles (2018), otro paso importante es la identificación de aquellas características compartidas por las instituciones históricas que influencian en el desarrollo económico actual, permitiendo distinguirlas de otras entidades que no logran tener una mayor repercusión. Un último paso, tomando en cuenta que la investigación no pudo abordar a detalle el caso de Bolivia donde también se aplicó la mita, sería profundizar en su influencia en las comunidades bolivianas e, incluso, en otras regiones latinoamericanas que estuvieron bajo esta institución, de modo que se pueda evaluar si efectivamente los impactos de la mita son similares o contrastantes con los encontrados en el Perú.

# %% [markdown]
# ## 5. (4 puntos) Código

# %%
from causalgraphicalmodels import CausalGraphicalModel
import matplotlib.pyplot as plt
import os
import numpy as np 
import pandas as pd 
import statsmodels.api as sm 
import statsmodels.formula.api as smf 
from itertools import combinations 
import plotnine as p
import statsmodels.api as sm
import statsmodels.formula.api as smf
import linearmodels.iv.model as lm
from linearmodels.iv import IV2SLS
from statsmodels.iolib.summary2 import summary_col
import seaborn as sns

# %% [markdown]
# ### Ploteo de Histogramas

# %% [markdown]
# Tienen que trabajar con la misma data de educacion que utilicé en la clase_11. En este documento encontrarán una descripción detallada de todas las variables en el dataset.Además se debe tomar en cuenta que la variable nearc2 representa si existe un college en el county para realizar los siguientes ploteos de histogramas.

# %%
# CARGAR DATA 
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

def read_data(file): 
    return pd.read_stata("https://raw.github.com/scunning1975/mixtape/master/" + file)

card = read_data("card.dta")
card.head(20)
# Out:
#       id  nearc2  nearc4  educ   age  fatheduc  motheduc    weight  momdad14  \
# 0    2.0     0.0     0.0   7.0  29.0       NaN       NaN  158413.0       1.0
# 1    3.0     0.0     0.0  12.0  27.0       8.0       8.0  380166.0       1.0
# 2    4.0     0.0     0.0  12.0  34.0      14.0      12.0  367470.0       1.0
# 3    5.0     1.0     1.0  11.0  27.0      11.0      12.0  380166.0       1.0
# 4    6.0     1.0     1.0  12.0  34.0       8.0       7.0  367470.0       1.0
# 5    7.0     1.0     1.0  12.0  26.0       9.0      12.0  380166.0       1.0
# 6    8.0     1.0     1.0  18.0  33.0      14.0      14.0  367470.0       1.0
# 7    9.0     1.0     1.0  14.0  29.0      14.0      14.0  496635.0       1.0
# 8   10.0     1.0     1.0  12.0  28.0      12.0      12.0  367772.0       1.0
# 9   11.0     1.0     1.0  12.0  29.0      12.0      12.0  480445.0       1.0
# 10  12.0     1.0     1.0   9.0  28.0      11.0      12.0  380166.0       1.0
# ...

# %% [markdown]
# #### 5.1) Grafique dos histogramas para la variable años de educación "educ" para cuando nearc2 == 1, y cuando nearc2 == 0. Compare y describa los patrones que encuentra.

# %% [markdown]
# - Histogramas separados de la variable educ (años de eduación) a partir de la variable nearc2 (si no existe (0) o existe (1) un college en el condado)

# %%
sns.displot(card, x="educ", col="nearc2", color='blue')

# %% [markdown]
# A partir de los histogramas, se puede observar una correlación que a primera vista es contraintuitiva, pues se muestra que la cercanía de una institución de educación superior y el aumento de años de educación tienen una correlación inversa, es decir, a mas cerca la institución, menos años de educación se adquiere. Asimismo, es posible afirmar que la presencia de universidades de 2 años en el condado de la muestra aumenta la posibilidad de asistir a la universidad y obtener estudios superiores. Finalmente, se puede decir que la ausencia de una institución de educación superior de 2 años cercana al condado no genera una relación fuerte a comparación con la situación en la que estas estucieran más próximas al condado.

# %% [markdown]
# #### 5.2) Grafique dos histogramas para la variable años del logaritmos de los ingresos "lwage" para cuando nearc2 == 1, y cuando nearc2 == 0. Compare y describa los patrones que encuentra.

# %% [markdown]
# - Histogramas separados de la variable lwage (logaritmo de los ingresos) a partir de la variable nearc2(si no existe (0) o existe (1) un college en el condado)

# %%
sns.displot(card, x="lwage", col="nearc2", color='blue')

# %% [markdown]
# A partir de los histogramas, se puede observar que la cercanía a un centro de estudios superiores con programas de 2 años de estudio guarda una relación con el logaritmo de ingresos de la muestra de esta investigacion. De este modo, se muestra que hay una distribución normal tanto en los casos cuando hay universidades con programas de 2 años cercanas al condado como cuando esto no es así, lo que implica que existe una distribución simétrica en la data. A la vez, es posible observar que la existencia de centros de educación superior con programas de 2 años en las cercanías del condado tiene un impacto negativo significativo en los logaritmos de ingresos de la muestra. Por consiguiente, la presencia de universidades con programas de 2 años en las proximidades del condado tiene un efecto significativo y también inverso sobre el logaritmo de ingresos.

# %% [markdown]
# ### Regresiones

# %% [markdown]
# #### 5.3) Corran una regresion lineal del tipo "lwage ~ educ + exper + black + south + married + smsa", y expliquen los resultados que encuentran.

# %%
#OLS
ols_reg = sm.OLS.from_formula("lwage ~ educ + exper + black + south + married + smsa", 
              data = card).fit()

ols_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  lwage   R-squared:                       0.305
# Model:                            OLS   Adj. R-squared:                  0.304
# Method:                 Least Squares   F-statistic:                     219.2
# Date:                Fri, 09 Dec 2022   Prob (F-statistic):          1.97e-232
# Time:                        17:49:57   Log-Likelihood:                -1273.9
# No. Observations:                3003   AIC:                             2562.
# Df Residuals:                    2996   BIC:                             2604.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      5.0633      0.064     79.437      0.000       4.938       5.188
# ...

# %% [markdown]
# - Explicación:
#
# En este modelo de regresión se ha buscado encontrar si existe una correlación entre el logaritmo de ingresos (lwage) y las variables independientes (años de educación[educ], experiencia [exper], si es de raza negra o no[black], si es del sur o no[south], si es casado o no[married] y la variable smsa). Cabe destacar que no se han considerado a ciertas variables, como nearc4 ni nearc2. Se evidencia que todas las variables cuentan con un p-value menor a 0.05, por ende se confirma que todas son significativas. Asimismo, el R2 indica que el modelo explica 30% de la variabilidad de la variable dependiente, logaritmos de ingresos, lo que indica que el modelo no es tan fuerte. Finalmente, el coeficiente de la variable años de educación (educ) nos indica que por cada aumento de los años de educación, los ingresos de los encuestados aumentan en 7.1%.

# %% [markdown]
# - Al haber valores invalidos en la variable married,esto se rellenan con ceros para que no afecte el resultado del modelo de regresión.

# %%
card['married'] = card['married'].fillna(0)

# %% [markdown]
# #### 5.4) Corran una regresion de tipo IV(usando el paquete IV2SLS) donde van a instrumentalizar la variable educ con nearc2 .
# Compare los resultados encontrados usando IV2SLS con la primera regresión. ¿Cambió el coeficiente relacionado a educ , por qué?

# %% [markdown]
# La regresión debería tener una forma de este tipo "lwage ~ 1 + exper + black + south + married + smsa + [educ ~ nearc2]".

# %%
#IV2SLS
iv_reg = IV2SLS.from_formula("lwage ~  1 + exper + black + south + married + smsa + [educ ~ nearc2]", card).fit()
iv_reg.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           IV-2SLS Estimation Summary
# ...
# Dep. Variable:                  lwage   R-squared:                     -1.3114
# Estimator:                    IV-2SLS   Adj. R-squared:                -1.3160
# No. Observations:                3010   F-statistic:                    289.62
# Date:                Fri, Dec 09 2022   P-value (F-stat)                0.0000
# Time:                        17:53:19   Distribution:                  chi2(6)
# Cov. Estimator:                robust
#
#                              Parameter Estimates
# ...
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# Intercept      0.1276     3.1412     0.0406     0.9676     -6.0290      6.2843
# black          0.1134     0.1816     0.6244     0.5324     -0.2425      0.4692
# ...

# %% [markdown]
# ###### Explicación de resultados:
#
# La creación de un nuevo modelo de regresión lineal donde se utilice como instrumento (Z) a la variable nearc2 (la presencia o no de centros de estudios superiores con programas de 2 años), permite encontrar que esta tiene un efecto en la variable años de educación y mediante esta tiene un efecto en el resultado, logaritmos de ingresos. Se observa que no todas las variables son significativas a diferencia del modelo de regresión anterior, siendo las únicas experiencia y años de educación. Además, por cada año adicional de educación, los ingresos de las personas aumentan aproximadamente en un 36%. Por ello, se afrimar que se encuentra un mayor aumento del logaritmo de ingresos al instrumentalizar el modelo de regresión en comparación con el modelo de regresión OSL. El modelo presenta un R ajustado negativo que señala la neutralidad ante la introducción de variables adicionales y el F-statistics tiene un exceso de 15, por lo que se señala que el instrumento no puede ser débil.

# %% [markdown]
# #### Compare los resultados encontrados en la regresión de arriba. ¿Cambió el coeficiente relacionado a educ , por qué?
#
# Al observar ambos modelos de regresión, se evidencia un cambio en el coeficiente de la variable "años de educación", lo que podría estar relacionado con la introducción del instrumento nearc2 (presencia (==1) o no(==0) de un centro de educación superior con programas de 2 años de estudios cerca al condado) en el segundo modelo. De este modo, es posible confirmar que la presencia de centros de estudios superiores con programas de 2 años cerca al lugar de residencia de la muestra cumple un rol importante en la continuación de estudios superiores, en los años de educación y en el logaritmo de ingresos.
