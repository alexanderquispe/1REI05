# %% [markdown]
# ## REPORTE 2:
# Nombre: Maysa Ríos Camargo - 20200917

# %% [markdown]
# ### Reporte Lectura
#
# Para poder conocer el estado de la economía peruana es necesario revisar su desarrollo previo. El artículo de Martinelli y Manson es una muestra importante de los trabajos que se enfocan en la historia monetaria y fiscal peruana. Este texto nos brinda una visión muy concisa del desarrollo de la economía peruana durante los últimos 65 años; sobre todo nos detalla las políticas económicas que se dieron en cada gobierno que marcó el destino de la situación en la que vivimos hoy. En otras palabras, este artículo plantea responder cuáles fueron las políticas monetarias y fiscales que mantuvieron al Perú en una situación de inflación crónica durante el siglo pasado y que en este siglo se pudo estabilizar por el cambio de políticas económicas y políticas.
#
# En ese marco, podemos observar que una de las mayores fortalezas del texto es brindar el trasfondo histórico de las políticas económicas tomadas en cada gobierno y luego explicarnos como estas causaron la inflación que se vivió en los ochenta. Asimismo, nos explica con qué políticas fiscales, reformas constitucionales y políticas monetarias se logró reducir la inflación hasta niveles estables. Me parece que seguir el hilo conductor para entender el desarrollo de los problemas en la economía peruana son claros porque se comienza con la contextualización y luego se profundiza con qué medidas específicas se aplicaron (financiamiento deuda externa, impuesto inflacionario, renegociación deuda externa, etc.) Por otro lado, una de las debilidades que pude notar es el poco desarrollo del impacto del fenómeno del Niño de 1982-1983. Me parece importante resaltar esto pues la reconstrucción de las zonas afectadas por un evento imprevisto y con la adición de un contexto de inflación en nuestro país, significó que hubiera muchas limitaciones para ayudar a los damnificados y que el Estado no pudiese afrontar de forma correcta los desastres naturales que ocurrieron debido a ese fenómeno climático. Menciono esto porque, aunque el papel tenga un enfoque en las políticas fiscales y monetarias, estas políticas públicas finalmente repercuten en la vida de los ciudadanos. En ese orden de ideas sería importante que los autores sean más explícitos con el efecto de las malas políticas económicas que se dieron en el Perú durante los ochenta.
#
# El artículo contribuye a la literatura sobre la historia económica del Perú en tanto analiza factores internos y externos que causaron la inflación y como se intentó resolver la inestabilidad que se vivió en la década pasada. Nos muestra la política fiscal y monetaria que se aplicó, cuáles fueron sus efectos, como se estabilizó la economía y cuáles son las herencias de las decisiones políticas que ahora nos permite tener la economía que hoy conocemos. Con respecto a esta contribución observamos que hay varios temas pendientes a tratar y frente ello, autores como Guevara en su artículo “Política Monetaria del Banco Central: Una Perspectiva Histórica” nos explican más a profundidad cuál ha sido el desempeño del BCR para estabilizar la economía e impedir más casos de hiperinflación. Me parece importante mencionar este texto porque el Banco Central de Reserva es uno de los mayores pilares para tener una economía estable y es una institución que tiene un objetivo claro. Asimismo, para complementar el avance del estudio de las políticas fiscales y monetarias en el Perú es importante revisar el texto de Oscar Dancourt, Waldo Mendoza y Leopoldo Vilcapoma. En su artículo titulado “Fluctuaciones económicas y shock externos, Perú 1950-1996”, ellos analizan cuál ha sido el efecto de los shocks externos y como se ha respondido a este problema desde las administraciones públicas. Es así que, este escrito nos mostraría los patrones por los que la economía peruana ha pasado con referencia a las estimulaciones económicas externas.

# %% [markdown]
# ### Código en Phyton
#
# Integrantes:
# Maysa Ríos Camargo (20200917)
# Andrea Canaval Suarez (20200945)
#
# Pregunta 1
#
# 1. Utilizando las ecuaciones derive paso a paso la curva IS matemáticamente (a partir de la condición de equilibrio Y = DA)
#
# DA = C + I + G + X − M;
# Y = C + I + G + X − M;
#
# DA = C0 + bYd + I0 − hr + G0 + tY + X0 - mYd
# DA = C0 + I0 - hr + G0 + X0 + b(1-t)Y - m(1-t)Y
# DA = C0 + I0 - hr + G0 + X0 + (b - m)(1-t)Y
# DA = α0 + α1Y
#
# 2. Utilizando la función de equilibrio IS donde r está en función de Y, encuentre  que representa la pendiente y qué signo tiene?
#
# r = 1/h * (𝐶0 + 𝐼0 + 𝐺0 + 𝑋0) - [1 − (𝑏 − 𝑚)(1 − 𝑡)]/h * Y
#
# La pendiente representa una relación inversa entre los tipos de interés real y el nivel de producto o renta en una economía; el signo que tiene es negativo.
#
# 3. Lea la sección 4.4 del material de enseñanza y explique cómo se deriva la curva IS a partir del equilibrio  y grafique lo siguiente:
#
# Llegamos al equilibrio ahorro-inversion y restamos la tributación, así obtenemos la ecuación del ingreso disponible. Recordemos que el ahorro total ya incluye al privado, del dobierno y externo. Es así que obtenemos la curva IS (igualdad entre ahorro y la inversión).

# %%
Y_size = 100 

Co = 36
Io = 41
Go = 71
Xo = 3
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, r, label = "IS", color = "#66CDAA") #Demanda agregada

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Título, ejes y leyenda
ax.set(title = "Curva IS", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %%
Y_size = 100 

Co = 36
Io = 41
Go = 71
Xo = 3
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

#--------------------------------------------------
# Recta de 45°

a = 2.5 

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)

# %%
Go = 35

def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
Y_size = 100 

Co = 36
Io = 41
Go = 71
Xo = 3
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 



ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.plot(Y, DA_IS_K, label = "DA_0", color = "C0") 
ax1.plot(Y, DA_G, label = "DA_1", color = "C0") 
ax1.plot(Y, L_45, color = "#404040") 

ax1.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
ax1.axvline(x = 54,  ymin= 0, ymax = 0.54, linestyle = ":", color = "grey")

ax1.text(6, 4, '$45°$', fontsize = 11.5, color = 'green')
ax1.text(2.5, -3, '$◝$', fontsize = 30, color = 'green')
ax1.text(72, 0, '$Y_0$', fontsize = 12, color = 'green')
ax1.text(56, 0, '$Y_1$', fontsize = 12, color = 'green')
ax1.text(67, 185, 'E_0', fontsize = 12, color = 'green')
ax1.text(50, 142, 'E_1', fontsize = 12, color = 'green')

ax1.set(title = "Derivación de la curva IS a partir del equilibrio $Y=DA$", xlabel = r'Y', ylabel = r'DA')
ax1.legend()


ax2.yaxis.set_major_locator(plt.NullLocator())   
ax2.xaxis.set_major_locator(plt.NullLocator())

ax2.plot(Y, r, label = "IS", color = "C1") 

ax2.axvline(x = 70.5, ymin= 0, ymax = 1, linestyle = ":", color = "yellow")
ax2.axvline(x = 54,  ymin= 0, ymax = 1, linestyle = ":", color = "yellow")
plt.axhline(y = 151.5, xmin= 0, xmax = 0.7, linestyle = ":", color = "yellow")
plt.axhline(y = 165, xmin= 0, xmax = 0.55, linestyle = ":", color = "yellow")

ax2.text(72, 128, '$Y_0$', fontsize = 12, color = 'blue')
ax2.text(56, 128, '$Y_1$', fontsize = 12, color = 'blue')
ax2.text(1, 153, '$r_0$', fontsize = 12, color = 'blue')
ax2.text(1, 167, '$r_1$', fontsize = 12, color = 'blue')
ax2.text(72, 152, 'E_0', fontsize = 12, color = 'blue')
ax2.text(55, 166, 'E_1', fontsize = 12, color = 'blue')

ax2.legend()

plt.show()

# %% [markdown]
# Pregunta 2:
#
# hr=(C0+G0+I0+X0)-(1-(B-M)(1-t))Y

# %% [markdown]
# r=1/h(C0+G0+I0+X0)-(1-(b-m)(1-t)/h)Y r=B0/h-(B1/h)Y

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
# Gráfico de la curva IS

# Dimensiones del gráfico
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(12, 10))

# Curvas a graficar
ax.plot(Y, r, label = "IS", color = "GREEN") #Demanda agregada

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Título, ejes y leyenda
ax.set(title = "Curva IS", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()
