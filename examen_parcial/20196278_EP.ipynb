# %% [markdown]
# $$EXÁMEN-PARCIAL$$

# %% [markdown]
# $PARTE-TEÓRICA$

# %% [markdown]
# PREGUNTA 1 $Multiplicador-Keynesiano$
#
# En el modelo de ingreso- gasto keynesiano, evaluamos un intercepto y una pendiente. El multiplicadorKeynesiano sería el intercepto de la función. os supuestos de esta función, explica Keynes son de una econmía cerra a corto plazo en dónde el sector de bienes de inversión y sector de bienes de consumo se encuentran.
# El resultado es por tanto el resultado de la sume da la relación de los componente autónomos. Es decir, la suma de los componente autónomos conformarían el multiplicador:
#
# $C_o+I_o+G_o+X_o-hr$
#
# Notese que esta tiene al Gasto de gobierno, en la que Keynes enfatizaba mucho. A mayor gasto de gobierno, la curva de de bienes cambia intercepto y eso incrementa el producto.
#
# Así si GO↑ aumentaría el intercepto:
#
# $En- la - grafica$
# Alfa sub 0, representara el multiplicador. Es decir va a contener $C_o+I_o+G_o+X_o-hr$
#
# ![multiplicador%20Keynesiano.jpg](attachment:multiplicador%20Keynesiano.jpg)

# %% [markdown]
# PREGUNTA 2 $deficit-exceso$
# Secede un deficit en la el modelo ingreso gasto cuando en la ecuación de la DA, sucede un desequilibrio. En ese caso, por ejemplo, el gasto de gobierno se reduce, eso provoca que la curva en general baje en su intercepto. Ello provoca que la DA, sea manor al producto incial. Es decir  :$DA<Y$. Esto provoca que el producto se ajuste.
#
# Sucede un execeso de demanda en el modelo cuando en la ecuación DA, sucede el desequilibrio contrario: Ejemplo Gasto de gobienro aumenta,eso produce que el intercepto incremente, y eso poduce a su vez  que se genera un exceso de DA. Es decir, $DA>Y$.
#
# En la grafica: vemos esos cambios
#
# ![exeso%20defecto.jpg](attachment:exeso%20defecto.jpg)

# %% [markdown]
# PREGUNTA 3 $politica : monetaria-fiscal$
#
# Una politica monetaria podrían ser politica tanto control en la masa monetaria $Ms_0$ como en la taza $r_0$
# Caso en la que se utilizó fue en la epoca de bonanza economica y recesión como lo ejemplifica en su texto, Martinelli C y Vega M (2018). En esta explcia que la politica monetaria ha sido de manejo de la taza $r_0$, que a funcionado contraciclica desde el 2003 en el Perú. Otra sería la de que se podría traducir a "creación de bonos". Esto puede ser entendido desde el estudios de Walter Dancourt (2014). Menciona que una politica para soportar el choque de la pandemia fue la emisión de cheditos soportados por el Estado. Es decir Gasto de gobierno.
#
# Una política fiscal sería la politica de tributación es decir l modificar al variable $t$ de impuestos. O el Gasto de gobienro$G_o$. en el que la politica fiscal sería de incremtnar o reducir este gasto. Ambas estan relacionadas al incremnteo o reducción de Y de producción: Esto se realiza con el fin de dinamizar la economía.

# %% [markdown]
# PREGUNTA 4 $aplicativos plin-yape$
#
# el mercado de dinero explicaria bien su relación , ya que en estas no existe una taza r: es decir, n¿puded considerarce nnula, por tanto, esto es favorable a la transacción e insentiva que más individuos se inserten.

# %% [markdown]
# PREGUNTA 5 $paper Dancurt$
#
# La fortaleza de este Paper está en que demuestra de qué manera, se ha cambiado la politica monetaria en el siglo XXI, y de qué manera esto a colaborado a entender el buena gestión en el control de la economía ante choques externos. Por un lado este autor enfatiza en el cómo se ha controlado la liberalización del tipo de cambio. Este autor explcia este control con la compra y venta de dólares y producción de creditos para tener una moneda a cierto tipo de cambio. Así mismo, no olvida la importancia de reducir la taza de interés que cambiando la taza de prestamos, se impulsaba la inversión. Argmenta que esta doble estrategio de politica fiscal y monetaria produci unadicotomía en la que si se incrementaba la producción se afectaba los precios. Caso contrario, si se priorizaban los precios, se afectaba la producción y los empleos. Así, la gestión del Bcr, ha sido de fundamentalmente, reguladora de estos dos parametros.

# %% [markdown]
#  $EJERCICIOS$
#     $El modelo ingreso-gasto en una economía abierta$
#
#  Pregunta 1
#  - Encuentre el Ingreso de Equilibrio  e identifique el multiplicador keynesiano.
#
#   ![ingreso-gasto.%20cambio%20externo.jpg](attachment:ingreso-gasto.%20cambio%20externo.jpg)

# %% [markdown]
#  - Analice los efectos sobre la variable endógena Y de una disminución del gasto fiscal (▲Go<0) .
#
#  ![Caso%20se%20reduce%20Go%20gastod%20e%20gobierno.%20.jpg](attachment:Caso%20se%20reduce%20Go%20gastod%20e%20gobierno.%20.jpg)

# %% [markdown]
#   - (2 puntos) Analice los efectos sobre la variable endógena "Y" de un incremento del PBI mundial (▲Y*>0) . El análisis debe ser intuitivo, matemático y gráfico.
#
#   ![producto%20internacinal%20sube.jpg](attachment:producto%20internacinal%20sube.jpg)

# %% [markdown]
# $Ejercicio 2$
#
# Modelo de OA-DA y el nuevo esquema institucional de Política Monetaria, donde la tasa de interés de referencia $r_0$ es usada como instrumento.

# %% [markdown]
# - Encuentre las ecuaciones de equilibrio
#
# ![Puntos%20de%20equilibrio.%20.jpg](attachment:Puntos%20de%20equilibrio.%20.jpg)

# %% [markdown]
# - Analice los efectos sobre las variables endógenas Y, P ante una subida de la tasa de interés de referencia $▲r_0>0$
# ![r%20taza%20manejo%20grafico.jpg](attachment:r%20taza%20manejo%20grafico.jpg)
