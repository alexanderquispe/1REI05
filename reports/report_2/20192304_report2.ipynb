# %% [markdown]
# #Reporte2 nombre:Ariana Sato Flores código:20192304

# %% [markdown]
# El autor tiene la intención de brindarnos una interpretación histórica desde un enfoque monetarista relacionado a los periodos inflación en el Perú, periodos mencionados como baja inflación, inflación crónica acelerada dado en los años 70’s, la hiperinflación en la segunda mitad de los años 80´s y la estabilización de la economía en los años 90. Aquello, será logrado con la ayuda de una realización de ejercicios de medición tales como el enfoque de contabilidad de crecimiento y enfoque de contabilidad fiscal. En adición, se tomarán en cuenta las políticas que se adoptaron antes, durante y después de la estanflación porque de esta manera se complementará el enfoque monetarista antes mencionado con una perspectiva más institucional.
#
# Como contribución del autor, encuentro que las explicaciones viables para los fenómenos con el uso de ejercicios empíricos en base a evidencias, son un aporte muy útil para los lectores a fin de llegar a conclusiones que explican muy bien los problemas que enfrenta la economía peruana. Además, las explicaciones que brinda son claras para entender cómo es que disminuyeron las inflaciones usando ejemplos de otros países y cómo es que Perú actúo a diferencia de ellos en las crisis monetarias.
#
# Continuando con el párrafo anterior, cabe resaltar que las fortalezas de este artículo son el uso de fórmulas matemáticas que explican por ejemplo el flujo de financiamiento de un gobierno, el financiamiento de la deuda externa y el impuesto por inflación. De esta manera, hacer comparaciones entre periodos. Mientas se hace esa explicación, el uso de gráficos para un mayor entendimiento son clave para aquellas personas que no están acostumbradas a términos económicos, así hace mucho más sencilla la lectura. Por otro lado, el uso de diferentes fuentes implica que el artículo tenga un enfoque amplio y más explicativo, brindándole mayor confiabilidad, así el autor nos muestra diferentes suposiciones de lo que podría haber pasado si se tomaban otras acciones, tomando en cuenta la opinión de otros autores. Su enfoque histórico ayuda a una mejor comprensión del contexto para las aplicaciones matemáticas, se produce un mayor acercamiento al fenómeno y la implementación de medidas económicas.
#
# Autores como Jiménez y Rodríguez (2020) brindan un enfoque más estadístico para la explicación de los choques económicos capitales en el Perú. De esta manera, la investigación dada por Martinelli y Vega, podría avanzar con la aplicación de modelos híbridos estadísticos para identificar y cuantificar el impacto de los shocks fiscales sobre el crecimiento del PIB del Perú durante 1995- 2018. Por ejemplo, estos autores sugieren  revisiones constantes de los multiplicadores fiscales y marcan expectativas para los siguientes años , llegando a la conclusión que la política fiscal anticíclica en el Perú debería ser impulsada principalmente por el gasto de capital.

# %% [markdown]
# Pregunta 1:

# %%
Parte a: El Modelo Ingreso-Gasto: la Curva IS

# %% [markdown]
# Sabemos que en el equilibrio el ingreso agregado tiene que ser igual a la demanda agregada, por lo que nos quedaría así
# Y=DA.

# %% [markdown]
# A partir de Y=DA, seguimos con la ecuación del punto de equilibrio a corto plazo:
#     𝑌 =(1/(1 − (𝑏 − 𝑚)(1 − 𝑡)(𝐶0 + 𝐼0 + 𝐺0 + 𝑋0 − ℎ𝑟)

# %% [markdown]
# Continuamos con las ecuaciones, pero desde la tasa de interés que es lo que va dentro del análisis:
#
#      r=(1/h*(𝐶0 + 𝐼0 + 𝐺0 + 𝑋0) −((1-(b-m)*(1-t)/h)(Y)
#
#         Lo reducimos a:
#
#         r=L1/h-(L2/h)y

# %% [markdown]
# El intercepto para la curva IS:
#     L1= 𝐶0 + 𝐺0 + Io + 𝑋0
#
# La pendiente sería:
#
#     L2= 1-(b-m)(1-t)

# %% [markdown]
# Pasamos a graficar nuestra función:

# %%
# %matplotlib widget
# %matplotlib inline
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
# Gráfico de la curva IS

# Dimensiones del gráfico
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, r, label = "IS", color = "#3D59AB") #Demanda agregada

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Título, ejes y leyenda
ax.set(title = "Curva IS", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# Derivación de la curva IS a partir del Equilibrio Y=DA

# %% [markdown]
# La ecuación a partir del equilibrio sabemos que es Y=DA
#
# 𝑌 =(1/(1 − (𝑏 − 𝑚)(1 − 𝑡)(𝐶0 + 𝐼0 + 𝐺0 + 𝑋0 − ℎ𝑟)

# %% [markdown]
# Ecuación desde la tasa de ineterés:
#     r=(1/h*(𝐶0 + 𝐼0 + 𝐺0 + 𝑋0) −((1-(b-m)*(1-t)/h)(Y)

# %% [markdown]
# Se simplifica la curva IS a la siguiente ecuación:
#     r=(B0/h)-(B1/h)*Y
#     Donde: β0 = C0 + I0 + G0 + X0 y β1 = 1 − (b − m)(1 − t)
#     Se tiene que recordar la ecuación de la Demanda Agregada para seguir con el gráfico

# %% [markdown]
# Demanda Agregada:

# %%
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

#--------------------------------------------------
# Recta de 45°

a = 2.5 

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)

#--------------------------------------------------
# Segunda curva de ingreso de equilibrio

    # Definir cualquier parámetro autónomo
Go = 35

# Generar la ecuación con el nuevo parámetro
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %% [markdown]
# Curva IS:

# %%
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
# Gráfico de la derivación de la curva IS a partir del equilibrio 

    # Dos gráficos en un solo cuadro (ax1 para el primero y ax2 para el segundo)
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 

#---------------------------------
    # Gráfico 1: ingreso de Equilibrio
ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.plot(Y, DA_IS_K, label = "DA_0", color = "C0") 
ax1.plot(Y, DA_G, label = "DA_1", color = "C0") 
ax1.plot(Y, L_45, color = "#404040") 

ax1.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "green")
ax1.axvline(x = 54,  ymin= 0, ymax = 0.54, linestyle = ":", color = "green")

ax1.text(6, 4, '$45°$', fontsize = 11.5, color = 'red')
ax1.text(2.5, -3, '$◝$', fontsize = 30, color = 'red')
ax1.text(72, 0, '$Y_0$', fontsize = 12, color = 'red')
ax1.text(56, 0, '$Y_1$', fontsize = 12, color = 'red')
ax1.text(67, 185, 'E_0', fontsize = 12, color = 'red')
ax1.text(50, 142, 'E_1', fontsize = 12, color = 'red')

ax1.set(title = "Derivación de la curva IS a partir del equilibrio $Y=DA$", xlabel = r'Y', ylabel = r'DA')
ax1.legend()

#---------------------------------
    # Gráfico 2: Curva IS

ax2.yaxis.set_major_locator(plt.NullLocator())   
ax2.xaxis.set_major_locator(plt.NullLocator())

ax2.plot(Y, r, label = "IS", color = "C1") 

ax2.axvline(x = 70.5, ymin= 0, ymax = 1, linestyle = ":", color = "green")
ax2.axvline(x = 54,  ymin= 0, ymax = 1, linestyle = ":", color = "green")
plt.axhline(y = 151.5, xmin= 0, xmax = 0.7, linestyle = ":", color = "green")
plt.axhline(y = 165, xmin= 0, xmax = 0.55, linestyle = ":", color = "green")

ax2.text(72, 128, '$Y_0$', fontsize = 12, color = 'red')
ax2.text(56, 128, '$Y_1$', fontsize = 12, color = 'red')
ax2.text(1, 153, '$r_0$', fontsize = 12, color = 'red')
ax2.text(1, 167, '$r_1$', fontsize = 12, color = 'red')
ax2.text(72, 152, 'E_0', fontsize = 12, color = 'red')
ax2.text(55, 166, 'E_1', fontsize = 12, color = 'red')

ax2.legend()

plt.show()

# %% [markdown]
# Parte b: La Curva IS o el equilibrio Ahorro- Inversión

# %% [markdown]
# Sabemos que la función ahorro es:
#     S = −(C0 + G0 + X0) + [1 − (b − m)(1 − t)]Y
#
# Y nuestra función inversión es:
#     I = I0 − hr

# %% [markdown]
# El intercepto de la curva sería:
#      𝑆 = 𝐼 , lo que representa la igualdad

# %% [markdown]
# El equilibrio ocurre en los puntos A y B que corresponden
# a los pares ordenados (Y0, r0) y (Y1, r1), La unión estos puntos representa la Curva IS
# En el gráfico se puede observar, una relación
# inversa entre la tasa de interés real y el ingreso. Tasas de interés más bajas corresponden
# a ingresos más altos.

# %%
# Graph of the IS curve


# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS", color = "#7FFFD4") #Demanda agregada

# Remove the quantities from the axes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())
ax.text(90, 140, 'IS', fontsize = 12, color = 'red')


# Title, axes adn legend
ax.set(title = "La Curva IS de equilibrio en el Mercado de Bienes", xlabel= 'Y', ylabel= 'r')
ax.legend()

ax.legend()
plt.show()

# %% [markdown]
# Pregunta c: Desequilibrios en el mercado de bienes

# %% [markdown]
# El desquilibrio en los mercados pueden ocurrir porque, por ejemplo, un precio real está por encima del precio de equilbrio,
# la demanda de los productos aumenta, pero como los precios son altos puede que haya menos demanda y por consiguiente el
# llamado "exceso de oferta".Por otro lado, cuando real es inferior al precio de equilibrio, habrá menos oferta de los productos y más demandantes dispuestos a adquirir esos productos.
# Se producirá por tanto un exceso de demanda, por lo tanto, el precio real tenderá a aumentar debido a la cantidad
# de personas que quieren el producto.Es por ello que no estos casos no son considerados dentro del punto de equilibrio en el mercado de bienes.

# %%
Gráfico:

# %%
# Curves to plot
# Parameters

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
Y = np.arange(Y_size)
# Equation 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (1/h)*(Co + Io + Go + Xo) - (1/h)*(1-(b-m)*(1-t))*Y
    return r_IS
r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS", color = "#7FFFD4") #Demanda agregada

# Remove the quantities from the axes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())
ax.text(0, 180, '$r_A$', fontsize = 12, color = 'red')
ax.text(22, 180, 'C', fontsize = 12, color = 'red')
ax.text(37, 180, 'A', fontsize = 12, color = 'red')
ax.text(52, 180, 'B', fontsize = 12, color = 'red')
ax.text(22, 127, '$Y_C$', fontsize = 12, color = 'red')
ax.text(37, 127, '$Y_A$', fontsize = 12, color = 'red')
ax.text(52, 127, '$Y_B$', fontsize = 12, color = 'red')
#/// Lineas horizontales | Lineas verticales
plt.axvline(x = 22,  ymin= 0, ymax= 0.69, linestyle = ":", color = "green")
plt.axvline(x = 37,  ymin= 0, ymax= 0.69, linestyle = ":", color = "green")
plt.axvline(x = 52,  ymin= 0, ymax= 0.69, linestyle = ":", color = "green")
plt.axhline(y = 180, xmin= 0, xmax = 0.7, linestyle = ":", color = "green")
#// Texto
plt.text(24, 160, 'Exceso de', fontsize = 11.5, color = '#FFEBCD')
plt.text(24, 155, 'demanda', fontsize = 11.5, color = '#FFEBCD')
#// Texto
plt.text(65, 190, 'Exceso de', fontsize = 11.5, color = '#FFEBCD')
plt.text(65, 185, 'Oferta', fontsize = 11.5, color = '#FFEBCD')

# Title, axes adn legend
ax.set(title = "Equilibrio y Desequilibrio en el Mercado de Bienes", xlabel= 'Y', ylabel= 'r')
ax.legend()

ax.legend()
plt.show()

# %% [markdown]
# Pregunta d :Movimientos de la curva IS

# %% [markdown]
# Parte 1:
#
# Si una política Fiscal Contractiva orgina una caída en el gasto del gobierno,
# por consecuencia, la demanda agregada disminuye porque disminuye el gasto público de las personas
# Aquello genera un desplazamiento de la curva IS hacia la izquierda porque tendrá que disminuir la
# producción y eso generaría un exceso de demanda.
#
# G0 ↓ →G ↓→DA ↓→ DA < Y  → Y ↓

# %%
# ORIGINAL IS Curve

# Parameters

Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Equation 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


#--------------------------------------------------
    # New IS Curve

# Define ONLY the changed parameter
t = 0.2

# Equation with the changed parameter
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_G = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# Graph

# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS", color = "red") #IS orginal
ax.plot(Y, r_G, label = "IS_t", color = "C1", linestyle = 'dashed') #New IS

# Text added
plt.text(47, 130, '∆t', fontsize=12, color='red')
plt.text(50, 140, '→', fontsize=15, color='green')

# Title and legend
ax.set(title = "Baja la tasa de impuestos $(t)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# Parte2:
#
# (t) ↓ → C ↓→DA ↓→ DA> Y  → Y ↑
#
# Cuando la tasa de interés de tributación, por consecuencia la demanda agregada sube porque las personas ahorran más dinero
# que es el porcentaje que le quita el Estado.Entonces, la demanda al subir también tiene que subir la producción, generando así
# un nivel de equilibrio ya antes mencionado. Por lo tanto, existe un cambio en el mercado de bienes
# lo cual se genera un desplazamiento hacia la derecha.

# %%
# Curva IS original
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


#--------------------------------------------------
    # NUEVA curva IS
    
# Definir SOLO el parámetro cambiado
t = 0.05

# Generar la ecuación con el nuevo parámetro
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_t = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
# Dimensiones del gráfico
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, r, label = "IS", color = "red") #IS orginal
ax.plot(Y, r_t, label = "IS_t", color = "#8A2BE2", linestyle = 'dashed') #Nueva IS

# Texto agregado
plt.text(67, 162, '∆t', fontsize=12, color='green')
plt.text(67, 158, ' →', fontsize=15, color='black')

# Título, ejes y leyenda
ax.set(title = "Disminución en la Tasa de Interés $(t)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# Parte 3:
#     (t) ↓ → Co ↓→ C ↓→ DA> Y  → Y ↑ t ↓ → M ↓ → DA ↓ → DA < Y  → Y ↓
#
#     La relación entre la propensión marginal a consumir y la Demanda agregada es directa. Si la propensión
#     marginal cae, por ende, caerá el consumo y eso causaría la caída de la demanda agregada y un exceso de demanda.
#     "Cuando aumenta (disminuye) “m”, la pendiente de la curva IS se incrementa
#     (reduce). Por el contrario, el aumento de la propensión marginal a consumir, “b”,
#     aumenta el tamaño del multiplicador, aumenta la pendiente de la DA y reduce la pendiente
#     de la curva IS. Esta gira en sentido contrario a las agujas del reloj" (Jimenez,2020,pp.74)

# %%
# Curva IS original
# Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


#--------------------------------------------------
    # NUEVA curva IS
    
# Definir SOLO el parámetro cambiado
b = 0.5

# Generar la ecuación con el nuevo parámetro
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_b = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
# Dimensiones del gráfico
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, r, label = "IS", color = "green") #IS orginal
ax.plot(Y, r_b, label = "IS_t", color = "#A52A2A", linestyle = 'dashed') #Nueva IS

# Texto agregado
plt.text(49, 162, '∆t', fontsize=12, color='green')
plt.text(49, 158, '←', fontsize=15, color='black')

# Título, ejes y leyenda
ax.set(title = "Disminución en la PMgC $(b)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()
