# %% [markdown]
# # Reporte 2  (83)

# %% [markdown]
# Julia Millen Massa Coronel 20196415

# %% [markdown]
# # Código en Python

# %% [markdown]
# # a. El Modelo Ingreso-Gasto: la Curva IS

# %%
# %matplotlib inline
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
import pandas as pd
from causalgraphicalmodels import CausalGraphicalModel

# %% [markdown]
# Utilizando las ecuaciones derive paso a paso la curva IS matemáticamente (a partir de la condición de equilibrio Y = DA).

# %% [markdown]
# Para llegar al equilibrio Ahorro-Inversión, debemos restar la tributación  de ambos miembros de la igualdad.

# %% [markdown]
# - Y - T = C + I + G + X - M-T
# - Y^d = C + I - T + G + X - M

# %% [markdown]
# se puede reescribir de la siguiente forma:

# %% [markdown]
# (Y^d - C) + (T - G) + (M - X) = I

# %% [markdown]
# Las tres partes constituyen los tres componentes del ahorro total : ahorro privado , ahorro del gobierno  y ahorro externo

# %% [markdown]
# S = S_p + S_g + S_e

# %% [markdown]
# Entonces, el ahorro total es igual a la inversión
# - S_p + S_g + S_e = I
# - S(Y) = I(r)

# %% [markdown]
# Haciendo reemplazos se obtiene que:

# %% [markdown]
# S_p + S_g + S_e = I_0 - hr
#  (Y^d - C_0 - bY^d) + (T - G_0) + (mY^d - X_0) = I_0 - hr

# %% [markdown]
# Considerando las observaciones anteriores sobre los componentes de la condición de equilibrio (Y):

# %% [markdown]
# [1 - (b - m)(1 - t)]Y - (C_0 + G_0 + X_0) = I_0 - hr

# %% [markdown]
# La curva IS se puede expresar con una ecuación donde la tasa de interés es una función del ingreso:

# %%
- hr = (C_0 + G_0 + I_0 + X_0) - (1 - (b - m)(1 - t))Y
- r= 1/h(Co+Go+Io+Xo)- [1-(b-m)(1-t)]*Y/h

# %% [raw]
# Utilizando la función de equilibrio IS donde r está en función de Y, encuentre △r/△Y que representa la pendiente y qué signo tiene?

# %% [markdown]
# - Δr/ΔY=-[1-(b-m)(1-t)]/h

# %% [markdown]
# - (1-t)--> 0<t<1--> +
# - b-m>0--> +
# - -(1-(+)(+))/h
# - -(+)/(+)= -
# - Sería de pendiente negativa

# %%
Y_size = 100 

Co = 37
Io = 41
Go = 72
Xo = 3
h = 0.6
b = 0.7
m = 0.3
t = 0.4

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, r, label = "IS", color = "#8B0A50") #Demanda agregada

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())
ax.set(title = "Curva IS", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# Lea la sección 4.4 del material de enseñanza y explique cómo se deriva la curva IS a partir del equilibrio Y=DA y grafique lo siguiente:

# %% [markdown]
# la ecuación del ingreso de equilibrio a corto plazo que fue obtenida a partir del equilibrio (Y=DA):

# %% [markdown]
# Y=[1/1-(b-m)(1-t)]*(Co+Io+Go+Xo-hr)

# %% [markdown]
# después de algunas operaciones, puede expresarse en función de la tasa de interés

# %% [markdown]
# r= [1/h]*(Co+Go+Io+Xo)-[1-(b-m)(1-t/h)]*Y

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)
a = 2.5 

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)
Go = 35
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 
ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.plot(Y, DA_IS_K, label = "DA_0", color = "C0") 
ax1.plot(Y, DA_G, label = "DA_1", color = "C0") 
ax1.plot(Y, L_45, color = "#404040") 

ax1.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
ax1.axvline(x = 54,  ymin= 0, ymax = 0.54, linestyle = ":", color = "grey")

ax1.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
ax1.text(2.5, -3, '$◝$', fontsize = 30, color = 'black')
ax1.text(72, 0, '$Y_0$', fontsize = 12, color = 'black')
ax1.text(56, 0, '$Y_1$', fontsize = 12, color = 'black')
ax1.text(67, 185, 'E_0', fontsize = 12, color = 'black')
ax1.text(50, 142, 'E_1', fontsize = 12, color = 'black')

ax1.set(title = "Derivación de la curva IS a partir del equilibrio $Y=DA$", xlabel = r'Y', ylabel = r'DA')
ax1.legend()
ax2.yaxis.set_major_locator(plt.NullLocator())   
ax2.xaxis.set_major_locator(plt.NullLocator())

ax2.plot(Y, r, label = "IS", color = "C1") 

ax2.axvline(x = 70.5, ymin= 0, ymax = 1, linestyle = ":", color = "grey")
ax2.axvline(x = 54,  ymin= 0, ymax = 1, linestyle = ":", color = "grey")
plt.axhline(y = 151.5, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
plt.axhline(y = 165, xmin= 0, xmax = 0.55, linestyle = ":", color = "grey")

ax2.text(72, 128, '$Y_0$', fontsize = 12, color = 'black')
ax2.text(56, 128, '$Y_1$', fontsize = 12, color = 'black')
ax2.text(1, 153, '$r_0$', fontsize = 12, color = 'black')
ax2.text(1, 167, '$r_1$', fontsize = 12, color = 'black')
ax2.text(72, 152, 'E_0', fontsize = 12, color = 'black')
ax2.text(55, 166, 'E_1', fontsize = 12, color = 'black')

ax2.legend()

plt.show()

# %% [markdown]
# # B. La Curva IS o el equilibrio Ahorro- Inversión

# %% [markdown]
# Derive la ecuación de IS a partir de la igualdad Ahorro-Inversión y grafique la curva IS de equilibrio en el Mercado de Bienes.

# %% [markdown]
# - S=I
# - (Yd-C)+(T-G)+(M-X)=I
# - [Yd-(Co+b*Yd)]+[t*Y-Go]+[m*Yd-Xo]=Io-h*r
# - [1-(b-m)(1-t)]*Y-[(Co+Go+Xo)]=Io-h*r
# - h*r= Io-[1-(b-m)(1-t)]*Y-(Co+Go+Xo)
# - h*r=[Io+Co+Go+Xo]-[1-(b-m)(1-t)]*Y
# - r= [1/h]*(Io+Co+Go+Xo)-[1-(b-m)(1-t)]*Y/h

# %% [markdown]
# Y_size = 100
#
# Co = 56
# Io = 34
# Go = 67
# Xo = 6
# h = 0.2
# b = 0.3
# m = 0.4
# t = 0.5
#
# Y = np.arange(Y_size)
#
# def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
#     r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
#     return r_IS
#
# r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
# y_max = np.max(r)
# fig, ax = plt.subplots(figsize=(10, 8))
#
# ax.plot(Y, r, label = "IS", color = "#8B0A50") #Demanda agregada
#
# ax.yaxis.set_major_locator(plt.NullLocator())
# ax.xaxis.set_major_locator(plt.NullLocator())
#
# ax.set(title = "Curva IS", xlabel= 'Y', ylabel= 'r')
# ax.legend()
#
# plt.show()

# %% [markdown]
# # c. Desequilibrios en el mercado de bienes

# %% [markdown]
# Grafique las áreas de exceso de oferta o exceso de demanda en el mercado de bienes. Explique por qué estos puntos están fuera de los puntos de equilibrio en el mercado de bienes.

# %% [markdown]
# El punto de equilibrio en la Curva IS es cuando la inversión es igual al ahorro. No obstante, se pueden dar desequilibrios, estos son el exceso de oferta y de demanda. Por un lado, el primero simboliza un exceso de ahorro y el segundo un exceso en la inversión.
# - juro que intenté hacer el gráfico , pero no importa cómo arregle los código o añada líneas, no sirvo para esto :(

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Equation 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (1/h)*(Co + Io + Go + Xo) - (1/h)*(1-(b-m)*(1-t))*Y
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))


ax.plot(Y, r, label = "IS", color = "C2") 

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Title, axes adn legend
ax.set(title = "Exceso de oferta y demanda", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

ax2.yaxis.set_major_locator(plt.NullLocator())   
ax2.xaxis.set_major_locator(plt.NullLocator())

ax2.plot(Y, r, label = "IS", color = "C1") 

ax2.axvline(x = 70.5, ymin= 0, ymax = 1, linestyle = ":", color = "grey")
ax2.axvline(x = 54,  ymin= 0, ymax = 1, linestyle = ":", color = "grey")
plt.axhline(y = 151.5, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
plt.axhline(y = 165, xmin= 0, xmax = 0.55, linestyle = ":", color = "grey")

ax2.text(72, 128, '$Y_0$', fontsize = 12, color = 'black')
ax2.text(56, 128, '$Y_1$', fontsize = 12, color = 'black')
ax2.text(1, 153, '$r_0$', fontsize = 12, color = 'black')
ax2.text(1, 167, '$r_1$', fontsize = 12, color = 'black')

ax2.set(title = " IS", xlabel= 'Y', ylabel= 'r')
ax2.legend()

plt.show()

# %% [markdown]
# # d. Movimientos de la curva IS

# %% [markdown]
# Analice una Política Fiscal Contractiva con caída del Gasto del Gobierno ( △G<0). El análisis debe ser intuitivo y gráfico.

# %% [markdown]
# $$//↓G-> ↓DA-> DA> Y-> ↓Y -> DA=Y //$$

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 80
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

Go = 50

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_G = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Y, r, label = "IS", color = "black") #IS orginal
ax.plot(Y, r_G, label = "IS_G", color = "C1", linestyle = 'dashed') #Nueva IS

plt.text(47, 162, '∆Go', fontsize=12, color='black')
plt.text(49, 159, '←', fontsize=15, color='grey')

ax.set(title = " Caída en el Gasto de Gobierno $(G_0)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# Analice una Política Fiscal Expansiva con una caída de la Tasa de Impuestos ( △t<0). El análisis debe ser intuitivo y gráfico.

# %% [markdown]
# $$//↓t-> ↑C-> ↑DA-> DA>Y--> ↑Y//$$

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.7

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
t = 0.3


def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_t = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Y, r, label = "IS", color = "black") #IS orginal
ax.plot(Y, r_t, label = "IS_t", color = "C1", linestyle = 'dashed') #Nueva IS

plt.text(47, 162, '∆t', fontsize=12, color='black')
plt.text(47, 158, '←', fontsize=15, color='grey')

ax.set(title = "Caída de la Tasa de Interés $(t)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# Analice una caída de la Propensión Marginal a Consumir (△b<0). El análisis debe ser intuitivo y gráfico.

# %% [markdown]
# $$//↓b-> ↓C-> ↓DA--> DA>Y-->↓Y//$$

# %%
Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.9
m = 0.2
t = 0.3

Y = np.arange(Y_size)

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
b = 0.2

def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r_t = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

ax.plot(Y, r, label = "IS", color = "black") #IS orginal
ax.plot(Y, r_t, label = "IS_t", color = "C1", linestyle = 'dashed') #Nueva IS

plt.text(47, 162, '∆t', fontsize=12, color='black')
plt.text(47, 158, '←', fontsize=15, color='grey')

ax.set(title = "Caída de la Propensión Marginal a Consumir  $(b)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# # Lectura

# %% [markdown]
# Considero que la pregunta de investigación del artículo se centra en interpretar bajo un enfoque monetarista y fiscal la inflación desde 1960 hasta 2017. De hecho, gran parte del capítulo está desarrollado en un enfoque histórico combinado en gran medida con este análisis; por ejemplo, nos comenta que antes de que en 1990 se estabilizara la inflación, se notaba que había una necesidad fiscal de la imposición inflacionista "en un régimen de dominio fiscal de la político monetaria".
# Una debilidad del autor es cómo estructura su capítulo. Nos habla de que para su análisis hará empleo de dos ejercicios de contabilidad y los empieza a explicar justo depués de la introducción. Después, en la tercera sección, empieza la parte más histórica del análisis. No obstante, sentí que fue un corte muy brusco. No hay una buena unión de ideas entre una parte y otra. Practicamente, desagregó la perspectiva histórica de su análisis con los juegos de contabilidad. Lo mejor hubiera sido que mientras desarrollaba la parte historica vaya, a su vez, explicando los ejercicios planteados; o , en el peor de los casos, escribir la parte histórica primero, pues así el lector tendría la contextualización y resultaría más beneficioso para entender los ejercicios de contabilidad.
# Evidentemente, la contribución que se rescata es el análisis histórico. Analizar fenomenos en un periodo corto de tiempo no es un trabajo sencillo, así que el análisis desde 1960 , no solo de los gobiernos en sí, sino de sus políticas monetarias y fiscales no es una investigación que una persona cualquiera realizaría.
# En los periódos analizados hubo imnumerables luchas por el poder político, que de alguna u otra forma, erosionaron la estructura institucional. Hubiera sido interesante que los autores explicaran cómo estas luchas afectaron o influyeron en las políticas monetarias y fiscales de esas épocas.
