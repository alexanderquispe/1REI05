# %% [markdown]
# # Examen Final
#
# ##### Belén Herrada Ruiz - 20203026

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns, warnings
import statsmodels.formula.api as smf
warnings.filterwarnings('ignore')
from causalgraphicalmodels import CausalGraphicalModel
from cProfile import label
# %matplotlib inline

# %% [markdown]
# ## 1. (3 puntos) Instrumental Variables (IV)
# Suponga que estamos interesados en estudiar la relación entre educación(X) y el nivel de ingresos(Y).
# Un investigador propone utilizar como variable instrumental(Z) el numero de horas que una persona utilizó para ver televisión cuando era niño.
#
# -Indetifique todos los elementos necesarios para implementar un enfoque de IV en este ejemplo.
#
# Respuesta: para poder implementar un enfoque de Instrumental Variables se debe satisface dos supuestos. El primero la relevenacia del instrumento a utilizar, en este caso sería el número de horas que una persona utilizó para ver televisión cuando era niño (z); es decier la correlación que debe tener con X , el segúndo es la viavilitdad de este para poder realizar el estudio. Entonces, lo elementos corresponderian a:
#
# (X) variable independiente-endogena al ser explicativa
#
# (y) variable dependiente (sobre el cual se quiere medir el efecto
#
# (z) variable instrumental
#
# -Explique el procedimiento para encontrar el efecto causal en este escenario. Puede utilizar ecuaciones
#
# Respuesta: Se debe primero comprobar la aislación de los efectos causales con la vairable instrumental, para a´si corregir el sesgo de endogeneidad.Por lo que se debe probar (z) la significancia en explicación de (x) primero y, luego,  se debe estimar una regresión de la variable de dependiente (y) sobre el valor predicho de (x) que es resultado de la primera parte.
#
# -¿El efecto de la educación sobre el nivel de ingresos es positivo o negativo? Argumente si los resultados serian causales o solamente de correlación
#
# Respuesta: El efecto que tiene la eduación sobre el nivel de ingresos es positivo, ya que a más estudios se intuye un aumento en el ingreso. Se puede establecer que existe una correlación entre ambas varirables, no obstante para establecer una causalidad se debe generar la regresión y considero encontrar otras variables instrumentales que contribuyan a aislar el efecto que se busca encontrar

# %% [markdown]
# ## 2. (3 puntos) Regression Discontinuity Design (RDD)
# Supongamos que estamos estudiando la eficacia de un programa de becas creado por el gobierno Peruano sobre las notas de los alumnos al final del primer semestre en la universidad. PRONABEC ha decidido que entregará becas a aquellos postulantes que tengan un promedio superior durante la secundaria igual a 16 .
#
# -Indetifique todos los elementos necesarios para implementar un RDD en este ejemplo.
#
# Respuesta: Para poder implementar un RDD se debe ubicar la metodología en el enunciado, siendo importante para poder encontrar el efecto causal determinar un punto de corte por el cual se imputa a la intervención a realizar en la investigación.
#
# -Running varible: el requisito de notas en la secundaria que el Pronabec ha dedido utilizar para entregar notas, al ser el que detemrina si eres tratado
#
# -Cutoff: promedio supeior o igual a 16, que es donde se realiza el corte de la variable
#
# -Bandwidth: final del primer semestre en la universidad, que es las observaciones incluir
#
# -Tratamiento : recibió la beca
#
# -Outcome: rendimiento académico
#
# -Explique el procedimiento para encontrar el efecto causal en este escenario. Puede utilizar ecuaciones.
#
# Respuesta: Para poder encontrar el efecto causal se debe deteminar el cutoff de la running variable, el cual ya fue identificado en el enunciado. Luego, se debe comparar los casos que se identifican a ambos lados del cutoff, en este caso sería notas mayores e iguales a la nota 16 y las notas menores a este. Así, entonce se determina quienes sería los que reciben el tratamiendo al obtener la media ponderada del efecto que genera  para aquellos que se encuentran justo en el margen de recibir tratamiento. Por último, se decine el tipo de estudio a usar,  ya sea Sharp Desing y Fuzzy Design
#
#
# -¿El efecto de la politica sobre el rendimiento de los estudiantes sería positivo o negativo (solo necesitan usar su intuición)? Argumente si los resultados serian causales o solamente de correlación.
#
# Respuesta: La política sobre el rendimiento de los estudiantes sería un efecto positivo, ya que base a la intiución este sirve cómo incentivo lo que generaría un aumento en los promedios de los alumnos y alumnas.

# %% [markdown]
# ## (3 puntos) Difference in Difference (DiD)
#
# Supongamos que estamos interesados ​​en estudiar el impacto de la migración en la tasa de empleo en dos regiones del Perú en 2017-2018. Tenemos datos anuales sobre la tasa de empleo en Lima, que experimentó una afluencia significativa de inmigrantes en 2018, y Puno que no experimentó el ingreso de migrantes (2017 ninguna de las regiones experimentó afluencia de migrantes). Podemos usar un análisis DID para comparar el cambio en las tasas de empleo entre las dos regiones a lo largo del tiempo para ver si la migración tuvo algún efecto.
#
# -Indetifique todos los elementos necesarios para implementar un DiD en este ejemplo.
#
# Respuesta: para identificar los efectos pre y post tratamiento, sus elementos, son:
#
# -Supuesto Paralelltrend (nada más cambia al mismo tiempo)
# -Outcome: variación de la tasas de empleo
# -Tratamiento: inmigración
# -Grupo de tratamiento: población en Lima 2018 (aumento de inmgirantes)
# -Grupo no tratamiento: población Puno 2017 (no inmigrante)
#
#
# -Explique el procedimiento para encontrar el efecto causal en este escenario. Puede utilizar ecuaciones.
#
# Respuesta: Debido a que el DIff compara lo que se ven en el grupo tratado despues del tratamiento  con la mejor estimación de lo que sería el grupo sin tratamiento. Por lo que se debe auslar la diferencia entre el grupo tratado y el no tratado, para así obtener efecto medio del tratamiento en ese grupo. Para así saber la eficacia del tratamiento.
#
#
# -¿El efecto de la migración sobre la tasa de empleo sería positivo o negativo (solo necesitan usar su intuición)? Argumente si los resultados serian causales o solamente de correlación .

# %% [markdown]
# ## 4. (4 puntos) Lecturas
# - [Bell, A., Chetty, R., Jaravel, X., Petkova, N., & Van Reenen, J. (2019). Who becomes an inventor in America? The importance of exposure to innovation. The Quarterly Journal of Economics, 134(2), 647-713.](https://www.nber.org/system/files/working_papers/w24062/w24062.pdf),  ¿Cuáles son las debilidades del enfoque del paper para responder su pregunta de investigación?
#
# Respuesta:
# La investigación realizada por Bell, Chetty, Jaravel, Petkovan y Van Reenen titulada ‘Who becomes an inventor in America? The importance of exposure to innovation’ que plantea cómo problemática a abordar la brecha de producción de inventos, específicamente caracterizan los factores que determinan quien se convierte en un inventor en los Estados Unidos. Esto debido a la importancia de la innovación para el crecimiento económico. Así, lograron presentar evidencia en los factores, que lo ocasionan al rastrear la vida de los inventores del país norteamericano desde su nacimiento a la adultez, y sus dimensiones  a través del ingreso de los padres, la “raza” y el género, a través de la pregunta planteada: ¿por qué la innovación varía tanto según las características al nacer? Para esto, algunas de las debilidades encontradas, primero dentro del documento es la falta de orientación directa y clara sobre políticas específicas para aumentar la exposición a la innovación, carencia que es admitida por los mismos autores. Luego, otra de las debilidades que se pueden encontrar es la misma limitación de la pregunta, ya que a pesar que es favorable delimitar la investigación por el favorecimiento de resultados y presiones estas variables señaladas para rastrear el efecto causal en la variación de la innovación no se pueden aplicar en otras regiones, como la sudamericana, ya que las brechas de acceso a recursos o educación son más significativas; por lo que no se puede generar una aplicabilidad fuera de la de delimitación.
#
#
#
# - [Dell, M. (2010). The persistent effects of Peru's mining mita. Econometrica, 78(6), 1863-1903](https://scholar.harvard.edu/files/dell/files/ecta8121_0.pdf), ¿Cuáles serían dos próximos pasos específicos para avanzar en su pregunta de investigación?
#
# Respuesta:
# Esta investigación, 'The persistent effects of Peru's' mining mita$ que retrata una regresión discotinua que busca entender qué tipo de papel juegan esas instituciones historicas en explicar ciertas situaciones presenttes en esos años. Como qué hace que una región esté más desarrollada que otra o qué instituciones ayudan a explicar el subdesarrollo. Es decir se busca generar una respuesta de una forma explicativa el efecto historico de largo plazo de outcomes. Este experimento natural  demuestra el impacto incremental el deficiente de crecimiento de los niños en un 6%  de la mita, siendo los resultados que las instituciones extracticas sí influyeron a largo plazdo en la prosperidad económica, destrución. De esta manera, los próximos pasos para avanzar en la pregunta de investigación sería, por un lago, la comparación de la utilización de la mita minera en el efecto de la población tomada con la utilización de la mineria ilegal alctual, la cual genera contrarrestantes efectos en multiples dimensiones como menciona Valenzuela. Por otro lado, un segunod paso, podría ser la aplicación de la metodología a otras explotaciones coloniales, cómo lo fue la extracción de caucho y su efecto en a las poblaciones nativas de la selva.
#
# Bibliografia
#
# Valenzuela, G. V. (2014). El efecto de la minería ilegal en el Perú: impactos económicos y sociales. Revista Lidera, (9), 119-120.
#
# García, J. (1982). Del caucho al oro: El proceso colonizador de Madre de Dios. Revista española de antropología americana, 12, 255-271.

# %% [markdown]
# # Código

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

def read_data(file): 
    return pd.read_stata("https://raw.github.com/scunning1975/mixtape/master/" + file)

base = read_data("card.dta")
base.head()
# Out:
#     id  nearc2  nearc4  educ   age  fatheduc  motheduc    weight  momdad14  \
# 0  2.0     0.0     0.0   7.0  29.0       NaN       NaN  158413.0       1.0
# 1  3.0     0.0     0.0  12.0  27.0       8.0       8.0  380166.0       1.0
# 2  4.0     0.0     0.0  12.0  34.0      14.0      12.0  367470.0       1.0
# 3  5.0     1.0     1.0  11.0  27.0      11.0      12.0  380166.0       1.0
# 4  6.0     1.0     1.0  12.0  34.0       8.0       7.0  367470.0       1.0
#
#    sinmom14  ...   KWW     IQ  married  libcrd14  exper     lwage  expersq  \
# 0       0.0  ...  15.0    NaN      1.0       0.0   16.0  6.306275    256.0
# 1       0.0  ...  35.0   93.0      1.0       1.0    9.0  6.175867     81.0
# 2       0.0  ...  42.0  103.0      1.0       1.0   16.0  6.580639    256.0
# 3       0.0  ...  25.0   88.0      1.0       1.0   10.0  5.521461    100.0
# 4       0.0  ...  34.0  108.0      1.0       0.0   16.0  6.591674    256.0
#
#     u_lwage  lwage_hat    u_educ
# ...

# %%
#Histogramas 

## Histograma para la variable años de educación

#Siendo:
#nearc2 == 1,
#cuando nearc2 == 0.

#Crear una sub data 
base1 = base[['educ','nearc2']]
base


Histograma.edu = sns.displot(data=base1, x="educ", col="nearc2", stat="count")
g.set(xlabel = "Años de Educación", ylabel = "Frecuencia")

plt.show()

# %% [markdown]
# Se evidencia similitud en la distribución de los resultados en ambos instogramas, evidenciadno una mayor alta frecuencia en 12.5, así siendo 0 no tener un college en el condado y 1 sí tener un college en el condado. Se observa que los que no tienen un college en su condado presenta una alta frencuencia de años de educación a acomparación de los sí, no obstante como ya se mencionó, la diferencia no es significativa.

# %%
#Histogramas para la variable logaritmos de los ingresos 

#Siendo: cuando nearc2 == 1, y cuando nearc2 == 0

#Creando una sub data para aisalr las variables
base2 = base[['lwage','nearc2']]
base2


Histograma.ingreso = sns.displot(data=base2, x="lwage", col="nearc2", stat="count")
g.set(xlabel = "Logaritmo de los ingresos", ylabel = "Frecuencia")
