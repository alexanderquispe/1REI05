# %% [markdown]
# # Examen Parcial
#
# #### Nombre: Claudia Katherine Milla Rojas
# #### Código: 20200526

# %% [markdown]
# ### Teoría
#
# 1. El multiplicador de inversión de Keynes es el multiplicador de gasto público, pues nos muestra lo que ocurre cuando se producen incrementos o reducciones del gasto público. Este influye en el modelo Ingreso-Gasto Keynesiano, pues cuando existe un incremento en  la inversión total, el ingreso aumentará en una cantidad que es k veces el incremento de la inversión. Nos evidencia que un cambio en la magnitud de los componentes autónomos de la demanda agregada genera un proceso multiplicador del ingreso hasta converger al nuevo ingreso y producto de equilibrio. De esta forma, en el primer incremento podemos observar que un incremento del ingreso genera un aumento de la demanda del consumo y, así, de la producción e ingreso en el sector que produce bienes de consumo. El segundo incremento se observa que aumenta la demanda de bienes de consumo y por tanto también la producción e ingreso del sector dedicado a los bienes de consumo.

# %%
pip install causalgraphicalmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Curva de ingreso 

    # Parámetros
Y_size = 100 

Co = 35
Io = 40
Go = 40
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
r = 0.9

Y = np.arange(Y_size)

    # Ecuación 
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

#--------------------------------------------------
# 45°

a = 2.5 

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from causalgraphicalmodels import CausalGraphicalModel
import matplotlib.pyplot as plt
import sympy as sy
import math
import sklearn
from sympy import *
import scipy as sp
import networkx
import ipywidgets as widgets
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col

# %%
# Gráfico
y_max = np.max(DA_IS_K)
fig, ax = plt.subplots(figsize=(10, 8))


# Curvas a graficar
ax.plot(Y, DA_IS_K, label = "DA", color = "blue") #curva ORIGINAL
ax.plot(Y, L_45, color = "brown") #línea de 45º

# Lineas punteadas
plt.axvline(x = 75, ymin= 0, ymax = 0.75, linestyle = ":", color = "grey")
plt.axvline(x = 56,  ymin= 0, ymax = 0.56, linestyle = ":", color = "grey")
plt.axvline(x = 20,  ymin= 0, ymax = 0.50, linestyle = ":", color = "grey")
plt.axhline(y = 139, xmin= 0, xmax = 0.55, linestyle = ":", color = "grey")

# Texto agregado
plt.text(0, 150, '$DA^e$', fontsize = 11.5, color = 'black')
plt.text(55, 145, '$E$', fontsize = 11.5, color = 'black')
plt.text(75, 150, '$B$', fontsize = 11.5, color = 'black')
plt.text(20, 130, '$A$', fontsize = 11.5, color = 'black')
plt.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
plt.text(2.5, -3, '$◝$', fontsize = 30, color = '#404040')
plt.text(57, 0, '$Y^e$', fontsize = 12, color = 'black')

# Título y leyenda
ax.set(title = "Modelo de Ingreso-Gasto: exceso y déficit de demanda", xlabel = r'Y', ylabel = r'DA')
ax.legend()

plt.show()

# %% [markdown]
# 2. En el presente gráfico, se logra observar que la oferta de producción se ajusta a los cambios de la demanda agregada. en la Por un lado, se observa que hay una mayor demanda agregada en comparación al nivel de producción en el punto A. Así, para conseguir el punto de equilibrio se ha producido un exceso de la demanda, la cual disminuye los inventarios, pero a su vez incrementa la producción. Por otro lado, observamos un exceso de producción en el punto B, lo cual genera un incremento de los inventarios y una disminución de la producción.

# %% [markdown]
# 3. Las herramientas de política fiscal son el gasto público y la tasa impositiva. Un ejemplo de ello en el caso peruano sería el bono Wanuchay, pues representa un gasto del Estado hacia los productores de la agricultura familiar con el objetivo de fortalecer la seguridad alimentaria del país según el Decreto de Urgencia N° 108-2021. Esto movilizaría la economía, pues al aumentar el gasto público se aumenta la producción y, con ello, el consumo. Por otro lado, las herramientas de política monetaria son la masa monetaria y la tasa de interes. En general, tiene que ver con la forma en la que se comporta el BCR respecto a la economía con el fin de movilizarla. Un ejemplo de ello en el Perú es cuando el BCR aumenta o disminuye la tasa de interés. De hecho, según la revista "Bloomberg al día", este año el BCR subió la tasa de interés de referencia al 7% con el fin de amortiguar la inflación y, así, hacer que la economía se mueva.

# %% [markdown]
# 4. YAPE y PLIN son un ejemplo de una implementación exitosa de las billeteras digitales en el Perú. Ambas aplicaciones, respaldadas por sus bancos correspondientes, nos permiten realizar transferencias al momento sin un costo adicional, por lo que poseen menor liquidez. No obstante, estas transferencias tienen que ser de montos menores. Sin embargo, aquello no quita el hecho de que faciliten el intercambio de dinero en Perú, teniendo en cuenta que gran parte de nuestra economía está compuesta por los negocios informales, los cuales no acedptan tarjetas en su mayoría. Asimismo, esto nos beneficia a nosotros como usuarios, pues es conocido que hay negocios informales que aceptan tarjetas, pero corremos el riesgo de ser víctimas del fraude (por ejemplo, nos pueden clonar las tarjetas). En base a ello, se podría decir que ambas aplicaciones han cumplido con las funciones de la economía, por lo que han logrado ser tan exitosas. Por un lado, con que “el dinero como unidad de cuenta disminuye los costos de transacción, pues reduce el número de precios existentes en la economía y facilita la realización de las transacciones”. Por otro lado, con la función de medio de pago, ya que el dinero entra en el circuito del crédito y se utiliza para liquidar o cancelar deudas. Asimismo, ambas billeteras representan un poder adquisitivo al largo del tiempo. Finalmente, con la función del dinero como método de intercambio, pues promueve la eficiencia económica al no cobrar algún tipo de comisión entre transferencias.

# %% [markdown]
# 5. En primer lugar, Dancourt concluye que el BCRP debería disminuir la tasa de interés y vender moneda extranjera para hacer frente a los shocks externos adversos. Se observa que la crisis de 2008-09 fue la única donde se disminuyó el impacto del choque externo adverso, ya que el banco disminuyó la tasa de interés de referencia, a diferencia de las otras seis crisis. En segundo lugar, arguye que el BCRP debe incrementar la tasa de interés y adquirir divisas en respuesta a los shocks externos favorables. Además, teniendo en cuenta ambas ideas el autor llega a la conclusión de que la intervención cambiaria esterilizada debe ser anticíclica. Asimismo, constata que una política monetaria como la planteada por Blanchard pueda ser empleada con el fin de estabilizar los niveles de precios y la actividad económica sin liquidar los recursos productivos a largo plazo, lo cual beneficia a nuestra economía, pues no es muy diversa. Lo interesante de la política de Blanchard es que une la regla de Taylor con una regla de intervención del tipo de cambio.

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# #### 1.1. Determinación del Ingreso de Equilibrio
#
# Para la determinar el ingreso de equilibrio, se tinee que la demanda agregada se denota como:
# $$ DA=C+I+G+X-M $$
#
# Datos que se conocen:
#
# $ C= C_0+bY^d$
#
# $ I= I_0-hr$
#
# $ G= G_0$
#
# $ X= x_1Y^*+x_2\epsilon$
#
# $ M= m_1Y^d-m_2\epsilon$
#
# $ T= tY$
#
# $Y^d=Y-T$
#
# $DA=C+I+G+(X-M)$
#
# $Y=DA$
#
# $\epsilon=\epsilon_0-p(r-r^*)$
#
#
# ##### Por ende:
#
# $ Y= C_0+bY^d+I_0-hr+G_0+x_1Y^*+x_2\epsilon-m_1Y^d+m_2\epsilon$
#
# $ Y-(b-m_1)Y^d = C_0 + I_0 + G_0 + x_1Y^* +(x_2+m_2)\epsilon-hr$
#
# $ Y-(b-m_1)(1-t)Y=C_0 + I_0 + G_0  + x_1Y^* + (x_2+m_2)(\epsilon_0-pr+pr^*)-hr$
#
# $ Y[1-(b-m_1)(1-t)]=C_0 + I_0 + G_0 + x_1Y^* + (x_2+m_2)(\epsilon_0+pr^*)-[(x_2+m_2)p+h]r$
#
# $Y=\frac{1}{1-(b-m_1)(1-t)} [C_0 + I_0 + G_0 + x_1Y^* + (x_2+m_2)(\epsilon_0+pr^*)]-\frac{1}{1-(b-m_1)(1-t)}[(x_2+m_2)p+h]r$
#
# Donde $\frac{1}{1-(b-m_1)(1-t)}$ es el multiplicador

# %% [markdown]
# #### 1.2.

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# #### 2.1 El Modelo DA-OA y el nuevo esquema institucional de la Politica Monetaria, en el que la tasa de interes de referencia $r_0 $ es usada como instrumento
#
# ###### Demanda Agregada
#
# $ IS: [1-b(1-t)]Y= C_o + I_o + G_o -hr_0$
#
# $ IS: \beta_1Y=\beta_0-hr_0$
#
# $ IS: r_0= \frac{\beta_0}{h}-\frac{\beta_1}{h}Y  $
#
# ###### Donde:
#
# $ \beta_0 = C_o + I_o + G_o $ y $ \beta_1 = 1 - (b)(1 - t) $
#
# $ LM: M_0^s-P=kY-jr_0$
#
# Se reemplaza ($r$), y se obtiene la ecuación de la demanda agregada ($DA$) , que ahora es una recta y no una hipérbola
#
# $$ M_0^s-P=kY-j\frac{\beta_0}{h}+j\frac{\beta_1}{h}Y $$
#
# $$ P=M_0^s+j\frac{\beta_0}{h}-j\frac{\beta_1}{h}Y -kY$$
#
# $$P=\frac{hM_0^s+j\beta_0}{h}-\frac{j\beta_1+hk}{h}Y$$
#
#
#
# ###### Oferta Agregada
#
# $P = P^e + θ(Y - \bar{Y})$
#
#
# Se tiene en cuenta que en el modelo $DA-OA$ hay tres variables endógenas.
#
# $$ Y^{eq}, r^{eq} ,P^{eq}$$
#
#
# Considerando la ecuación de la demanda agregada $(DA)$:
#
# $$P=\frac{hM_0^s+j\beta_0}{h}-\frac{j\beta_1+hk}{h}Y ...(1)$$
#
#
# Y la ecuación de la oferta agregada $(OA)$:
#
# $$P=P^e+\theta(Y-Y ̅ ) ...(2)$$
#
# - Para hallar $ Y^{eq\_da\_oa}$ igualamos ecuaciones 1 y 2
#
# $$\frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}Y = P^e + θ(Y - \bar{Y})$$
#
# $$Y^{eq\_da\_oa} = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$
#
#
# ###### De esta forma
#
# - Para encontrar $P^{eq}$ solamente reemplazamos $ Y^{eq}$ en la ecuación de oferta agregada
#
# $$P^{eq\_da\_oa} = P^e + θ( Y^{eq\_da\_oa} - \bar{Y} )$$
#
# $$P^{eq\_da\_oa} = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} )$$

# %% [markdown]
# #### 2.2.

# %%
# Variables como símbolos
Co, Io, Go, Xo, h, r, b, m, t, beta_0, beta_1  = symbols('Co Io Go Xo h r b m t beta_0, beta_1')

k, j, Ms, P, Y = symbols('k j Ms P Y')

# Beta_0 y beta_1
beta_0 = (Co + Io + Go + Xo)
beta_1 = ( 1-(b-m)*(1-t) )

# Producto de equilibrio y la tasa de interés de equilibrio en el modelo IS-LM

Y_eq = (k*beta_0)/(k*h + j*beta_1) - ( beta_1 / (k*h + j*beta_1) )*(Ms/P)
r_eq = (j*beta_0)/(k*h + j*beta_1) + ( h / (k*h + j*beta_1) )*(Ms/P)

# %%
df_Y_eq_r = diff(Y_eq, r)
print("Diferencial del Producto con respecto al de la tasa de interés =" , df_Y_eq_r)
# Out:
# Diferencial del Producto con respecto al de la tasa de interés = 0

# %%
#1--------------------------
    # Demanda Agregada ORGINAL
    
#### Parámetros

Y_size = 100 

Co = 35
Io = 40
Go = 50
Xo = 2
h = 0.8
b = 0.4
m = 0.5
t = 0.8
r = 0.3

k = 2
j = 1                
Ms = 200             
P  = 8  

Y = np.arange(Y_size)


### Ecuación

B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_AD = P_AD(h, Ms, j, B0, B1, k, Y)

#2--------------------------
    # Oferta Agregada ORIGINAL
    
### Parámetros

Y_size = 100

Pe = 70
θ = 3
_Y = 20  

Y = np.arange(Y_size)

### Ecuación

def P_AS(r, _Y, Y, θ):
    P_AS = r + θ*(Y-_Y)
    return P_AS

P_AS = P_AS(r, _Y, Y, θ)


#--------------------------------------------------
    # NUEVA Oferta Agregada

#### parámetro cambiado

r = 0.9

#### Generar la ecuación con el nuevo parámetro

def P_AS_Pe(Pe, _Y, Y, θ):
    P_AS = Pe + θ*(Y-_Y)
    return P_AS

P_r = P_AS_Pe(Pe, _Y, Y, θ)

# %%
## Gráfico del modelo DA-OA

#### Dimensiones del gráfico

y_max = np.max(P)
fig, ax = plt.subplots(figsize=(10, 8))

#### Curvas a graficar 

ax.plot(Y, P_AD, label = "AD", color = "red") #DA
ax.plot(Y, P_AS, label = "AS", color = "brown") #OA
ax.plot(Y, P_r, label = "AS_r", color = "green", linestyle = 'dashed') #OA_r

#### Eliminar valores de ejes

ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())


#### Leyenda

ax.set(title="AD-AS", xlabel= r'Y', ylabel= r'P')
ax.legend()

plt.show()
