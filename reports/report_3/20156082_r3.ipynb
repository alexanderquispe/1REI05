# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
import pandas as pd
import numpy as np
import random
import math
import sklearn
import scipy as sp
import networkx
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col
from causalgraphicalmodels import CausalGraphicalModel

# %% [markdown]
# # REPORTE 3

# %% [markdown]
# ## Lectura: La Macroeconomía de la cuarentena: Un modelo de dos sectores
#
# Durante el 2020, ocurrió en el Perú el derrumbe del PBI y del empleo en 11 y 15 por ciento. Esta caída fue una de las más pronunciadas a nivel de América Latina y más severas desde el año 1989. Mendoza, Mancilla & Velarde (2021) en su artículo La Macroeconomía de la cuarentena: Un modelo de dos sectores abordan la pregunta de investigación acerca de cuáles fueron los efectos macroeconómicos de la cuarentena en la economía peruana.
# A lo largo del artículo, los autores buscan explicar los impactos generados a partir de la presentación de un modelo macroeconómico que pueda reproducir los hechos ocurridos frente a los efectos macroeconómicos de la cuarentena, la cual fue usada como instrumento de contención de la Covid-19. De esta manera, desarrollan la simulación de estos efectos estableciendo dos sectores, los cuales son keynesianos y están conectados a través del consumo de los trabajadores El sector 1 es aquel que fue afectado de manera directa por el cierre de actividades durante la cuarentena. En este sector se encuentran empresas como restaurantes, hoteles, aerolíneas, entre otros. El sector 2 es aquel que puso continuar con sus operaciones durante ese tiempo, pero que fue afectado de forma indirecta por el otro sector. Aquí se encuentran la producción de alimentos, así como los bienes y servicios indispensables.
# Los autores desarrollan una estructura que facilita la comprensión del artículo económico, de modo que presentan gráficos en los que comparan los resultados para ambos sectores y modelos, y también desarrollan ecuaciones de funciones. Por un lado, los autores presentan el modelo macroeconómico, el cual, según indican en el artículo, está inspirado en Blanchard (2021) y elaborado con el instrumental de Mendoza (2016). De esta manera, se establece que con respecto a la demanda agregada, en el mercado de bienes de ambos hay una relación inversa entre los precios y la producción; asimismo, respecto a la oferta agregada, ambos sectores tienen como determinantes el precio esperado y la brecha del PBI del sector. Además, se presenta los tres subsistemas que derivan del modelo general: corto plazo, equilibrio estacionario y tránsito al equilibrio estacionario.
# Por otro lado, se aborda directamente los efectos macroeconómicos de la cuarentena, de manera que se establece que se registra un impacto inicial en el sector 1 en la oferta agregada y en el consumo autónomo. En este sentido, se presenta 2 ejercicios para evidenciar los efectos sobre la producción y los precios a partir del choque mencionado. En el primer ejercicio, luego de los descensos de la producción y los precios en ambos sectores en el primer periodo, se evidencia que la economía va recuperándose paulatinamente hasta que la economía alcanza un nuevo equilibrio estacionario. En el segundo ejercicio ocurre un choque que produce una fuerte elevación del PBI en ambos sectores, acompañado de un aumento de precios. Luego, este incremento de precios esperado conducirá al descenso del PBI en ambos sectores hasta que los precios retornen a su nivel de antes de la pandemia.
# Los autores explican que la recuperación “rápida” del PBI, incluso por encima de niveles pre pandemia, se a debe a la política crediticia aplicada por el BCRP y el MEF, respecto a los créditos bancarios. Esto permitió la supervivencia de miles de empresas grandes y pequeñas. Este artículo ha demostrado la relevancia de los modelos macroeconómicos para medir los efectos de las fluctuaciones en la economía, de manera que sea posible reproducir los hechos que impactaron al modelo.
# Finalmente, es importante tomar en cuenta otros factores de gran relevancia que se desarrollaron a partir de la Covid-19. Como lo señalan Jaramillo y López (2021) en Políticas para combatir la pandemia del Covid-19, las muertes generadas por la propagación del virus incidieron fuertemente en la economía peruana. Por ello, es fundamental identificar los errores que se tomaron en cuanto al manejo de la salud pública, de manera que se pueda identificar cómo fue el manejo y el posterior impacto para la economía.

# %% [markdown]
# ## MERCADO MONETARIO
#
# ### Instrumentos de política monetaria que puede utilizar el Banco Central
#
# Las políticas monetarias hacen referencia a la cantidad de dinero circulando en la economía, cuyo principal objetivo es la estabilidad de los precios. El Banco Central es la autoridad monetaria y cabeza del sistema bancario. Como tal tiene
# la capacidad de controlar o gestionar la oferta monetaria (políticas monetaria extractivas o contractivas). Dichos movimientos son realizados mediante el uso de determinados instrumentos.
# El primer instrumento de política monetaria que utiliza el Banco Central para aumentar o disminuir la oferta monetaria, es la Operación de Mercado Abierto. El Banco Central hace estas operaciones mediante la compra o venta de activos financieros o bonos a los bancos comerciales. Aparte de las operaciones de mercado abierto, el banco central dispone como segundo instrumento el coeficiente legal de encaje. Por último, se encuentra la tasa de interés de referencia de la política monetaria.

# %% [markdown]
# ### Oferta real de dinero

# %% [markdown]
# Para expresar la oferta real de dinero (M^s) en el Mercado de Dinero se deriva la oferta nominal de dinero o masa monetaria (M^o) dividida entre el nivel general de precios de la economía (𝑃)
#
# $$ M^s = \frac{M^o}{P} $$
#
# Asimismo, se asume que el nivel de precios está dado para todo el análisis de corto plazo.

# %% [markdown]
# ### Demanda real de dinero

# %% [markdown]
# En general, la gente demanda dinero, como demanda cualquier otro bien o servicio, porque desea mantener cierto monto de riqueza líquida. Hay varios motivos por los que una empresa o familias demandan dinero, por lo que los tipos de demanda de dinero son:
# a. Transacción: se refiere a la necesidad de usar billetes para el intercambio
# b. Precaución: cuando la demanda suele depender del nivel de ingresos
# c. Especulación: se refiere a jugar
#
# La demanda de dinero por los motivos transacción y precaución dependen del ingreso, entonces:
#
# $$ L_1 = kY $$
#
# El motivo de especulación dependerá negativa o inversamente de la tasa de interés de los bonos:
#
# $$ L_2 = -ji $$
#
# Si asumimos que ambos tipos de demanda están en términos reales, la función de demanda real de dinero será:
#
# $$ L = L_1 + L_2 $$
#
# $$ L = kY -ji $$
#
# La magnitud del parámetro “k” indica la sensibilidad de la demanda de dinero ante variaciones del ingreso “Y”, y la del parámetro “j” indica cuán sensible es la demanda de dinero ante las variaciones de la tasa de interés nominal de los bonos, “i”.

# %% [markdown]
# ### Ecuación de equilibrio en el mercado de dinero

# %% [markdown]
# El corto plazo está caracterizado por el supuesto de un nivel de precios fijo y exógeno. Por lo tanto, puede suponerse que la inflación esperada es igual a cero, lo implica que no hay diferencia entre la tasa de interés nominal y real, es decir, que son aproximadamente iguales: $$ i = r $$
#
# Entonces la ecuación del equilibrio en el mercado monetario es:
# $$ \frac{M^s}{P} = kY - jr $$
#
# #### Gráfico

# %%
# Parameters
r_size = 100

k = 0.4
j = 0.2                
P  = 10 
Y = 43.7
MS_0 = 500

r = np.arange(r_size)

# Funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_0 = MD(k, j, P, r, Y)


# Función de la oferta de dinero.
MS = MS_0 / P
MS
# Out:
# 50.0

# %%
# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="Equilibrio en el mercado de dinero", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = '#CD5C5C')

# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "black")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=7.5, xmin= 0, xmax= 0.5, linestyle = ":", color = "red")

# Agregamos texto
ax1.text(0, 7.5, "$r_0$", fontsize = 12, color = 'blue')

ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# ## EFECTOS DENTRO DEL MERCADO DE DINERO
#
# ###  Disminución en la demanda de dinero
#
# Cuando disminuye el ingreso "Y", la demanda de dinero también disminuye. Si el mercado estaba en equilibrio, esta disminución del ingreso genera un déficit de la demanda en el mercado. El equilibrio debe restablecerse con una depreciación de la tasa de interés. La curva de demanda de dinero se desplaza hacia abajo.

# %% [markdown]
# ## CURVA LM

# %% [markdown]
# ### Derivación de la curva LM a partir del equilibrio en el mercado monetario
#
# Se refiere a todos los puntos de equilibrio dentro del mercado monetario. El equilibrio es cuando la demanda es igual a la oferta:
#
# $$ M^s = \frac{M_o^s}{P} $$
# $$ M^d = kY -jr $$
#
# $$ M^d = M^s $$
#
# $$ kY -jr = \frac{M_o^s}{P} $$
#
# $$ kY - \frac{M_o^s}{P} = jr $$
#
# $$ \frac{kY}{j} - \frac{M_o^s}{Pj} = r $$
#
# La tasa de interés que equilibra el mercado monetario será igual a:
# $$ r = -\frac{1}{j}\frac{M_o^s}{P_o} + \frac{k}{j}Y $$
#
# Son dos ecuaciones simultáneas. Todos los parámetros son positivos. La propensión marginal a consumir está entre cero y uno: 𝟎 < 𝒃 < 1

# %%
# Parametros
Y_size = 100

k = 20
j = 20                
Ms = 210             
P  = 30               

Y = np.arange(Y_size)


# Ecuación

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

# %%
# Gráfico de la curva LM

# Dimensiones del gráfico
y_max = np.max(i)
v = [0, Y_size, 0, y_max]   
fig, ax = plt.subplots(figsize=(10, 8))

# Eliminar las cantidades de los ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Curvas a graficar
ax.plot(Y, i, label="LM", color = 'purple')

# Título y leyenda
ax.set(title="LM SCHEDULE", xlabel=r'Y', ylabel=r'r')
ax.legend()


plt.show()

# %% [markdown]
# ### Disminución en la masa monetaria
#
# Cambios en la oferta nominal de dinero también producen cambios en la tasa de interés para equilibrar el mercado monetario; por lo tanto, también afecta la posición de la curva LM.
#
# La disminución de la oferta monetaria provoca aumentos de la tasa de interés para los diferentes tipos de ingreso dados. En otras palabras, para un mismo nivel de ingreso, cuando disminuye la oferta de dinero, la tasa de interés debe subir para que se restaure el equilibrio en el mercado monetario.
#
# Intuición: Si disminuye la Masa Monetaria, la recta se desplaza a la izquierda y la tasa de interés de equilibrio aumenta.

# %%
#--------------------------------------------------
    # Curva LM ORIGINAL

# Parámetros

Y_size = 100

k = 20
j = 20               
Ms = 700             
P  = 20               

Y = np.arange(Y_size)

# Ecuación

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

#--------------------------------------------------
    # NUEVA curva LM

# Definir SOLO el parámetro cambiado
Ms = 200

# Generar la ecuación con el nuevo parámetro
def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)

# %%
# Dimensiones del gráfico
y_max = np.max(i)
v = [0, Y_size, 0, y_max]   
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, i, label="LM", color = 'orange')
ax.plot(Y, i_Ms, label="LM_Ms", color = 'green', linestyle = 'dashed')

# Texto agregado
plt.text(47, 76, '∆$M^s$', fontsize=12, color='black')
plt.text(49, 70, '←', fontsize=15, color='grey')

# Título y leyenda
ax.set(title = "Incremento en la Masa Monetaria $(M^s)$", xlabel=r'Y', ylabel=r'r')
ax.legend()


plt.show()

# %% [markdown]
# ### Aumento de capital
#
# Cambios en la oferta nominal de dinero también producen cambios en la tasa de interés para equilibrar el mercado monetario; por lo tanto, también afecta la posición de la curva LM.
#
# Intuición: Si la sensibilidad aumenta, nos da una certeza de cuanto será la variación del ingreso.

# %%
#--------------------------------------------------
    # Curva LM ORIGINAL

# Parámetros

Y_size = 100

k = 20
j = 20               
Ms = 700             
P  = 20               

Y = np.arange(Y_size)

# Ecuación

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

#--------------------------------------------------
    # NUEVA curva LM

# Definir SOLO el parámetro cambiado
k = 5

# Generar la ecuación con el nuevo parámetro
def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)

# %%
# Dimensiones del gráfico
y_max = np.max(i)
v = [0, Y_size, 0, y_max]   
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, i, label="LM", color = 'orange')
ax.plot(Y, i_Ms, label="LM_Ms", color = 'green', linestyle = 'dashed')

# Texto agregado
plt.text(47, 76, '∆$k$', fontsize=12, color='black')
plt.text(49, 70, '↑', fontsize=15, color='grey')

# Título y leyenda
ax.set(title = "Incremento en la Masa Monetaria $(M^s)$", xlabel=r'Y', ylabel=r'r')
ax.legend()


plt.show()
