# %% [markdown]
# ## REPORTE Nº2:
# #### Alumno: Sonia Margarita Lecaros Jimenez / Código: 20226229
# #### Curso: Fundamentos de Macroeconomia - 1REI05

# %% [markdown]
# ## PARTE 1
#
#
# En el artículo materia de lectura de este reporte, los autores tratan de interpretar de puntos de vista político, social y económico la historia monetaria y fiscal de Perú desde 1960, teniendo particular interes el tema de la inflación a traves de las decadas y el tratamiento dado para evitar la hiperinflación en las últimas décadas. Tambien nos explica como a traves de cambio en el regimen de politicas adoptadas por el gobierno fue posible revertir la hiperinflación en la que estaba sumada el país entre 1985 - 1990.
# En la lectura se detalla de forma muy didáctica hechos históricos pero con un enfoque monetarista y económico lo que brinda detalles adicionales y el trasfondo de las decisiones tomadas para el cambio en el curso de la politicas económicas, este es quizas la mayor fortaleza de la lectura, poder narras sucesos historicos y asociarlos con políticas económicas.
# La contribución de esta lectura es dar a conocer que no solo basta tener buenas políticas económicas para poder tener una económia saludable en el país sino tambien tiene que ir de la mano con el apoyo popular de la población, un esquema constitucional democrático que brinde autonomía e independencia a todos los organismos participativos del Estado y adicionalmente la participación de funcionarios públicos competentes que puedan ejecutar las políticas económicas adcuadas para el crecimiento del país.
# Uno de los pasos importantes a tener en consideración para seguir con una política fiscal buena es respetar la independencia del Banco Central de Reserva, rechazar la imprudencia fiscal, evitar disputas entre los poderes del estado y contar con funcionarios competentes en el Ministerio de Economía y Finanzas.

# %%
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
from sympy import *
import pandas as pd

# %% [markdown]
# ## Codigo en Python

# %% [markdown]
# # a. El Modelo Ingreso-Gasto: la Curva IS
#
# * Utilizando las ecuaciones derive paso a paso la curva IS matemáticamente (a partir de la condición de equilibrio Y = DA).
#   En el modelo Ingreso-Gasto el equilibrio entre el Ingreso y la DA representa el equilibrio en el mercado de bienes
#
#   $$ 𝑌 = (𝐶_0 + 𝐼_0 + 𝐺_0 + 𝑋_0 − ℎ𝑟) + (𝑏 − 𝑚)(1 − 𝑡)𝑌 $$
#   $$ [1 − (𝑏 − 𝑚)(1 − 𝑡)]𝑌 = 𝐶_0 + 𝐼_0 + 𝐺_0 + 𝑋_0 − ℎ𝑟 $$
#   $$ Y = \frac{1}{𝐶_0 + 𝐼_0 + 𝐺_0 + 𝑋_0 − ℎ𝑟)}  $$
#
# * Y en funcion de r $$ Y = f(r) $$
#
#   $$ Y = \frac{1}{(1 − (𝑏 − 𝑚)(1 − 𝑡))} (C_0 + I_0 + G_0 + X_0) - \frac{h}{1 − (𝑏 − 𝑚)(1 − 𝑡)} r $$

# %% [markdown]
# * Utilizando la función de equilibrio IS donde r está en función de Y, encuentre  Ar / Ay
#   que representa la pendiente y qué signo tiene?
#
#   La igualdad entre el ahorro y la inversion representa la curva IS
#   De la pregunta (1) se deriva que r en funcion de y $$ r=𝑓(Y)$$
#
#   $$ r = \frac{1}{h} (C_0 + I_0 + G_0 + X_0) - \frac{1 − (𝑏 − 𝑚)(1 − 𝑡)}{h} Y $$
#
#   La ecuacion lineal $$ r = b + m * y $$
#
#   $$ r = \frac{B_0}{h} - \frac{B_1}{h} Y $$
#
#   Derivando r en funcion a Y  $$ \frac{∆r}{∆y} = 0 - \frac{B_1}{h} $$
#
#   # La pendiente tiene signo negativo

# %% [markdown]
# * Lea la sección 4.4 del material de enseñanza y explique cómo se deriva la curva IS a partir del equilibrio $$ Y = DA $$  y grafique:
#
# El equilibrio de  la curva IS representa una situación en la que todo lo que se produce en la economía (Y)
# es consumido por todos los agentes de la misma (sector público, sector privado y sector exterior), o lo que es lo mismo,
# el ahorro iguala a la inversión.

# %%
# Recta de 45°
a = 2.5 
def L_45(a, Y):
    L_45 = a*Y
    return L_45
L_45 = L_45(a, Y)

#--------------------------------------------------
# Curva de ingreso de equilibrio ORIGINAL

# Parámetros
Y_size = 100 

Co = 25
Io = 30
Go = 60
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3 #tasa de tributación
r = 0.9

Y = np.arange(Y_size)

    # Ecuación 
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

#--------------------------------------------------
# NUEVA curva de ingreso de equilibrio

# Definir SOLO el parámetro cambiado
Co = 35
Io = 40
Go = 70
DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %% [markdown]
# ## IS CURVE

# %%
# Curves to plot
# Parameters

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3

Y = np.arange(Y_size)


# Equation 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (1/h)*(Co + Io + Go + Xo) - (1/h)*(1-(b-m)*(1-t))*Y
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %%
# Plot of the derivation of the IS curve from equality (DA = Y)

    # Two graphs in one frame
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 

#---------------------------------
    # Graph 1: Short-Term Equilibrium Income
    
ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.plot(Y, DA_IS_K, label = "DA_0", color = "C0", linestyle = "-") 
ax1.plot(Y, DA_G, label = "DA_1", color = "C0", linestyle = ":") 
ax1.plot(Y, L_45, color = "#404040") 

ax1.axvline(x = 70.5, ymin= 0, ymax = 0.69, linestyle = ":", color = "grey")
ax1.axvline(x = 54,  ymin= 0, ymax = 0.54, linestyle = ":", color = "grey")

ax1.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
ax1.text(2.5, -3, '$◝$', fontsize = 30, color = 'black')
ax1.text(72, 0, '$Y_1$', fontsize = 12, color = 'black')
ax1.text(56, 0, '$Y_0$', fontsize = 12, color = 'black')
ax1.text(67, 185, 'E_1', fontsize = 12, color = 'black')
ax1.text(50, 142, 'E_0', fontsize = 12, color = 'black')

ax1.set(title = "Derivacion de la Curva IS", xlabel = r'Y', ylabel = r'DA')
ax1.legend()

#---------------------------------
    # Graph 2: IS Curve

ax2.yaxis.set_major_locator(plt.NullLocator())   
ax2.xaxis.set_major_locator(plt.NullLocator())

ax2.plot(Y, r, label = "IS", color = "C1") 

ax2.axvline(x = 70.5, ymin= 0, ymax = 1, linestyle = ":", color = "grey")
ax2.axvline(x = 54,  ymin= 0, ymax = 1, linestyle = ":", color = "grey")
plt.axhline(y = 151.5, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
plt.axhline(y = 165, xmin= 0, xmax = 0.55, linestyle = ":", color = "grey")

ax2.text(72, 128, '$Y_1$', fontsize = 12, color = 'black')
ax2.text(56, 128, '$Y_0$', fontsize = 12, color = 'black')
ax2.text(1, 153, '$r_1$', fontsize = 12, color = 'black')
ax2.text(1, 167, '$r_0$', fontsize = 12, color = 'black')
ax2.text(72, 152, 'E_1', fontsize = 12, color = 'black')
ax2.text(55, 166, 'E_0', fontsize = 12, color = 'black')

ax2.set(title = " IS", xlabel= 'Y', ylabel= 'r')
ax2.legend()

plt.show()

# %% [markdown]
# ## b. La Curva IS o el equilibrio Ahorro Inversión
#
# * Derive la ecuacion de IS  a partir de la igualdad Ahorro inversion y grafique la curva IS de equilibrio del Mercado de Bienes

# %% [markdown]
# * El equilibrio entre el ingreso y la demanda agregada es equivalente al equilibrio entre el ahorro total y la inversión
#    $$ DA= Y $$
#    $$ 𝑌 = 𝐶  + 𝐼  + 𝐺  + 𝑋 - M $$
#
#   Restando la tributación T en ambos lado
#   $$ 𝑌 - T = 𝐶  + 𝐼 - T  + 𝐺  + 𝑋 - M $$
#   $$ 𝑌^d = 𝐶  + 𝐼 - T  + 𝐺  + 𝑋 - M $$
#
#   Esta igualdad se puede reescribir de la siguiente manera:
#   $$ (𝑌^d - 𝐶) + ( T  - 𝐺 ) + (M - 𝑋 ) = I $$
#
#   El lado derecho constituye el ahorro total que es igual a la inversión
#
#   $$ S_p + S_g + S_e = 𝐼_O - hr $$
#
#   $$ S = 𝐼_O - hr $$
#
#   Esta igualdad entre el ahorro y la inversión representa precisamente la curva IS
#
#   $$ S(Y) = 𝐼(r) $$
#
#   Haciendo reemplazos se obtiene que:
#
#   $$ (𝑌^d - C_O - b𝑌^d) + (T -G_O) + (m𝑌^d - X_O)  = 𝐼_O - hr $$
#
#   Mediante operaciones algebráicas se obtiene
#
#    $$ [1 -( b - m) (1 - t)] 𝑌 - ( C_O + G_O + X_O) = 𝐼_O - hr $$
#
#    $$ r = \frac{1}{h} (C_0 + I_0 + G_0 + X_0) - \frac{1 − (𝑏 − 𝑚)(1 − 𝑡)}{h} Y $$
#
#   La ecuación lineal $$ r = b + m * y $$
#
#   $$ r = \frac{B_0}{h} - \frac{B_1}{h} Y $$

# %%
# Graph of the IS curve


# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS", color = "C1") #Demanda agregada

# Remove the quantities from the axes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())
ax.text(90, 140, 'IS', fontsize = 12, color = 'black')


# Title, axes adn legend
ax.set(title = "La Curva IS de equilibrio en el Mercado de Bienes", xlabel= 'Y', ylabel= 'r')
ax.legend()

ax.legend()
plt.show()

# %% [markdown]
# ## c. Desequilibrio en el mercado de bienes
#
# Grafique las áreas de exceso de oferta o exceso de demanda en el mercado de bienes. Explique por que estos puntos están fuera de los puntos de equilibrio en el mercado de bienes.
#
# Cada vez que los mercados experimentan una inestabilidad como por ejemplo se producen precios desequilibrados, excedentes y escasez,  las fuerzas del mercado conducirán nuevamente a precios de equilibrio.
# En el gráfico existe un exceso de oferta cuando el precio real del producto está por encima del precio del mercado, dando lugar a un aumento de la oferta, y asu vez conllevará a que disminuya la demanda, lo que dará como resultado que el precio real del producto baje.
# Si sucede lo contrario, es decir, el precio real está por debajo del precio de mercado, habrá menos oferta y a la vez una mayor demanda, de esta forma, el producto se agotaría en stock y el precio subiría.

# %%
# Curves to plot
# Parameters

Y_size = 100 

Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
Y = np.arange(Y_size)
# Equation 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (1/h)*(Co + Io + Go + Xo) - (1/h)*(1-(b-m)*(1-t))*Y
    return r_IS
r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS", color = "C1") #Demanda agregada

# Remove the quantities from the axes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())
ax.text(0, 180, '$r_A$', fontsize = 12, color = 'black')
ax.text(22, 180, 'C', fontsize = 12, color = 'black')
ax.text(37, 180, 'A', fontsize = 12, color = 'black')
ax.text(52, 180, 'B', fontsize = 12, color = 'black')
ax.text(22, 127, '$Y_C$', fontsize = 12, color = 'black')
ax.text(37, 127, '$Y_A$', fontsize = 12, color = 'black')
ax.text(52, 127, '$Y_B$', fontsize = 12, color = 'black')
#/// Lineas horizontales | Lineas verticales
plt.axvline(x = 22,  ymin= 0, ymax= 0.69, linestyle = ":", color = "grey")
plt.axvline(x = 37,  ymin= 0, ymax= 0.69, linestyle = ":", color = "grey")
plt.axvline(x = 52,  ymin= 0, ymax= 0.69, linestyle = ":", color = "grey")
plt.axhline(y = 180, xmin= 0, xmax = 0.7, linestyle = ":", color = "grey")
#// Texto
plt.text(24, 160, 'Exceso de', fontsize = 11.5, color = '#3D59AB')
plt.text(24, 155, 'demanda', fontsize = 11.5, color = '#3D59AB')
#// Texto
plt.text(65, 190, 'Exceso de', fontsize = 11.5, color = '#3D59AB')
plt.text(65, 185, 'Oferta', fontsize = 11.5, color = '#3D59AB')

# Title, axes adn legend
ax.set(title = "Equilibrio y Desequilibrio en el Mercado de Bienes", xlabel= 'Y', ylabel= 'r')
ax.legend()

ax.legend()
plt.show()

# %% [markdown]
# ## d. Movimiento de la curva IS
#
# Utilizando el modelo macroeconómico en a) responda los siguiente:
# * Analice un política fiscal contractiva con caída del gasto del gobierno. El análisis debe ser intuitivo y gráfico

# %%
#-------------------------------------------------- 
# ORIGINAL IS Curve
# Parameters
Y_size = 100 
Co = 35
Io = 40
Go = 70
Xo = 2
h = 0.7
b = 0.8
m = 0.2
t = 0.3
Y = np.arange(Y_size)

# Equation 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

#--------------------------------------------------
    # New IS Curve

# Contraccion en el gasto del gobierno $(G_0)$
Go = 60
r_G = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# Politica fiscal expansiva caida tasa de impuesto $(↓t)
Go = 70
t = -0.1
r_t = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# Politica fiscal expansiva caida tasa de impuesto $(↓t)
Go = 70
b = 0.4
r_b = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)

# %% [markdown]
# ## Intuición:
#
# $$ ∆G < 0 →  ↓G $$
# $$ ↓Go → ↑G → DA↑ → DA > I → ↓Y $$

# %%
# Graph

# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS0", color = "black") #IS orginal
ax.plot(Y, r_G, label = "IS_1", color = "C1", linestyle = 'dashed') #New IS

# Text added
plt.text(47, 162, '∆Go', fontsize=12, color='black')
plt.text(49, 159, '↓', fontsize=15, color='grey')

ax.text(90, 140, 'IS0', fontsize = 18, color = 'black')
ax.text(80, 130, 'IS1', fontsize = 18, color = 'black')

# Title and legend
ax.set(title = "Contracción en el gasto del gobierno $(G_0)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# * Analice un politica fiscal expansiva con caida de la tasa de impuesto. El análisis debe ser intuitivo y gráfico
# ## Intuición:
#
# $$ ↓E →  ∆T < 0 $$

# %%
# Graph

# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS0", color = "black") #IS orginal
ax.plot(Y, r_t, label = "IS1", color = "C1", linestyle = 'dashed') #New IS

# Text added
plt.text(70, 162, '∆t', fontsize=12, color='black')
plt.text(70, 159, '↓', fontsize=15, color='grey')

ax.text(90, 170, 'IS1', fontsize = 18, color = 'black')
ax.text(80, 130, 'IS0', fontsize = 18, color = 'black')

# Title and legend
ax.set(title = "Politica fiscal expansiva caída tasa de impuesto $(↓t)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()

# %% [markdown]
# * Analice una caida de la propensión Marginal a consumir
# ## Intuición:
# $$ ∆b < 0 $$

# %%
# Graph

# Dimensions
y_max = np.max(r)
fig, ax = plt.subplots(figsize=(10, 8))

# Curves to plot
ax.plot(Y, r, label = "IS0", color = "black") #IS orginal
ax.plot(Y, r_b, label = "IS1", color = "C1", linestyle = 'dashed') #New IS

# Text added
plt.text(47, 162, '∆b', fontsize=12, color='black')
plt.text(49, 159, '↓', fontsize=15, color='grey')

ax.text(90, 140, 'IS0', fontsize = 18, color = 'black')
ax.text(75, 130, 'IS1', fontsize = 18, color = 'black')

# Title and legend
ax.set(title = "Caída de la Propensión Marginal a consumir $(↓b)$", xlabel= 'Y', ylabel= 'r')
ax.legend()

plt.show()
