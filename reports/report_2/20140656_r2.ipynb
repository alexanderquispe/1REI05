# %% [markdown]
# # Parte 1: Reporte

# %% [markdown]
# El artículo, muestra la inflación tan alarmante que tuvo el Perú durante los años 1970 y 1980, el cual, fue resultado de los impuestos inflacionarios del régimen de predominio fiscal de la política monetaria. Esto sucedió cuando la acumulación de deuda dejó de estar disponible y una administración populista se involucró en una política contraproducente de control de precios y crédito flexible. A su vez, analizan cuantitativamente 3 mediciones: contabilidad de crecimiento, contabilidad fiscal y análisis de las políticas adoptadas (es decir, una perspectiva institucional). La conclusión de este análisis fue que los déficits fiscales fueron financiados por medio de impuestos inflacionarios y la acumulación de la deuda pública externa. También, que la BCRP, fue la principal fuente de financiamiento interno que lamentablemente fue criticado por la falta de transparencia en sus acciones. Terminó concluyendo, que la acción del Estado, fue contraproducente y agravaron la situación.
#
# Asimismo, el artículo muestra resultados que permiten analizar no solo la problemática de la hiperinflación sino también las posibles soluciones a ella mediante datos históricos y cuantitativos. En este punto, destaca las debilidades instituciones políticas e institucionales del Perú durante el periodo de la hiperinflación. Pero, demuestra poca información e importancia al tema de los choques internos, como lo fue el conflicto armado interno, los desastres, la centralización que se vivió en la época, entre otros.
#
# Este artículo, es importante porque muestra los “beneficios'' que le trajo al país una "adecuada" política fiscal y monetaria, que de alguna manera, justifica la continuidad de la política monetaria y fiscal del país. Sin embargo, sería bueno que pueda existir dentro del artículo, la opinión pública, ya que en la actualidad, tiene mucho peso y se ha ido incrementando por las constantes marchas debido a las irregularidades que existe dentro de todo el sistema del Estado, incluyendo la política fiscal que en los últimos años, no ha realizado una buena gestión.
#
# Considero que para avanzar en esta investigación, se debería comparar las políticas fiscales y monetarias durante la época vivida entre  1970 y 1980, y los últimos años, importante porque el Perú, es un país que ha pasado y sigue pasando por varias crisis de diversa índole, y, esto es necesario para identificar los cambios, continuidades, fallas y fortalezas de la política económica del país.

# %% [markdown]
# # Parte 2: Códigos
#
# PROFESOR, AÚN NO TENÍA GRUPO Y YA HABÍA COMENZADO HACER EL EJERCICIO 1 SOLA, PERO A PARTIR DEL EJERCICIO 2, 3 Y 4 LO COMENZAMOS A TRABAJAR EN EQUIPO JUNTO A MI COMPAÑERA:
# Dana Aneliz Rodriguez Sandi (20190910)

# %% [markdown]
# # Ejercicio 1:

# %% [markdown]
# # 1.1:
# Para calcular la "Curva IS"(IS), a partir de la condición de equilibrio Y^e = DA :
#
# Datos:
# $$ C = C_0 + bY^d $$
# $$ I = I_0 - hr $$
# $$ G = G_0 $$
# $$ T = tY $$
# $$ X = X_0 $$
# $$ M = mY^d $$
# ----------------------------
# Resultado de la suma de "Datos" que es igual a "DA":
# $ DA = C + I + G + X -M $
#
# Para encontrar el Y^e , le restaremos la "Tributación Total" (T) a la ecuación:
#
# $ Y-T = Y-T = Y^dC + I + G + X -M -T $
# * $ Y-T = Y^d $ #(dato)
#
# Reemplazamos dato en: $ Y^d= C + I + G+X-M-T $
#
# Despejando la inversión: $ Y^d - C - G - X + M + T = I $
# * $ Y^d - C = Sector privado(Sp) $
# * $ T - G = Sector gobierno(Sg) $
# * $ M-X = sector externo o internacional(Se) $
# * $ Sp + Sg+ Se = S $
#
# Ordenando en la ecuación:
# $ (Y^d - C)+(T-G)+(M-X)= I $
#
# * $ (Y^d - C)+(T-G)+(M-X) = Ahorro Total (S) $
#
# Por tanto, tenemos que:
#
# $ Sp + Sg+ Se = S $
#
# $ S(Y) =I (r) $
#
# Reemplazando en la ecuación del Ahorro Total (S):
# * $ Y^d =(1-t)y $ #(dato)
#
#  $ [(Y^d - (C_O + bY^d)]+[t^y - G_O]+[mY^d-X_O]=I_O - hr $
#  $ [1-(b-m)(1-t)]*Y - [C_O+G_O+X_O]=I_O - hr $
#
# * $ [1-(b-m)(1-t)]*Y - [C_O+G_O+X_O] = S $ #(dato)
# * $ I_O - hr =I $ #(dato)
#
# Despejando "hr":
#
# $ hr=I_0-[1-(b-m)(1-t)]*Y-(C_O+G_O+Y_O) $
#
# $$ hr = (C_0 + G_0 + I_0 + X_0) - (1 - (b - m)(1 - t))Y $$
#
# $$ r = \frac{1}{h}(C_0 + G_0 + I_0 + X_0) - \frac{1 - (b - m)(1 - t)}{h}Y $$
#
# Simplificando:
#
# $$ r = \frac{X_0}{h} - \frac{X_1}{h}Y $$
#
# * Intercepto: $ X_0 = C_0 + G_0 + I_0 + X_0  $
# * Pendiente: $  X_1 = 1 - (b - m)(1 - t) $

# %% [markdown]
# # 1.2:
#
# Partiendo de la ecuación "r" ( vista en el punto 1.1):
#
# $$ r = \frac{1}{h}(C_0 + G_0 + I_0 + X_0) - \frac{1 - (b - m)(1 - t)}{h}Y $$
#
# Hallar: $ ∆r/∆Y $
#
# Considernado el diferencial de $∆r$:
#
#  * $∆r$ =  $ \frac{1}{h}(C_0 + G_0 + I_0 + X_0) - \frac{1 - (b - m)(1 - t)}{h}* ∆Y $
#
#  Dando forma:
#
# $ ∆r/∆Y = - \frac{1 - (b - m)(1 - t)}{h} $
#
#
# Entonces:
#
# $$ \frac{∆r}{∆Y} = (-)(+) $$
#
# Dado que $∆r < 0$,  la multiplicación de unn negativo y un positivo, da como resultado un negativo. Por tanto quedaría:
#
# $$ \frac{∆r}{∆Y} = (-) $$
#
# $$ \frac{∆r}{∆Y} < 0 $$
#
#
# La pendiente de la Curva IS es mayor que cero y puede graficarse en el plano (Y,r) con una recta con pendiente negativa.

# %% [markdown]
# # 1.3:
# Haciendo reemplazos y algunas operaciones en esta condición de equilibro, se obtiene:
#
# $ Y=\frac{1}{1-(b-m)(1-t)}(C_0 + G_0 + I_0 + X_0) - \frac{h}{(1-(b-m)(1-t))}*Y $
#
# O también se puede expresar de la siguiente manera:
#
# $ r=\frac{1}{h}(C_0 + G_0 + I_0 + X_0) - \frac{1 - (b - m)(1 - t)}{h}*Y $
#
# En esta ecuación, el Ingreso (Y) y la tasa de interés (r), equilibran el mercado de bienes. Se puede graficar a partir del equilibrio $ DA = Y $ en la recta de 45°.
#
# Dado el ingreso de equilibro $ “Y_0” $ que corresponde a una tasa de interés real igual a $ “r_0” $ , se produce una reducción de la tasa de interés que ahora será igual a r_1; es decir: $ 𝑟_0 > r_1 $ . Esta reducción de la tasa de interés eleva la magnitud del intercepto de la función de la Demanda Agregada (DA) desplazándola hacia arriba dando lugar a un ingreso de equilibrio de mayor magnitud e igual a $ Y_1 $ .

# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sy
import pandas as pd
from causalgraphicalmodels import CausalGraphicalModel
from sympy import *

# %%
# Parámetros

Y_size = 100 

Co = 36
Io = 41
Go = 71
Xo = 3
h = 0.6
b = 0.7 # b > m
m = 0.1
t = 0.2
r = 0.8

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_IS_K = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# Recta de 45°

a = 2.5

def L_45(a, Y):
    L_45 = a*Y
    return L_45

L_45 = L_45(a, Y)

# Segunda curva de ingreso de equilibrio

    # Definir cualquier parámetro autónomo
Go = 35

# Generar la ecuación con el nuevo parámetro
def DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y):
    DA_K = (Co + Io + Go + Xo - h*r) + ((b - m)*(1 - t)*Y)
    return DA_K

DA_G = DA_K(Co, Io, Go, Xo, h, r, b, m, t, Y)

# %%
# Parámetros
Y_size = 100 

Co = 36
Io = 41
Go = 71
Xo = 3
h = 0.6
b = 0.7 # b > m
m = 0.1
t = 0.2
r = 0.8

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = (Co + Io + Go + Xo - Y * (1-(b-m)*(1-t)))/h
    return r_IS

r = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


# Gráfico de la derivación de la curva IS a partir de la igualdad (DA = Y)

    # Dos gráficos en un solo cuadro (ax1 para el primero y ax2 para el segundo)
fig, (ax1, ax2) = plt.subplots(2, figsize=(8, 16)) 

#---------------------------------
    # Gráfico 1: ingreso de Equilibrio
ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.plot(Y, DA_IS_K, label = "$DA_0$", color = "brown") 
ax1.plot(Y, DA_G, label = "$DA_1$", color = "brown",linestyle = 'dashed') 
ax1.plot(Y, L_45, color = "black") 

ax1.axvline(x = 94, ymin= 0, ymax = 0.9, linestyle = ":", color = "yellow")
ax1.axvline(x = 75,  ymin= 0, ymax = 0.74, linestyle = ":", color = "yellow")

ax1.text(6, 4, '$45°$', fontsize = 11.5, color = 'black')
ax1.text(2.5, -3, '$◝$', fontsize = 30, color = 'black')
ax1.text(74, -24, '$Y_0$', fontsize = 15, color = 'black')
ax1.text(94, -24, '$Y_1$', fontsize = 15, color = 'black')
ax1.text(72, 192, '$E_0$', fontsize = 12, color = 'black')
ax1.text(92, 241, '$E_1$', fontsize = 12, color = 'black')
ax1.text(50, 230, '$DA(r_1);siendo r_1<r_0$', fontsize = 12, color = 'black')
ax1.text(50, 220, '$↓$', fontsize = 12, color = 'black')
ax1.text(50, 188, '$DA(r_0)$', fontsize = 12, color = 'black')
ax1.text(50, 180, '$↓$', fontsize = 12, color = 'black')


ax1.set(title = "Derivación de la curva IS a partir del equilibrio $Y=DA$", xlabel = r'Y', ylabel = r'DA')
ax1.legend()

    # Curva IS

ax2.yaxis.set_major_locator(plt.NullLocator())   
ax2.xaxis.set_major_locator(plt.NullLocator())

ax2.plot(Y, r, label = "IS", color = "C1") 

ax2.axvline(x = 94, ymin= 0, ymax = 1, linestyle = ":", color = "yellow")
ax2.axvline(x = 75,  ymin= 0, ymax = 1, linestyle = ":", color = "yellow")
plt.axhline(y = 170, xmin= 0, xmax = 0.9, linestyle = ":", color = "yellow")
plt.axhline(y = 187, xmin= 0, xmax = 0.735, linestyle = ":", color = "yellow")

ax2.text(72, 157, '$Y_0$', fontsize = 15, color = 'black')
ax2.text(94, 157, '$Y_1$', fontsize = 15, color = 'black')
ax2.text(-10, 187, '$r_0$', fontsize = 12, color = 'black')
ax2.text(-10, 170, '$r_1$', fontsize = 12, color = 'black')
ax2.text(75, 187, '$E_0$', fontsize = 12, color = 'black')
ax2.text(96, 170, '$E_1$', fontsize = 12, color = 'black')

ax2.legend()

plt.show()

# %% [markdown]
# En el segundo gráfico, se muestra las desigualdades $ 𝑟_0 > r_1 $ y $ 𝑌_0 < Y_1 $ que son los valores de la tasa de interés y del ingreso, equilibran el mercado de bienes. Asimismo, se pueden representar en el plano (Y, r) como una recta con pendiente negativa que pasa por lo puntos $ (𝑌_0, r_o) $ y $ ( Y_1, 𝑟_1) $, la cual, representa la Curva IS que muestra el equilibrio en el mercado de bienes.

# %% [markdown]
# # Ejercicio 2:

# %% [markdown]
# Ahorro total (ahorro privado + ahorro del gobierno + ahorro externo) = Inversión (I)
#
# $ S=I_0-h*r $
#
# $ S_p+S_g+S_e=I_0-h*r $
#
# $(Y^d-C_0-b*Y^d)+(T-G_O)+(m*Y^d-X_0)=I_0-h*r$
#
# $Y^d*(1-b+m)+T-G_0-C_0-X_0=I_0-h*r $
#
# $Y^d=Y-T=(1-t)Y$
#
# $Y*(1-t)*(1-b+m)+t*Y-G_0-C_0-X_0=I_0-h*r$
#
# $Y*(t+(1-t)*(1-b+m))-G_0-C_0-X_0-I_0=-h*r$
#
# $Y*(t+(1-t)-(1-t)*b+(1-t)*m)-G_0-C_0-X_0-I_0=-h*r$
#
# $Y*(1-(1-t)*(m-b))-G_0-C_0-X_0-I_0=-h*r$
#
# $G_0-C_0-X_0-I_0-Y*(1-(1-t)*(m-b))=h*r$
#
# $\frac{G_0-C_0-X_0-I_0}{h}-\frac{(1-(1-t)*(m-b))}{h}*Y=r$

# %%
# Curva IS
Y_size = 100 

Co = 15
Io = 18
Go = 28
Xo = 5
h = 0.8
b = 0.5
m = 0.3
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return r_IS

IS = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)


# Curva IS
   

fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="LA CURVA IS DE EQUILIBRIO EN EL MERCADO DE BIENES", xlabel=r'Y', ylabel=r'r')

ax.text(100, -20, '$IS$', fontsize = 12, color = 'green')

ax.plot(IS, "k-")
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())                                     
plt.show()

# %% [markdown]
# # Ejercicio 3:

# %%
# Curva IS
Y_size = 100 

Co = 15
Io = 18
Go = 28
Xo = 5
h = 0.8
b = 0.5
m = 0.3
t = 0.3

Y = np.arange(Y_size)


# Ecuación 
def r_IS(b, m, t, Co, Io, Go, Xo, h, Y):
    r_IS = ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return r_IS

IS = r_IS(b, m, t, Co, Io, Go, Xo, h, Y)



fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="LA CURVA IS DE EQUILIBRIO EN EL MERCADO DE BIENES", xlabel=r'Y', ylabel=r'r')

ax.text(100, -20, '$IS$', fontsize = 12, color = 'black')
ax.text(45, 34.13, '$A$', fontsize = 12, color = 'black')
ax.text(15, 34.13, '$C$', fontsize = 12, color = 'black')
ax.text(75, 34.13, '$B$', fontsize = 12, color = 'black')
ax.text(-10, 34.13, '$r_A$', fontsize = 12, color = 'black')
ax.text(18, 15, 'Exceso de Demanda', fontsize = 12, color = 'black')
ax.text(55, 50, 'Exceso de Oferta', fontsize = 12, color = 'black')



ax.axvline(x = 45, ymin= 0, ymax = 0.55, linestyle = ":", color = "yellow")
ax.axvline(x = 75, ymin= 0, ymax = 0.55, linestyle = ":", color = "yellow")
ax.axvline(x = 15, ymin= 0, ymax = 0.55, linestyle = ":", color = "yellow")
plt.axhline(y = 34.13, xmin= 0, xmax = 0.75, linestyle = ":", color = "yellow")

ax.plot(IS, "k-")
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())                                     
plt.show()

# %% [markdown]
# Estos puntos están fuera de los puntos de equilibrio, ya que los puntos de equilibrio se encuentran dentro de la curva IS. Por lo que si existe un punto a la derecha de la curva IS este sería exceso de oferta y al lado izquierdo sería exceso de demanda.

# %% [markdown]
# # Ejercicio 4:

# %% [markdown]
# # DATOS:
#
# $$ β_0=intercepto $$
# $$ β_1=pendiente $$

# %% [markdown]
# # 4.1:

# %%
# Curva IS
Y_size = 100 

Co = 15
Io = 18
Go = 28
Xo = 5
h = 0.8
b = 0.5
m = 0.3
t = 0.3
r = 8.2

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def IS_5(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_5= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_5

IS_G= IS_5(Co, Io, Go, Xo, h, r, b, m, t, Y)



Go=10

def IS_6(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_6= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_6

IS_G2= IS_6(Co, Io, Go, Xo, h, r, b, m, t, Y)

fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="EFECTOS DEL AUMENTO DEL GASTO DE GOBIERNO", xlabel=r'Y', ylabel=r'r')

ax.plot(IS_G, label = "IS", color = "C0") 
ax.plot(IS_G2, label = "IS_1", linestyle=':', color = "C3") 
ax.text(100, -20, '$IS$', fontsize = 12, color = 'black')
ax.text(100, -40, '$IS_1$', fontsize = 12, color = 'black')

ax.plot(IS_G, "k-", color = 'blue',Label="IS")
ax.plot(IS_G2, "b-", color = 'red',linestyle=':',Label="IS_1")
ax.yaxis.set_major_locator(plt.NullLocator())   # Hide ticks
ax.xaxis.set_major_locator(plt.NullLocator())   # Hide ticks
       
plt.legend()        
plt.show()
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_13452\1071132536.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(IS_G, "k-", color = 'blue',Label="IS")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [6], in <cell line: 42>()
#      39 ax.text(100, -20, '$IS$', fontsize = 12, color = 'black')
#      40 ax.text(100, -40, '$IS_1$', fontsize = 12, color = 'black')
# ---> 42 ax.plot(IS_G, "k-", color = 'blue',Label="IS")
#      43 ax.plot(IS_G2, "b-", color = 'red',linestyle=':',Label="IS_1")
#      44 ax.yaxis.set_major_locator(plt.NullLocator())   # Hide ticks
#
# File D:\ANACONDA\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
# ...

# %% [markdown]
# De forma intuitiva, se obtiene:
# La caída del Gasto del Gobierno, disminuye la demanda agregada de bienes
# generando así un déficit de demanda que da lugar a un desplazamiento de la curva IS hacia la izquierda.
#
# $$ G↓→β_0↓ $$
#
# $$ 	G↓→DA↓→DA<Y→Y↓ $$

# %% [markdown]
# # 4.2:

# %%
# Curva IS
Y_size = 100 

Co = 15
Io = 18
Go = 28
Xo = 5
h = 0.8
b = 0.5
m = 0.3
t = 0.7
r = 8.2

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def IS_7(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_7= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_7

IS_t= IS_7(Co, Io, Go, Xo, h, r, b, m, t, Y)



t = 0.07

def IS_8(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_8= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_8

IS_t2= IS_8(Co, Io, Go, Xo, h, r, b, m, t, Y)

fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="EFECTOS DE UN AUMENTO EN LA TASA DE IMPUESTOS", xlabel=r'Y', ylabel=r'r')

ax.plot(IS_t, label = "IS", color = "C0") 
ax.plot(IS_t2, label = "IS_1", linestyle=':', color = "C3") 
ax.text(100, -35, '$IS$', fontsize = 12, color = 'black')
ax.text(100, -20, '$IS_1$', fontsize = 12, color = 'black')

ax.plot(IS_t, "k-", color = 'blue',Label="IS")
ax.plot(IS_t2, "b-", color = 'red',linestyle=':',Label="IS_1")
ax.yaxis.set_major_locator(plt.NullLocator())   # Hide ticks
ax.xaxis.set_major_locator(plt.NullLocator())   # Hide ticks
       
plt.legend()        
plt.show()
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_13452\642123304.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(IS_t, "k-", color = 'blue',Label="IS")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [7], in <cell line: 42>()
#      39 ax.text(100, -35, '$IS$', fontsize = 12, color = 'black')
#      40 ax.text(100, -20, '$IS_1$', fontsize = 12, color = 'black')
# ---> 42 ax.plot(IS_t, "k-", color = 'blue',Label="IS")
#      43 ax.plot(IS_t2, "b-", color = 'red',linestyle=':',Label="IS_1")
#      44 ax.yaxis.set_major_locator(plt.NullLocator())   # Hide ticks
#
# File D:\ANACONDA\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
# ...

# %% [markdown]
# De forma intuitiva, se obtiene:
#
# Los cambios en los parámetros “b”, “m” y “t” modifican la pendiente de la curva IS. Si se adopta una política fiscal restrictiva disminuyendo la tasa de tributación, la pendiente de la IS disminuye, provocando un movimiento en el sentido opuesto al de las agujas del reloj.
# $$ 	t↓→β_1↑ $$
#
# $$ t↓→(1-t)*Y↑→Y^d↑→C↑→DA↑→DA>Y→Y↑ $$

# %% [markdown]
# # 4.3:

# %%
# Curva IS
Y_size = 100 

Co = 15
Io = 18
Go = 28
Xo = 5
h = 0.8
b = 0.5
m = 0.3
t = 0.3
r = 8.2

Y = np.arange(Y_size)

# Ecuación de la curva del ingreso de equilibrio

def IS_9(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_9= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_9

IS_b= IS_9(Co, Io, Go, Xo, h, r, b, m, t, Y)


b=0.03

def IS_10(Co, Io, Go, Xo, h, r, b, m, t, Y):
    IS_10= ((Co+Io+Go+Xo)/h-Y*((1-(1-t)*(b-m))/h))
    return IS_10

IS_b2= IS_10(Co, Io, Go, Xo, h, r, b, m, t, Y)


fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="EFECTOS DE UN AUMENTO EN LA PMgC ", xlabel=r'Y', ylabel=r'r')

ax.plot(IS_b, label = "IS", color = "C0") 
ax.plot(IS_b2, label = "IS_1", linestyle=':', color = "C3") 
ax.text(100, -20, '$IS$', fontsize = 12, color = 'black')
ax.text(100, -60, '$IS_1$', fontsize = 12, color = 'black')

ax.plot(IS_b, "k-", color = 'blue',Label="IS")
ax.plot(IS_b2, "b-", color = 'red',linestyle=':',Label="IS_1")
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())   
       
plt.legend()        
plt.show()
# Out:
# C:\Users\aless\AppData\Local\Temp\ipykernel_13452\708025093.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k-" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(IS_b, "k-", color = 'blue',Label="IS")
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 42>()
#      39 ax.text(100, -20, '$IS$', fontsize = 12, color = 'black')
#      40 ax.text(100, -60, '$IS_1$', fontsize = 12, color = 'black')
# ---> 42 ax.plot(IS_b, "k-", color = 'blue',Label="IS")
#      43 ax.plot(IS_b2, "b-", color = 'red',linestyle=':',Label="IS_1")
#      44 ax.yaxis.set_major_locator(plt.NullLocator())
#
# File D:\ANACONDA\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
# ...

# %% [markdown]
# De forma intuitiva, se obtiene:
# Los cambios en la propensión marginal a importar “m”, tienen efectos en la pendiente de la curva IS parecidos a los provocados por los cambios en la tasa de tributación “t”: cuando disminuye (aumenta) “m”, la pendiente de la curva IS se disminuye (aumenta). Por el contrario, la disminución de la propensión marginal a consumir, “b”, disminuye el tamaño del multiplicador, disminuye la pendiente de la DA y aumenta la pendiente de la curva IS. Esta gira en sentido de las agujas del reloj.
#
# $$ 	b↓→β_1↑ $$
#
# $$ 	b↓→C↓→DA↓→DA<Y→Y↓ $$
