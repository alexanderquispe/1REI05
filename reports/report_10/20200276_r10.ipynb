# %% [markdown]
# # Reporte 10
#
# ## Nombre: Karen Andrea Arevalo Calle
# ## Codigo: 20200276
#
# # Parte 1: Reporte de Lectura
# Bell, A., Chetty, R., Jaravel, X., Petkova, N., & Van Reenen, J. (2019). Who becomes an inventor in America? The importance of exposure to innovation. The Quarterly Journal of Economics, 134(2), 647-713.

# %% [markdown]
# La lectura de Bell, Jaravel, Petkova y Van centra en la problemática de que existen distintos factores que terminan influyendo en la innovación que no necesariamente son considerados de manera convencional donde se enfocan generalmente las "habilidades naturales". Es por ello que, esto genera brechas en la innovación y se desperdicia el talento humano, En ese sentido, la investigación de centra por las siguientes preguntas de investigación: ¿Es posible que factores como la clase, raza y sexo sean determinantes para que una persona se convierte en inventor?, ¿Cuáles son los canales que explican esta diferencia?, ¿Existe mayor posibilidad de que las niñas se dediquen a la innovación si están expuestas a inventoras desde temprana edad?, ¿Es más probable que los niños que se trasladen a áreas con mayor innovación en su edad temprana se conviertan en inventores?, y finalmente, ¿Acaso los niños de familias con bajos ingresos habrían podido terminar teniendo innovaciones de impacto?. Los autores hacen un minucioso análisis de la mano de la data que manejan para responder todas estas cuestiones.
#
# Los autores parten por una tesis central que dictamina que la falta de exposición a la innovación puede ser útil para explicar por qué los niños talentosos de familias con bajos ingresos, pertenecientes a las minorías étnicas y/o mujeres, tienen menos probabilidades de convertirse en inventores a largo plazo. Para lo cual, se argumenta que los mecanismos de transmisión seríen el desarrollo del capital humano, mentorías y redes de contacto. Un punto fuerte del análisis es que los autores se dedican también a explorar no se limitan solo al análisis de la probabilidad de convertirse en inventores; sino también a abordar la cuestión de que existiría talento perdido "lost Einsteins".
#
# Seguidamente, para la metodología, los autores utilizan una mezcla de bases de datos. En primer lugar, se emplea una base de datos de patentes emparejadas con base de datos de contribuyentes (impuestos) de EEUU. En segundo lugar, se emplea una base del récord académico de alumnos (sólo Nueva York). Y, por último, una muestra panel del total de inventores (1996-2012). Además, se realizan tres análisis con diferentes metodologías: En primer lugar, se observan las características del inventor al nacer: Se realizan comparaciones en medias de convertirse en inventor según características (ingreso, raza, sexo), en bruto y condicionadas mediante un algoritmo de emparejamiento por el ingreso y los resultados en test de matemáticas. En segudo lugar, se elabora un Informe sobre el entorno infantil y exposición a la innovación; Se realizan comparaciones y regresiones (MCO) condicionadas a algunas características para determinar si explican el efecto de la brecha de innovación. Aquí, pata el caso del modelo intergeneracional del tipo de innovación, se añade una variable distancia (d) que mide que tan alejado está la invención/patente realizada con los padres, compañeros de los padres y el vecindario, dándose así la siguiente ecuación:
#
# $$ y_{cj} = k_c + b_dP_{c+d,j}+e_{cj} $$
#
# En tercer lugar, se analizan los efectos del vecindario en e nivel de innovación, realizándose una regresión con los efectos fijos:
#
# $$ y_i = α + βm_iΔ_{od} + γ1Δ_{od} + γ2X_i + e_i $$
#
# En cuanto a los resultados, los autores obtienen que, en cuanto a las características de los inventores al nacer; se observaron brechas de innovación por características de nacimiento. Observándose así que la probabilidad de convertirse en inventor es mayor en el top 1% de los ingresos de los padres comparándolo con los de debajo de la mediana. Asimismo, se encontró que existen diferencias étnicas favorables para los asiáticos y blancos no hispanos y desfavorables para negros no hispanos e hispanos, aun emparejando por ingresos y resultandos en los test. De igual forma, el % de mujeres ha crecido de manera sostenida aunque a tasas muy bajas, a ese ritmo se estima que en 118 años recién se llegaría a la paridad. Por otro lado se observaron si habían diferencias en habilidades las cuáles explicarían diferencias en innovación. En ese sentido, se vio que la mayor parte de la brecha de innovación se explica por factores que afectan a los niños antes de que ingresen al mercado laboral.
#
# En segundo lugar, en cuanto al entorno infantil y exposición a la innovación, se observó como resultados que los niños con padres o compañeros de padres inventores son mpas probables de convertirse en innovadores que aquellos con padres no inventores. Asimismo, parte de la razón por la que los hijos de inventores tienen más probabilidades de convertirse en inventores se debe a la exposición a la nnovación más que  a las diferencias en los talentos naturales. También, los canales de transmisión de capital humano específico, tienen acceso a redes que ayudan a los niños a perseguir un determinado xcampo, adquisición de informaciín sobre determinadas carreras o efectos de modelo a seguir. De la misma manera, se vio que es más probable que las mujeres innoven en esa categoría en el área donde crecieron.
#
# En tercer lugar, en relación a los efectos del vecindario, se observó que si un niño crece en una zona CZ con ratio de innovación una desviación estándar por encima de su media, su probabilidad de convertirse en inventor crece en 22%. Asimismo, moverse de una zona del 25 percentil de inventores per cápita a una del 75 percentil incrementa la probabilidad de ser inventor en un 37%. Por lo tanto, la exposición a la innovación tiene impactos sustanciales no solo en los tipos de innovación que persiguen los niños, sino también en si se convierten en inventores o no. Finalmente, en cuanto el potencial de los "Einstein perdidos" se observa que la probabilidad de que un individuo se convierta en un inventor estrella (de alto rendimiento) es tan sensible a sus condiciones al nacer como la probabilidad de que innove. En ese sentido, se entiende que hay muchas personas Einstein que no siguen una carrera en innovación a pesar de que podrían haber tenido innovaciones de gran impacto si lo hubieran hecho.
#
# Por un lado, me gustaría señalar algunas críticas, puntos débiles o limitaciones en cuanto a la investigación de los autores en el paper. Por ejemplo, se podrían haber considerado o buscado otras variables relacionadas a la innovación y a las preguntas de investigación para incorporarlas en el manejo de la data (muy a parte de los datos sobre las patentes). Esto debido a que no todas las innovaciones terminan siendo patentadas. Finalmente, en base a la tesis de los auores se pueden proponer líneas de investigación alternas. Por ejemplo, se puede replicar la metodología empleada para el caso de países en desarrollo o para el caso de Perú. En ese sentido, el trabajo de [Seclén & Ponce (2017)](https://dialnet.unirioja.es/descarga/articulo/7185825.pdf) la cual nos puede servir como punto de partida pues analiza la innovación en el Perú a partir de indicadores sintéticos. Asimismo, también se podría evaluar el impacto de los programas o políticas destinadas a incentivar la innovación y observar cuáles son más efectivas en cerrar las brechas mencionadas en el paper. Para ello, las investigaciones de [Bárcena, Prado, Abramo & Pérez (2017)](https://www.cepal.org/sites/default/files/events/files/brechas_ejes_y_desafios_en_el_vinculo_entre_lo_social_y_lo_productivo.pdf) sobre "Brechas, ejes y desafíos en el vínculo entre lo social y lo productivo" y el análisis de [Loray (2016)](https://journals.openedition.org/revestudsoc/1018) sobre "Políticas públicas en ciencia, tecnología e innovación" corresponden a literaturas pertinentes para esta propuesta.

# %% [markdown]
# # Parte 2: Código en Python
# Código hecho por Karen Arevalo y Mayeli Charra

# %%
# !pip install causalgraphicalmodels
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns, warnings
import statsmodels.formula.api as smf
warnings.filterwarnings('ignore')
from causalgraphicalmodels import CausalGraphicalModel
from cProfile import label
# %matplotlib inline

# %% [markdown]
# ### Regresión Discontinua
# En esta sección, puede guiarse del siguiente bookdown.
# - Explique de manera muy breve y resumida en qué consiste una regresión discontinua.
#
# La regresión discontinua tiene como objetivo determinar los efectos causales de intervenciones al asignar puntos cut-off o punto de corte por encima o por debajo del punto que se asigna en la intervención. El principal supuesto de este diseño es la continuidad de la variable, ya que cualquier discontinuidad implica alguna causa.
#
# Se toma en cuenta las siguiente definiciones necesarias para aplicar el método:
# - Variable de ejecucion ($X$)
# - Punto de corte (Cutoff) ($C_0$)
# - Ancho de banda ($h$)
# - Tratamiento ($D$)
#
# Además, en el gráfico se observa que  la Variable de ejecución es una variable continua. Esta asigna unidades al tratamiento y se basa en una puntuación de "corte" donde si se obtiene una puntuación superior al corte se coloca en el grupo de tratamiento y las unidades inferiores no.

# %%
sprinkler = CausalGraphicalModel(
    nodes=["RunningVariable", "AboveCutoff", "Treatment", "Z", "Outcome"],
    edges=[
        ("Z", "RunningVariable"), 
        ("RunningVariable", "AboveCutoff"), 
        ("RunningVariable", "Outcome"),
        ("AboveCutoff", "Treatment"), 
        ("Z", "Outcome"), 
        ("Treatment", "Outcome")
    ]
)

# draw return a graphviz `dot` object, which jupyter can render
sprinkler.draw()

# %% [markdown]
# ![r10_image.png](data:image/png;base64,...)

# %% [markdown]
# - Detalle un ejemplo en la vida real en donde podría emplear una regresión discontinua.
#
# Se podría aplicar para evaluar el impacto de la asignación de becas como Beca18 tomando en cuenta un método cuasi experimental de regresión discontinua para estimar los efectos intermedios del programa. Para ello se tomará como referencia los resultados de una convocatoria donde los indicadores relevantes sobre acceso, permanencia, continuidad, deserción. De esa manera se busca afianzar y mejorar los resultados de gestión del programa social que demuestran una contribución significativa a la reducción de la brecha educativa.   [Saavedra,L.(2019)](https://hdl.handle.net/11042/3898)
#
# - Explique el diseño Sharp Desing y comente un ejemplo en la vida real en donde podría aplicarlo (sea lo más detallado posible).
#
# En la Discontinuidad de la Regresión, se aceptan dos tipos de estudios RDD. Hay diseños en los que la probabilidad de tratamiento pasa de 0 a 1 en el punto de corte, (diseño "sharp"). Es decir, la regla de asignación se cumple de manera determinista. Donde, los individuos elegibles bajo ninguna circunstancia cambian o afectan esta asignación. Además el efecto se puede conocer con una comparación de medias.
#
# Por ejemplo, este diseño podría ser aplicable para probar que los programas de recuperación universitaria ayuden a mejorar la  persistencia y rendimiento de los estudiantes. Para en este caso estimar los efectos causales, es posible usar un diseño de regresión discontinua sharp de modo que es posible explorar la asignación de los estudiantes a la recuperación. Aunque se use el metodo sharp y no haya una forma directa de comprobar que los indiviudos tengan control sobre la asignación, para probar la validez de la asignación se toma los supuestos del diseño donde si la distribución de la varaible asignación presenta alguna discontinuidad en el punto de corte.     [Duchini, E. (2017).](https://www.sciencedirect.com/science/article/abs/pii/S0272775716304605)
#
# Formalmente el diseño Sharp se representa como:
#
# $$
# D_i =
#    \begin{cases} 1
#        \text{si} & X_i\geq{c_0}
#        \\ 0
#        \text{ if } & X_i < c_0
#    \end{cases}
# $$

# %% [markdown]
# ### Aplicaciones
# Ahora guíese del siguiente script visto en clase.
# Siguiendo todo el apartado Simulated Data, trabaje con la siguiente ecuación, según sea su caso, y replique los resultados correspondientes, incluidos los gráficos respectivos.

# %% [markdown]
# * Ecuaciones:
#
# 1. $ Y= 15 + 22D + 2.5X + e $
#
# 2. $ Y= 12 + 60D + 1.3X + e$

# %% [markdown]
# * Graficando ecuación 1

# %%
## Random data
dat = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
dat.loc[dat.x<0, 'x'] = 0
dat = dat[dat.x<100]
dat['D'] = 0
# Cutoff
dat.loc[dat.x>50, 'D'] = 1
# Simulated Y
dat['y'] = 15 + 22*dat.D + 2.5 * dat.x + np.random.normal(0, 20, dat.shape[0])
# Not Treatment
dat_0 = dat[dat.D == 0]
# Treatment
dat_1 = dat[dat.D == 1]

# %% [markdown]
# Visualmente hay un aumento del punto de corte

# %%
# Colors 
treat_c = "#568A9B" # Treatment
n_treat = "#A10728" # Not treatment
# Plot
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %% [markdown]
# Ahora estimamos un modelo para cada lado, en este caso el modelo que mejor se ajustaría sería el modelo lineal, para ello generamos una función para incluir las predicciones en la base de datos.

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

data_y0 = y_hat_lin(dat_0)
data_y1 = y_hat_lin(dat_1)

# %% [markdown]
# Predicciones

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3);

# %% [markdown]
# * Encontrando el efecto Salto de la ecuación 1 y ploteando

# %% [markdown]
# Para medir el salto (Efecto), para este caso sólo nos centraremos en la última observación prevista para el lado izquierdo y en la primera prevista para el lado izquierdo, ya que allí se observa un salto.

# %%
eff = min(data_y1.yhat) - max(data_y0.yhat)
eff = round(eff,  2)
print("Effect:", f"{eff}")
# Out:
# Effect: 23.91

# %% [markdown]
# Visualmente podemos ver el efecto en el punto de corte, recuerda que el efecto real es de 23 unidades

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff}", xy = (51, eff + 76))
plt.annotate("", xy = (51, max(data_y0.yhat)), xytext = (51, min(data_y1.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));

# %% [markdown]
# * Graficando la ecuación 2

# %%
## Random data
dat = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
dat.loc[dat.x<0, 'x'] = 0
dat = dat[dat.x<100]
dat['D'] = 0
# Cutoff
dat.loc[dat.x>50, 'D'] = 1
# Simulated Y
dat['y'] = 12 + 60*dat.D + 1.3 * dat.x + np.random.normal(0, 20, dat.shape[0])
# Not Treatment
dat_0 = dat[dat.D == 0]
# Treatment
dat_1 = dat[dat.D == 1]

# %% [markdown]
# Visualmente hay un aumento en el punto de corte

# %%
# Colors 
treat_c = "#568A9B" # Treatment
n_treat = "#A10728" # Not treatment
# Plot
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %% [markdown]
# Ahora estimamos un modelo para cada lado, en este caso el modelo que mejor se ajustaría sería el modelo lineal, para ello generamos una función para incluir las predicciones en la base de datos.

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

data_y0 = y_hat_lin(dat_0)
data_y1 = y_hat_lin(dat_1)

# %% [markdown]
# Predicciones

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3);

# %% [markdown]
# * Encontrando el efecto Salto de la ecuación 2 y ploteando

# %%
eff = min(data_y1.yhat) - max(data_y0.yhat)
eff = round(eff,  2)
print("Effect:", f"{eff}")
# Out:
# Effect: 58.08

# %% [markdown]
# Visualmente podemos ver el efecto en el punto de corte, recuerda que el efecto real es de 58 unidades

# %%
plt.scatter("x", "y", data = dat_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = dat_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = data_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = data_y1, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff}", xy = (51, eff + 76))
plt.annotate("", xy = (51, max(data_y0.yhat)), xytext = (51, min(data_y1.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));
