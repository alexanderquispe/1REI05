# %% [markdown]
# # Reporte 10
#
# ### MariaJose Murillo (20193538)
#
#
# ## Lectura
#
# El texto “Who becomes an inventor in America? The importance of exposure to innovation” tiene como meta analizar quien se convierte en inventor identificando los nuevos enfoques que aumentan las tasas de innovación, donde se incluye a subgrupos como mujeres y niños de escasos recursos. Es por ello que la pregunta de investigación es ¿Qué factores determinan quien se convierte en inventor en los Estados Unidos?, para lo cual los autores se concentran en el rol de la capacidad inventiva y el entorno. El análisis logrado a partir de esta premisa será clave para “ver un retrato completo” de los inventores de EEUU, ya que será la primera vez en donde no se tomará en cuenta la información demográfica básica ni la edad o genero del inventor, si no de que se guía a través de la vinculación de patentes entre 1996 y 2014, donde se puede “rastrear la vida de los inventores desde el nacimiento hasta la edad adulta para identificar los factores que determinan quién se convierte en uno”, ampliando asi la investigación en torno a los inventores en la época moderna. Asi mismo, también se cuestionan ¿Por qué las tasas de innovación varían tanto según las características al nacer?, el cual tiene como hipótesis de que el origen y entorno de los niños influye en ellos, lo que a la larga los lleva a elegir diferentes carreras, en donde nos brinda el ejemplo de las personas que crecieron en Silicon Valley, quienes son mas propensas a dedicarse al sector computacional, mientras que los que vivieron en Minneapolis, conocido por la fabricación de dispositivos médicos, son mas probables a dedicarse al sector de salud. Otros factores que podrían influenciar son el entorno familiar puede afectar, ya que “los niños cuyos padres tienen patentes en alguna clase de tecnología tienen más probabilidades de patentar exactamente en ese campo” e incluso el género, ya que posteriormente se demostrara que, mientras que los inventores masculinos influyen en las tasas de innovación de los hombres, no logran hacerlo en las tasas de las mujeres, siendo estas influenciadas por inventoras de su mismo género.
#
# **Se considera que este articulo cuenta con diversas fortalezas** entre las cuales figuran tomar en cuenta los estudios de la población estudiada. Si bien al inicio da a entender que solo se fijara en el desempeño académico básico en los cursos de inglés, arte y matemáticas, demuestra que este último solo predecirá un 5.7% de las brechas de innovación, siendo los puntajes obtenidos al final de la escuela secundaria mas importantes que los ya mencionados, puesto que explicarían el 60.1% de la brecha. Esto nos indica dos cosas, la primera de que un alumno sea bueno en el ámbito matemático a temprana edad no significara imperativamente que se convierta en una figura sobresaliente en el ámbito de la innovación cuando crezca; y la segunda de la importancia de estar expuesto constantemente a estímulos que motiven el descubrimiento y aprendizaje inclusive en los niveles superiores de la educación, donde usualmente se cree que la capacidad de procesar nueva información es baja a comparación de temprana edad.
#
# Siguiendo esta línea, otra de sus fortalezas es contribuir con la investigación de varias literaturas. La primera es sobre *elección de carrera*, si bien existen estudios sobre como los infantes son propensos a seguir las ocupaciones de sus padres en las ramas como la medicina o derecho realizados por Laband y Lentz en los 80’s, estos no han logrado separar los efectos de la exposición causal de los efectos de selección como si lo hace el presente trabajo, el cual se enfoca en la innovación. La segunda es sobre *la mala asignación de talento entre ocupaciones*, donde refuta la investigación de Hsieh al indicar que “la asignación de talento a la innovación está impulsada por la exposición en lugar de las habilidades heredadas”. Finalmente, a la de *los orígenes de los inventores y determinantes del emprendimiento*, donde si bien hubo estudios anteriores realizados por Agion (2017) o Nicolaou (2008), este articulo los complementa al descubrir factores que afectan la carrera y efectos de la exposición infantil, presentando datos y estadísticas.
#
# En términos generales, no se encontró debilidades significativas al articulo, no obstante, se considera que hubiera sido bueno incluir mas registros de distritos escolares. Es entendible que los autores hayan escogido a la ciudad de New York, puesto que es la que cuenta con mayor numero de habitantes en Estados Unidos, sin embargo, opino que hubiera sido de interés ver si el mismo fenómeno hallado en la presente investigación se refleja en ciudades como Phoenix, Arizona o en Dallas, Texas, quienes a pesar de estar también entre las ciudades más pobladas, el boom demográfico no fue tan centralizado como ha ocurrido en New York, el cual es el centro financiero del país.
#
# **Para obtener los resultados**, los autores decidieron guiarse de diversas fuentes de datos como por ejemplo los registros de patentes, las cuales tiene información de las concesiones de patentas realizadas por residentes americanos que figuran como inventores (tanto en el ámbito de tener los derechos como el de la propiedad intelectual) donde se extrae información de su ubicación geográfica, nombres y numero de patente. Asi mismo, a los registros de impuesto federales sobre la renta para obtener información acerca del sexo, ingresos y ubicación donde se incluyen declaraciones de renta y declaraciones de información de terceros para tener información sobre las ganancias que no presentan en las declaraciones de impuestos, finalmente, los registros del distrito escolar de la ciudad de New York, donde se obtienen los puntajes en las pruebas de la infancia de aproximadamente 2.5 millones de niños hasta octavo grado para los cursos de inglés, artes y matemáticas
#
# Dicho ello, se descubre la significancia de diversos factores determinan las brechas en la innovación. Uno de ellos es el ingreso de los padres, donde se demuestra que los hijos de familias de mayores ingresos tienen mayores probabilidades de convertirse en inventores, siendo esta cifra diez veces mayor a los que tienen padres debajo de la mediana de ingresos. Entre las causas para que esto ocurra es que “La relación entre la innovación y los ingresos de los padres es representativa de la relación entre lograr el éxito profesional y los ingresos de los padres en general”. Otro de los factores es la raza/etnia, donde se observo que entre el 1.6% y 3.3% de 1000 niños blancos y asiáticos respectivamente tiene probabilidades de convertirse en inventores a diferencia de los niños negros o hispanos, quienes solo presentan un 0.5% y 0.2%.
#
# El género, como se mencionó párrafos anteriores, también juega un papel importante, indicando que dado que solo el 18% de los inventores nacidos en los 80’s son mujeres (y tomando en cuenta el lento crecimiento de esta cifra), tardaríamos aproximadamente 118 en alcanzar la paridad de género en este ámbito. Esta brecha en el genero esta presente aun en las escuelas, en las cuales los puntajes de las pruebas de octavo grado representan solo el 8.5% de la brecha de genero en cuanto a innovación
# Por último, también resalta el factor geográfico, donde los niños que crecen en áreas donde ocurre la mayor innovación tienen a ser mas propensos a ser inventores, especificando lugares como la costa de California y el medio oeste rural, regiones que se caracterizan por tener mayores niveles de movilidad intergeneracional y menos padres solteros. No obstante, hay ciudades que rompen este esquema como Detroit, donde a pesar que la movilidad de ingresos medios es baja, los niños continúan con una mayor probabilidad de convertirse en inventores, o como Rhode Island, donde el 28.7% de los futuros inventores son mujeres
# En cuanto a “los Einstein perdidos”, estos serían mujeres, minorías y niños de bajos ingresos, quienes podrían inventar al mismo ritmo que los hombres blancos de familias de ingresos altos, sin embargo, no siguen una carrera en innovación ya que “falta de exposición puede descartar no solo a los inventores marginales, sino también a los "Einstein" que producen innovaciones que tienen los mayores impactos en la sociedad”
#
#
# **Entre los próximos pasos a investigar** seria profundizar el rol de la mujer en la investigación científica como señala el articulo de Gonzales (2016) donde profundiza acerca de los enfoques y problemas actuales que tiene el genero femenino en el campo de la ciencia y tecnología, denunciando la injusticia epistémica, la cual consiste en segregación de género en el ámbito tecnológico, alegando que este refuerza estereotipos acerca del rol de la mujer (en productos como videojuegos o electrodomésticos), empoderando a su vez lo que ella denomina ciberfeminismo, es decir, alentando a las mujeres a acercarse al ámbito de la tecnología de la información y comunicaciones (TIC) y viendo estas herramientas como una forma de liberación y empoderamiento mediante la creación.
#
# Además de ello, se podría abarcar las limitaciones económicas a las que se ven expuestos los estudiantes, quienes debido a la falta de presupuesto y apoyo se ven obligados a abandonar sus investigaciones, las cuales pudieron marcar la pauta en el mundo académico si no fuera por estas razones, lo cual daría razón al articulo trabajado y su teoría de los “Einstein ocultos”. Esto es apoyado en el articulo de Salas (2019), el cual, tras una investigación en los estudiantes de psicología de la Universidad de San Martin de Porres y San Ignacio de Loyola de Perú, concluyo en que estas limitaciones traen como consecuencia la falta de desarrollo en cuanto a la investigación en un país en donde en los últimos 20 años, a pesar de presentar un crecimiento económico sostenido, no ha tenido un crecimiento científico. Sumado a esto, se podría profundizar en las políticas publicas para incentivar la innovación, un ejemplo de ello son las Becas para Investigaciones en Áreas Naturales Protegidas, auspiciado por el SERNARP - MINAM, donde se da apoyo financiero a jóvenes investigadores “para el desarrollo de estudios que contribuyan con información científica que sirva de soporte para las decisiones de manejo y gestión en las áreas naturales protegidas del SINANPE”, ofreciendo un fondo de 77 mil de soles
#
# Por último, se podría hacer una comparación entre el numero de patentes producidas por países desarrollados con países de la periferia, como lo hace López (2008), quien compara el crecimiento y desarrollo tecnológico de Corea del Sur y México, enfocándose en el rol de los inventores prolíficos como actores clave en la producción de nuevas ideas y gestores que estimulan a los grupos de investigación. Este estudio demuestra que en países como Corea, “gobierno, las instituciones y los mismos inventores han reconocido el valor que representa la producción de nuevo conocimiento que existe de contribuir a los procesos de innovación y de cambio tecnológico para competir en la economía mundial” mientras que en México “no se ha establecido un régimen orientado a facultar las capacidades de aprendizaje, imitación y adaptación del conocimiento”, lo cual lo ha llevado a perder oportunidades y redes de inversión.
#
#
# **REFERENCIAS**
# - Fernández, N., Gonzales, M. (2016) Ciencia, tecnología y género. Enfoques y problemas actuales http://www.scielo.org.ar/scielo.php?script=sci_arttext&pid=S1850-00132016000100004
# - López, I (2008) Inventores prolíficos, conocimiento tecnológico y patentes: México y Corea https://www.scielo.org.mx/scielo.php?script=sci_arttext&pid=S0188-33802008000200004
# - Salas, E. (2019) Comprendiendo las limitaciones de la investigación http://www.scielo.org.pe/scielo.php?script=sci_arttext&pid=S2307-79992019000400001
# - SERNARP (2022) Concurso de Becas para Investigaciones prioritarias en Áreas Naturales Protegidas 2022-II https://www.gob.pe/institucion/sernanp/campa%C3%B1as/3955-concurso-de-becas-para-investigaciones-en-anp

# %% [markdown]
# ## CODIGO
# Hecho por
# - Mariajose Murillo (20193538)
# - Joaquin del Castillo (20201448)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns, warnings
import statsmodels.formula.api as smf
warnings.filterwarnings('ignore')
from causalgraphicalmodels import CausalGraphicalModel
from cProfile import label
# %matplotlib inline

# %% [markdown]
# ## Regresion Discontinua
# #### 1. Explique de manera muy breve y resumida en qué consiste una regresión discontinua.
# La regresión discontinua es un diseño cuasi-experimental y este nos permite poder realizar inferencias causales en ausencia de la aleatorización. Se aplica cuando la exposición de interés se asigna, por lo menos en un ámbito parcial, en función del valor de una variable aleatoria continua, si es que esta se encuentra por encima o por debajo de un valor umbral determinado. En otras palabras analiza las causas de la intervención estudiada a través de la asignación de un valor de corte que se encuentre debajo o arriba del asignado por la intervención.
#
#
# #### 2. Detalle un ejemplo en la vida real en donde podría emplear una regresión discontinua.
# Se podría estudiar con la regresión discontinua la relación entre el impuesto a la riqueza en Suecia y el cambio en el indice de pobreza. En 1964 se instauró el impuesto a la riqueza en Suecia. En base a ello se podría estudiar si el nivel de pobreza cambió después de este umbral que es la aplicación del impuesto a la riqueza.
#
#
# #### 3. Explique el diseño Sharp Desing y comente un ejemplo en la vida real en donde podría aplicarlo (sea lo más detallado posible).
# En el caso del Sharp Design en la regresión discontinua es el cambio de la probabilidad de 1 a 0 (o 100% a 0) de las unidades de pertenecer al grupo de tratamiento. Bajo esta presentación un ejemplo podría ser el apoyo del Estado a los 100 municipios más pobres del país, tal como sucede en Mexico. En este sentido, si no se forma parte de los 100 municipios más pobres pues no puede pertenecer al grupo de tratamiento, pero si es el número 100 o menos pasa a representar parte del grupo de tratamiento.
#
#
# ## Aplicaciones
# ### CASO 1 :
# $$ Y = 15 + 22D + 2.5 X + e $$

# %%
## Random data
caso1 = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
caso1.loc[caso1.x<0, 'x'] = 0
caso1 = caso1[caso1.x<100]
caso1['D'] = 0
# Cutoff
caso1.loc[caso1.x>50, 'D'] = 1
# Simulated Y
caso1['y'] = 15 + 22*caso1.D + 2.5 * caso1.x + np.random.normal(0, 20, caso1.shape[0])
# Not Treatment
caso1_0 = caso1[caso1.D == 0]
# Treatment
caso1_1 = caso1[caso1.D == 1]

# %%
# Colors 
treat_c = "#568A9B" # Treatment
n_treat = "#A10728" # Not treatment
# Plot
plt.scatter("x", "y", data = caso1_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = caso1_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

caso1_y0 = y_hat_lin(caso1_0)
caso1_y1 = y_hat_lin(caso1_1)

# %%
plt.scatter("x", "y", data = caso1_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = caso1_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = caso1_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = caso1_y1, color = treat_c, lw = 3);

# %% [markdown]
# ### - Jump Effect 1

# %%
eff = min(caso1_y1.yhat) - max(caso1_y0.yhat)
eff = round(eff,  2)
print("Effect:", f"{eff}")
# Out:
# Effect: 23.19

# %%
plt.scatter("x", "y", data = caso1_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = caso1_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = caso1_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = caso1_y1, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff}", xy = (51, eff + 76))
plt.annotate("", xy = (51, max(caso1_y0.yhat)), xytext = (51, min(caso1_y1.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));

# %% [markdown]
# ## CASO 2:
#
# $$ Y = 12 + 60D + 1.3X + e$$

# %%
## Random data
caso2 = pd.DataFrame({'x': np.random.normal(50, 25, 1000)})
caso2.loc[caso2.x<0, 'x'] = 0
caso2 = caso2[caso2.x<100]
caso2['D'] = 0
# Cutoff
caso2.loc[caso2.x>50, 'D'] = 1
# Simulated Y
caso2['y'] = 12 + 60*caso2.D + 1.3 * caso2.x + np.random.normal(0, 20, caso2.shape[0])
# Not Treatment
caso2_0 = caso2[caso2.D == 0]
# Treatment
caso2_1 = caso2[caso2.D == 1]

# %%
# Colors 
treat_c = "#568A9B" # Treatment
n_treat = "#A10728" # Not treatment
# Plot
plt.scatter("x", "y", data = caso2_0, color = n_treat, alpha= .7, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = caso2_1, color = treat_c, alpha= .7, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")
plt.legend();

# %%
def y_hat_lin(da_ta, x = "x", y = "y"):
    yhat = smf.ols(f"{y} ~ {x}", data = da_ta).fit().predict()
    da_ta["yhat"] = yhat
    da_ta.sort_values('yhat', inplace = True)
    return da_ta

caso2_y0 = y_hat_lin(caso2_0)
caso2_y1 = y_hat_lin(caso2_1)

# %%
plt.scatter("x", "y", data = caso2_0, color = n_treat, alpha= .2, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = caso2_1, color = treat_c, alpha= .2, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = caso2_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = caso2_y1, color = treat_c, lw = 3);

# %% [markdown]
# ### - Jump Effect 2

# %%
eff = min(caso2_y1.yhat) - max(caso2_y0.yhat)
eff = round(eff,  2)
print("Effect:", f"{eff}")
# Out:
# Effect: 65.46

# %%
plt.scatter("x", "y", data = caso2_0, color = n_treat, alpha= .03, s = 7, label = "Not treatment")
plt.scatter("x", "y", data = caso2_1, color = treat_c, alpha= .03, s = 7, label = "Treatment")
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff")

plt.plot("x", "yhat", data = caso2_y0, color = n_treat, lw = 3)
plt.plot("x", "yhat", data = caso2_y1, color = treat_c, lw = 3)
plt.axvline(50, color = "black", linestyle = "-.", label = r"$c_0$: Cutoff", lw = 1)
plt.annotate(f"{eff}", xy = (51, eff + 76))
plt.annotate("", xy = (51, max(caso2_y0.yhat)), xytext = (51, min(data_y1.yhat)), 
            arrowprops=dict(arrowstyle="<->",
                            connectionstyle="arc3"));
