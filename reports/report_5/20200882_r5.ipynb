# %% [markdown]
# Franco Hurtado Aguilar - 20200882

# %% [markdown]
# # Parte 1: Reporte

# %% [markdown]
# Durante el periodo de 2002 a 2013, el desempeño macroeconómico del Perú fue excepcional, considerando las buenas circunstancias externas, que estimulaban el crecimiento del PBI y permitían una tasa de inflación baja. A pesar de la crisis de 2008-2009, la economía peruana logró recuperarse a pesar de la baja de precios de los metales y para el 2014 ya había conseguido triplicar el índice de precios de sus exportaciones. Por supuesto, un importante factor, a parte del buen contexto económico internacional, fue el papel del BCR y las medidas que tomó. Entre estas se resalta marcar su objetivo específico de la tasa de inflación y acumular grandes reservas de divisas. Con esto, consiguió combatir el impacto en la tasa de cambio de shocks externos y los consiguientes ataques especulativos, logrando un nuevo nivel de eficacia en políticas monetarias y estabilidad macroeconómica.
# Entonces, el artículo se pregunta cómo funcionaron los principales instrumentos de política monetaria se utilizaron en el periodo de 2002 – 2013. En el análisis se discute el uso y el impacto de estos, la tasa de interés de corto plazo fijada por el BCR, el coeficiente de encaje legal en moneda nacional y extranjera, la intervención esterilizada en el mercado cambiario y el proceso de desdolarización del crédito bancario. El artículo propone entonces un desarrollo apropiado para responder a su pregunta de investigación, describiendo en general todos los mecanismos de política monetaria que se utilizan en Perú para el control demostrando su efectividad y funcionamiento al comparar lo sucedido en dos crisis distintas. Asimismo, resalta el importe papel que tomó el BCR para el control de estas crisis y propiciar un crecimiento macroeconómico efectivo en tiempos prósperos.
# Sin embargo, el artículo podría haber profundizado más en por qué las políticas monetarias implementadas por el BCR fueron tan efectivas aquí en Perú, a comparación de otros países. Es decir, no solo poder explicar cómo es que funcionaron estas políticas, sino por qué fueron eficaces en el caso peruano, considerando que, por ejemplo, en países como Ecuador, donde la economía es dolarizada, muchos de esos canales de política monetaria para controlar los shocks se ven reducidos.
# Asimismo, uno de los factores que beneficiaron la eficacia de esta institución fue la independencia que obtuvo al definir su objetivo específico de la tasa de inflación (Pastor 2022: 9), a pesar de que menciona esta decisión, no define la importancia en este sentido de la medida. Este factor fue clave ya que permitió definir metas explícitas de inflación, dando gran flexibilidad al BCR para responder a los choques económicos y usar a la vez otros instrumentos indirectos para asegurar la estabilidad financiera (Pastor 2022: 16).
#
# Bibliografía:
#
# PASTOR, Gonzalo. El Banco Central de Reserva del Perú: 1922-2022.
#
# https://www.bcrp.gob.pe/docs/Publicaciones/Revista-Moneda/moneda-189/moneda-189-02.pdf

# %% [markdown]
# # Parte 2: Código

# %% [markdown]
# ### 1. A partir del siguiente sistema de ecuaciones que representan el modelo DA-OA

# %% [markdown]
# ### 1.1. Encuentre las ecuaciones de Ingreso , tasa de interés ,  de equilibrio (Escriba paso a paso la derivación de estas ecuaciones).

# %% [markdown]
# Considerando que tenemos las siguientes ecuaciones:
#
# * Demanda Agregada:
#
# $$ IS:[1-b(1-t)Y=C_0+I_0+G_0-hr$$
#
#
# $$LM: \frac{M_0^s}{P_0}=kY-jr $$
#
#
# * Oferta Agregada:
#
# $$ P=P^e+θ(Y-\bar{Y}) $$
#
# Teniendo en cuenta que: $$ \bar{Y}=Y_f $$
#
#
#
#
#
#
# Considerando la ecuación de la demanda agregada que ahora es una recta y no una hipérbola $(DA)$:
#
# $$  P = \frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}Y \ ...(1)$$
#
# Y la ecuación de la oferta agregada $(OA)$:
#
# $$ P = P^e + θ(Y - \bar{Y}) \ ...(2)$$
#
#
# - Hallamos Ingreso ($Y^e$) igualando las dos ecuaciones:
#
# $$ \frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}Y = P^e + θ(Y - \bar{Y}) $$
#
# $$ Y^e = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$
#
#
# - Hallamos ($P^e$) de equilibrio, reemplazando $Y^e$ en la ecuación de oferta agregada:
#
# $$ P^e = P^e + θ( Y^{eq\_da\_oa} - \bar{Y} ) $$
#
# $$ P^e = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) $$
#
#
# <!-- - Para hallar P^e, despejamos la ecuación de $OA$ en función de Y:
#
# $$ P = P^e + θ(Y - \bar{Y}) $$
#
# $$ Y = \frac{P - P^e - θ\bar{Y}}{θ} $$
#
# Y reemplazamos $Y$ en la ecuación de $DA$:
#
# $$ P^e = (\frac{h Mo^s + jB_o}{h} - \frac{jB_1 + hk}{h}) * (\frac{P - P^e - θ\bar{Y}}{θ}) $$ -->
#
#
#
# - Hallamos tasa de interés ($r^e$), reemplazando ($P^e$) en la ecuación de tasa de interés de equilibrio del modelo IS-LM.
#
# - ($Y^e$) Tasa de interés de equilibrio:
#
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P)$$
#
# - Tasa de interés de equilibrio en DA-OA
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P^e)$$
#
# $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) ) $$
#
#
# ### Entonces, las ecuaciones de las tres variables serían:
# 1. ($Y^e$) Ingreso: $$ Y^e = [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})]$$
#
# 2. ($r^e$) Tasa de interés: $$ r^e = \frac{kB_o}{kh + jB_1} - (\frac{B_1}{kh + jB_1})*(Ms_o - P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*\\
# [(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) ) $$
#
# 3. ($P^e$) Equilibrio: $$ P^e = P^e + θ( [ \frac{1}{(θ + \frac{jB_1 + hk}{h})} ]*[(\frac{h Mo^s + jB_o}{h} - P^e + θ\bar{Y})] - \bar{Y} ) $$

# %% [markdown]
# ### 1.2. Grafique el equilibrio simultáneo en el modelo DA-OA.

# %%
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np               

import sympy as sy
import pandas as pd

# %%
#1--------------------------
    # Demanda Agregada
    
# Parámetros

Y_size = 100 

Co = 30
Io = 45
Go = 55
Xo = 1.5
h = 0.7
b = 0.3
m = 0.6
t = 0.75

k = 2.2
j = 1.2              
Ms = 300             
P  = 9  

Y = np.arange(Y_size)


# Ecuación

B0 = Co + Io + Go + Xo
B1 = 1 - (b-m)*(1-t)

def P_AD(h, Ms, j, B0, B1, k, Y):
    P_AD = ((h*Ms + j*B0)/h) - (Y*(j*B1 + h*k)/h)
    return P_AD

P_AD = P_AD(h, Ms, j, B0, B1, k, Y)


#2--------------------------
    # Oferta Agregada
    
# Parámetros

Y_size = 100

Pe = 150 
θ = 5
_Y = 25   

Y = np.arange(Y_size)


# Ecuación

def P_AS(Pe, _Y, Y, θ):
    P_AS = Pe + θ*(Y-_Y)
    return P_AS

P_AS = P_AS(Pe, _Y, Y, θ)

# líneas punteadas autómaticas

# definir la función line_intersection
def line_intersection(line1, line2):
    xdiff = (line1[0][0] - line1[1][0], line2[0][0] - line2[1][0])
    ydiff = (line1[0][1] - line1[1][1], line2[0][1] - line2[1][1])

    def det(a, b):
        return a[0] * b[1] - a[1] * b[0]

    div = det(xdiff, ydiff)
    if div == 0:
       raise Exception('lines do not intersect')

    d = (det(*line1), det(*line2))
    x = det(d, xdiff) / div
    y = det(d, ydiff) / div
    return x, y

    # coordenadas de las curvas (x,y)
A = [P_AD[0], Y[0]] # DA, coordenada inicio
B = [P_AD[-1], Y[-1]] # DA, coordenada fin

C = [P_AS[0], Y[0]] # L_45, coordenada inicio
D = [P_AS[-1], Y[-1]] # L_45, coordenada fin

    # creación de intersección

intersec = line_intersection((A, B), (C, D))
intersec # (y,x)

 # Gráfico del modelo DA-OA

# Dimensiones del gráfico
y_max = np.max(P)
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar 
ax.plot(Y, P_AD, label = "DA", color = "#F9FF33") #DA
ax.plot(Y, P_AS, label = "OA", color = "#D133FF") #OA

# Líneas punteadas
plt.axhline(y=intersec[0], xmin= 0, xmax= 0.55, linestyle = ":", color = "#6A0D0D")
plt.axvline(x=intersec[1],  ymin= 0, ymax= 0.55, linestyle = ":", color = "#6A0D0D")

# Texto agregado
plt.text(0, 280, '$P_0$', fontsize = 12, color = 'black')
plt.text(50, 25, '$Y_0$', fontsize = 12, color = 'black')
plt.text(55, 280, '$E_0$', fontsize = 12, color = 'black')


# Eliminar valores de ejes
ax.yaxis.set_major_locator(plt.NullLocator())   
ax.xaxis.set_major_locator(plt.NullLocator())

# Título, ejes y leyenda
ax.set(title="DA-OA", xlabel= r'Y', ylabel= r'P')
ax.legend()

plt.show()

# %% [markdown]
# ### 2. Estática comparativa

# %% [markdown]
# ### 2.1. Analice los efectos sobre las variables endógenas Y, P y r de una disminución del gasto fiscal $ (ΔG0<0) $ . El análisis debe ser intuitivo, matemático y gráfico. En una figura, se debe que usar los ejes r e Y (modelo IS-LM), y en la otra, los ejes P y r (modelo DA-OA).

# %% [markdown]
# Intuitivo:
#
# $$ G0↓→DA↓→DA<Y→[Y↓]→Md↓→Md<Ms→[r↓] $$
#
# $$ →Y↓→(Y-\bar Y)↓→[P↓] $$

# %% [markdown]
# Matemático:
#
# $$ \dfrac{hj}{\beta1j+hk}\dfrac{ΔG0P0j+M_0^sh}{h*P0j}=ΔY $$
#
# $$ \dfrac{hj}{\beta1j+hk}\dfrac{ΔG0P0j}{hP0j}=ΔY $$
#
# $$ \dfrac{hj}{\beta1j+hk}\dfrac{ΔG0}{h}=ΔY $$
#
# $$ \dfrac{j}{\beta1j+hk}=\dfrac{ΔY}{ΔG0}<0 $$
#
# $$ \dfrac{k\beta1}{j\beta1+kh}\dfrac{ΔG0P0k-\beta1M_0^s}{\beta1P0k}=Δr $$
#
# $$ \dfrac{k\beta1}{j\beta1+kh}\dfrac{ΔG0P0k}{\beta1P0k}=Δr $$
#
# $$ \dfrac{k\beta1}{j\beta1+kh}\dfrac{ΔG0}{\beta1}=Δr $$
#
# $$ \dfrac{k}{j\beta1+kh}=\dfrac{Δr}{ΔG0}<0 $$
#
# $$ ΔP=P^e+\theta(ΔY-\bar Y) $$
#
# $$ ΔP=\thetaΔY<0 $$
#
# $$ ΔY<0 $$
#
# $$ ΔP<0 $$

# %% [markdown]
# Demostración gráfica:

# %%
# IS
Y_size = 100 
b = 0.6                 
m = 0.5                 
t = 0.85                 
C0 = 19                 
I0 = 21                 
G0 = 30                 
X0 = 20                  
h =  0.8                  

Y = np.arange(Y_size)   
#----------------------
def r_is(b, m, t, C0, I0, G0, X0, h, Y):
    r_is = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_is

def Y_is(b, m, t, C0, I0, G0, X0, h, r):
    Y_is = (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_is

r = r_is(b, m, t, C0, I0, G0, X0, h, Y)
#-----------------------
# LM 
Y_size = 100

k = 13.5                
j = 9               
Ms = 8700           
P  = 35               

Y = np.arange(Y_size)
#-----------------------
def LM( k, j, Ms, P, Y):
    LM = (-Ms/P)/j + k/j*Y
    return LM

LM = LM( k, j, Ms, P, Y)
#-----------------------
# No hay variación en el mercado de dinero

Ms = 9700
def LM_Ms( k, j, Ms, P, Y):
    LM_Ms = (-Ms/P)/j + k/j*Y
    return LM_Ms

LM_Ms = LM_Ms( k, j, Ms, P, Y)
#-----------------------
# Variación en el gasto público

G0 = 25
def r_is_Go(b, m, t, C0, I0, G0, X0, h, Y):
    r_is_Go = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_is_Go

def Y_is_Go(b, m, t, C0, I0, G0, X0, h, r):
    Y_is_Go = (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_is_Go

r_is_Go = r_is_Go(b, m, t, C0, I0, G0, X0, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_is(b, m, t, C0, I0, G0, X0, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Disminución del gasto público $(dG_0 < 0)$ (IS-LM)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r, label = "IS", color = "#E60F5D")
ax.plot(Y, r_is_Go, label = "IS'", linestyle='dashed', color = "#E60F5D")
ax.plot(Y, LM, label="LM", color = "#0D6A41")  
ax.plot(Y, LM_Ms, label="LM'", linestyle='dashed', color = "#0D6A41")  

plt.axvline(x=51.2,  ymin= 0, ymax= 0.53, linestyle='dashed', color = 'grey')
plt.axhline(y=49, xmin= 0, xmax= 0.51, linestyle='dashed', color = 'grey')

plt.axhline(y=43, xmin= 0, xmax= 0.50, linestyle='dashed', color = 'grey')
plt.axvline(x=50,  ymin= 0, ymax= 0.49, linestyle='dashed', color = 'grey')
plt.text(52,52, 'E', fontsize = 12, color = 'black')

plt.text(45,38, 'E_1', fontsize = 12, color = "black")


ax.legend()
plt.show()

# %%
# OA
Y_size = 100 
Pe = 200
o = 4
Y_bar = 40

Y = np.arange(Y_size)   
#-----------------------
def OA(Pe, o, Y, Y_bar):
    OA = Pe+o*(Y-Y_bar)
    return OA

def OA_Y(Pe, Y_bar, o, P):
    OA_Y = Y_bar+P/o-Pe/o
    return OA_Y

OA = OA(Pe, o, Y, Y_bar)
#-----------------------
# DA
Y_size = 100

h = 1
Ms = 278.8
j = 0.8
beta1 = 1.5
k = 2.08
beta0 = 100

Y = np.arange(Y_size)
#-----------------------
def DA (h, Ms, j, beta1, k, beta0, Y):
    DA= ((h*Ms+j*beta0)/h)-(Y*(j*beta1+h*k)/h)
    return DA

DA = DA(h, Ms, j, beta1, k, beta0, Y)
#-----------------------
# Variación en el gasto público -> beta0 disminuye

beta0 = 73
def DA_B(h, Ms, j, beta1, k, beta0, Y):
    DA_B = ((h*Ms+j*beta0)/h)-(Y*(j*beta1+h*k)/h)
    return DA_B

DA_B = DA_B(h, Ms, j, beta1, k, beta0, Y)
#-----------------------
# No hay variación en OA

Pe = 200

def OA_p (Pe, o, Y, Y_bar):
    OA_p = Pe+o*(Y-Y_bar)
    return OA_p

def Y_OA_p(Pe, Y_bar, o, P):
    Y_OA_p = Y_bar+P/o-Pe/o
    return Y_OA_p

OA_p = OA_p(Pe, o, Y, Y_bar)
#-----------------------------
y_max = np.max(r)
x_max = OA_Y(Pe, Y_bar, o, P)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="$(dG_0 < 0)$ beta0<0 (OA-DA)", xlabel= 'Y', ylabel= 'P')

ax.plot(Y, OA, label = "OA", color = "green")
ax.plot(Y, OA_p, label = "OA'", linestyle='dashed', color = "green")
ax.plot(Y, DA, label="DA", color = "blue")  
ax.plot(Y, DA_B, label="DA'", linestyle='dashed', color = "blue")  

plt.axvline(x=43.75,  ymin= 0, ymax= 0.50, linestyle='dashed', color = 'grey')
plt.axhline(y=215, xmin= 0, xmax= 0.4375, linestyle='dashed', color = 'grey')


plt.plot(43.75, 215, marker="o", color="black")
plt.text(43.75,222, 'E', fontsize = 14, color = 'black')

plt.plot(40.78, 203.13, marker="o", color="black")
plt.text(39.78,179.13, 'E_1', fontsize = 14, color = "black")

plt.axhline(y=203.13, xmin= 0, xmax= 0.40, linestyle='dashed', color = 'grey')
plt.axvline(x=40.78,  ymin= 0, ymax= 0.45, linestyle='dashed', color = 'grey')
ax.legend()

plt.show()

# %% [markdown]
# ### 2.2. Analice los efectos sobre las variables endógenas Y, P y r de una disminución de la masa monetaria. . El análisis debe ser intuitivo, matemático y gráfico. En una figura, se debe que usar los ejes r e Y (modelo IS-LM), y en la otra, los ejes P, Y (modelo DA-OA).

# %% [markdown]
# Intuitivo:
#
# $$ Ms↓→Ms<Md→[r↑]→I↓→DA↓→DA<Y→[Y↓] $$
#
# $$ Y↓→(Y-\bar Y)↓→[P↓] $$

# %% [markdown]
# Matemático:
#
# $$ \dfrac{hj}{\beta1j+hk}\dfrac{\beta0P0j+ΔM_0^sh}{hP0j}=ΔY $$
#
# $$ \dfrac{hj}{\beta1j+hk}\dfrac{ΔM_0^s}{P0j}=ΔY $$
#
# $$ \dfrac{h}{\beta1j+hk}\dfrac{ΔM_0^s}{P0}=ΔY $$
#
# $$ \dfrac{h}{\beta1j+hk}\dfrac{1}{P0}=\dfrac{ΔY}{ΔM_0^s}<0 $$
#
# $$ \dfrac{k\beta1}{j\beta1+kh}\dfrac{\beta0P0k-\beta1ΔM_0^s}{\beta1P0k}=Δr $$
#
# $$ \dfrac{k\beta1}{j\beta1+kh}(-\dfrac{ΔM_0^s}{P0k})=Δr $$
#
# $$ \dfrac{\beta1}{j\beta1+kh}(-\dfrac{ΔM_0^s}{P0})=Δr $$
#
# $$ \dfrac{\beta1}{j\beta1+kh}(-\dfrac{1}{P0})=\dfrac{Δr}{ΔM_0^s}>0 $$
#
# $$ ΔP=P^e+\theta(ΔY-\bar Y) $$
#
# $$ ΔP=\thetaΔY<0 $$
#
# $$ ΔY<0 $$
#
# $$ ΔP<0 $$

# %%
# IS
Y_size = 100 
b = 0.6                 
m = 0.5                 
t = 0.85                 
C0 = 19                 
I0 = 21                 
G0 = 30                 
X0 = 20                  
h =  0.8                  

Y = np.arange(Y_size)   
#-----------------------
def r_is(b, m, t, C0, I0, G0, X0, h, Y):
    r_is = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_is

def Y_is(b, m, t, C0, I0, G0, X0, h, r):
    Y_is= (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_is

r_is= r_is(b, m, t, C0, I0, G0, X0, h, Y)
#-----------------------
# LM 
Y_size = 100

k = 13.5                
j = 9               
Ms = 8700           
P  = 35               

Y = np.arange(Y_size)
#-----------------------
def LM( k, j, Ms, P, Y):
    LM = (-Ms/P)/j + k/j*Y
    return LM

LM= LM( k, j, Ms, P, Y)
#-----------------------
# Hay variación en la oferta de dinero

Ms = 4700
def LM_Ms( k, j, Ms, P, Y):
    LM_Ms = (-Ms/P)/j + k/j*Y
    return LM_Ms

LM_Ms = LM_Ms( k, j, Ms, P, Y)
#-----------------------
# NO hay varición en el mercado de bienes

G0 = 40
def r_is_Go(b, m, t, C0, I0, G0, X0, h, Y):
    r_is_Go = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_is_Go

def Y_is_Go(b, m, t, C0, I0, G0, X0, h, r):
    Y_is_Go = (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_is_Go

r_is_Go = r_is_Go(b, m, t, C0, I0, G0, X0, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_is(b, m, t, C0, I0, G0, X0, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Disminución de la oferta de dinero (IS-LM)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r_is, label = "IS", color = "brown")
ax.plot(Y, r_is_Go, label = "IS'", linestyle='dashed', color = "brown")
ax.plot(Y, LM, label="LM", color = "purple")  
ax.plot(Y, LM_Ms, label="LM'", linestyle='dashed', color = "purple")  

plt.axvline(x=51.21,  ymin= 0, ymax= 0.45, linestyle='dashed', color = 'grey')
plt.axhline(y=48.5, xmin= 0, xmax= 0.51, linestyle='dashed', color = 'grey')

plt.axhline(y=60.5, xmin= 0, xmax= 0.515, linestyle='dashed', color = 'grey')
plt.axvline(x=51,  ymin= 0, ymax= 0.55, linestyle='dashed', color = 'grey')
plt.text(52,47, 'E', fontsize = 14, color = 'black')

plt.text(48,65, 'E_1', fontsize = 14, color = "black")


ax.legend()
plt.show()

# %%
# OA
Y_size = 100 
Pe = 300
o = 5
Y_bar = 50

Y = np.arange(Y_size)   
#-----------------------
def OA(Pe, o, Y, Y_bar):
    OA = Pe+o*(Y-Y_bar)
    return OA

def OA_Y(Pe, Y_bar, o, P):
    OA_Y = Y_bar+P/o-Pe/o
    return OA_Y

OA = OA(Pe, o, Y, Y_bar)
#-----------------------
# DA
Y_size = 100

h = 1.2
Ms = 290
j = 0.7
beta1 = 1.4
k = 2.3
beta0 = 120

Y = np.arange(Y_size)
#-----------------------
def DA(h, Ms, j, beta1, k, beta0, Y):
    DA= ((h*Ms+j*beta0)/h)-(Y*(j*beta1+h*k)/h)
    return DA

DA = DA(h, Ms, j, beta1, k, beta0, Y)
#-----------------------
# Variación en la oferta de dinero

Ms = 200
def DA_Ms(h, Ms, j, beta1, k, beta0, Y):
    DA_Ms = ((h*Ms+j*beta0)/h)-(Y*(j*beta1+h*k)/h)
    return DA_Ms

DA_Ms = DA_Ms(h, Ms, j, beta1, k, beta0, Y)
#-----------------------
# No hay variación en la OA
Pe = 300

def OA_p(Pe, o, Y, Y_bar):
    OA_p = Pe+o*(Y-Y_bar)
    return OA_p

def Y_OA_p(Pe, Y_bar, o, P):
    Y_OA_p = Y_bar+P/o-Pe/o
    return Y_OA_p

OA_p = OA_p(Pe, o, Y, Y_bar)
#-----------------------------
y_max = np.max(r)
x_max = OA_Y(Pe, Y_bar, o, P)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="disminución de la oferta de dinero (OA-DA)", xlabel= 'Y', ylabel= 'P')

ax.plot(Y, OA, label = "OA", color = "red")
ax.plot(Y, OA_p, label = "OA'", linestyle='dashed', color = "red")
ax.plot(Y, DA, label="DA", color = "green")  
ax.plot(Y, DA_Ms, label="DA'", linestyle='dashed', color = "green")  




plt.text(39,235, 'E', fontsize = 14, color = 'black')

plt.axvline(x=38,  ymin= 0, ymax= 0.48, linestyle='dashed', color = 'grey')
plt.axhline(y=240, xmin= 0, xmax= 0.38, linestyle='dashed', color = 'grey')


plt.text(24,180, 'E_1', fontsize = 14, color = "black")

plt.axhline(y=185, xmin= 0, xmax= 0.28, linestyle='dashed', color = 'grey')
plt.axvline(x=27,  ymin= 0, ymax= 0.40, linestyle='dashed', color = 'grey')


ax.legend()
plt.show()

# %% [markdown]
# ### 2.3. Analice los efectos sobre las variables endógenas Y, P y r de un incremento de la tasa de impuestos $ (Δt>0) $ . El análisis debe ser intuitivo, matemático y gráfico. En una figura, se debe que usar los ejes r e Y (modelo IS-LM), y en la otra, los ejes P, Y (modelo DA-OA).

# %% [markdown]
# Intuitivo
#
# $$ t↑→(1-t)↓→C↓→DA↓→DA<Y→[Y↓]→Md↓→Md<Ms→[r↓] $$
#
# $$ Y↓→(Y-\bar Y)↓→[P↓] $$

# %% [markdown]
# Matemático
#
# $$ Para simplificar: "" t↑→\beta1↑, entonces: Δ\beta1>0 "" $$
#
# $$ \dfrac{jh}{Δ\beta1j+kh}\dfrac{\beta0P0j+hM_0^s}{jhP0}=ΔY $$
#
# $$ \dfrac{1}{Δ\beta1j+hk}\dfrac{\beta0P0j+hM_0^s}{P0}=ΔY $$
#
# $$ \dfrac{\beta0jP0}{P0Δ\beta1j+P0kh}+\dfrac{hM_0^s}{P0Δ\beta1j+P0kh}=ΔY $$
#
# $$ \dfrac{\beta0P0j+hM_0^s}{P0Δ\beta1j+P0hk}=ΔY<0 $$
#
# $$ \dfrac{kΔ\beta1}{jΔ\beta1+kh}\dfrac{\beta0P0k-Δ\beta1M_0^s}{Δ\beta1P0k}=Δr $$
#
# $$ \dfrac{k}{jΔ\beta1+kh}\dfrac{\beta0P0k-Δ\beta1M_0^s}{P0k}=Δr $$
#
# $$ \dfrac{k}{jΔ\beta1+kh}\dfrac{\beta0P0k}{P0k}+\dfrac{k}{jΔ\beta1+kh}(-\dfrac{Δ\beta1M_0^s}{P0k})=Δr<0 $$
#
# $$ ΔP=P^e+\theta(ΔY-\bar Y) $$
#
# $$ ΔP=\thetaΔY<0 $$
#
# $$ ΔY<0 $$
#
# $$ ΔP<0 $$

# %% [markdown]
# Demostración gráfica

# %%
# IS
Y_size = 100 
b = 0.6                 
m = 0.5                 
t = 0.85                 
C0 = 19                 
I0 = 21                 
G0 = 30                 
X0 = 20                  
h =  0.8               

Y = np.arange(Y_size)   
#-----------------------
def r_is(b, m, t, C0, I0, G0, X0, h, Y):
    r_is = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_is

def Y_is(b, m, t, C0, I0, G0, X0, h, r):
    Y_is = (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_is

r_is = r_is(b, m, t, C0, I0, G0, X0, h, Y)
#-----------------------
# LM

Y_size = 100

k = 13.5                
j = 9               
Ms = 8700           
P  = 35              

Y = np.arange(Y_size)
#-----------------------
def LM( k, j, Ms, P, Y):
    LM = (-Ms/P)/j + k/j*Y
    return LM

LM = LM( k, j, Ms, P, Y)
#-----------------------
# No hay variación en el mercado de dinero

Ms = 8700
def LM_Ms( k, j, Ms, P, Y):
    LM_Ms = (-Ms/P)/j + k/j*Y
    return LM_Ms

LM_Ms = LM_Ms( k, j, Ms, P, Y)
#-----------------------
# Variación en la tasa de interés

t = 2
def r_IS_t(b, m, t, C0, I0, G0, X0, h, Y):
    r_IS_t = (C0 + I0 + G0 + X0 - Y * (1-(b-m)*(1-t)))/h
    return r_IS_t

def Y_IS_t(b, m, t, C0, I0, G0, X0, h, r):
    Y_IS = (C0 + I0 + G0 + X0 - h*r)/(1-(b-m)*(1-t))
    return Y_IS

r_t = r_IS_t(b, m, t, C0, I0, G0, X0, h, Y)
#-----------------------------
y_max = np.max(r)
x_max = Y_is(b, m, t, C0, I0, G0, X0, h, 0)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="aumento en la tasa de interés (IS-LM)", xlabel= 'Y', ylabel= 'r')

ax.plot(Y, r_is, label = "IS", color = "skyblue")
ax.plot(Y, r_t, label = "IS'", linestyle='dashed', color = "skyblue")
ax.plot(Y, LM, label="LM", color = "brown")  
ax.plot(Y, LM_Ms, label="LM'", linestyle='dashed', color = "brown")  

plt.text(52,50, 'E', fontsize = 14, color = 'black')
plt.axvline(x=51.5,  ymin= 0, ymax= 0.52, linestyle='dashed', color = 'grey')
plt.axhline(y=49, xmin= 0, xmax= 0.52, linestyle='dashed', color = 'grey')

plt.text(45,40, 'E_1', fontsize = 14, color = "black")
plt.axhline(y=44, xmin= 0, xmax= 0.49, linestyle='dashed', color = 'grey')
plt.axvline(x=49,  ymin= 0, ymax= 0.49, linestyle='dashed', color = 'grey')


ax.legend()
plt.show()

# %%
# OA
Y_size = 100 
Pe = 300
o = 5
Y_bar = 50

Y = np.arange(Y_size)   
#-----------------------
def OA(Pe, o, Y, Y_bar):
    OA = Pe+o*(Y-Y_bar)
    return OA

def Y_OA(Pe, Y_bar, o, P):
    Y_OA = Y_bar+P/o-Pe/o
    return Y_OA

OA= OA(Pe, o, Y, Y_bar)
#-----------------------
# DA
Y_size = 100

h = 1.2
Ms = 290
j = 0.7
beta1 = 1.4
k = 2.3
beta0 = 120

Y = np.arange(Y_size)
#-----------------------
def DA(h, Ms, j, beta1, k, beta0, Y):
    DA = ((h*Ms+j*beta0)/h)-(Y*(j*beta1+h*k)/h)
    return DA

DA = DA(h, Ms, j, beta1, k, beta0, Y)
#-----------------------
# Variación en la DA

beta1 = 2
def DA_b(h, Ms, j, beta1, k, beta0, Y):
    DA_b = ((h*Ms+j*beta0)/h)-(Y*(j*beta1+h*k)/h)
    return DA_b

DA_b = DA_b(h, Ms, j, beta1, k, beta0, Y)
#-----------------------
# No hay variación en la OA

Pe = 300

def OA_p(Pe, o, Y, Y_bar):
    OA_p= Pe+o*(Y-Y_bar)
    return OA_p

def Y_OA_p(Pe, Y_bar, o, P):
    Y_OA_p = Y_bar+P/o-Pe/o
    return Y_OA_p

OA_p = OA_p(Pe, o, Y, Y_bar)
#-----------------------------
y_max = np.max(r)
x_max = Y_OA(Pe, Y_bar, o, P)

v = [0, x_max, 0, y_max]                        
fig, ax = plt.subplots(figsize=(10, 8))
ax.set(title="Aumento en la tasa de interés (OA-DA)", xlabel= 'Y', ylabel= 'P')

ax.plot(Y, OA, label = "OA", color = "yellow")
ax.plot(Y, OA_p, label = "OA'", linestyle='dashed', color = "yellow")
ax.plot(Y, DA, label="DA", color = "orange")  
ax.plot(Y, DA_b, label="DA'", linestyle='dashed', color = "orange") 

plt.text(39,235, 'E', fontsize = 14, color = 'black')
plt.axhline(y=240, xmin= 0, xmax= 0.39, linestyle='dashed', color = 'grey')
plt.axvline(x=38.5,  ymin= 0, ymax= 0.43, linestyle='dashed', color = 'grey')

plt.text(32,220, 'E_1', fontsize = 14, color = "black")
plt.axvline(x=36.5,  ymin= 0, ymax= 0.41, linestyle='dashed', color = 'grey')
plt.axhline(y=230, xmin= 0, xmax= 0.38, linestyle='dashed', color = 'grey')


ax.legend()
plt.show()
