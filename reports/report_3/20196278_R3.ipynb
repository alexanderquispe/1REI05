# %% [markdown]
# $$REPORT_Nº3:$$
# $$Name: Santiago Alberto Vera Quispe $$
# $$Code: 20196278$$

# %% [markdown]
# La pregunta analiza, en el contexto actual de pandemia, el desplome del PBI y los Ingresos de la población en referencia a dos modelos macroeconómicos Keynesianos donde la producción es afectada por la demanda y, donde se observan dos sectores interrelacionados. Sector uno, como el sector de producción de bienes no-necesario, y sector dos, como sector de bienes necesarios como la agricultura. Se realizó un análisis separado y posteriormente se observó su interrelación en que la contracción que recibe el sector 1, afecta al sector 2 en la demanda. Así mismo, muestra la relación con las políticas crediticias que permitieron soportar la reducción del PBI y reducción de trabajo que trajo la pandemia
#
# Las fortalezas de este articulo es su desarrollo matemático intuitivo que se apoya en gráficos que construye a partir de las variables relacionadas a estos dos sectores. En ese sentido, en primer lugar, propone supuesto y defunciones. En el modelo del facto 1 propuesto se demuestra matemáticamente que el consumo no-esencial, no está asociado a un consumo de subsistencia. Este componente depende las expectativas de ingreso, y, por lo tanto, es susceptible a crisis como la sanitaria. Al trabajar con modelos, genera en ese sentido supuestos: la inversión depende negativamente de la tasa de interés; y el gasto de gobierno no tiene restricciones para financiarse, es decir, puede influir en el mercado. Así, mismo, desarrolla el mercado de bienes y mercado de precios tanto para el sector 1 y sector 2: se expone que la taza de interés es exógena, política monetaria BCR, la relación inversa de mercado de bienes y a la producción. Por último, genera sus modelos en base a subsistemas de corto plazo, equilibrio estacionario y el tránsito hacia este último.
#
# Este artículo logra avanzar, ya que, una vez terminada la explicación matemática, presenta un análisis de “ejercicios” en los dos sectores de consumo, en el nivel de los precios y el PBI. Así, su análisis se basa en la caída de la oferta agregada y el consumo por la cuarentena. Por un lado, presenta el modelo a corto plazo y los choques en la caída del consumo real, consumo autónomo, y contracción de la demanda que finalmente inducen a la contracción de la oferta. Paralelamente se analiza el nivel de precios con la caída de la producción relacionándolo con la reducción a nivel de precios. Así mismo, para el sector dos se menciona que es afectado por la demanda proveniente del sector 2; sin embargo, en esta también hay una caída en el consumo la demanda y PBI. Esta reducción reproducción también conduce a un nivel bajo de precios. Estas características las demuestra en gráficos y concluye que la taza de interés no cambió, pero al producción y precios caen, aunque resalta que es más acentuada en el sector 1.
#
# Por otro lado, continua con el análisis en el análisis del subsistema estacionario en el que se genera una caída del ingreso disponible, por la caída del PBI potencial junto a la disminución del consumo autónomo: se genera menos demanda y a su vez reduce el nivel de precios. En este modelo también se evidencia como el sector 1 y su producción no varía, pero se produce una disminución en el sector 2 consumo producto de la disminución en el sector 1, menos demanda y un eso de oferta que produce bajos precios finalmente. Amos sectores mestura su caída de precios y reducción de producción. Esto lo demuestra con los gráficos y los desplazamientos que produce el consumo en los respectivos sectores.
#
# Finalmente, en su análisis presenta el transito al equilibrio estacionario en que se supera la condición de corto plazo y se analiza un segundo periodo. Se menciona que la reducción de precios del sector 1 considera a la reducción precios del sector 2. La demanda se incrementa y esto produce una reactivación economía. La caída de recios genera caída de costos que viene del sector 1, a la vez que la mayor producción incrementa también los precios. Pero, en suma, se muestra una reducción del precio. Así, “análogo” al sector 1, el sector 2 recupera producción   y reducen los niveles de precios. En ambos sectores la reactivación de la producción, se eleva la adquisición de los trabajadores que elevan, a su vez, el consumo. Esto se debe una “dinámica” de aumento del producto y caída de precios hasta alcanzar el nuevo equilibrio. Esto se evidencia en el desplazamiento de la curva de la demanda agregada sin que la taza de interés cambie.
#
# Finalmente, podemos decir que este análisis comparado es específico y bien estructurado con un marco teórico claro y con componentes o elementos que explican en los modelos propuestos de qué manera la cuarenta a afectado a la economía en una recesión y en una reactivación. Sus conclusiones son claras en la medida que explica que la política crediticia durante la pandemia, nunca antes vista en su potencia, habría de ser la responsable de la reactivación económica, logrando una PBI aún mayor pre pandemia. Esta explicación la realiza en una modelación de un ejercicio que analiza el comportamiento de las variables cada trimestre: choques transitoria pudieron permitir una recuperación economía. Así mismo, como le mismo autor reconoce, este estudio se podría expandir y, no únicamente, se debería efectuar en los ámbitos sanitarios y de los dos sectores analizados.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import sympy as sy

# %%
import pandas as pd

# %%
import numpy as np

# %%
import random

# %%
import math

# %%
import sklearn

# %%
import scipy as sp

# %%
import networkx

# %%
import statsmodels.api as sm

# %%
import statsmodels.formula.api as smf

# %%
from statsmodels.iolib.summary2 import summary_col

# %%
from causalgraphicalmodels import CausalGraphicalModel

# %% [markdown]
# $$PREGUNTA1$$

# %% [markdown]
# $Sub pregunta 1$

# %% [markdown]
# El banco central o BCR, solo puede usar dos política monetarias para poder afectar al nivel de "r", o al nivel de precios. Estas estarían dadas precisamente por su condición de su función.
# Eso se debe a que tiene el de la cantidad de dinero emitida en la economía.
# - Si la política es expansiva:BRC ha inyectado cantidades de dinero(Incrementa al oferta de deinero) que s epdeu hacer mendiente la compra de bonos.
# - Si la politica es contractiva El BCR comeinza la reducción de cantidad de dinero (dsiminuye la oferta de dinero). se puede hacer la venta de bonos.
# Caso ejemplo
# BCR: decidió sacar dinero es Contractiva, Si decide poner dinero es Expansiva: Esto se debe a que Si la cantidad abunda, el precio del dinero cae. El precio de un billete se mide con la inflación. Así, esto e inflación

# %% [markdown]
# $Sub pregunta 2$

# %% [markdown]
# La oferta real de dinero se crea a partir de lo que "felix jimenes" menciona como oferta nominal de dinero
# $$Ms$$
# Esta oferta tendría muchos parametros, sin embargo, para que esta sera real, debe ser dividida por
# $$"P"$$.
# El valor "P" se entiende como el nivel general de precios de la economía
# $$Ms=M0s/P$$
# - NOTESE: que desde al concención de Felix, la oferta de dinero se enteinde como lo qeu se ofrece en dinero liquido, ya que el autor considera que elm dinero en el banco no es parte de esta oferta.

# %% [markdown]
# $Sub pregunta 3$

# %% [markdown]
# Al derivar al demanad real de dinero hay que considera como se coomprende la demanda en un inicio. Esta se entiende como
# $$Md=L1-L2$$
# Dónde L1 = es la demanda por transacción y precaución (necesidad de dinero para compra o necesidad de dienro para una deuda)
# Donde L2 = es la demanda por especulacón (necesidad de dinero especulativa en relación a la taza de interes bancaria )
# $$L1=k(Y)$$
# - L1 estaria compuesto por "k" entendida como elasticidad de ingreso, y "Y" como producto
# $$L2 = - j(i)$$
# - L2 estaría compuesto por "j" como la elasticidad de sustitución en el banco, y "i"como taza de interes nominal de ese banco.
# ASÍ: decimos que esta ecuanción está dada por
# $$Md=k(Y)-j(i)$$
# PEOR PARA QUE SEA LA DEMADN REAL. se debe ajustar la taza "i" a una taza "r" real. Sin embargo, por motivos de la grafica del modelo y por que no existe gran diferencia, decimos que "r=i"; por tanto, el cambiar este valor nos da una DEMANDA REAL.
# $$Md=k(Y)-j(r)$$

# %% [markdown]
# $Sub pregunta 4$

# %% [markdown]
# Como se ha mencionado antes:
# ASÍ: decimos que esta ecuanción está dada por
# $$Md=k(Y)-j(i)$$
# Esta sería una demanda nominal, ya que no hay ajuste del nivel de la taza en al realidad ya que no considera el factor inflación
# SI embargo.
# Pero para que la demanda sea REAL. se debe ajustar la taza "i" a una taza "r" real. Sin embargo, por motivos de la grafica del modelo y por que no existe gran diferencia, decimos que "r=i"; por tanto, el cambiar este valor nos da una DEMANDA REAL.
# $$Md=k(Y)-j(r)$$

# %% [markdown]
# $Sub pregunta 5$

# %%
# Parameters
r_size = 100

k = 0.5
j = 0.2                
P  = 10 
Y = 35
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_0 = MD(k, j, P, r, Y)
# Necesitamos crear la oferta de dinero.
MS = MS_0 / P
MS


# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="Money Market Equilibrium", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = '#CD5C5C')

# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=7.5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 7.5, "$r_0$", fontsize = 20, color = 'black')
ax1.text(90, 0.5, "$L(Y_0)$", fontsize = 20, color = 'black')

ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# $$PREGUNTA 2$$

# %% [markdown]
# $CASO 1$; Explique y grafique qué sucede en el mercado de dinero si ▲ Y<0; es decir cuando el producto cae.

# %% [markdown]
# Es este caso vemos que la producción cae. Así en las ecuaciones de mercado de bienes se verán afectadas por esta reducción ya que esta ecuación contempla "Y" como factor de la demanda. La oferta no se moverá ya que no se indica una politica del BCR.
# Para el caso
# $$Y=50→reduce→Y_1=30$$

# %%
# Parameters con cambio en el nivel del producto
r_size = 100

k = 0.5
j = 0.2                
P  = 10 
Y_1 = 30
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_1 = MD(k, j, P, r, Y_1)
# Necesitamos crear la oferta de dinero.
MS = MS_0 / P
MS

# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="Money Market Equilibrium", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = '#CD5C5C')
#ax1.plot(MD_1, label= '$L_0$', color = '#CD5C5C')


# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=7.5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 7.5, "$r_0$", fontsize = 12, color = 'black')
ax1.text(50, 0, "$(Ms/P)_0$", fontsize = 12, color = 'black')
ax1.text(50, 7.5, "$E_0$", fontsize = 12, color = 'black')

# Nuevas curvas a partir del cambio en el nivel del producto
ax1.plot(MD_1, label= '$L_1$', color = '#4287f5')
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")
ax1.axhline(y=5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")
ax1.text(0, 5, "$r_1$", fontsize = 16, color = 'black')
ax1.text(50, 5, "$E_1$", fontsize = 16, color = 'black')


ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# podemos observar en la grafica que los puntos de intersección con la oferta ha cambiado, Peor eso no signfica que la oferta ha cambiado perocé, sino que el valro de la taza de la oferta ha cambiado debido al cambio en la producción
# Esto afecta negativamente en un reducción
# Esto se explica ya que la relación de Md y Y es directa en la ecuación $Md = k (Y) - (j)(i)$
# $$Md↓=Y↓$$
# Así se produce una caida de "r"
# $$r_0>r_1$$

# %% [markdown]
# $CASO2$

# %% [markdown]
# Explique y grafique qué sucede en el mercado de dinero si ▲K<0; Es decir si cae la elasticidad del ingreso.

# %% [markdown]
# Es este caso vemos que la elasticidad "k" cae. Así en las ecuaciones de mercado de bienes se verán afectadas por esta reducción ya que esta ecuación contempla a "k" como factor de la demanda. La oferta no se moverá ya que no se indica una politica del BCR.
# Para el caso $$k=0.5→reduce→k_1=0.3$$

# %%
# Parameters con cambio en el nivel del producto
r_size = 100

k = 0.5
j = 0.2                
P  = 10 
k_1 = 0.3
MS_0 = 500

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_1 = MD(k_1, j, P, r, Y)
# Necesitamos crear la oferta de dinero.
MS = MS_0 / P
MS

# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="Money Market Equilibrium", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = '#CD5C5C')
#ax1.plot(MD_1, label= '$L_0$', color = '#CD5C5C')


# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=7.5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 7.5, "$r_0$", fontsize = 12, color = 'black')
ax1.text(50, 2, "$(Ms/P)_0$", fontsize = 12, color = 'black')
ax1.text(50, 7.5, "$E_0$", fontsize = 12, color = 'black')

# Nuevas curvas a partir del cambio en el nivel del producto
ax1.plot(MD_1, label= '$L_1$', color = '#4287f5')
#---
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")
ax1.axhline(y=0.55, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")
ax1.text(0, 0, "$r_1$", fontsize = 16, color = 'black')
ax1.text(50, 0, "$E_1$", fontsize = 16, color = 'black')


ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# podemos observar en la grafica que los puntos de intersección con la oferta ha cambiado, Peor eso no signfica que la oferta ha cambiado per cé, sino que el valor de la taza de la oferta ha cambiado debido al cambio en la elasticidad "k"
# Esto afecta negativamente en una reducción de la taza "r" o precio del dinero.
# Esto se explica ya que la relación de Md y Y es directa en la ecuación $Md = k (Y) - (j)(i)$
# $$Md↓=k↓$$
# Así se produce una caida de "r"
# $$r_0>r_1$$

# %% [markdown]
# $CASO3$

# %% [markdown]
# Explique y grafique qué sucede en el mercado de dinero si ▲Ms < 0

# %% [markdown]
# Es este caso vemos que la elasticidad "Ms" cae. Así en las ecuaciones de mercado de bienes se verán afectadas por esta reducción ya que esta ecuación contempla a "Ms" como factor de la oferta. La oferta se moverá ya que se indica una politica del de una reducción de "Ms".
# Para el caso $$Ms_0=500→reduce→Ms_1=250$$

# %%
# Parameters con cambio en el nivel del producto
r_size = 100

k = 0.5
j = 0.2                
P_1  = 10 
Y = 35
MS_0 = 250

r = np.arange(r_size)

# Necesitamos crear la funcion de demanda 

def MD(k, j, P, r, Y):
    MD_eq = (k*Y - j*r)
    return MD_eq
MD_1 = MD(k, j, P_1, r, Y)
# Necesitamos crear la oferta de dinero.
MS_1 = MS_0 / P_1
MS

# Equilibrio en el mercado de dinero

# Creamos el seteo para la figura 
fig, ax1 = plt.subplots(figsize=(10, 8))

# Agregamos titulo t el nombre de las coordenadas
ax1.set(title="Money Market Equilibrium", xlabel=r'M^s / P', ylabel=r'r')

# Ploteamos la demanda de dinero
ax1.plot(MD_0, label= '$L_0$', color = '#CD5C5C')
#ax1.plot(MD_1, label= '$L_0$', color = '#CD5C5C')


# Para plotear la oferta de dinero solo necesitamos crear una linea vertical
ax1.axvline(x = MS,  ymin= 0, ymax= 1, color = "grey")

# Creamos las lineas puntadas para el equilibrio
ax1.axhline(y=7.5, xmin= 0, xmax= 0.5, linestyle = ":", color = "black")

# Agregamos texto
ax1.text(0, 7.5, "$r_0$", fontsize = 12, color = 'black')
ax1.text(50, 0, "$(Ms/P)_0$", fontsize = 12, color = 'black')
ax1.text(50, 7.5, "$E_0$", fontsize = 12, color = 'black')


# Nuevas curvas a partir del cambio en el nivel del producto
#ax1.plot(MD_1, label= '$L_1$', color = '#4287f5')
ax1.axvline(x = MS_1,  ymin= 0, ymax= 1, color = "grey")

ax1.axhline(y=12.5, xmin= 0, xmax= 0.27, linestyle = ":", color = "black")
ax1.text(0, 12.5, "$r_1$", fontsize = 12, color = 'black')
ax1.text(25, 0, "$(Ms/P)_1$", fontsize = 12, color = 'black')
ax1.text(25, 12.5, "$E_1$", fontsize = 12, color = 'black')

ax1.yaxis.set_major_locator(plt.NullLocator())   
ax1.xaxis.set_major_locator(plt.NullLocator())

ax1.legend()

plt.show()

# %% [markdown]
# podemos observar en la grafica que los puntos de intersección con la oferta ha cambiado, Peor eso no signfica que la oferta ha cambiado per cé, sino que el valor de la taza de la oferta ha cambiado debido al cambio en la elasticidad "k"
# Esto afecta negativamente en una reducción de la taza "r" o precio del dinero.
# Esto se explica ya que la relación de Md y Y es directa en la ecuación $Ms=Ms_0/P$
# $$Ms↓=Ms_0↑$$
# Así se produce un aumento de "r"
# $$r_0<r_1$$

# %% [markdown]
# $$PREGUNTA 3$$

# %% [markdown]
# $SubPregunta1$

# %% [markdown]
# Para derivar la curva LM, long money, se debe evaluar priemro las ecuaciones de equilibrio monerario. Este está dado por dos funciones.
# Por un lado: función de oferta:
# - La oferta real de dinero se crea a partir de lo que "felix jimenes" menciona como oferta nominal de dinero$$Ms$$
# - Esta oferta tendría muchos parametros, sin embargo, para que esta sera real, debe ser dividida por $$"P"$$.
# - El valor "P" se entiende como el nivel general de precios de la economía $$Ms=M0s/P$$
# por otro lado: función de demanda:
# - Al derivar al demanad real de dinero hay que considera como se coomprende la demanda en un inicio. Esta se entiende como$$Md=L1-L2$$
# - Dónde L1 = es la demanda por transacción y precaución Donde L2 = es la demanda por especulacón$$L1=k(Y)$$
# - L1 estaria compuesto por "k" entendida como elasticidad de ingreso, y "Y" como producto$$L2 = - j(i)$$
# - ASÍ: decimos que esta ecuanción está dada por $$Md=k(Y)-j(i)$$

# %% [markdown]
# Así, evaluando las curvas anteriores: Igualamos el Md com Ms para encontrar todos los puntos de qeuilibrio que formas la curava LM.
# - PRIEMRO: evaluamos $k(Y)-j(i)=Ms_0/P$.
# - A CONTINUACIÓN: efectuamos y separamos el elemento de taza de interés:$r= - Ms_0/P*j+k*Y/j $
#
# Esa sería finalmente la derivación de la ecuación de LM.

# %% [markdown]
# $SubPregunta2$

# %% [markdown]
# ¿Cuál es el efecto de una disminución en la Masa Monetaria ? ▲Ms<0

# %%
# Parámetros

Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 20               

Y = np.arange(Y_size)

# Ecuación

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

#--------------------------------------------------
    # NUEVA curva LM

# Definir SOLO el parámetro cambiado
Ms = 10

# Generar la ecuación con el nuevo parámetro
def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)


# Dimensiones del gráfico
y_max = np.max(i)
v = [0, Y_size, 0, y_max]   
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, i, label="LM", color = 'black')
ax.plot(Y, i_Ms, label="LM_Ms", color = '#3D59AB', linestyle = 'dashed')

# Texto agregado
plt.text(42, 80, '∆$M^s$', fontsize=12, color='black')
plt.text(40, 75, '←', fontsize=15, color='grey')

# Título y leyenda
ax.set(title = "reducción en la Masa Monetaria $(M^s)$", xlabel=r'Y', ylabel=r'r')
ax.legend()


plt.show()

# %% [markdown]
# Podemos ver en la gráfica una disminución reducción de la curva o su desplazameinto a la derecha, ya que al evaluar la ecuación de equilibrio de LM:
# - $r= - Ms_0/P*j+k*Y/j $
# Esto se debe al cambio del elemento de Ms_0. ya que cambio
# - $Ms_0=200→Ms_1=10$
#  como cantidad de dinero en la oferta
#
# MEDAINTE AL INTUICIÓN:
# Esto se explica ya que la relación de Md y Y es directa en la ecuación $Ms=Ms_0/P$ relación inversa
# $$Ms↓=r↑$$
# por tanto si se produce un cambio negativo en Ms, etonces como su relación genera un cambio en al curva desplazandola . Así vemos que los puntos de equilibio cambioados y se eso en la grafica de la linea de puntos.

# %% [markdown]
# $Sub Pregunta 3$

# %% [markdown]
# ¿Cuál es el efecto de un aumento en k?, ▲k>0

# %%
# Parámetros

Y_size = 100

k = 2
j = 1                
Ms = 200             
P  = 20               

Y = np.arange(Y_size)

# Ecuación

def i_LM( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i = i_LM( k, j, Ms, P, Y)

#--------------------------------------------------
    # NUEVA curva LM

# Definir SOLO el parámetro cambiado
k = 5

# Generar la ecuación con el nuevo parámetro
def i_LM_Ms( k, j, Ms, P, Y):
    i_LM = (-Ms/P)/j + k/j*Y
    return i_LM

i_Ms = i_LM_Ms( k, j, Ms, P, Y)


# Dimensiones del gráfico
y_max = np.max(i)
v = [0, Y_size, 0, y_max]   
fig, ax = plt.subplots(figsize=(10, 8))

# Curvas a graficar
ax.plot(Y, i, label="LM", color = 'black')
ax.plot(Y, i_Ms, label="LM_Ms", color = '#3D59AB', linestyle = 'dashed')

# Texto agregado
plt.text(50, 140, '∆$M^s$', fontsize=12, color='black')
plt.text(45, 135, '←', fontsize=15, color='grey')

# Título y leyenda
ax.set(title = "reducción en la Masa Monetaria $(M^s)$", xlabel=r'Y', ylabel=r'r')
ax.legend()


plt.show()

# %% [markdown]
# Podemos ver en la gráfica una disminución reducción de la curva o su desplazameinto a la derecha, ya que al evaluar la ecuación de equilibrio de LM:
# - $r= - Ms_0/P*j+k*Y/j $
# Esto se debe al cambio del elemento de Ms_0. ya que cambio
# - $k=2→k_1=5$
#  como cantidad de dinero en la oferta
#
# MEDAINTE AL INTUICIÓN:
# Esto se explica ya que la relación de Md y Y es directa en la ecuación $Ms=Ms_0/P$ relación inversa
# - $$k↑=r↑$$
# por tanto si se produce un cambio positivo en "k", entonces como su relación genera un cambio en al curva desplazandola a la ziquierda, Sin embargo se debe considerar que el cambio de
# - $k→2k_1$
# este cambio se ubica en la pendiente, ya que "k" es el elemento de elasticidad que se ubica en la pendeinte postiva de la función de equilibiro de LM
#
# Así vemos que los puntos de equilibio cambioados y se eso en la grafica de la linea de puntos, PERO unicamente se cambia la pendiente, y por ello vemos la distribución de puntos distinta en la inclinación de la curva.
